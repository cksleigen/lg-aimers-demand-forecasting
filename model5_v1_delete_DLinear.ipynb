# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# -*- coding: utf-8 -*-
"""
Enhanced N-HiTS + Improved PatchTST + Improved TimesNet + GRU (4-Model Ensemble)
+ Optional Optuna Tuning + Multi-fold CV + Safe AMP + Memory-safe EMA

주요 반영:
- DLinear 모델 완전 제거
- 4개 모델로만 앙상블 구성: N-HiTS, PatchTST, TimesNet, GRU
- PatchEmbedding 패딩 오류 수정(2D replicate 금지 → 직접 복제)
- predict_one_file_generic DataFrame 전치(shape mismatch) 수정
- 패딩 일관성(훈련/추론: replicate)
- ImprovedTimesNet: FFT 주파수 필터 + 2D Conv
- ImprovedPatchTST: 더 촘촘한 패치, multi-head projection, time/meta 통합 강화
- invloss_weights: NaN/Inf 안전화
- EMA evaluate 백업 해제 + empty_cache
- Optuna: 학습 레벨 일부 포함(옵션)
- 하이퍼/얼리스톱 Config화
- 다중 fold 검증 평균으로 앙상블 가중치 산출
"""

import os, gc, glob, json, math, random, warnings
from dataclasses import dataclass
from typing import List, Dict, Tuple, Optional

import numpy as np
import pandas as pd

import torch
from torch import nn
from torch.utils.data import Dataset, DataLoader
import torch.nn.functional as F

# ---- Optuna (옵션) ----
try:
    import optuna
    HAS_OPTUNA = True
except Exception:
    HAS_OPTUNA = False

warnings.filterwarnings('ignore')

# =====================
# Config
# =====================
@dataclass
class EnhancedNHiTSConfig:
    # 경로
    train_csv: str = "/content/drive/MyDrive/data/train/train_original.csv"
    test_glob: str = "/content/drive/MyDrive/data/test/*.csv"
    submission_template_csv: str = "/content/drive/MyDrive/data/sample_submission.csv"
    out_submission_csv: str = "/content/drive/MyDrive/data/delete_dlinear_submission.csv"

    # 컬럼명
    date_col: str = "영업일자"
    item_col: str = "영업장명_메뉴명"
    target_col: str = "매출수량"

    # 윈도우
    in_len: int = 28
    out_len: int = 7

    # 학습 설정
    train_end_date: str = "2024-06-15"
    seed: int = 42
    device: str = "cuda" if torch.cuda.is_available() else "cpu"
    log1p: bool = True

    # 공용 학습 하이퍼파라미터(풀 학습)
    EPOCHS_FULL: int = 100
    BATCH_FULL: int = 256
    BASE_LR_FULL: float = 6e-4
    MAX_LR_FULL: float = 1.5e-3
    WD_FULL: float = 6e-4

    # 튜닝 (옵션)
    USE_OPTUNA: bool = False
    N_TRIALS: int = 30
    EPOCHS_TUNE: int = 40
    BATCH_TUNE: int = 256

    # CV folds(끝나는 주의 토요일 등)
    cv_fold_end_dates: Tuple[str, ...] = ("2024-06-14", "2024-06-07", "2024-05-31")

    # DataLoader
    num_workers: int = 4
    pin_memory: bool = True
    persistent_workers: bool = False  # 메모리 안전 우선

    # N-HiTS 구조
    hidden: int = 384
    n_blocks: int = 3
    n_layers: int = 1
    n_pool_kernel_size: Optional[List[int]] = None
    pooling_mode: str = "MaxPool1d"
    interpolation_mode: str = "linear"
    dropout: float = 0.22
    stack_types: Optional[List[str]] = None
    n_freq_downsample: Optional[List[int]] = None

    # Loss
    eps_smape: float = 0.01
    zero_weight: float = 0.01
    hurdle_lambda: float = 0.15

    # AMP/EMA
    use_amp: bool = True
    use_compile: bool = False
    ema_decay: float = 0.9998

    # 가중치/공휴일
    store_weights: Optional[Dict[str, float]] = None
    custom_holidays_list: Optional[List[str]] = None

    # ==== PatchTST ====
    ptst_d_model: int = 192
    ptst_nhead: int = 8
    ptst_num_layers: int = 2
    ptst_patch_len: int = 3
    ptst_stride: int = 2
    ptst_dropout: float = 0.2
    ptst_head_hidden: int = 256
    ptst_ff_mult: float = 1.5  # Config화

    # ==== TimesNet ====
    tnet_channels: int = 128
    tnet_blocks: int = 3
    tnet_kernels: Tuple[int, int, int] = (3, 5, 7)
    tnet_dropout: float = 0.12
    tnet_head_hidden: int = 256

    # ==== GRU ====
    gru_hidden: int = 256
    gru_layers: int = 2
    gru_dropout: float = 0.1
    gru_bidirectional: bool = False
    gru_head_hidden: int = 256

    # ==== 훈련 보조 ====
    grad_clip: float = 0.5
    earlystop_patience_ratio: float = 0.12
    earlystop_patience_min: int = 8

DEFAULT_STORE_WEIGHTS = {
    "미라시아": 7.71, "담하": 6.51, "연회장": 3.48, "라그로타": 3.44,
    "느티나무 셀프BBQ": 2.78, "화담숲주막": 1.43, "카페테리아": 1.31,
    "화담숲카페": 1.14, "포레스트릿": 1.00,
}

DEFAULT_CUSTOM_HOLIDAYS = [
    '2023-01-01','2023-01-21','2023-01-22','2023-01-23','2023-01-24','2023-03-01','2023-05-01',
    '2023-05-05','2023-05-27','2023-06-06','2023-08-15','2023-09-28','2023-09-29','2023-09-30',
    '2023-10-02','2023-10-03','2023-10-09','2023-12-25',
    '2024-01-01','2024-02-09','2024-02-10','2024-02-11','2024-02-12','2024-03-01','2024-04-10',
    '2024-05-01','2024-05-05','2024-05-06','2024-05-15','2024-06-06','2024-08-15','2024-09-16',
    '2024-09-17','2024-09-18','2024-10-01','2024-10-03','2024-10-09','2024-12-25',
    '2025-01-01','2025-01-28','2025-01-29','2025-01-30','2025-03-01','2025-03-03','2025-05-01',
    '2025-05-05','2025-05-06','2025-06-06','2025-08-15'
]

# =====================
# Feature Utils
# =====================
def set_seed(seed: int = 42):
    random.seed(seed); np.random.seed(seed)
    torch.manual_seed(seed); torch.cuda.manual_seed_all(seed)

def sine_cosine_encoding(value: float, max_val: float):
    return math.sin(2 * math.pi * value / max_val), math.cos(2 * math.pi * value / max_val)

def get_menu_category(menu_name: str) -> str:
    menu_lower = menu_name.lower()
    if any(word in menu_lower for word in ['막걸리', '소주', '맥주', '와인', '참이슬', '처음처럼', '카스', '하이네켄', '버드와이저', '스텔라']):
        return 'alcohol'
    elif any(word in menu_lower for word in ['찌개', '탕', '국밥', '라면', '해장국', '갈비탕']):
        return 'hot_food'
    elif any(word in menu_lower for word in ['삼겹', '갈비', '목살', 'bbq', '구이', '불고기']):
        return 'bbq'
    elif any(word in menu_lower for word in ['아이스크림', '식혜', '콜라', '스프라이트', '에이드']):
        return 'dessert_drink'
    elif any(word in menu_lower for word in ['아메리카노', '라떼', '커피']):
        return 'coffee'
    elif any(word in menu_lower for word in ['냉면', '파스타', '스파게티', '면', '우동']):
        return 'noodles'
    elif any(word in menu_lower for word in ['비빔밥', '볶음밥', '공깃밥', '정식']):
        return 'rice'
    else:
        return 'others'

def get_store_type(store_name: str) -> str:
    if store_name == "느티나무 셀프BBQ":
        return 'outdoor'
    elif store_name in ["라그로타", "미라시아"]:
        return 'fine_dining'
    elif store_name == "담하":
        return 'traditional'
    elif store_name == "연회장":
        return 'event'
    elif store_name in ["카페테리아", "포레스트릿", "화담숲카페"]:
        return 'casual'
    else:
        return 'specialty'

def build_enhanced_features(dates: List[pd.Timestamp], holidays_set: set) -> pd.DataFrame:
    df = pd.DataFrame({"date": dates})
    df["dow"] = df["date"].dt.weekday
    df["month"] = df["date"].dt.month
    df["day"] = df["date"].dt.day
    df["week"] = df["date"].apply(lambda d: int(d.isocalendar().week))
    df["quarter"] = df["date"].dt.quarter
    df["is_friday"] = (df["dow"] == 4).astype(int)
    df["is_saturday"] = (df["dow"] == 5).astype(int)
    df["is_sunday"] = (df["dow"] == 6).astype(int)
    df["is_weekend"] = df["dow"].isin([5,6]).astype(int)
    df["is_holiday"] = df["date"].isin(holidays_set).astype(int)
    df["is_off"] = ((df["is_weekend"]==1) | (df["is_holiday"]==1)).astype(int)
    df["tomorrow"] = df["date"] + pd.Timedelta(days=1)
    df["yesterday"] = df["date"] - pd.Timedelta(days=1)
    df["is_before_holiday"] = df["tomorrow"].isin(holidays_set).astype(int)
    df["is_after_holiday"] = df["yesterday"].isin(holidays_set).astype(int)
    df["is_month_start"] = (df["day"] <= 3).astype(int)
    df["is_month_end"] = (df["day"] >= 28).astype(int)
    df["is_spring"] = df["month"].isin([4,5,6]).astype(int)
    df["is_summer"] = df["month"].isin([7,8]).astype(int)
    df["is_autumn"] = df["month"].isin([9,10,11]).astype(int)
    df["is_winter"] = df["month"].isin([12,1,2,3]).astype(int)
    df["is_summer_vacation"] = df["month"].isin([7,8]).astype(int)
    df["is_winter_vacation"] = df["month"].isin([12,1,2]).astype(int)
    df[["month_sin", "month_cos"]] = df["month"].apply(lambda m: pd.Series(sine_cosine_encoding(m, 12)))
    df[["dow_sin", "dow_cos"]] = df["dow"].apply(lambda d: pd.Series(sine_cosine_encoding(d, 7)))
    df[["doy_sin", "doy_cos"]] = df["date"].apply(lambda d: pd.Series(sine_cosine_encoding(d.dayofyear, 365)))
    df[["week_sin", "week_cos"]] = df["week"].apply(lambda w: pd.Series(sine_cosine_encoding(w, 52)))
    df[["quarter_sin", "quarter_cos"]] = df["quarter"].apply(lambda q: pd.Series(sine_cosine_encoding(q, 4)))
    return df.drop(columns=["tomorrow", "yesterday"])

def parse_store_name(item_full: str) -> str:
    return item_full.split("_")[0]

def parse_menu_name(item_full: str) -> str:
    return item_full.split("_", 1)[1] if "_" in item_full else item_full

def make_val_mask_by_week(dataset: 'EnhancedNHiTSDataset', end_date_str: str) -> np.ndarray:
    end_date = pd.to_datetime(end_date_str)
    start_date = end_date - pd.Timedelta(days=6)
    ted = dataset.target_end_dates
    return (ted >= start_date) & (ted <= end_date)

# =====================
# Dataset
# =====================
class EnhancedNHiTSDataset(Dataset):
    def __init__(self, cfg: EnhancedNHiTSConfig, df: pd.DataFrame):
        self.cfg = cfg
        self.df = df.copy()
        if cfg.date_col not in self.df.columns or cfg.item_col not in self.df.columns or cfg.target_col not in self.df.columns:
            raise ValueError("입력 데이터에 필요한 컬럼이 없습니다.")
        self.df[cfg.date_col] = pd.to_datetime(self.df[cfg.date_col])
        self.df[cfg.target_col] = pd.to_numeric(self.df[cfg.target_col], errors='coerce').fillna(0.0).clip(lower=0)

        pivot = self.df.pivot(index=cfg.date_col, columns=cfg.item_col, values=cfg.target_col).sort_index()
        self.items = list(pivot.columns)
        self.dates = list(pivot.index)
        self.values = pivot.fillna(0.0).values.astype(np.float32)

        holidays_set = set(pd.to_datetime(cfg.custom_holidays_list)) if cfg.custom_holidays_list else set()
        caldf = build_enhanced_features(self.dates, holidays_set)
        self.cal_feats = caldf.drop(columns=["date"]).values.astype(np.float32)
        self.cal_feat_names = [c for c in caldf.columns if c != "date"]

        stores = [parse_store_name(it) for it in self.items]
        menus = [parse_menu_name(it) for it in self.items]

        self.store2idx = {s: i for i, s in enumerate(sorted(set(stores)))}
        self.item_store_idx = np.array([self.store2idx[s] for s in stores], dtype=np.int64)
        self.n_stores = len(self.store2idx)

        menu_categories = [get_menu_category(m) for m in menus]
        self.cat2idx = {c: i for i, c in enumerate(sorted(set(menu_categories)))}
        self.item_cat_idx = np.array([self.cat2idx[c] for c in menu_categories], dtype=np.int64)
        self.n_categories = len(self.cat2idx)

        store_types = [get_store_type(s) for s in stores]
        self.type2idx = {t: i for i, t in enumerate(sorted(set(store_types)))}
        self.item_type_idx = np.array([self.type2idx[t] for t in store_types], dtype=np.int64)
        self.n_types = len(self.type2idx)

        sw = cfg.store_weights or {}
        self.sample_weights = np.array([sw.get(parse_store_name(it), 1.0) for it in self.items], dtype=np.float32)

        self.indices: List[Tuple[int,int]] = []
        self.target_end_dates: List[pd.Timestamp] = []
        T = len(self.dates)
        Lx, Ly = cfg.in_len, cfg.out_len
        cutoff = pd.to_datetime(cfg.train_end_date)
        max_start = max(0, T - (Lx + Ly))

        for j in range(len(self.items)):
            for t0 in range(0, max_start + 1):
                end_date = self.dates[t0 + Lx + Ly - 1]
                if end_date <= cutoff:
                    self.indices.append((t0, j))
                    self.target_end_dates.append(end_date)

        # Type-safe datetime64 ns
        self.target_end_dates = np.asarray(self.target_end_dates, dtype='datetime64[ns]')

    def __len__(self):
        return len(self.indices)

    def __getitem__(self, idx):
        cfg = self.cfg
        t0, j = self.indices[idx]
        Lx, Ly = cfg.in_len, cfg.out_len

        x = self.values[t0:t0 + Lx, j]
        y = self.values[t0 + Lx:t0 + Lx + Ly, j]

        if cfg.log1p:
            x_in = np.log1p(x); y_out = np.log1p(y)
        else:
            x_in, y_out = x.copy(), y.copy()

        past_cal = self.cal_feats[t0:t0 + Lx, :]
        fut_cal = self.cal_feats[t0 + Lx:t0 + Lx + Ly, :]

        store_idx = self.item_store_idx[j]
        cat_idx = self.item_cat_idx[j]
        type_idx = self.item_type_idx[j]
        sample_w = self.sample_weights[j]

        zero_mask = (y == 0).astype(np.float32)
        pos_mask = (y > 0).astype(np.float32)

        return {
            "x": torch.from_numpy(x_in).float(),
            "y": torch.from_numpy(y_out).float(),
            "past_cal": torch.from_numpy(past_cal).float(),
            "fut_cal": torch.from_numpy(fut_cal).float(),
            "store_idx": torch.tensor(store_idx, dtype=torch.long),
            "cat_idx": torch.tensor(cat_idx, dtype=torch.long),
            "type_idx": torch.tensor(type_idx, dtype=torch.long),
            "sample_w": torch.tensor(sample_w, dtype=torch.float32),
            "zero_mask": torch.from_numpy(zero_mask).float(),
            "pos_mask": torch.from_numpy(pos_mask).float(),
        }

# =====================
# N-HiTS
# =====================
class NHiTSBlock(nn.Module):
    def __init__(self, input_size: int, output_size: int, hidden_size: int,
                 n_layers: int, dropout: float, pooling_mode: str = "MaxPool1d",
                 n_pool_kernel_size: int = 2, interpolation_mode: str = "linear"):
        super().__init__()
        if pooling_mode == "MaxPool1d":
            self.pooling_layer = nn.MaxPool1d(kernel_size=n_pool_kernel_size, stride=n_pool_kernel_size, ceil_mode=True)
        else:
            self.pooling_layer = nn.AvgPool1d(kernel_size=n_pool_kernel_size, stride=n_pool_kernel_size, ceil_mode=True)
        pooled_size = math.ceil(input_size / n_pool_kernel_size)
        layers = [nn.Linear(pooled_size, hidden_size), nn.ReLU(), nn.Dropout(dropout)]
        for _ in range(n_layers - 1):
            layers += [nn.Linear(hidden_size, hidden_size), nn.ReLU(), nn.Dropout(dropout)]
        self.mlp = nn.Sequential(*layers)
        self.output_layer = nn.Linear(hidden_size, output_size)

    def forward(self, x):
        x = x.unsqueeze(1)
        x_pooled = self.pooling_layer(x).squeeze(1)
        h = self.mlp(x_pooled)
        output = self.output_layer(h)
        return output

class EnhancedNHiTSModel(nn.Module):
    def __init__(self, in_len: int, out_len: int, cal_dim: int, n_stores: int,
                 n_categories: int, n_types: int, cfg: EnhancedNHiTSConfig):
        super().__init__()
        if cfg.n_pool_kernel_size is None or len(cfg.n_pool_kernel_size) < cfg.n_blocks:
            base_kernels = [2, 2, 1]
            cfg.n_pool_kernel_size = [base_kernels[i % len(base_kernels)] for i in range(cfg.n_blocks)]
        if cfg.stack_types is None or len(cfg.stack_types) < cfg.n_blocks:
            base_types = ["identity", "identity", "trend"]
            cfg.stack_types = [base_types[i % len(base_types)] for i in range(cfg.n_blocks)]
        if cfg.n_freq_downsample is None or len(cfg.n_freq_downsample) < cfg.n_blocks:
            base_downsample = [2, 1, 1]
            cfg.n_freq_downsample = [base_downsample[i % len(base_downsample)] for i in range(cfg.n_blocks)]

        self.out_len = out_len
        self.stack_types = cfg.stack_types

        self.store_emb = nn.Embedding(n_stores, 64)
        self.cat_emb = nn.Embedding(n_categories, 32)
        self.type_emb = nn.Embedding(n_types, 16)
        self.cal_proj = nn.Linear(cal_dim, 128)

        self.blocks = nn.ModuleList([
            NHiTSBlock(in_len, out_len, cfg.hidden, cfg.n_layers, cfg.dropout,
                       pooling_mode=cfg.pooling_mode, n_pool_kernel_size=cfg.n_pool_kernel_size[i],
                       interpolation_mode=cfg.interpolation_mode) for i in range(cfg.n_blocks)
        ])

        self.basis_weights = nn.ParameterList([
            nn.Parameter(torch.randn(out_len, max(1, out_len // cfg.n_freq_downsample[i])))
            for i in range(cfg.n_blocks)
        ])

        meta_dim = 64 + 32 + 16 + 128
        self.meta_integration = nn.Sequential(
            nn.Linear(meta_dim, cfg.hidden),
            nn.ReLU(), nn.Dropout(cfg.dropout),
            nn.Linear(cfg.hidden, out_len)
        )

        self.prob_head = nn.Sequential(
            nn.Linear(meta_dim + 1, cfg.hidden),
            nn.ReLU(), nn.Dropout(cfg.dropout),
            nn.Linear(cfg.hidden, cfg.hidden // 2),
            nn.ReLU(), nn.Dropout(cfg.dropout),
            nn.Linear(cfg.hidden // 2, out_len)
        )

    def forward(self, x, past_cal, fut_cal, store_idx, cat_idx, type_idx):
        store_emb = self.store_emb(store_idx)
        cat_emb = self.cat_emb(cat_idx)
        type_emb = self.type_emb(type_idx)
        cal_all = torch.cat([past_cal, fut_cal], dim=1).mean(dim=1)
        cal_emb = self.cal_proj(cal_all)
        meta_feat = torch.cat([store_emb, cat_emb, type_emb, cal_emb], dim=-1)

        outputs = []
        for i, block in enumerate(self.blocks):
            block_output = block(x)
            if self.stack_types[i] == "trend":
                basis = self.basis_weights[i]  # [out_len, k]
                block_output = block_output @ basis            # <-- basis.T 제거
                block_output = F.interpolate(block_output.unsqueeze(1), size=self.out_len,
                                            mode='linear', align_corners=False).squeeze(1)
            outputs.append(block_output)
        nhits_output = torch.stack(outputs, dim=0).sum(dim=0)

        meta_adjustment = self.meta_integration(meta_feat)
        value_pred = nhits_output + meta_adjustment

        prob_feat = torch.cat([meta_feat, x.mean(dim=1, keepdim=True)], dim=-1)
        prob_logits = self.prob_head(prob_feat)
        return value_pred, prob_logits

# =====================
# PatchTST (개선)
# =====================
def _build_sinusoidal_pos(L: int, d_model: int, device: torch.device, dtype: torch.dtype):
    pos = torch.arange(L, device=device, dtype=dtype).unsqueeze(1)
    i = torch.arange(d_model, device=device, dtype=dtype).unsqueeze(0)
    div = torch.exp(- (i // 2) * math.log(10000.0) / max(1, (d_model // 2)))
    angle = pos * div
    pe = torch.zeros((L, d_model), device=device, dtype=dtype)
    pe[:, 0::2] = torch.sin(angle[:, 0::2])
    pe[:, 1::2] = torch.cos(angle[:, 1::2])
    return pe.unsqueeze(0)

class PatchEmbedding(nn.Module):
    def __init__(self, seq_len: int, patch_len: int, stride: int, d_model: int):
        super().__init__()
        assert patch_len > 0 and stride > 0
        self.patch_len = patch_len
        self.stride = stride
        self.d_model = d_model
        self.proj = nn.Linear(patch_len, d_model)

    def forward(self, x):  # x: [B, L]
        B, L = x.shape
        if L < self.patch_len:
            pad = self.patch_len - L
            # replicate: 마지막 값 복제하여 왼쪽에 붙임
            last_val = x[:, -1:].repeat(1, pad)
            x = torch.cat([last_val, x], dim=1)

        patches = x.unfold(dimension=1, size=self.patch_len, step=self.stride)  # [B, Np, P]
        Np = patches.size(1)
        x_e = self.proj(patches)
        pe = _build_sinusoidal_pos(Np, self.d_model, x_e.device, x_e.dtype)  # [1,Np,D]
        x_e = x_e + pe
        return x_e

class ImprovedPatchTSTTiny(nn.Module):
    def __init__(self, cfg: EnhancedNHiTSConfig, in_len: int, out_len: int,
                 cal_dim: int, n_stores: int, n_categories: int, n_types: int):
        super().__init__()
        patch_len = max(2, min(cfg.ptst_patch_len, max(2, in_len // 8)))
        stride = max(1, patch_len // 2)
        self.embed = PatchEmbedding(in_len, patch_len, stride, cfg.ptst_d_model)

        enc_layer = nn.TransformerEncoderLayer(
            d_model=cfg.ptst_d_model,
            nhead=cfg.ptst_nhead,
            dim_feedforward=int(cfg.ptst_d_model * cfg.ptst_ff_mult),
            dropout=cfg.ptst_dropout,
            batch_first=True,
            activation='gelu',
            norm_first=True
        )
        self.encoder = nn.TransformerEncoder(enc_layer, num_layers=cfg.ptst_num_layers + 1)

        self.multi_heads = nn.ModuleList([
            nn.Sequential(
                nn.LayerNorm(cfg.ptst_d_model),
                nn.Linear(cfg.ptst_d_model, max(16, cfg.ptst_head_hidden // 4)),
                nn.GELU(),
                nn.Dropout(cfg.ptst_dropout),
                nn.Linear(max(16, cfg.ptst_head_hidden // 4), out_len)
            ) for _ in range(4)
        ])

        self.time_proj = nn.Sequential(
            nn.Linear(cal_dim * 2, max(16, cfg.ptst_d_model // 2)),
            nn.GELU(),
            nn.Dropout(cfg.ptst_dropout)
        )

        self.store_emb = nn.Embedding(n_stores, 64)
        self.cat_emb = nn.Embedding(n_categories, 32)
        self.type_emb = nn.Embedding(n_types, 16)
        self.cal_proj = nn.Linear(cal_dim, 128)

        meta_dim = 64 + 32 + 16 + 128 + max(16, cfg.ptst_d_model // 2)
        self.meta_integration = nn.Sequential(
            nn.Linear(meta_dim, cfg.ptst_head_hidden),
            nn.GELU(), nn.Dropout(cfg.ptst_dropout),
            nn.Linear(cfg.ptst_head_hidden, max(32, cfg.ptst_head_hidden // 2)),
            nn.GELU(), nn.Dropout(cfg.ptst_dropout),
            nn.Linear(max(32, cfg.ptst_head_hidden // 2), out_len)
        )
        self.prob_head = nn.Sequential(
            nn.Linear(meta_dim + 1, cfg.ptst_head_hidden),
            nn.GELU(), nn.Dropout(cfg.ptst_dropout),
            nn.Linear(cfg.ptst_head_hidden, max(32, cfg.ptst_head_hidden // 2)),
            nn.GELU(), nn.Dropout(cfg.ptst_dropout),
            nn.Linear(max(32, cfg.ptst_head_hidden // 2), out_len)
        )
        self.residual_weight = nn.Parameter(torch.tensor(0.1))

    def forward(self, x, past_cal, fut_cal, store_idx, cat_idx, type_idx):
        z = self.embed(x)
        z = self.encoder(z)
        z_global = z.mean(dim=1)
        z_last = z[:, -1, :]
        z_max, _ = z.max(dim=1)
        z_first = z[:, 0, :]

        head_preds = []
        for i, head in enumerate(self.multi_heads):
            vec = [z_global, z_last, z_max, z_first][i]
            head_preds.append(head(vec))
        seq_out = torch.stack(head_preds, dim=0).mean(dim=0)

        time_info = torch.cat([past_cal.mean(dim=1), fut_cal.mean(dim=1)], dim=-1)
        time_emb = self.time_proj(time_info)

        store_emb = self.store_emb(store_idx)
        cat_emb = self.cat_emb(cat_idx)
        type_emb = self.type_emb(type_idx)
        cal_emb = self.cal_proj(torch.cat([past_cal, fut_cal], dim=1).mean(dim=1))
        meta_feat = torch.cat([store_emb, cat_emb, type_emb, cal_emb, time_emb], dim=-1)

        meta_adjustment = self.meta_integration(meta_feat)
        value_pred = seq_out + self.residual_weight * meta_adjustment

        prob_logits = self.prob_head(torch.cat([meta_feat, x.mean(dim=1, keepdim=True)], dim=-1))
        return value_pred, prob_logits

# =====================
# Improved TimesNet (주파수 + 2D Conv)
# =====================
import torch
import torch.nn as nn
import torch.nn.functional as F

class FrequencyBlock(nn.Module):
    def __init__(self, seq_len: int, top_k: int = 5):
        super().__init__()
        self.seq_len = int(seq_len)
        self.top_k = int(min(max(top_k, 1), max(1, self.seq_len // 2)))

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        # x: [B, C, L]
        B, C, L = x.shape
        in_dtype = x.dtype

        # --- FFT만 fp32로 강제 (AMP/half 회피) ---
        x32 = x.to(torch.float32)

        # rFFT: [B, C, L//2 + 1] (complex64)
        x_freq = torch.fft.rfft(x32, dim=-1)

        # 진폭 평균 기반 top-k 주파수 선택
        amp = torch.abs(x_freq).mean(dim=1)                # [B, L//2 + 1]
        _, top_idx = torch.topk(amp, k=self.top_k, dim=-1)

        # 선택 주파수만 보존
        x_freq_filt = torch.zeros_like(x_freq)
        for i in range(B):
            x_freq_filt[i, :, top_idx[i]] = x_freq[i, :, top_idx[i]]

        # iFFT 복원 (float32)
        x_filt32 = torch.fft.irfft(x_freq_filt, n=L, dim=-1)  # [B, C, L]

        # 원래 dtype으로 되돌림 (예: fp16)
        x_filt = x_filt32.to(in_dtype)
        return x_filt

class ImprovedTimesBlock(nn.Module):
    """
    개선된 TimesNet 블록:
      - FrequencyBlock으로 주파수 필터링
      - 시간 × 주파수 2D 컨볼루션 경로
      - 다중 커널 1D 컨볼루션 경로
      - 채널 정합을 위한 1x1 Conv (등록형, 학습 가능)
      - 안정적 정규화/드롭아웃
    """
    def __init__(
        self,
        in_ch: int,
        out_ch: int,
        seq_len: int,
        kernels=(3, 5, 7),
        top_k: int = 5,
        dropout: float = 0.1,
    ):
        super().__init__()
        assert in_ch > 0 and out_ch > 0 and seq_len > 0
        self.in_ch = int(in_ch)
        self.out_ch = int(out_ch)
        self.seq_len = int(seq_len)

        # 주파수 필터링
        self.freq_block = FrequencyBlock(seq_len=self.seq_len, top_k=top_k)

        # period 설정(너무 작아지지 않도록 하한 2)
        self.period_base = max(2, self.seq_len // 4)

        # 2D conv 경로(시간×주파수 지도)
        self.conv2d = nn.Sequential(
            nn.Conv2d(self.in_ch, self.out_ch, kernel_size=(3, 3), padding=1),
            nn.GELU(),
            nn.Conv2d(self.out_ch, self.out_ch, kernel_size=(3, 3), padding=1),
            nn.GELU(),
        )

        # 1D 다중 커널 경로 (브랜치 합 채널 수가 out_ch와 정확히 일치하도록 분배)
        ks = list(kernels)
        n_br = len(ks)
        per = max(1, self.out_ch // n_br)
        branch_chs = [per] * n_br
        for i in range(self.out_ch - sum(branch_chs)):
            branch_chs[i % n_br] += 1

        branches = []
        for i, k in enumerate(ks):
            ch = branch_chs[i]
            branches.append(
                nn.Sequential(
                    nn.Conv1d(self.in_ch, ch, kernel_size=k, padding=k // 2),
                    nn.GELU(),
                    nn.Conv1d(ch, ch, kernel_size=k, padding=k // 2),
                    nn.GELU(),
                )
            )
        self.conv1d_branches = nn.ModuleList(branches)
        self.br_sum_ch = sum(branch_chs)

        # 채널 정합(학습 가능 1x1 conv, forward에서 새로 만들지 않음)
        self.channel_proj = (
            nn.Conv1d(self.br_sum_ch, self.out_ch, kernel_size=1)
            if self.br_sum_ch != self.out_ch
            else nn.Identity()
        )

        # 정규화/드롭아웃 (출력 텐서의 shape [B, out_ch, L]에 맞춘 LayerNorm)
        self.norm = nn.LayerNorm([self.out_ch, self.seq_len])
        self.dropout = nn.Dropout(dropout)

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        """
        x: [B, C, L] (C=in_ch, L=seq_len)
        return: [B, out_ch, L]
        """
        B, C, L = x.shape
        assert C == self.in_ch, f"in_ch mismatch: got {C}, expected {self.in_ch}"

        # 1) 주파수 필터링
        xf = self.freq_block(x)  # [B, C, L]

        # 2) 2D 경로 (period 분할 후 Conv2d 적용)
        period = self.period_base
        if L % period != 0:
            pad_len = period - (L % period)
            # 마지막 값을 복제해 패딩(시간축)
            xf = F.pad(xf, (0, pad_len), mode="replicate")
            L_pad = L + pad_len
        else:
            pad_len = 0
            L_pad = L

        # [B, C, L_pad] -> [B, C, period, L_pad//period]
        x2d = xf.reshape(B, C, period, L_pad // period).contiguous()
        z2d = self.conv2d(x2d)  # [B, out_ch, period, L_pad//period]
        z2d_flat = z2d.reshape(B, self.out_ch, L_pad)
        if pad_len > 0:
            z2d_flat = z2d_flat[:, :, :L]  # 원래 길이로 복원

        # 3) 1D 다중 커널 경로
        z1d_list = [branch(x) for branch in self.conv1d_branches]   # 각 [B, ch_i, L]
        z1d = torch.cat(z1d_list, dim=1)                            # [B, br_sum_ch, L]
        z1d = self.channel_proj(z1d)                                 # [B, out_ch, L]

        # 4) 합치기(+ 잔차적 의미)
        out = z2d_flat + z1d                                         # [B, out_ch, L]

        # 5) 정규화 & 드롭아웃
        #   LayerNorm의 normalized_shape는 마지막 두 축([C,L]) 기준이므로 입력 [B,C,L]과 호환
        out = self.norm(out)
        out = self.dropout(out)
        return out

class ImprovedTimesNetTiny(nn.Module):
    def __init__(self, cfg: EnhancedNHiTSConfig, in_len: int, out_len: int,
                 cal_dim: int, n_stores: int, n_categories: int, n_types: int):
        super().__init__()
        # 1) 채널은 8의 배수 권장(속도 유리)
        C = max(32, min(cfg.tnet_channels, 96))
        C = (C // 8) * 8  # 8의 배수로 스냅

        self.stem = nn.Conv1d(1, C, kernel_size=3, padding=1)

        # 2) 초고속 블록(Depthwise + Pointwise), bias=False로 연산 약간 절감
        def fast_block(C: int, p: float):
            return nn.Sequential(
                nn.Conv1d(C, C, kernel_size=3, padding=1, groups=C, bias=True),   # depthwise
                nn.Conv1d(C, C, kernel_size=1, bias=False),                      # pointwise
                nn.GELU(),
                nn.Conv1d(C, C, kernel_size=3, padding=1, groups=C, bias=True),
                nn.Conv1d(C, C, kernel_size=1, bias=False),
                nn.GELU(),
                nn.Dropout(p)
            )

        self.blocks = nn.ModuleList([
            fast_block(C, p=max(0.0, min(cfg.tnet_dropout, 0.1)))
            for _ in range(max(1, cfg.tnet_blocks))
        ])

        # 3) 헤드: AdaptiveAvgPool 대신 mean 사용(오버헤드 ↓)
        head_hidden = max(128, min(cfg.tnet_head_hidden, 192))
        self.head_fc1 = nn.Linear(C, head_hidden)
        self.head_fc2 = nn.Linear(head_hidden, out_len)
        self.head_drop = nn.Dropout(cfg.tnet_dropout)

        # meta
        self.store_emb = nn.Embedding(n_stores, 64)
        self.cat_emb   = nn.Embedding(n_categories, 32)
        self.type_emb  = nn.Embedding(n_types, 16)
        self.cal_proj  = nn.Linear(cal_dim, 128)
        meta_dim = 64 + 32 + 16 + 128
        self.meta_integration = nn.Sequential(
            nn.Linear(meta_dim, head_hidden),
            nn.ReLU(),
            nn.Dropout(cfg.tnet_dropout),
            nn.Linear(head_hidden, out_len),
        )
        self.prob_head = nn.Sequential(
            nn.Linear(meta_dim + 1, head_hidden),
            nn.ReLU(),
            nn.Dropout(cfg.tnet_dropout),
            nn.Linear(head_hidden, out_len),
        )
        self.meta_res_weight = nn.Parameter(torch.tensor(0.15))

    def forward(self, x, past_cal, fut_cal, store_idx, cat_idx, type_idx):
        # [B,L] -> [B,C,L]
        z = self.stem(x.unsqueeze(1))
        for blk in self.blocks:
            z = z + blk(z)  # residual

        # Global Average Pool (manual mean) -> FC
        z_mean = z.mean(dim=-1)           # [B, C]
        seq_out = self.head_fc2(self.head_drop(F.gelu(self.head_fc1(z_mean))))

        # meta
        store_emb = self.store_emb(store_idx)
        cat_emb   = self.cat_emb(cat_idx)
        type_emb  = self.type_emb(type_idx)
        cal_all   = torch.cat([past_cal, fut_cal], dim=1).mean(dim=1)
        cal_emb   = self.cal_proj(cal_all)
        meta_feat = torch.cat([store_emb, cat_emb, type_emb, cal_emb], dim=-1)

        value_pred  = seq_out + self.meta_res_weight * self.meta_integration(meta_feat)
        prob_logits = self.prob_head(torch.cat([meta_feat, x.mean(dim=1, keepdim=True)], dim=-1))
        return value_pred, prob_logits


# =====================
# GRU (경량)
# =====================
class GRUTiny(nn.Module):
    def __init__(self, cfg: EnhancedNHiTSConfig, in_len: int, out_len: int,
                 cal_dim: int, n_stores: int, n_categories: int, n_types: int):
        super().__init__()
        self.gru = nn.GRU(
            input_size=1,
            hidden_size=cfg.gru_hidden,
            num_layers=cfg.gru_layers,
            batch_first=True,
            dropout=cfg.gru_dropout if cfg.gru_layers > 1 else 0.0,
            bidirectional=cfg.gru_bidirectional
        )
        d_mul = 2 if cfg.gru_bidirectional else 1
        self.head = nn.Sequential(nn.LayerNorm(cfg.gru_hidden * d_mul),
                                  nn.Linear(cfg.gru_hidden * d_mul, out_len))
        # meta
        self.store_emb = nn.Embedding(n_stores, 64)
        self.cat_emb = nn.Embedding(n_categories, 32)
        self.type_emb = nn.Embedding(n_types, 16)
        self.cal_proj = nn.Linear(cal_dim, 128)
        meta_dim = 64+32+16+128
        self.meta_integration = nn.Sequential(
            nn.Linear(meta_dim, cfg.gru_head_hidden),
            nn.ReLU(), nn.Dropout(0.1),
            nn.Linear(cfg.gru_head_hidden, out_len)
        )
        self.prob_head = nn.Sequential(
            nn.Linear(meta_dim + 1, cfg.gru_head_hidden),
            nn.ReLU(), nn.Dropout(0.1),
            nn.Linear(cfg.gru_head_hidden, cfg.gru_head_hidden // 2),
            nn.ReLU(), nn.Dropout(0.1),
            nn.Linear(cfg.gru_head_hidden // 2, out_len)
        )

    def forward(self, x, past_cal, fut_cal, store_idx, cat_idx, type_idx):
        z_in = x.unsqueeze(-1)     # [B,L,1]
        z_out, _ = self.gru(z_in)  # [B,L,H*d]
        z_last = z_out[:, -1, :]   # [B,H*d]
        seq_out = self.head(z_last)
        store_emb = self.store_emb(store_idx)
        cat_emb = self.cat_emb(cat_idx)
        type_emb = self.type_emb(type_idx)
        cal_all = torch.cat([past_cal, fut_cal], dim=1).mean(dim=1)
        cal_emb = self.cal_proj(cal_all)
        meta_feat = torch.cat([store_emb, cat_emb, type_emb, cal_emb], dim=-1)
        value_pred = seq_out + self.meta_integration(meta_feat)
        prob_logits = self.prob_head(torch.cat([meta_feat, x.mean(dim=1, keepdim=True)], dim=-1))
        return value_pred, prob_logits

# =====================
# Loss / EMA
# =====================
class UltraEnhancedHurdleLoss(nn.Module):
    def __init__(self, eps: float = 0.01, zero_weight: float = 0.01, lambda_bce: float = 0.15):
        super().__init__()
        self.eps = eps; self.zero_weight = zero_weight; self.lambda_bce = lambda_bce
        self.bce = nn.BCEWithLogitsLoss(reduction='none')

    def forward(self, v_pred_log, p_logits, y_true_log, pos_mask, sample_w):
        z = (pos_mask > 0).float()
        bce = self.bce(p_logits, z)
        yp_val = torch.expm1(v_pred_log).clamp_min(0.0)
        yt_val = torch.expm1(y_true_log).clamp_min(0.0)
        ultra_eps = torch.where(yt_val < 0.5, self.eps * 0.2,
                                torch.where(yt_val < 2.0, self.eps * 0.5, self.eps))
        denom = (torch.abs(yp_val) + torch.abs(yt_val)).clamp_min(ultra_eps)
        smape_pos = 2.0 * torch.abs(yp_val - yt_val) / denom
        smape_pos = smape_pos * (yt_val > 0).float()
        p = torch.sigmoid(p_logits)
        y_hat = p * yp_val
        denom2 = (torch.abs(y_hat) + torch.abs(yt_val)).clamp_min(ultra_eps)
        smape_all = 2.0 * torch.abs(y_hat - yt_val) / denom2
        ultra_zero_weight = torch.where(
            yt_val < 0.01, torch.full_like(yt_val, self.zero_weight * 0.1),
            torch.where(yt_val < 0.1, torch.full_like(yt_val, self.zero_weight * 0.3),
                        torch.where(yt_val < 1.0, torch.full_like(yt_val, self.zero_weight * 0.6), torch.ones_like(yt_val)))
        )
        smape_all = smape_all * ultra_zero_weight
        bce_s = bce.mean(dim=1); pos_s = smape_pos.mean(dim=1); all_s = smape_all.mean(dim=1)
        sample_loss = self.lambda_bce * bce_s + 0.4 * pos_s + 0.6 * all_s
        sw = sample_w.view(-1); wsum = sw.sum().clamp_min(1e-8)
        loss = (sample_loss * sw).sum() / wsum
        return loss, sample_loss.detach(), sw.detach()

class EMA:
    def __init__(self, model: nn.Module, decay: float = 0.9998):
        self.decay = decay
        self.shadow = {name: p.detach().clone() for name, p in model.named_parameters() if p.requires_grad}

    def update(self, model: nn.Module):
        with torch.no_grad():
            for name, p in model.named_parameters():
                if p.requires_grad:
                    self.shadow[name].mul_((self.decay)).add_(p.detach(), alpha=1-self.decay)

    def apply_to(self, model: nn.Module):
        with torch.no_grad():
            for name, p in model.named_parameters():
                if p.requires_grad:
                    p.copy_(self.shadow[name])

# =====================
# Trainer (공용)
# =====================
class GenericTrainer:
    def __init__(self, cfg: EnhancedNHiTSConfig, dataset: EnhancedNHiTSDataset, model: nn.Module,
                 epochs: int, batch_size: int, base_lr: float, max_lr: float, weight_decay: float):
        self.cfg = cfg; self.dataset = dataset; self.model = model.to(cfg.device)
        self.device = torch.device(cfg.device)
        self.criterion = UltraEnhancedHurdleLoss(cfg.eps_smape, cfg.zero_weight, cfg.hurdle_lambda)
        self.ema = EMA(self.model, decay=cfg.ema_decay)
        self.epochs = epochs; self.batch_size = batch_size
        self.base_lr = base_lr; self.max_lr = max_lr; self.weight_decay = weight_decay

    def make_loaders_from_mask(self, mask_val: np.ndarray):
        idx_all = np.arange(len(self.dataset))
        val_idx = idx_all[mask_val]; train_idx = idx_all[~mask_val]
        train_subset = torch.utils.data.Subset(self.dataset, train_idx)
        val_subset = torch.utils.data.Subset(self.dataset, val_idx)
        train_loader = DataLoader(
            train_subset, batch_size=self.batch_size, shuffle=True,
            num_workers=self.cfg.num_workers, pin_memory=self.cfg.pin_memory,
            persistent_workers=self.cfg.persistent_workers, drop_last=False
        )
        val_loader = DataLoader(
            val_subset, batch_size=self.batch_size, shuffle=False,
            num_workers=self.cfg.num_workers, pin_memory=self.cfg.pin_memory,
            persistent_workers=self.cfg.persistent_workers, drop_last=False
        )
        return train_loader, val_loader

    @torch.no_grad()
    def evaluate(self, loader: DataLoader, use_ema: bool = True) -> float:
        if loader is None:
            return float('inf')
        self.model.eval()

        backup = None
        if use_ema:
            backup = {k: v.detach().clone() for k, v in self.model.state_dict().items()}
            self.ema.apply_to(self.model)

        total_loss = 0.0
        total_weight = 0.0

        amp_ctx = torch.autocast(device_type='cuda', dtype=torch.float16) if (
            self.cfg.use_amp and torch.cuda.is_available() and self.device.type == "cuda"
        ) else torch.cuda.amp.autocast(enabled=False)

        with amp_ctx:
            for batch in loader:
                x = batch["x"].to(self.device)
                y = batch["y"].to(self.device)
                past_cal = batch["past_cal"].to(self.device)
                fut_cal = batch["fut_cal"].to(self.device)
                store_idx = batch["store_idx"].to(self.device)
                cat_idx = batch["cat_idx"].to(self.device)
                type_idx = batch["type_idx"].to(self.device)
                sample_w = batch["sample_w"].to(self.device)
                pos_mask = batch["pos_mask"].to(self.device)

                v_pred, p_logits = self.model(x, past_cal, fut_cal, store_idx, cat_idx, type_idx)
                _, sample_loss, sw = self.criterion(v_pred, p_logits, y, pos_mask, sample_w)

                total_loss += (sample_loss * sw).sum().item()
                total_weight += sw.sum().item()

        if use_ema and backup is not None:
            self.model.load_state_dict(backup)
            del backup
            gc.collect(); torch.cuda.empty_cache()

        if total_weight <= 0:
            return float('inf')
        return total_loss / total_weight

    def train_with_loaders(self, train_loader: DataLoader, val_loader: DataLoader, model_name="Model"):
        optim = torch.optim.AdamW(self.model.parameters(), lr=self.base_lr, weight_decay=self.weight_decay, betas=(0.9,0.999))
        steps_per_epoch = max(1, len(train_loader))
        sched = torch.optim.lr_scheduler.OneCycleLR(
            optim, max_lr=self.max_lr, epochs=self.epochs,
            steps_per_epoch=steps_per_epoch, pct_start=0.05,
            div_factor=max(1e-8, self.max_lr / max(1e-8, self.base_lr))
        )
        patience = max(self.cfg.earlystop_patience_min, int(self.epochs * self.cfg.earlystop_patience_ratio))
        best_val = float("inf"); best_state = None; no_improve=0
        for epoch in range(1, self.epochs+1):
            self.model.train()
            amp_ctx = torch.autocast(device_type='cuda', dtype=torch.float16) if (self.cfg.use_amp and torch.cuda.is_available() and self.device.type=="cuda") else torch.cuda.amp.autocast(enabled=False)
            running = []
            for batch in train_loader:
                x = batch["x"].to(self.device); y = batch["y"].to(self.device)
                past_cal = batch["past_cal"].to(self.device); fut_cal = batch["fut_cal"].to(self.device)
                store_idx = batch["store_idx"].to(self.device); cat_idx = batch["cat_idx"].to(self.device)
                type_idx = batch["type_idx"].to(self.device); sample_w = batch["sample_w"].to(self.device)
                pos_mask = batch["pos_mask"].to(self.device)
                with amp_ctx:
                    v_pred, p_logits = self.model(x, past_cal, fut_cal, store_idx, cat_idx, type_idx)
                    loss, _, _ = self.criterion(v_pred, p_logits, y, pos_mask, sample_w)
                optim.zero_grad(set_to_none=True); loss.backward()
                torch.nn.utils.clip_grad_norm_(self.model.parameters(), self.cfg.grad_clip)
                optim.step(); sched.step(); self.ema.update(self.model)
                running.append(loss.detach().item())
            val_loss = self.evaluate(val_loader, use_ema=True)
            tr_mean = float(np.mean(running)) if running else float('nan')
            print(f"[{model_name}] [Epoch {epoch:03d}] train_loss: {tr_mean:.5f}  val_loss: {val_loss:.5f}")
            if val_loss < best_val:
                best_val = val_loss
                best_state = {k: v.detach().cpu().clone() for k, v in self.model.state_dict().items()}
                no_improve = 0
            else:
                no_improve += 1
                if no_improve >= patience:
                    print(f"[{model_name}] Early stopping at epoch {epoch}")
                    break
        if best_state is not None:
            self.model.load_state_dict(best_state)
        self.ema.apply_to(self.model)
        return self.model, best_val

# =====================
# Predict Utils (공용)
# =====================
@torch.no_grad()
def predict_one_file_generic(
    cfg: EnhancedNHiTSConfig,
    model: nn.Module,
    test_df: pd.DataFrame,
    store2idx: Dict,
    cat2idx: Dict,
    type2idx: Dict
) -> pd.DataFrame:
    device = torch.device(cfg.device)
    if test_df is None or len(test_df) == 0:
        return pd.DataFrame()

    tdf = test_df.copy()
    if cfg.date_col not in tdf.columns or cfg.item_col not in tdf.columns or cfg.target_col not in tdf.columns:
        return pd.DataFrame()

    tdf[cfg.date_col] = pd.to_datetime(tdf[cfg.date_col], errors="coerce")
    tdf = tdf.dropna(subset=[cfg.date_col])
    if len(tdf) == 0:
        return pd.DataFrame()

    tdf[cfg.target_col] = pd.to_numeric(tdf[cfg.target_col], errors="coerce").fillna(0.0).clip(lower=0)

    try:
        pivot = (
            tdf.pivot(index=cfg.date_col, columns=cfg.item_col, values=cfg.target_col)
               .sort_index()
               .fillna(0.0)
        )
    except Exception:
        return pd.DataFrame()
    if pivot.shape[1] == 0:
        return pd.DataFrame()

    items = list(pivot.columns)
    dates = list(pivot.index)
    values = pivot.values.astype(np.float32)

    # replicate padding (훈련과 일관)
    Lx = cfg.in_len
    if len(dates) < Lx:
        pad_rows = Lx - len(dates)
        first_row = values[0:1, :] if len(dates) > 0 else np.zeros((1, values.shape[1]), dtype=np.float32)
        pad = np.repeat(first_row, pad_rows, axis=0)
        values = np.vstack([pad, values])
        start_date = dates[0] if len(dates) > 0 else pd.Timestamp("2000-01-01")
        backfill = [start_date - pd.Timedelta(days=i) for i in range(pad_rows, 0, -1)]
        dates = backfill + dates

    last_date = dates[-1]
    future_dates = [last_date + pd.Timedelta(days=i) for i in range(1, cfg.out_len + 1)]
    holidays_set = set(pd.to_datetime(cfg.custom_holidays_list)) if cfg.custom_holidays_list else set()

    past_cal = build_enhanced_features(dates[-Lx:], holidays_set).drop(columns=["date"]).values.astype(np.float32)
    fut_cal  = build_enhanced_features(future_dates, holidays_set).drop(columns=["date"]).values.astype(np.float32)

    x_np = values[-Lx:, :].T  # [B,L]
    if cfg.log1p:
        x_np = np.log1p(x_np)

    B = len(items)
    x = torch.from_numpy(x_np).to(device=device, dtype=torch.float32)
    past_cal_b = torch.from_numpy(np.repeat(past_cal[None, :, :], B, axis=0)).to(device=device, dtype=torch.float32)
    fut_cal_b  = torch.from_numpy(np.repeat(fut_cal [None, :, :], B, axis=0)).to(device=device, dtype=torch.float32)

    stores = [parse_store_name(it) for it in items]
    menus  = [parse_menu_name(it) for it in items]

    safe_store_default = next(iter(store2idx.values()), 0)
    safe_cat_default   = next(iter(cat2idx.values()), 0)
    safe_type_default  = next(iter(type2idx.values()), 0)

    store_idx = torch.as_tensor([store2idx.get(s, safe_store_default) for s in stores], device=device, dtype=torch.long)
    cat_idx   = torch.as_tensor([cat2idx.get(get_menu_category(m), safe_cat_default) for m in menus], device=device, dtype=torch.long)
    type_idx  = torch.as_tensor([type2idx.get(get_store_type(s), safe_type_default) for s in stores], device=device, dtype=torch.long)

    use_cuda_amp = bool(cfg.use_amp and torch.cuda.is_available() and device.type == "cuda")
    amp_ctx = torch.autocast(device_type="cuda", dtype=torch.float16) if use_cuda_amp else torch.cuda.amp.autocast(enabled=False)

    model.eval()
    with amp_ctx:
        v_pred_log, p_logits = model(x, past_cal_b, fut_cal_b, store_idx, cat_idx, type_idx)  # [B, out_len]
        y_val  = torch.expm1(v_pred_log).clamp_min(0.0)
        y_prob = torch.sigmoid(p_logits)
        y_hat  = (y_prob * y_val).clamp_min(0.0).detach().cpu().numpy()  # [B, out_len]

    # rows=아웃스텝, cols=아이템 (전치!)
    out = pd.DataFrame(
        y_hat.T,
        index=[f"D+{i}" for i in range(1, cfg.out_len + 1)],
        columns=items
    )
    out = out.replace([np.inf, -np.inf], 0.0).fillna(0.0)
    return out

# =====================
# Ensemble Helper
# =====================
def invloss_weights(vals: List[float], eps: float = 1e-8) -> List[float]:
    arr = np.array(vals, dtype=np.float64)
    arr[~np.isfinite(arr)] = np.nan
    if np.all(np.isnan(arr)):
        return (np.ones_like(arr) / len(arr)).tolist()
    safe = np.nan_to_num(arr, nan=np.nanmax(arr) * 1.5)
    inv = 1.0 / np.clip(safe, eps, None)
    if not np.isfinite(inv).any() or inv.sum() <= 0:
        return (np.ones_like(inv) / len(inv)).tolist()
    w = inv / inv.sum()
    return w.tolist()

# =====================
# Model factory
# =====================
def build_model_by_name(name: str, cfg: EnhancedNHiTSConfig, ds: EnhancedNHiTSDataset,
                        trial: Optional['optuna.trial.Trial']=None) -> nn.Module:
    if name == "N-HiTS":
        hidden = trial.suggest_categorical("nh_hidden", [256, 384, 512]) if trial else cfg.hidden
        n_layers = trial.suggest_categorical("nh_layers", [1, 2, 3]) if trial else cfg.n_layers
        dropout = trial.suggest_float("nh_dropout", 0.0, 0.3) if trial else cfg.dropout
        nh_cfg = EnhancedNHiTSConfig(**{**cfg.__dict__, "hidden": hidden, "n_layers": n_layers, "dropout": dropout})
        return EnhancedNHiTSModel(cfg.in_len, cfg.out_len, ds.cal_feats.shape[1], ds.n_stores, ds.n_categories, ds.n_types, nh_cfg)

    if name == "PatchTST":
        d_model = trial.suggest_categorical("pt_d_model", [192, 256, 320]) if trial else cfg.ptst_d_model
        nhead   = trial.suggest_categorical("pt_nhead", [8, 12]) if trial else cfg.ptst_nhead
        nlayer  = trial.suggest_categorical("pt_nlayers", [2, 3, 4]) if trial else cfg.ptst_num_layers
        p_len   = trial.suggest_categorical("pt_patch", [2, 3, 4]) if trial else max(2, cfg.ptst_patch_len // 2)
        stride  = trial.suggest_categorical("pt_stride", [1, 2]) if trial else max(1, cfg.ptst_stride // 2)
        drop    = trial.suggest_float("pt_dropout", 0.05, 0.2) if trial else cfg.ptst_dropout
        ff_mult = trial.suggest_float("ptst_ff_mult", 1.5, 3.5) if trial else cfg.ptst_ff_mult
        pt_cfg = EnhancedNHiTSConfig(**{**cfg.__dict__,
            "ptst_d_model": d_model, "ptst_nhead": nhead, "ptst_num_layers": nlayer,
            "ptst_patch_len": p_len, "ptst_stride": stride, "ptst_dropout": drop, "ptst_ff_mult": ff_mult
        })
        return ImprovedPatchTSTTiny(pt_cfg, cfg.in_len, cfg.out_len, ds.cal_feats.shape[1], ds.n_stores, ds.n_categories, ds.n_types)

    if name == "TimesNet":
        channels = trial.suggest_categorical("tn_channels", [96, 128, 160]) if trial else cfg.tnet_channels
        blocks   = trial.suggest_categorical("tn_blocks", [2, 3, 4]) if trial else cfg.tnet_blocks
        drop     = trial.suggest_float("tn_dropout", 0.0, 0.3) if trial else cfg.tnet_dropout
        tn_cfg = EnhancedNHiTSConfig(**{**cfg.__dict__,
            "tnet_channels": channels, "tnet_blocks": blocks, "tnet_dropout": drop
        })
        return ImprovedTimesNetTiny(tn_cfg, cfg.in_len, cfg.out_len, ds.cal_feats.shape[1], ds.n_stores, ds.n_categories, ds.n_types)

    if name == "GRU":
        hidden = trial.suggest_categorical("gru_hidden", [128, 192, 256]) if trial else cfg.gru_hidden
        layers = trial.suggest_categorical("gru_layers", [1, 2, 3]) if trial else cfg.gru_layers
        drop   = trial.suggest_float("gru_dropout", 0.0, 0.3) if trial else cfg.gru_dropout
        bidi   = trial.suggest_categorical("gru_bidi", [False, True]) if trial else cfg.gru_bidirectional
        gr_cfg = EnhancedNHiTSConfig(**{**cfg.__dict__,
            "gru_hidden": hidden, "gru_layers": layers, "gru_dropout": drop, "gru_bidirectional": bidi
        })
        return GRUTiny(gr_cfg, cfg.in_len, cfg.out_len, ds.cal_feats.shape[1], ds.n_stores, ds.n_categories, ds.n_types)

    raise ValueError(f"Unknown model name: {name}")

def optuna_objective_factory(model_name: str, cfg: EnhancedNHiTSConfig, ds: EnhancedNHiTSDataset, mask_val: np.ndarray):
    def objective(trial: 'optuna.trial.Trial') -> float:
        # 훈련 레벨도 일부 튜닝(옵션)
        base_lr = trial.suggest_float("base_lr", 3e-4, 3e-3, log=True)
        max_lr  = trial.suggest_float("max_lr",  8e-4, 6e-3, log=True)
        wd      = trial.suggest_float("weight_decay", 1e-6, 8e-4, log=True)
        grad_clip = trial.suggest_float("grad_clip", 0.3, 1.0)
        pat_ratio = trial.suggest_float("pat_ratio", 0.15, 0.35)

        tmp_cfg = EnhancedNHiTSConfig(**{**cfg.__dict__,
            "grad_clip": grad_clip, "earlystop_patience_ratio": pat_ratio
        })
        model = build_model_by_name(model_name, tmp_cfg, ds, trial)
        trainer = GenericTrainer(tmp_cfg, ds, model, epochs=tmp_cfg.EPOCHS_TUNE, batch_size=tmp_cfg.BATCH_TUNE,
                                 base_lr=base_lr, max_lr=max_lr, weight_decay=wd)
        train_loader, val_loader = trainer.make_loaders_from_mask(mask_val)
        _, val_loss = trainer.train_with_loaders(train_loader, val_loader, model_name=f"{model_name}-TUNE")
        trial.set_user_attr("val_loss", float(val_loss))
        return float(val_loss)
    return objective

def run_optuna_for_model(model_name: str, cfg: EnhancedNHiTSConfig, ds: EnhancedNHiTSDataset, mask_val: np.ndarray):
    if not HAS_OPTUNA:
        print(f"[Optuna] optuna가 설치되어 있지 않습니다. '{model_name}' 튜닝을 건너뜁니다.")
        return None, None
    print(f"[Optuna] Start tuning for {model_name} (trials={cfg.N_TRIALS})")
    pruner = optuna.pruners.MedianPruner(n_startup_trials=5, n_warmup_steps=10, interval_steps=1)
    sampler = optuna.samplers.TPESampler(multivariate=True, group=True, constant_liar=True, seed=cfg.seed)
    study = optuna.create_study(direction="minimize", sampler=sampler, pruner=pruner, study_name=f"study_{model_name}")
    study.optimize(optuna_objective_factory(model_name, cfg, ds, mask_val), n_trials=cfg.N_TRIALS, show_progress_bar=False)
    print(f"[Optuna] Best {model_name} val_loss: {study.best_value:.6f}")
    best_params = study.best_params
    return study, best_params

def build_final_model_with_best(model_name: str, cfg: EnhancedNHiTSConfig, ds: EnhancedNHiTSDataset, best_params: Optional[dict]) -> nn.Module:
    if best_params is None:
        return build_model_by_name(model_name, cfg, ds, None)

    tmp = dict(cfg.__dict__)
    if model_name == "N-HiTS":
        if "nh_hidden" in best_params: tmp["hidden"] = best_params["nh_hidden"]
        if "nh_layers" in best_params: tmp["n_layers"] = best_params["nh_layers"]
        if "nh_dropout" in best_params: tmp["dropout"] = best_params["nh_dropout"]

    elif model_name == "PatchTST":
        mapping = {"pt_d_model":"ptst_d_model","pt_nhead":"ptst_nhead","pt_nlayers":"ptst_num_layers",
                   "pt_patch":"ptst_patch_len","pt_stride":"ptst_stride","pt_dropout":"ptst_dropout",
                   "ptst_ff_mult":"ptst_ff_mult"}
        for k, v in mapping.items():
            if k in best_params:
                tmp[v] = best_params[k]

    elif model_name == "TimesNet":
        mapping = {"tn_channels":"tnet_channels","tn_blocks":"tnet_blocks","tn_dropout":"tnet_dropout"}
        for k, v in mapping.items():
            if k in best_params:
                tmp[v] = best_params[k]

    elif model_name == "GRU":
        mapping = {"gru_hidden":"gru_hidden","gru_layers":"gru_layers","gru_dropout":"gru_dropout","gru_bidi":"gru_bidirectional"}
        for k, v in mapping.items():
            if k in best_params:
                tmp[v] = best_params[k]

    new_cfg = EnhancedNHiTSConfig(**tmp)
    return build_model_by_name(model_name, new_cfg, ds, None)

# =====================
# Main
# =====================
if __name__ == "__main__":
    cfg = EnhancedNHiTSConfig()
    if cfg.store_weights is None: cfg.store_weights = DEFAULT_STORE_WEIGHTS
    if cfg.custom_holidays_list is None: cfg.custom_holidays_list = DEFAULT_CUSTOM_HOLIDAYS
    set_seed(cfg.seed)

    print("=== Enhanced 4-Model Ensemble (+ Optuna Tuning) 시작 ===")

    if not os.path.exists(cfg.train_csv):
        raise FileNotFoundError(f"학습 파일을 찾을 수 없습니다: {cfg.train_csv}")
    train_df = pd.read_csv(cfg.train_csv)
    ds = EnhancedNHiTSDataset(cfg, train_df)

    # ===== (옵션) Optuna per-model 튜닝 =====
    best_params_all = {}
    if cfg.USE_OPTUNA:
        if not HAS_OPTUNA:
            print("⚠️ cfg.USE_OPTUNA=True지만 optuna가 설치되어 있지 않습니다. 튜닝은 건너뜁니다.")
        else:
            # 단일 fold로 튜닝 효율화(첫 fold)
            tune_mask_val = make_val_mask_by_week(ds, cfg.cv_fold_end_dates[0])
            for name in ["N-HiTS", "PatchTST", "TimesNet", "GRU"]:
                study, best_params = run_optuna_for_model(name, cfg, ds, tune_mask_val)
                best_params_all[name] = best_params
            os.makedirs("./data", exist_ok=True)
            with open("./data/optuna_best_params.json", "w", encoding="utf-8") as f:
                json.dump(best_params_all, f, ensure_ascii=False, indent=2)

    # ===== 모델 학습 (멀티 폴드 평균 val) =====
    model_names = ["TimesNet", "GRU", "N-HiTS", "PatchTST"]
    trained_models: Dict[str, nn.Module] = {}
    avg_val_losses: Dict[str, float] = {}

    for name in model_names:
        print(f"📚 {name} 학습...")

        # 0) 초기 스냅샷 확보(항상 같은 초기 가중치에서 시작)
        base_model = build_final_model_with_best(
            name, cfg, ds, best_params_all.get(name) if cfg.USE_OPTUNA else None
        )
        init_state = {k: v.detach().cpu().clone() for k, v in base_model.state_dict().items()}
        del base_model
        gc.collect(); torch.cuda.empty_cache()

        fold_vals = []
        best_fold = None
        best_fold_state = None

        # 1) 폴드별로 항상 fresh 모델/트레이너
        for fold_i, end_date in enumerate(cfg.cv_fold_end_dates, start=1):
            mask_val = make_val_mask_by_week(ds, end_date)

            model_f = build_final_model_with_best(
                name, cfg, ds, best_params_all.get(name) if cfg.USE_OPTUNA else None
            )
            model_f.load_state_dict(init_state, strict=True)  # ← 동일 초기값
            trainer = GenericTrainer(
                cfg, ds, model_f,
                epochs=cfg.EPOCHS_FULL, batch_size=cfg.BATCH_FULL,
                base_lr=cfg.BASE_LR_FULL, max_lr=cfg.MAX_LR_FULL, weight_decay=cfg.WD_FULL
            )
            train_loader, val_loader = trainer.make_loaders_from_mask(mask_val)
            model_f, val_loss = trainer.train_with_loaders(
                train_loader, val_loader, model_name=f"{name}-F{fold_i}"
            )
            fold_vals.append(float(val_loss))

            # 베스트 폴드 state 보관
            if (best_fold is None) or (val_loss < fold_vals[best_fold]):
                best_fold = fold_i - 1  # index
                best_fold_state = {k: v.detach().cpu().clone() for k, v in model_f.state_dict().items()}

            # 폴드별 객체 정리
            del trainer, train_loader, val_loader, model_f
            gc.collect(); torch.cuda.empty_cache()

        # 2) 폴드 평균 성능
        avg_val = float(np.mean(fold_vals)) if len(fold_vals) > 0 else float('inf')
        avg_val_losses[name] = avg_val
        print(f"[VAL(avg over folds)] {name}={avg_val:.5f}")

        # 3) 추론용 fresh 모델 생성 후 베스트 폴드 state 로드
        final_model = build_final_model_with_best(
            name, cfg, ds, best_params_all.get(name) if cfg.USE_OPTUNA else None
        )
        if best_fold_state is not None:
            final_model.load_state_dict(best_fold_state, strict=True)
        trained_models[name] = final_model.to(cfg.device)

    # ===== 가중치 산출(역손실, 안전화) =====
    vals_in_order = [avg_val_losses.get(n, np.nan) for n in model_names]
    w = invloss_weights(vals_in_order)
    weights = dict(zip(model_names, w))
    print("[Ensemble Weights] " + "  ".join([f"{k}={weights[k]:.3f}" for k in model_names]))

    # ===== 추론 & 제출 =====
    print("🔮 4-Model 앙상블 예측...")
    test_files = sorted(glob.glob(cfg.test_glob))
    if not os.path.exists(cfg.submission_template_csv):
        raise FileNotFoundError(f"제출 템플릿 파일을 찾을 수 없습니다: {cfg.submission_template_csv}")
    sub_template = pd.read_csv(cfg.submission_template_csv)
    all_preds = []

    if len(test_files) == 0:
        print("⚠️ 테스트 파일이 없습니다. 제출 생성을 건너뜁니다.")
    else:
        for test_idx, test_file in enumerate(test_files):
            print(f"  📊 {test_file} 처리 중...")
            try:
                tdf = pd.read_csv(test_file)
            except Exception as e:
                print(f"  ⚠️ 파일 로드 실패: {e}")
                continue

            df_preds = {}
            for name in model_names:
                df = predict_one_file_generic(cfg, trained_models[name], tdf, ds.store2idx, ds.cat2idx, ds.type2idx)
                if df.empty:
                    print(f"  ⚠️ {name} 예측이 비어 있습니다. 이 모델은 스킵합니다.")
                df_preds[name] = df

            # 공통 아이템 집합 정렬
            non_empty = [df for df in df_preds.values() if df is not None and not df.empty]
            if len(non_empty) == 0:
                print(f"  ⚠️ {test_file} 유효 예측이 없어 스킵합니다.")
                continue
            items = list(non_empty[0].columns)
            for k in df_preds:
                if df_preds[k] is not None and not df_preds[k].empty:
                    df_preds[k] = df_preds[k].reindex(columns=items).fillna(0.0)

            # 가중 앙상블
            mix = np.zeros_like(non_empty[0].values, dtype=np.float64)
            for name in model_names:
                df = df_preds.get(name, None)
                if df is None or df.empty:
                    continue
                mix += weights[name] * df.values
            mix = np.clip(mix, 0, None)

            submit_block = pd.DataFrame(
                mix,
                index=[f"D+{i}" for i in range(1, cfg.out_len + 1)],
                columns=items
            )
            submit_block.index = [f"TEST_{test_idx:02d}+{k}일" for k in range(1, cfg.out_len + 1)]
            all_preds.append(submit_block)

    if len(all_preds) == 0:
        print("⚠️ 유효한 예측 결과가 없어 제출 파일을 생성하지 않았습니다.")
    else:
        final_submit = pd.concat(all_preds, axis=0)
        final_submit.reset_index(inplace=True)
        final_submit.rename(columns={"index": "영업일자"}, inplace=True)

        final_submit = final_submit.reindex(columns=sub_template.columns, fill_value=0)

        num_cols = [c for c in final_submit.columns if c != "영업일자"]
        for col in num_cols:
            Q95 = final_submit[col].quantile(0.95)
            final_submit[col] = np.where(final_submit[col] > Q95 * 2.0, Q95 * 1.5, final_submit[col])

        final_submit[num_cols] = np.rint(np.clip(final_submit[num_cols].values, a_min=0, a_max=None)).astype(int)
        os.makedirs(os.path.dirname(cfg.out_submission_csv), exist_ok=True)
        final_submit.to_csv(cfg.out_submission_csv, index=False, encoding="utf-8-sig")
        print(f"✅ 앙상블 완료! → {cfg.out_submission_csv}")

    print("🏆 N-HiTS + PatchTST + TimesNet + GRU 학습/추론 끝")
# Out:
# === Enhanced 4-Model Ensemble (+ Optuna Tuning) 시작 ===
# 📚 TimesNet 학습...
# [TimesNet-F1] [Epoch 001] train_loss: 0.44015  val_loss: 1.06720
# [TimesNet-F1] [Epoch 002] train_loss: 0.38232  val_loss: 1.00333
# [TimesNet-F1] [Epoch 003] train_loss: 0.37308  val_loss: 0.93399
# [TimesNet-F1] [Epoch 004] train_loss: 0.36709  val_loss: 0.87213
# [TimesNet-F1] [Epoch 005] train_loss: 0.36083  val_loss: 0.81764
# [TimesNet-F1] [Epoch 006] train_loss: 0.35522  val_loss: 0.76989
# [TimesNet-F1] [Epoch 007] train_loss: 0.35101  val_loss: 0.72861
# [TimesNet-F1] [Epoch 008] train_loss: 0.34834  val_loss: 0.69313
# [TimesNet-F1] [Epoch 009] train_loss: 0.34562  val_loss: 0.66305
# [TimesNet-F1] [Epoch 010] train_loss: 0.34311  val_loss: 0.63743
# [TimesNet-F1] [Epoch 011] train_loss: 0.34172  val_loss: 0.61404
# [TimesNet-F1] [Epoch 012] train_loss: 0.34024  val_loss: 0.59278
# [TimesNet-F1] [Epoch 013] train_loss: 0.33849  val_loss: 0.57432
# [TimesNet-F1] [Epoch 014] train_loss: 0.33723  val_loss: 0.55800
# [TimesNet-F1] [Epoch 015] train_loss: 0.33596  val_loss: 0.54452
# [TimesNet-F1] [Epoch 016] train_loss: 0.33434  val_loss: 0.53278
# [TimesNet-F1] [Epoch 017] train_loss: 0.33311  val_loss: 0.52287
# [TimesNet-F1] [Epoch 018] train_loss: 0.33224  val_loss: 0.51365
# [TimesNet-F1] [Epoch 019] train_loss: 0.33145  val_loss: 0.50502
# [TimesNet-F1] [Epoch 020] train_loss: 0.32999  val_loss: 0.49687
# [TimesNet-F1] [Epoch 021] train_loss: 0.32852  val_loss: 0.48903
# [TimesNet-F1] [Epoch 022] train_loss: 0.32757  val_loss: 0.48159
# [TimesNet-F1] [Epoch 023] train_loss: 0.32643  val_loss: 0.47457
# [TimesNet-F1] [Epoch 024] train_loss: 0.32569  val_loss: 0.46816
# [TimesNet-F1] [Epoch 025] train_loss: 0.32439  val_loss: 0.46168
# [TimesNet-F1] [Epoch 026] train_loss: 0.32412  val_loss: 0.45591
# [TimesNet-F1] [Epoch 027] train_loss: 0.32281  val_loss: 0.45021
# [TimesNet-F1] [Epoch 028] train_loss: 0.32187  val_loss: 0.44499
# [TimesNet-F1] [Epoch 029] train_loss: 0.32058  val_loss: 0.43992
# [TimesNet-F1] [Epoch 030] train_loss: 0.32024  val_loss: 0.43525
# [TimesNet-F1] [Epoch 031] train_loss: 0.31939  val_loss: 0.43098
# [TimesNet-F1] [Epoch 032] train_loss: 0.31812  val_loss: 0.42691
# [TimesNet-F1] [Epoch 033] train_loss: 0.31799  val_loss: 0.42323
# [TimesNet-F1] [Epoch 034] train_loss: 0.31688  val_loss: 0.41931
# [TimesNet-F1] [Epoch 035] train_loss: 0.31626  val_loss: 0.41588
# [TimesNet-F1] [Epoch 036] train_loss: 0.31524  val_loss: 0.41306
# [TimesNet-F1] [Epoch 037] train_loss: 0.31458  val_loss: 0.41071
# [TimesNet-F1] [Epoch 038] train_loss: 0.31343  val_loss: 0.40842
# [TimesNet-F1] [Epoch 039] train_loss: 0.31337  val_loss: 0.40642
# [TimesNet-F1] [Epoch 040] train_loss: 0.31256  val_loss: 0.40442
# [TimesNet-F1] [Epoch 041] train_loss: 0.31218  val_loss: 0.40240
# [TimesNet-F1] [Epoch 042] train_loss: 0.31191  val_loss: 0.40046
# [TimesNet-F1] [Epoch 043] train_loss: 0.31086  val_loss: 0.39879
# [TimesNet-F1] [Epoch 044] train_loss: 0.31045  val_loss: 0.39722
# [TimesNet-F1] [Epoch 045] train_loss: 0.30960  val_loss: 0.39589
# [TimesNet-F1] [Epoch 046] train_loss: 0.30896  val_loss: 0.39464
# [TimesNet-F1] [Epoch 047] train_loss: 0.30862  val_loss: 0.39346
# [TimesNet-F1] [Epoch 048] train_loss: 0.30827  val_loss: 0.39240
# [TimesNet-F1] [Epoch 049] train_loss: 0.30763  val_loss: 0.39139
# [TimesNet-F1] [Epoch 050] train_loss: 0.30699  val_loss: 0.39059
# [TimesNet-F1] [Epoch 051] train_loss: 0.30634  val_loss: 0.38980
# [TimesNet-F1] [Epoch 052] train_loss: 0.30582  val_loss: 0.38905
# [TimesNet-F1] [Epoch 053] train_loss: 0.30541  val_loss: 0.38844
# [TimesNet-F1] [Epoch 054] train_loss: 0.30511  val_loss: 0.38789
# [TimesNet-F1] [Epoch 055] train_loss: 0.30459  val_loss: 0.38740
# [TimesNet-F1] [Epoch 056] train_loss: 0.30423  val_loss: 0.38692
# [TimesNet-F1] [Epoch 057] train_loss: 0.30368  val_loss: 0.38646
# [TimesNet-F1] [Epoch 058] train_loss: 0.30334  val_loss: 0.38606
# [TimesNet-F1] [Epoch 059] train_loss: 0.30256  val_loss: 0.38576
# [TimesNet-F1] [Epoch 060] train_loss: 0.30259  val_loss: 0.38540
# [TimesNet-F1] [Epoch 061] train_loss: 0.30222  val_loss: 0.38510
# [TimesNet-F1] [Epoch 062] train_loss: 0.30167  val_loss: 0.38484
# [TimesNet-F1] [Epoch 063] train_loss: 0.30140  val_loss: 0.38451
# [TimesNet-F1] [Epoch 064] train_loss: 0.30106  val_loss: 0.38431
# [TimesNet-F1] [Epoch 065] train_loss: 0.30055  val_loss: 0.38411
# [TimesNet-F1] [Epoch 066] train_loss: 0.30039  val_loss: 0.38402
# [TimesNet-F1] [Epoch 067] train_loss: 0.30022  val_loss: 0.38390
# [TimesNet-F1] [Epoch 068] train_loss: 0.29972  val_loss: 0.38377
# [TimesNet-F1] [Epoch 069] train_loss: 0.29945  val_loss: 0.38367
# [TimesNet-F1] [Epoch 070] train_loss: 0.29894  val_loss: 0.38357
# [TimesNet-F1] [Epoch 071] train_loss: 0.29849  val_loss: 0.38354
# [TimesNet-F1] [Epoch 072] train_loss: 0.29838  val_loss: 0.38348
# [TimesNet-F1] [Epoch 073] train_loss: 0.29833  val_loss: 0.38344
# [TimesNet-F1] [Epoch 074] train_loss: 0.29798  val_loss: 0.38340
# [TimesNet-F1] [Epoch 075] train_loss: 0.29756  val_loss: 0.38340
# [TimesNet-F1] [Epoch 076] train_loss: 0.29754  val_loss: 0.38337
# [TimesNet-F1] [Epoch 077] train_loss: 0.29738  val_loss: 0.38331
# [TimesNet-F1] [Epoch 078] train_loss: 0.29690  val_loss: 0.38330
# [TimesNet-F1] [Epoch 079] train_loss: 0.29692  val_loss: 0.38333
# [TimesNet-F1] [Epoch 080] train_loss: 0.29663  val_loss: 0.38334
# [TimesNet-F1] [Epoch 081] train_loss: 0.29628  val_loss: 0.38326
# [TimesNet-F1] [Epoch 082] train_loss: 0.29596  val_loss: 0.38324
# [TimesNet-F1] [Epoch 083] train_loss: 0.29617  val_loss: 0.38324
# [TimesNet-F1] [Epoch 084] train_loss: 0.29585  val_loss: 0.38327
# [TimesNet-F1] [Epoch 085] train_loss: 0.29580  val_loss: 0.38328
# [TimesNet-F1] [Epoch 086] train_loss: 0.29579  val_loss: 0.38331
# [TimesNet-F1] [Epoch 087] train_loss: 0.29552  val_loss: 0.38331
# [TimesNet-F1] [Epoch 088] train_loss: 0.29534  val_loss: 0.38332
# [TimesNet-F1] [Epoch 089] train_loss: 0.29512  val_loss: 0.38328
# [TimesNet-F1] [Epoch 090] train_loss: 0.29538  val_loss: 0.38328
# [TimesNet-F1] [Epoch 091] train_loss: 0.29515  val_loss: 0.38328
# [TimesNet-F1] [Epoch 092] train_loss: 0.29526  val_loss: 0.38331
# [TimesNet-F1] [Epoch 093] train_loss: 0.29489  val_loss: 0.38338
# [TimesNet-F1] [Epoch 094] train_loss: 0.29505  val_loss: 0.38342
# [TimesNet-F1] Early stopping at epoch 94
# [TimesNet-F2] [Epoch 001] train_loss: 0.43552  val_loss: 1.04362
# [TimesNet-F2] [Epoch 002] train_loss: 0.38135  val_loss: 0.98151
# [TimesNet-F2] [Epoch 003] train_loss: 0.37309  val_loss: 0.91453
# [TimesNet-F2] [Epoch 004] train_loss: 0.36638  val_loss: 0.85697
# [TimesNet-F2] [Epoch 005] train_loss: 0.35993  val_loss: 0.80629
# [TimesNet-F2] [Epoch 006] train_loss: 0.35441  val_loss: 0.76044
# [TimesNet-F2] [Epoch 007] train_loss: 0.35054  val_loss: 0.72039
# [TimesNet-F2] [Epoch 008] train_loss: 0.34751  val_loss: 0.68590
# [TimesNet-F2] [Epoch 009] train_loss: 0.34459  val_loss: 0.65621
# [TimesNet-F2] [Epoch 010] train_loss: 0.34273  val_loss: 0.62933
# [TimesNet-F2] [Epoch 011] train_loss: 0.34108  val_loss: 0.60610
# [TimesNet-F2] [Epoch 012] train_loss: 0.33929  val_loss: 0.58472
# [TimesNet-F2] [Epoch 013] train_loss: 0.33770  val_loss: 0.56516
# [TimesNet-F2] [Epoch 014] train_loss: 0.33660  val_loss: 0.54807
# [TimesNet-F2] [Epoch 015] train_loss: 0.33534  val_loss: 0.53318
# [TimesNet-F2] [Epoch 016] train_loss: 0.33447  val_loss: 0.51995
# [TimesNet-F2] [Epoch 017] train_loss: 0.33310  val_loss: 0.50837
# [TimesNet-F2] [Epoch 018] train_loss: 0.33140  val_loss: 0.49779
# [TimesNet-F2] [Epoch 019] train_loss: 0.33036  val_loss: 0.48882
# [TimesNet-F2] [Epoch 020] train_loss: 0.32945  val_loss: 0.48062
# [TimesNet-F2] [Epoch 021] train_loss: 0.32846  val_loss: 0.47254
# [TimesNet-F2] [Epoch 022] train_loss: 0.32746  val_loss: 0.46514
# [TimesNet-F2] [Epoch 023] train_loss: 0.32667  val_loss: 0.45793
# [TimesNet-F2] [Epoch 024] train_loss: 0.32548  val_loss: 0.45123
# [TimesNet-F2] [Epoch 025] train_loss: 0.32444  val_loss: 0.44512
# [TimesNet-F2] [Epoch 026] train_loss: 0.32363  val_loss: 0.43945
# [TimesNet-F2] [Epoch 027] train_loss: 0.32236  val_loss: 0.43426
# [TimesNet-F2] [Epoch 028] train_loss: 0.32166  val_loss: 0.42945
# [TimesNet-F2] [Epoch 029] train_loss: 0.32074  val_loss: 0.42469
# [TimesNet-F2] [Epoch 030] train_loss: 0.31960  val_loss: 0.42011
# [TimesNet-F2] [Epoch 031] train_loss: 0.31914  val_loss: 0.41617
# [TimesNet-F2] [Epoch 032] train_loss: 0.31811  val_loss: 0.41265
# [TimesNet-F2] [Epoch 033] train_loss: 0.31747  val_loss: 0.40964
# [TimesNet-F2] [Epoch 034] train_loss: 0.31652  val_loss: 0.40681
# [TimesNet-F2] [Epoch 035] train_loss: 0.31616  val_loss: 0.40412
# [TimesNet-F2] [Epoch 036] train_loss: 0.31502  val_loss: 0.40164
# [TimesNet-F2] [Epoch 037] train_loss: 0.31423  val_loss: 0.39924
# [TimesNet-F2] [Epoch 038] train_loss: 0.31363  val_loss: 0.39702
# [TimesNet-F2] [Epoch 039] train_loss: 0.31339  val_loss: 0.39502
# [TimesNet-F2] [Epoch 040] train_loss: 0.31246  val_loss: 0.39313
# [TimesNet-F2] [Epoch 041] train_loss: 0.31132  val_loss: 0.39141
# [TimesNet-F2] [Epoch 042] train_loss: 0.31111  val_loss: 0.38969
# [TimesNet-F2] [Epoch 043] train_loss: 0.31072  val_loss: 0.38810
# [TimesNet-F2] [Epoch 044] train_loss: 0.31008  val_loss: 0.38671
# [TimesNet-F2] [Epoch 045] train_loss: 0.30956  val_loss: 0.38540
# [TimesNet-F2] [Epoch 046] train_loss: 0.30900  val_loss: 0.38425
# [TimesNet-F2] [Epoch 047] train_loss: 0.30852  val_loss: 0.38314
# [TimesNet-F2] [Epoch 048] train_loss: 0.30789  val_loss: 0.38218
# [TimesNet-F2] [Epoch 049] train_loss: 0.30717  val_loss: 0.38126
# [TimesNet-F2] [Epoch 050] train_loss: 0.30695  val_loss: 0.38048
# [TimesNet-F2] [Epoch 051] train_loss: 0.30652  val_loss: 0.37985
# [TimesNet-F2] [Epoch 052] train_loss: 0.30610  val_loss: 0.37934
# [TimesNet-F2] [Epoch 053] train_loss: 0.30561  val_loss: 0.37883
# [TimesNet-F2] [Epoch 054] train_loss: 0.30511  val_loss: 0.37842
# [TimesNet-F2] [Epoch 055] train_loss: 0.30477  val_loss: 0.37809
# [TimesNet-F2] [Epoch 056] train_loss: 0.30434  val_loss: 0.37779
# [TimesNet-F2] [Epoch 057] train_loss: 0.30399  val_loss: 0.37765
# [TimesNet-F2] [Epoch 058] train_loss: 0.30359  val_loss: 0.37753
# [TimesNet-F2] [Epoch 059] train_loss: 0.30317  val_loss: 0.37741
# [TimesNet-F2] [Epoch 060] train_loss: 0.30312  val_loss: 0.37732
# [TimesNet-F2] [Epoch 061] train_loss: 0.30250  val_loss: 0.37730
# [TimesNet-F2] [Epoch 062] train_loss: 0.30200  val_loss: 0.37731
# [TimesNet-F2] [Epoch 063] train_loss: 0.30193  val_loss: 0.37734
# [TimesNet-F2] [Epoch 064] train_loss: 0.30130  val_loss: 0.37735
# [TimesNet-F2] [Epoch 065] train_loss: 0.30072  val_loss: 0.37739
# [TimesNet-F2] [Epoch 066] train_loss: 0.30081  val_loss: 0.37737
# [TimesNet-F2] [Epoch 067] train_loss: 0.30017  val_loss: 0.37742
# [TimesNet-F2] [Epoch 068] train_loss: 0.30009  val_loss: 0.37748
# [TimesNet-F2] [Epoch 069] train_loss: 0.29977  val_loss: 0.37750
# [TimesNet-F2] [Epoch 070] train_loss: 0.29967  val_loss: 0.37757
# [TimesNet-F2] [Epoch 071] train_loss: 0.29941  val_loss: 0.37765
# [TimesNet-F2] [Epoch 072] train_loss: 0.29882  val_loss: 0.37773
# [TimesNet-F2] [Epoch 073] train_loss: 0.29877  val_loss: 0.37782
# [TimesNet-F2] Early stopping at epoch 73
# [TimesNet-F3] [Epoch 001] train_loss: 0.43450  val_loss: 1.06659
# [TimesNet-F3] [Epoch 002] train_loss: 0.38153  val_loss: 1.00432
# [TimesNet-F3] [Epoch 003] train_loss: 0.37262  val_loss: 0.93724
# [TimesNet-F3] [Epoch 004] train_loss: 0.36620  val_loss: 0.87837
# [TimesNet-F3] [Epoch 005] train_loss: 0.36065  val_loss: 0.82766
# [TimesNet-F3] [Epoch 006] train_loss: 0.35518  val_loss: 0.78304
# [TimesNet-F3] [Epoch 007] train_loss: 0.35054  val_loss: 0.74527
# [TimesNet-F3] [Epoch 008] train_loss: 0.34795  val_loss: 0.71287
# [TimesNet-F3] [Epoch 009] train_loss: 0.34561  val_loss: 0.68333
# [TimesNet-F3] [Epoch 010] train_loss: 0.34344  val_loss: 0.65659
# [TimesNet-F3] [Epoch 011] train_loss: 0.34189  val_loss: 0.63218
# [TimesNet-F3] [Epoch 012] train_loss: 0.34050  val_loss: 0.61030
# [TimesNet-F3] [Epoch 013] train_loss: 0.33917  val_loss: 0.59060
# [TimesNet-F3] [Epoch 014] train_loss: 0.33758  val_loss: 0.57251
# [TimesNet-F3] [Epoch 015] train_loss: 0.33615  val_loss: 0.55580
# [TimesNet-F3] [Epoch 016] train_loss: 0.33496  val_loss: 0.54096
# [TimesNet-F3] [Epoch 017] train_loss: 0.33391  val_loss: 0.52712
# [TimesNet-F3] [Epoch 018] train_loss: 0.33293  val_loss: 0.51446
# [TimesNet-F3] [Epoch 019] train_loss: 0.33163  val_loss: 0.50363
# [TimesNet-F3] [Epoch 020] train_loss: 0.33058  val_loss: 0.49350
# [TimesNet-F3] [Epoch 021] train_loss: 0.32948  val_loss: 0.48396
# [TimesNet-F3] [Epoch 022] train_loss: 0.32843  val_loss: 0.47598
# [TimesNet-F3] [Epoch 023] train_loss: 0.32752  val_loss: 0.46806
# [TimesNet-F3] [Epoch 024] train_loss: 0.32638  val_loss: 0.46059
# [TimesNet-F3] [Epoch 025] train_loss: 0.32576  val_loss: 0.45366
# [TimesNet-F3] [Epoch 026] train_loss: 0.32458  val_loss: 0.44723
# [TimesNet-F3] [Epoch 027] train_loss: 0.32365  val_loss: 0.44150
# [TimesNet-F3] [Epoch 028] train_loss: 0.32254  val_loss: 0.43565
# [TimesNet-F3] [Epoch 029] train_loss: 0.32213  val_loss: 0.43047
# [TimesNet-F3] [Epoch 030] train_loss: 0.32085  val_loss: 0.42535
# [TimesNet-F3] [Epoch 031] train_loss: 0.32006  val_loss: 0.42082
# [TimesNet-F3] [Epoch 032] train_loss: 0.31894  val_loss: 0.41671
# [TimesNet-F3] [Epoch 033] train_loss: 0.31812  val_loss: 0.41266
# [TimesNet-F3] [Epoch 034] train_loss: 0.31746  val_loss: 0.40916
# [TimesNet-F3] [Epoch 035] train_loss: 0.31652  val_loss: 0.40616
# [TimesNet-F3] [Epoch 036] train_loss: 0.31588  val_loss: 0.40332
# [TimesNet-F3] [Epoch 037] train_loss: 0.31539  val_loss: 0.40081
# [TimesNet-F3] [Epoch 038] train_loss: 0.31454  val_loss: 0.39849
# [TimesNet-F3] [Epoch 039] train_loss: 0.31366  val_loss: 0.39634
# [TimesNet-F3] [Epoch 040] train_loss: 0.31328  val_loss: 0.39451
# [TimesNet-F3] [Epoch 041] train_loss: 0.31229  val_loss: 0.39289
# [TimesNet-F3] [Epoch 042] train_loss: 0.31195  val_loss: 0.39137
# [TimesNet-F3] [Epoch 043] train_loss: 0.31132  val_loss: 0.38995
# [TimesNet-F3] [Epoch 044] train_loss: 0.31086  val_loss: 0.38863
# [TimesNet-F3] [Epoch 045] train_loss: 0.31010  val_loss: 0.38750
# [TimesNet-F3] [Epoch 046] train_loss: 0.30957  val_loss: 0.38633
# [TimesNet-F3] [Epoch 047] train_loss: 0.30888  val_loss: 0.38534
# [TimesNet-F3] [Epoch 048] train_loss: 0.30864  val_loss: 0.38445
# [TimesNet-F3] [Epoch 049] train_loss: 0.30792  val_loss: 0.38373
# [TimesNet-F3] [Epoch 050] train_loss: 0.30764  val_loss: 0.38312
# [TimesNet-F3] [Epoch 051] train_loss: 0.30668  val_loss: 0.38251
# [TimesNet-F3] [Epoch 052] train_loss: 0.30647  val_loss: 0.38191
# [TimesNet-F3] [Epoch 053] train_loss: 0.30597  val_loss: 0.38140
# [TimesNet-F3] [Epoch 054] train_loss: 0.30551  val_loss: 0.38092
# [TimesNet-F3] [Epoch 055] train_loss: 0.30516  val_loss: 0.38045
# [TimesNet-F3] [Epoch 056] train_loss: 0.30445  val_loss: 0.38010
# [TimesNet-F3] [Epoch 057] train_loss: 0.30429  val_loss: 0.37970
# [TimesNet-F3] [Epoch 058] train_loss: 0.30395  val_loss: 0.37937
# [TimesNet-F3] [Epoch 059] train_loss: 0.30325  val_loss: 0.37906
# [TimesNet-F3] [Epoch 060] train_loss: 0.30278  val_loss: 0.37879
# [TimesNet-F3] [Epoch 061] train_loss: 0.30264  val_loss: 0.37857
# [TimesNet-F3] [Epoch 062] train_loss: 0.30202  val_loss: 0.37836
# [TimesNet-F3] [Epoch 063] train_loss: 0.30190  val_loss: 0.37814
# [TimesNet-F3] [Epoch 064] train_loss: 0.30160  val_loss: 0.37803
# [TimesNet-F3] [Epoch 065] train_loss: 0.30132  val_loss: 0.37788
# [TimesNet-F3] [Epoch 066] train_loss: 0.30089  val_loss: 0.37774
# [TimesNet-F3] [Epoch 067] train_loss: 0.30032  val_loss: 0.37762
# [TimesNet-F3] [Epoch 068] train_loss: 0.30009  val_loss: 0.37758
# [TimesNet-F3] [Epoch 069] train_loss: 0.29974  val_loss: 0.37753
# [TimesNet-F3] [Epoch 070] train_loss: 0.29962  val_loss: 0.37746
# [TimesNet-F3] [Epoch 071] train_loss: 0.29929  val_loss: 0.37736
# [TimesNet-F3] [Epoch 072] train_loss: 0.29911  val_loss: 0.37730
# [TimesNet-F3] [Epoch 073] train_loss: 0.29872  val_loss: 0.37728
# [TimesNet-F3] [Epoch 074] train_loss: 0.29861  val_loss: 0.37719
# [TimesNet-F3] [Epoch 075] train_loss: 0.29849  val_loss: 0.37720
# [TimesNet-F3] [Epoch 076] train_loss: 0.29817  val_loss: 0.37717
# [TimesNet-F3] [Epoch 077] train_loss: 0.29801  val_loss: 0.37717
# [TimesNet-F3] [Epoch 078] train_loss: 0.29750  val_loss: 0.37718
# [TimesNet-F3] [Epoch 079] train_loss: 0.29745  val_loss: 0.37724
# [TimesNet-F3] [Epoch 080] train_loss: 0.29731  val_loss: 0.37726
# [TimesNet-F3] [Epoch 081] train_loss: 0.29712  val_loss: 0.37728
# [TimesNet-F3] [Epoch 082] train_loss: 0.29682  val_loss: 0.37730
# [TimesNet-F3] [Epoch 083] train_loss: 0.29676  val_loss: 0.37728
# [TimesNet-F3] [Epoch 084] train_loss: 0.29651  val_loss: 0.37728
# [TimesNet-F3] [Epoch 085] train_loss: 0.29635  val_loss: 0.37730
# [TimesNet-F3] [Epoch 086] train_loss: 0.29595  val_loss: 0.37730
# [TimesNet-F3] [Epoch 087] train_loss: 0.29636  val_loss: 0.37734
# [TimesNet-F3] [Epoch 088] train_loss: 0.29619  val_loss: 0.37735
# [TimesNet-F3] Early stopping at epoch 88
# [VAL(avg over folds)] TimesNet=0.37923
# 📚 GRU 학습...
# [GRU-F1] [Epoch 001] train_loss: 0.40007  val_loss: 0.90779
# [GRU-F1] [Epoch 002] train_loss: 0.36159  val_loss: 0.80809
# [GRU-F1] [Epoch 003] train_loss: 0.35289  val_loss: 0.72371
# [GRU-F1] [Epoch 004] train_loss: 0.34834  val_loss: 0.66873
# [GRU-F1] [Epoch 005] train_loss: 0.34408  val_loss: 0.63515
# [GRU-F1] [Epoch 006] train_loss: 0.34108  val_loss: 0.61491
# [GRU-F1] [Epoch 007] train_loss: 0.33688  val_loss: 0.59893
# [GRU-F1] [Epoch 008] train_loss: 0.33388  val_loss: 0.58529
# [GRU-F1] [Epoch 009] train_loss: 0.33095  val_loss: 0.57357
# [GRU-F1] [Epoch 010] train_loss: 0.32836  val_loss: 0.56409
# [GRU-F1] [Epoch 011] train_loss: 0.32508  val_loss: 0.55630
# [GRU-F1] [Epoch 012] train_loss: 0.32100  val_loss: 0.54815
# [GRU-F1] [Epoch 013] train_loss: 0.31657  val_loss: 0.53920
# [GRU-F1] [Epoch 014] train_loss: 0.31247  val_loss: 0.52986
# [GRU-F1] [Epoch 015] train_loss: 0.30729  val_loss: 0.51971
# [GRU-F1] [Epoch 016] train_loss: 0.30211  val_loss: 0.50920
# [GRU-F1] [Epoch 017] train_loss: 0.29590  val_loss: 0.49809
# [GRU-F1] [Epoch 018] train_loss: 0.29037  val_loss: 0.48667
# [GRU-F1] [Epoch 019] train_loss: 0.28432  val_loss: 0.47601
# [GRU-F1] [Epoch 020] train_loss: 0.27857  val_loss: 0.46615
# [GRU-F1] [Epoch 021] train_loss: 0.27277  val_loss: 0.45676
# [GRU-F1] [Epoch 022] train_loss: 0.26726  val_loss: 0.44808
# [GRU-F1] [Epoch 023] train_loss: 0.26217  val_loss: 0.44043
# [GRU-F1] [Epoch 024] train_loss: 0.25687  val_loss: 0.43369
# [GRU-F1] [Epoch 025] train_loss: 0.25123  val_loss: 0.42790
# [GRU-F1] [Epoch 026] train_loss: 0.24656  val_loss: 0.42287
# [GRU-F1] [Epoch 027] train_loss: 0.24153  val_loss: 0.41829
# [GRU-F1] [Epoch 028] train_loss: 0.23723  val_loss: 0.41453
# [GRU-F1] [Epoch 029] train_loss: 0.23350  val_loss: 0.41132
# [GRU-F1] [Epoch 030] train_loss: 0.22931  val_loss: 0.40881
# [GRU-F1] [Epoch 031] train_loss: 0.22583  val_loss: 0.40653
# [GRU-F1] [Epoch 032] train_loss: 0.22285  val_loss: 0.40457
# [GRU-F1] [Epoch 033] train_loss: 0.21908  val_loss: 0.40275
# [GRU-F1] [Epoch 034] train_loss: 0.21645  val_loss: 0.40090
# [GRU-F1] [Epoch 035] train_loss: 0.21347  val_loss: 0.39900
# [GRU-F1] [Epoch 036] train_loss: 0.21073  val_loss: 0.39708
# [GRU-F1] [Epoch 037] train_loss: 0.20844  val_loss: 0.39525
# [GRU-F1] [Epoch 038] train_loss: 0.20611  val_loss: 0.39328
# [GRU-F1] [Epoch 039] train_loss: 0.20401  val_loss: 0.39136
# [GRU-F1] [Epoch 040] train_loss: 0.20178  val_loss: 0.38948
# [GRU-F1] [Epoch 041] train_loss: 0.19996  val_loss: 0.38759
# [GRU-F1] [Epoch 042] train_loss: 0.19781  val_loss: 0.38557
# [GRU-F1] [Epoch 043] train_loss: 0.19575  val_loss: 0.38349
# [GRU-F1] [Epoch 044] train_loss: 0.19380  val_loss: 0.38161
# [GRU-F1] [Epoch 045] train_loss: 0.19249  val_loss: 0.37966
# [GRU-F1] [Epoch 046] train_loss: 0.19067  val_loss: 0.37764
# [GRU-F1] [Epoch 047] train_loss: 0.18938  val_loss: 0.37560
# [GRU-F1] [Epoch 048] train_loss: 0.18759  val_loss: 0.37372
# [GRU-F1] [Epoch 049] train_loss: 0.18652  val_loss: 0.37204
# [GRU-F1] [Epoch 050] train_loss: 0.18491  val_loss: 0.37041
# [GRU-F1] [Epoch 051] train_loss: 0.18361  val_loss: 0.36904
# [GRU-F1] [Epoch 052] train_loss: 0.18255  val_loss: 0.36773
# [GRU-F1] [Epoch 053] train_loss: 0.18121  val_loss: 0.36653
# [GRU-F1] [Epoch 054] train_loss: 0.17980  val_loss: 0.36544
# [GRU-F1] [Epoch 055] train_loss: 0.17905  val_loss: 0.36428
# [GRU-F1] [Epoch 056] train_loss: 0.17778  val_loss: 0.36332
# [GRU-F1] [Epoch 057] train_loss: 0.17659  val_loss: 0.36246
# [GRU-F1] [Epoch 058] train_loss: 0.17576  val_loss: 0.36173
# [GRU-F1] [Epoch 059] train_loss: 0.17466  val_loss: 0.36105
# [GRU-F1] [Epoch 060] train_loss: 0.17369  val_loss: 0.36039
# [GRU-F1] [Epoch 061] train_loss: 0.17270  val_loss: 0.35977
# [GRU-F1] [Epoch 062] train_loss: 0.17170  val_loss: 0.35919
# [GRU-F1] [Epoch 063] train_loss: 0.17079  val_loss: 0.35872
# [GRU-F1] [Epoch 064] train_loss: 0.17006  val_loss: 0.35831
# [GRU-F1] [Epoch 065] train_loss: 0.16925  val_loss: 0.35793
# [GRU-F1] [Epoch 066] train_loss: 0.16854  val_loss: 0.35766
# [GRU-F1] [Epoch 067] train_loss: 0.16780  val_loss: 0.35744
# [GRU-F1] [Epoch 068] train_loss: 0.16707  val_loss: 0.35725
# [GRU-F1] [Epoch 069] train_loss: 0.16619  val_loss: 0.35705
# [GRU-F1] [Epoch 070] train_loss: 0.16557  val_loss: 0.35682
# [GRU-F1] [Epoch 071] train_loss: 0.16512  val_loss: 0.35671
# [GRU-F1] [Epoch 072] train_loss: 0.16421  val_loss: 0.35657
# [GRU-F1] [Epoch 073] train_loss: 0.16381  val_loss: 0.35642
# [GRU-F1] [Epoch 074] train_loss: 0.16318  val_loss: 0.35635
# [GRU-F1] [Epoch 075] train_loss: 0.16257  val_loss: 0.35628
# [GRU-F1] [Epoch 076] train_loss: 0.16205  val_loss: 0.35624
# [GRU-F1] [Epoch 077] train_loss: 0.16154  val_loss: 0.35622
# [GRU-F1] [Epoch 078] train_loss: 0.16102  val_loss: 0.35623
# [GRU-F1] [Epoch 079] train_loss: 0.16061  val_loss: 0.35623
# [GRU-F1] [Epoch 080] train_loss: 0.16012  val_loss: 0.35624
# [GRU-F1] [Epoch 081] train_loss: 0.15983  val_loss: 0.35628
# [GRU-F1] [Epoch 082] train_loss: 0.15942  val_loss: 0.35633
# [GRU-F1] [Epoch 083] train_loss: 0.15901  val_loss: 0.35643
# [GRU-F1] [Epoch 084] train_loss: 0.15880  val_loss: 0.35651
# [GRU-F1] [Epoch 085] train_loss: 0.15847  val_loss: 0.35658
# [GRU-F1] [Epoch 086] train_loss: 0.15823  val_loss: 0.35665
# [GRU-F1] [Epoch 087] train_loss: 0.15802  val_loss: 0.35670
# [GRU-F1] [Epoch 088] train_loss: 0.15778  val_loss: 0.35672
# [GRU-F1] [Epoch 089] train_loss: 0.15764  val_loss: 0.35676
# [GRU-F1] Early stopping at epoch 89
# [GRU-F2] [Epoch 001] train_loss: 0.40253  val_loss: 0.89931
# [GRU-F2] [Epoch 002] train_loss: 0.36122  val_loss: 0.80494
# [GRU-F2] [Epoch 003] train_loss: 0.35246  val_loss: 0.72736
# [GRU-F2] [Epoch 004] train_loss: 0.34748  val_loss: 0.67436
# [GRU-F2] [Epoch 005] train_loss: 0.34396  val_loss: 0.64013
# [GRU-F2] [Epoch 006] train_loss: 0.34023  val_loss: 0.62005
# [GRU-F2] [Epoch 007] train_loss: 0.33621  val_loss: 0.60310
# [GRU-F2] [Epoch 008] train_loss: 0.33367  val_loss: 0.58862
# [GRU-F2] [Epoch 009] train_loss: 0.33078  val_loss: 0.57636
# [GRU-F2] [Epoch 010] train_loss: 0.32705  val_loss: 0.56531
# [GRU-F2] [Epoch 011] train_loss: 0.32402  val_loss: 0.55573
# [GRU-F2] [Epoch 012] train_loss: 0.32044  val_loss: 0.54441
# [GRU-F2] [Epoch 013] train_loss: 0.31615  val_loss: 0.53212
# [GRU-F2] [Epoch 014] train_loss: 0.31205  val_loss: 0.52025
# [GRU-F2] [Epoch 015] train_loss: 0.30676  val_loss: 0.50822
# [GRU-F2] [Epoch 016] train_loss: 0.30233  val_loss: 0.49650
# [GRU-F2] [Epoch 017] train_loss: 0.29649  val_loss: 0.48519
# [GRU-F2] [Epoch 018] train_loss: 0.29132  val_loss: 0.47361
# [GRU-F2] [Epoch 019] train_loss: 0.28576  val_loss: 0.46219
# [GRU-F2] [Epoch 020] train_loss: 0.28035  val_loss: 0.45183
# [GRU-F2] [Epoch 021] train_loss: 0.27469  val_loss: 0.44236
# [GRU-F2] [Epoch 022] train_loss: 0.26934  val_loss: 0.43383
# [GRU-F2] [Epoch 023] train_loss: 0.26410  val_loss: 0.42632
# [GRU-F2] [Epoch 024] train_loss: 0.25927  val_loss: 0.42003
# [GRU-F2] [Epoch 025] train_loss: 0.25423  val_loss: 0.41475
# [GRU-F2] [Epoch 026] train_loss: 0.25012  val_loss: 0.41054
# [GRU-F2] [Epoch 027] train_loss: 0.24516  val_loss: 0.40683
# [GRU-F2] [Epoch 028] train_loss: 0.24114  val_loss: 0.40372
# [GRU-F2] [Epoch 029] train_loss: 0.23693  val_loss: 0.40085
# [GRU-F2] [Epoch 030] train_loss: 0.23323  val_loss: 0.39814
# [GRU-F2] [Epoch 031] train_loss: 0.22923  val_loss: 0.39528
# [GRU-F2] [Epoch 032] train_loss: 0.22582  val_loss: 0.39266
# [GRU-F2] [Epoch 033] train_loss: 0.22239  val_loss: 0.39032
# [GRU-F2] [Epoch 034] train_loss: 0.21903  val_loss: 0.38787
# [GRU-F2] [Epoch 035] train_loss: 0.21618  val_loss: 0.38523
# [GRU-F2] [Epoch 036] train_loss: 0.21310  val_loss: 0.38253
# [GRU-F2] [Epoch 037] train_loss: 0.21059  val_loss: 0.37993
# [GRU-F2] [Epoch 038] train_loss: 0.20796  val_loss: 0.37738
# [GRU-F2] [Epoch 039] train_loss: 0.20597  val_loss: 0.37484
# [GRU-F2] [Epoch 040] train_loss: 0.20352  val_loss: 0.37241
# [GRU-F2] [Epoch 041] train_loss: 0.20143  val_loss: 0.37015
# [GRU-F2] [Epoch 042] train_loss: 0.19921  val_loss: 0.36787
# [GRU-F2] [Epoch 043] train_loss: 0.19739  val_loss: 0.36567
# [GRU-F2] [Epoch 044] train_loss: 0.19562  val_loss: 0.36354
# [GRU-F2] [Epoch 045] train_loss: 0.19396  val_loss: 0.36153
# [GRU-F2] [Epoch 046] train_loss: 0.19226  val_loss: 0.35962
# [GRU-F2] [Epoch 047] train_loss: 0.19068  val_loss: 0.35779
# [GRU-F2] [Epoch 048] train_loss: 0.18869  val_loss: 0.35612
# [GRU-F2] [Epoch 049] train_loss: 0.18754  val_loss: 0.35450
# [GRU-F2] [Epoch 050] train_loss: 0.18584  val_loss: 0.35290
# [GRU-F2] [Epoch 051] train_loss: 0.18442  val_loss: 0.35135
# [GRU-F2] [Epoch 052] train_loss: 0.18346  val_loss: 0.34991
# [GRU-F2] [Epoch 053] train_loss: 0.18198  val_loss: 0.34859
# [GRU-F2] [Epoch 054] train_loss: 0.18058  val_loss: 0.34730
# [GRU-F2] [Epoch 055] train_loss: 0.17958  val_loss: 0.34608
# [GRU-F2] [Epoch 056] train_loss: 0.17812  val_loss: 0.34487
# [GRU-F2] [Epoch 057] train_loss: 0.17712  val_loss: 0.34370
# [GRU-F2] [Epoch 058] train_loss: 0.17625  val_loss: 0.34267
# [GRU-F2] [Epoch 059] train_loss: 0.17516  val_loss: 0.34170
# [GRU-F2] [Epoch 060] train_loss: 0.17417  val_loss: 0.34085
# [GRU-F2] [Epoch 061] train_loss: 0.17299  val_loss: 0.34007
# [GRU-F2] [Epoch 062] train_loss: 0.17217  val_loss: 0.33939
# [GRU-F2] [Epoch 063] train_loss: 0.17109  val_loss: 0.33882
# [GRU-F2] [Epoch 064] train_loss: 0.17033  val_loss: 0.33830
# [GRU-F2] [Epoch 065] train_loss: 0.16958  val_loss: 0.33783
# [GRU-F2] [Epoch 066] train_loss: 0.16867  val_loss: 0.33745
# [GRU-F2] [Epoch 067] train_loss: 0.16781  val_loss: 0.33709
# [GRU-F2] [Epoch 068] train_loss: 0.16707  val_loss: 0.33682
# [GRU-F2] [Epoch 069] train_loss: 0.16637  val_loss: 0.33657
# [GRU-F2] [Epoch 070] train_loss: 0.16570  val_loss: 0.33629
# [GRU-F2] [Epoch 071] train_loss: 0.16520  val_loss: 0.33611
# [GRU-F2] [Epoch 072] train_loss: 0.16461  val_loss: 0.33598
# [GRU-F2] [Epoch 073] train_loss: 0.16387  val_loss: 0.33591
# [GRU-F2] [Epoch 074] train_loss: 0.16333  val_loss: 0.33578
# [GRU-F2] [Epoch 075] train_loss: 0.16271  val_loss: 0.33571
# [GRU-F2] [Epoch 076] train_loss: 0.16246  val_loss: 0.33571
# [GRU-F2] [Epoch 077] train_loss: 0.16183  val_loss: 0.33567
# [GRU-F2] [Epoch 078] train_loss: 0.16140  val_loss: 0.33567
# [GRU-F2] [Epoch 079] train_loss: 0.16084  val_loss: 0.33566
# [GRU-F2] [Epoch 080] train_loss: 0.16040  val_loss: 0.33570
# [GRU-F2] [Epoch 081] train_loss: 0.16004  val_loss: 0.33566
# [GRU-F2] [Epoch 082] train_loss: 0.15965  val_loss: 0.33570
# [GRU-F2] [Epoch 083] train_loss: 0.15917  val_loss: 0.33575
# [GRU-F2] [Epoch 084] train_loss: 0.15895  val_loss: 0.33582
# [GRU-F2] [Epoch 085] train_loss: 0.15870  val_loss: 0.33588
# [GRU-F2] [Epoch 086] train_loss: 0.15839  val_loss: 0.33589
# [GRU-F2] [Epoch 087] train_loss: 0.15826  val_loss: 0.33594
# [GRU-F2] [Epoch 088] train_loss: 0.15779  val_loss: 0.33603
# [GRU-F2] [Epoch 089] train_loss: 0.15766  val_loss: 0.33610
# [GRU-F2] [Epoch 090] train_loss: 0.15738  val_loss: 0.33617
# [GRU-F2] [Epoch 091] train_loss: 0.15735  val_loss: 0.33624
# [GRU-F2] [Epoch 092] train_loss: 0.15718  val_loss: 0.33632
# [GRU-F2] [Epoch 093] train_loss: 0.15712  val_loss: 0.33636
# [GRU-F2] Early stopping at epoch 93
# [GRU-F3] [Epoch 001] train_loss: 0.40434  val_loss: 0.92470
# [GRU-F3] [Epoch 002] train_loss: 0.36046  val_loss: 0.82793
# [GRU-F3] [Epoch 003] train_loss: 0.35215  val_loss: 0.74268
# [GRU-F3] [Epoch 004] train_loss: 0.34803  val_loss: 0.68212
# [GRU-F3] [Epoch 005] train_loss: 0.34398  val_loss: 0.65033
# [GRU-F3] [Epoch 006] train_loss: 0.34011  val_loss: 0.63087
# [GRU-F3] [Epoch 007] train_loss: 0.33634  val_loss: 0.61421
# [GRU-F3] [Epoch 008] train_loss: 0.33375  val_loss: 0.59861
# [GRU-F3] [Epoch 009] train_loss: 0.33001  val_loss: 0.58381
# [GRU-F3] [Epoch 010] train_loss: 0.32729  val_loss: 0.57016
# [GRU-F3] [Epoch 011] train_loss: 0.32400  val_loss: 0.55998
# [GRU-F3] [Epoch 012] train_loss: 0.32057  val_loss: 0.54999
# [GRU-F3] [Epoch 013] train_loss: 0.31673  val_loss: 0.54133
# [GRU-F3] [Epoch 014] train_loss: 0.31249  val_loss: 0.53289
# [GRU-F3] [Epoch 015] train_loss: 0.30687  val_loss: 0.52354
# [GRU-F3] [Epoch 016] train_loss: 0.30184  val_loss: 0.51347
# [GRU-F3] [Epoch 017] train_loss: 0.29633  val_loss: 0.50275
# [GRU-F3] [Epoch 018] train_loss: 0.29037  val_loss: 0.49150
# [GRU-F3] [Epoch 019] train_loss: 0.28465  val_loss: 0.47991
# [GRU-F3] [Epoch 020] train_loss: 0.27895  val_loss: 0.46921
# [GRU-F3] [Epoch 021] train_loss: 0.27251  val_loss: 0.45878
# [GRU-F3] [Epoch 022] train_loss: 0.26694  val_loss: 0.44894
# [GRU-F3] [Epoch 023] train_loss: 0.26192  val_loss: 0.44030
# [GRU-F3] [Epoch 024] train_loss: 0.25656  val_loss: 0.43271
# [GRU-F3] [Epoch 025] train_loss: 0.25150  val_loss: 0.42621
# [GRU-F3] [Epoch 026] train_loss: 0.24676  val_loss: 0.42094
# [GRU-F3] [Epoch 027] train_loss: 0.24234  val_loss: 0.41656
# [GRU-F3] [Epoch 028] train_loss: 0.23761  val_loss: 0.41272
# [GRU-F3] [Epoch 029] train_loss: 0.23454  val_loss: 0.40946
# [GRU-F3] [Epoch 030] train_loss: 0.22973  val_loss: 0.40670
# [GRU-F3] [Epoch 031] train_loss: 0.22621  val_loss: 0.40435
# [GRU-F3] [Epoch 032] train_loss: 0.22308  val_loss: 0.40219
# [GRU-F3] [Epoch 033] train_loss: 0.21994  val_loss: 0.39986
# [GRU-F3] [Epoch 034] train_loss: 0.21653  val_loss: 0.39732
# [GRU-F3] [Epoch 035] train_loss: 0.21387  val_loss: 0.39496
# [GRU-F3] [Epoch 036] train_loss: 0.21169  val_loss: 0.39260
# [GRU-F3] [Epoch 037] train_loss: 0.20897  val_loss: 0.39011
# [GRU-F3] [Epoch 038] train_loss: 0.20667  val_loss: 0.38746
# [GRU-F3] [Epoch 039] train_loss: 0.20405  val_loss: 0.38505
# [GRU-F3] [Epoch 040] train_loss: 0.20185  val_loss: 0.38283
# [GRU-F3] [Epoch 041] train_loss: 0.19966  val_loss: 0.38071
# [GRU-F3] [Epoch 042] train_loss: 0.19805  val_loss: 0.37863
# [GRU-F3] [Epoch 043] train_loss: 0.19587  val_loss: 0.37661
# [GRU-F3] [Epoch 044] train_loss: 0.19432  val_loss: 0.37449
# [GRU-F3] [Epoch 045] train_loss: 0.19254  val_loss: 0.37235
# [GRU-F3] [Epoch 046] train_loss: 0.19086  val_loss: 0.37029
# [GRU-F3] [Epoch 047] train_loss: 0.18919  val_loss: 0.36823
# [GRU-F3] [Epoch 048] train_loss: 0.18785  val_loss: 0.36624
# [GRU-F3] [Epoch 049] train_loss: 0.18639  val_loss: 0.36434
# [GRU-F3] [Epoch 050] train_loss: 0.18473  val_loss: 0.36235
# [GRU-F3] [Epoch 051] train_loss: 0.18344  val_loss: 0.36044
# [GRU-F3] [Epoch 052] train_loss: 0.18198  val_loss: 0.35858
# [GRU-F3] [Epoch 053] train_loss: 0.18096  val_loss: 0.35681
# [GRU-F3] [Epoch 054] train_loss: 0.17964  val_loss: 0.35505
# [GRU-F3] [Epoch 055] train_loss: 0.17877  val_loss: 0.35323
# [GRU-F3] [Epoch 056] train_loss: 0.17762  val_loss: 0.35149
# [GRU-F3] [Epoch 057] train_loss: 0.17644  val_loss: 0.34986
# [GRU-F3] [Epoch 058] train_loss: 0.17522  val_loss: 0.34838
# [GRU-F3] [Epoch 059] train_loss: 0.17426  val_loss: 0.34696
# [GRU-F3] [Epoch 060] train_loss: 0.17311  val_loss: 0.34564
# [GRU-F3] [Epoch 061] train_loss: 0.17254  val_loss: 0.34439
# [GRU-F3] [Epoch 062] train_loss: 0.17146  val_loss: 0.34325
# [GRU-F3] [Epoch 063] train_loss: 0.17047  val_loss: 0.34214
# [GRU-F3] [Epoch 064] train_loss: 0.16962  val_loss: 0.34108
# [GRU-F3] [Epoch 065] train_loss: 0.16879  val_loss: 0.34009
# [GRU-F3] [Epoch 066] train_loss: 0.16824  val_loss: 0.33918
# [GRU-F3] [Epoch 067] train_loss: 0.16731  val_loss: 0.33828
# [GRU-F3] [Epoch 068] train_loss: 0.16665  val_loss: 0.33744
# [GRU-F3] [Epoch 069] train_loss: 0.16609  val_loss: 0.33668
# [GRU-F3] [Epoch 070] train_loss: 0.16538  val_loss: 0.33602
# [GRU-F3] [Epoch 071] train_loss: 0.16468  val_loss: 0.33537
# [GRU-F3] [Epoch 072] train_loss: 0.16396  val_loss: 0.33476
# [GRU-F3] [Epoch 073] train_loss: 0.16353  val_loss: 0.33421
# [GRU-F3] [Epoch 074] train_loss: 0.16285  val_loss: 0.33366
# [GRU-F3] [Epoch 075] train_loss: 0.16220  val_loss: 0.33319
# [GRU-F3] [Epoch 076] train_loss: 0.16181  val_loss: 0.33276
# [GRU-F3] [Epoch 077] train_loss: 0.16132  val_loss: 0.33227
# [GRU-F3] [Epoch 078] train_loss: 0.16063  val_loss: 0.33186
# [GRU-F3] [Epoch 079] train_loss: 0.16044  val_loss: 0.33146
# [GRU-F3] [Epoch 080] train_loss: 0.15989  val_loss: 0.33111
# [GRU-F3] [Epoch 081] train_loss: 0.15948  val_loss: 0.33074
# [GRU-F3] [Epoch 082] train_loss: 0.15897  val_loss: 0.33051
# [GRU-F3] [Epoch 083] train_loss: 0.15873  val_loss: 0.33022
# [GRU-F3] [Epoch 084] train_loss: 0.15850  val_loss: 0.32997
# [GRU-F3] [Epoch 085] train_loss: 0.15823  val_loss: 0.32975
# [GRU-F3] [Epoch 086] train_loss: 0.15775  val_loss: 0.32952
# [GRU-F3] [Epoch 087] train_loss: 0.15770  val_loss: 0.32930
# [GRU-F3] [Epoch 088] train_loss: 0.15733  val_loss: 0.32912
# [GRU-F3] [Epoch 089] train_loss: 0.15714  val_loss: 0.32895
# [GRU-F3] [Epoch 090] train_loss: 0.15700  val_loss: 0.32881
# [GRU-F3] [Epoch 091] train_loss: 0.15701  val_loss: 0.32867
# [GRU-F3] [Epoch 092] train_loss: 0.15679  val_loss: 0.32855
# [GRU-F3] [Epoch 093] train_loss: 0.15662  val_loss: 0.32845
# [GRU-F3] [Epoch 094] train_loss: 0.15665  val_loss: 0.32835
# [GRU-F3] [Epoch 095] train_loss: 0.15631  val_loss: 0.32828
# [GRU-F3] [Epoch 096] train_loss: 0.15631  val_loss: 0.32822
# [GRU-F3] [Epoch 097] train_loss: 0.15622  val_loss: 0.32815
# [GRU-F3] [Epoch 098] train_loss: 0.15627  val_loss: 0.32808
# [GRU-F3] [Epoch 099] train_loss: 0.15620  val_loss: 0.32803
# [GRU-F3] [Epoch 100] train_loss: 0.15621  val_loss: 0.32798
# [VAL(avg over folds)] GRU=0.33995
# 📚 N-HiTS 학습...
# [N-HiTS-F1] [Epoch 001] train_loss: 0.42408  val_loss: 0.90575
# [N-HiTS-F1] [Epoch 002] train_loss: 0.36589  val_loss: 0.85157
# [N-HiTS-F1] [Epoch 003] train_loss: 0.35678  val_loss: 0.78962
# [N-HiTS-F1] [Epoch 004] train_loss: 0.35307  val_loss: 0.72161
# [N-HiTS-F1] [Epoch 005] train_loss: 0.35034  val_loss: 0.65157
# [N-HiTS-F1] [Epoch 006] train_loss: 0.34657  val_loss: 0.59060
# [N-HiTS-F1] [Epoch 007] train_loss: 0.34404  val_loss: 0.54322
# [N-HiTS-F1] [Epoch 008] train_loss: 0.34173  val_loss: 0.50898
# [N-HiTS-F1] [Epoch 009] train_loss: 0.34062  val_loss: 0.48483
# [N-HiTS-F1] [Epoch 010] train_loss: 0.33811  val_loss: 0.46590
# [N-HiTS-F1] [Epoch 011] train_loss: 0.33695  val_loss: 0.45162
# [N-HiTS-F1] [Epoch 012] train_loss: 0.33591  val_loss: 0.44125
# [N-HiTS-F1] [Epoch 013] train_loss: 0.33413  val_loss: 0.43334
# [N-HiTS-F1] [Epoch 014] train_loss: 0.33363  val_loss: 0.42769
# [N-HiTS-F1] [Epoch 015] train_loss: 0.33248  val_loss: 0.42344
# [N-HiTS-F1] [Epoch 016] train_loss: 0.33183  val_loss: 0.42004
# [N-HiTS-F1] [Epoch 017] train_loss: 0.33108  val_loss: 0.41714
# [N-HiTS-F1] [Epoch 018] train_loss: 0.32984  val_loss: 0.41490
# [N-HiTS-F1] [Epoch 019] train_loss: 0.32958  val_loss: 0.41309
# [N-HiTS-F1] [Epoch 020] train_loss: 0.32866  val_loss: 0.41157
# [N-HiTS-F1] [Epoch 021] train_loss: 0.32810  val_loss: 0.41053
# [N-HiTS-F1] [Epoch 022] train_loss: 0.32757  val_loss: 0.40978
# [N-HiTS-F1] [Epoch 023] train_loss: 0.32748  val_loss: 0.40917
# [N-HiTS-F1] [Epoch 024] train_loss: 0.32642  val_loss: 0.40859
# [N-HiTS-F1] [Epoch 025] train_loss: 0.32595  val_loss: 0.40792
# [N-HiTS-F1] [Epoch 026] train_loss: 0.32560  val_loss: 0.40731
# [N-HiTS-F1] [Epoch 027] train_loss: 0.32490  val_loss: 0.40685
# [N-HiTS-F1] [Epoch 028] train_loss: 0.32459  val_loss: 0.40634
# [N-HiTS-F1] [Epoch 029] train_loss: 0.32379  val_loss: 0.40581
# [N-HiTS-F1] [Epoch 030] train_loss: 0.32338  val_loss: 0.40531
# [N-HiTS-F1] [Epoch 031] train_loss: 0.32272  val_loss: 0.40475
# [N-HiTS-F1] [Epoch 032] train_loss: 0.32305  val_loss: 0.40420
# [N-HiTS-F1] [Epoch 033] train_loss: 0.32180  val_loss: 0.40367
# [N-HiTS-F1] [Epoch 034] train_loss: 0.32181  val_loss: 0.40313
# [N-HiTS-F1] [Epoch 035] train_loss: 0.32198  val_loss: 0.40266
# [N-HiTS-F1] [Epoch 036] train_loss: 0.32123  val_loss: 0.40216
# [N-HiTS-F1] [Epoch 037] train_loss: 0.32047  val_loss: 0.40168
# [N-HiTS-F1] [Epoch 038] train_loss: 0.32036  val_loss: 0.40117
# [N-HiTS-F1] [Epoch 039] train_loss: 0.31969  val_loss: 0.40071
# [N-HiTS-F1] [Epoch 040] train_loss: 0.31956  val_loss: 0.40010
# [N-HiTS-F1] [Epoch 041] train_loss: 0.31862  val_loss: 0.39966
# [N-HiTS-F1] [Epoch 042] train_loss: 0.31877  val_loss: 0.39923
# [N-HiTS-F1] [Epoch 043] train_loss: 0.31834  val_loss: 0.39883
# [N-HiTS-F1] [Epoch 044] train_loss: 0.31777  val_loss: 0.39853
# [N-HiTS-F1] [Epoch 045] train_loss: 0.31813  val_loss: 0.39815
# [N-HiTS-F1] [Epoch 046] train_loss: 0.31742  val_loss: 0.39785
# [N-HiTS-F1] [Epoch 047] train_loss: 0.31701  val_loss: 0.39744
# [N-HiTS-F1] [Epoch 048] train_loss: 0.31750  val_loss: 0.39710
# [N-HiTS-F1] [Epoch 049] train_loss: 0.31680  val_loss: 0.39692
# [N-HiTS-F1] [Epoch 050] train_loss: 0.31591  val_loss: 0.39676
# [N-HiTS-F1] [Epoch 051] train_loss: 0.31543  val_loss: 0.39659
# [N-HiTS-F1] [Epoch 052] train_loss: 0.31567  val_loss: 0.39642
# [N-HiTS-F1] [Epoch 053] train_loss: 0.31553  val_loss: 0.39626
# [N-HiTS-F1] [Epoch 054] train_loss: 0.31505  val_loss: 0.39611
# [N-HiTS-F1] [Epoch 055] train_loss: 0.31436  val_loss: 0.39597
# [N-HiTS-F1] [Epoch 056] train_loss: 0.31429  val_loss: 0.39583
# [N-HiTS-F1] [Epoch 057] train_loss: 0.31388  val_loss: 0.39564
# [N-HiTS-F1] [Epoch 058] train_loss: 0.31360  val_loss: 0.39552
# [N-HiTS-F1] [Epoch 059] train_loss: 0.31338  val_loss: 0.39543
# [N-HiTS-F1] [Epoch 060] train_loss: 0.31305  val_loss: 0.39534
# [N-HiTS-F1] [Epoch 061] train_loss: 0.31275  val_loss: 0.39534
# [N-HiTS-F1] [Epoch 062] train_loss: 0.31250  val_loss: 0.39522
# [N-HiTS-F1] [Epoch 063] train_loss: 0.31227  val_loss: 0.39521
# [N-HiTS-F1] [Epoch 064] train_loss: 0.31190  val_loss: 0.39523
# [N-HiTS-F1] [Epoch 065] train_loss: 0.31177  val_loss: 0.39522
# [N-HiTS-F1] [Epoch 066] train_loss: 0.31132  val_loss: 0.39526
# [N-HiTS-F1] [Epoch 067] train_loss: 0.31107  val_loss: 0.39528
# [N-HiTS-F1] [Epoch 068] train_loss: 0.31092  val_loss: 0.39524
# [N-HiTS-F1] [Epoch 069] train_loss: 0.31088  val_loss: 0.39523
# [N-HiTS-F1] [Epoch 070] train_loss: 0.31046  val_loss: 0.39515
# [N-HiTS-F1] [Epoch 071] train_loss: 0.31001  val_loss: 0.39512
# [N-HiTS-F1] [Epoch 072] train_loss: 0.30994  val_loss: 0.39512
# [N-HiTS-F1] [Epoch 073] train_loss: 0.30951  val_loss: 0.39511
# [N-HiTS-F1] [Epoch 074] train_loss: 0.30979  val_loss: 0.39509
# [N-HiTS-F1] [Epoch 075] train_loss: 0.30925  val_loss: 0.39509
# [N-HiTS-F1] [Epoch 076] train_loss: 0.30912  val_loss: 0.39513
# [N-HiTS-F1] [Epoch 077] train_loss: 0.30882  val_loss: 0.39514
# [N-HiTS-F1] [Epoch 078] train_loss: 0.30860  val_loss: 0.39514
# [N-HiTS-F1] [Epoch 079] train_loss: 0.30881  val_loss: 0.39515
# [N-HiTS-F1] [Epoch 080] train_loss: 0.30873  val_loss: 0.39516
# [N-HiTS-F1] [Epoch 081] train_loss: 0.30816  val_loss: 0.39514
# [N-HiTS-F1] [Epoch 082] train_loss: 0.30817  val_loss: 0.39513
# [N-HiTS-F1] [Epoch 083] train_loss: 0.30811  val_loss: 0.39512
# [N-HiTS-F1] [Epoch 084] train_loss: 0.30764  val_loss: 0.39511
# [N-HiTS-F1] [Epoch 085] train_loss: 0.30767  val_loss: 0.39511
# [N-HiTS-F1] [Epoch 086] train_loss: 0.30741  val_loss: 0.39510
# [N-HiTS-F1] Early stopping at epoch 86
# [N-HiTS-F2] [Epoch 001] train_loss: 0.42460  val_loss: 0.88144
# [N-HiTS-F2] [Epoch 002] train_loss: 0.36579  val_loss: 0.82767
# [N-HiTS-F2] [Epoch 003] train_loss: 0.35680  val_loss: 0.76991
# [N-HiTS-F2] [Epoch 004] train_loss: 0.35281  val_loss: 0.70503
# [N-HiTS-F2] [Epoch 005] train_loss: 0.35016  val_loss: 0.64119
# [N-HiTS-F2] [Epoch 006] train_loss: 0.34704  val_loss: 0.58704
# [N-HiTS-F2] [Epoch 007] train_loss: 0.34438  val_loss: 0.54553
# [N-HiTS-F2] [Epoch 008] train_loss: 0.34229  val_loss: 0.51430
# [N-HiTS-F2] [Epoch 009] train_loss: 0.34023  val_loss: 0.49011
# [N-HiTS-F2] [Epoch 010] train_loss: 0.33849  val_loss: 0.47186
# [N-HiTS-F2] [Epoch 011] train_loss: 0.33692  val_loss: 0.45767
# [N-HiTS-F2] [Epoch 012] train_loss: 0.33568  val_loss: 0.44634
# [N-HiTS-F2] [Epoch 013] train_loss: 0.33507  val_loss: 0.43718
# [N-HiTS-F2] [Epoch 014] train_loss: 0.33369  val_loss: 0.42968
# [N-HiTS-F2] [Epoch 015] train_loss: 0.33270  val_loss: 0.42374
# [N-HiTS-F2] [Epoch 016] train_loss: 0.33195  val_loss: 0.41923
# [N-HiTS-F2] [Epoch 017] train_loss: 0.33118  val_loss: 0.41548
# [N-HiTS-F2] [Epoch 018] train_loss: 0.33020  val_loss: 0.41228
# [N-HiTS-F2] [Epoch 019] train_loss: 0.32968  val_loss: 0.40964
# [N-HiTS-F2] [Epoch 020] train_loss: 0.32850  val_loss: 0.40739
# [N-HiTS-F2] [Epoch 021] train_loss: 0.32823  val_loss: 0.40557
# [N-HiTS-F2] [Epoch 022] train_loss: 0.32737  val_loss: 0.40416
# [N-HiTS-F2] [Epoch 023] train_loss: 0.32707  val_loss: 0.40294
# [N-HiTS-F2] [Epoch 024] train_loss: 0.32651  val_loss: 0.40189
# [N-HiTS-F2] [Epoch 025] train_loss: 0.32642  val_loss: 0.40080
# [N-HiTS-F2] [Epoch 026] train_loss: 0.32573  val_loss: 0.39986
# [N-HiTS-F2] [Epoch 027] train_loss: 0.32527  val_loss: 0.39887
# [N-HiTS-F2] [Epoch 028] train_loss: 0.32425  val_loss: 0.39785
# [N-HiTS-F2] [Epoch 029] train_loss: 0.32392  val_loss: 0.39678
# [N-HiTS-F2] [Epoch 030] train_loss: 0.32349  val_loss: 0.39584
# [N-HiTS-F2] [Epoch 031] train_loss: 0.32329  val_loss: 0.39496
# [N-HiTS-F2] [Epoch 032] train_loss: 0.32304  val_loss: 0.39401
# [N-HiTS-F2] [Epoch 033] train_loss: 0.32258  val_loss: 0.39313
# [N-HiTS-F2] [Epoch 034] train_loss: 0.32212  val_loss: 0.39227
# [N-HiTS-F2] [Epoch 035] train_loss: 0.32179  val_loss: 0.39133
# [N-HiTS-F2] [Epoch 036] train_loss: 0.32127  val_loss: 0.39047
# [N-HiTS-F2] [Epoch 037] train_loss: 0.32139  val_loss: 0.38963
# [N-HiTS-F2] [Epoch 038] train_loss: 0.32048  val_loss: 0.38887
# [N-HiTS-F2] [Epoch 039] train_loss: 0.32010  val_loss: 0.38824
# [N-HiTS-F2] [Epoch 040] train_loss: 0.31962  val_loss: 0.38764
# [N-HiTS-F2] [Epoch 041] train_loss: 0.31928  val_loss: 0.38713
# [N-HiTS-F2] [Epoch 042] train_loss: 0.31953  val_loss: 0.38666
# [N-HiTS-F2] [Epoch 043] train_loss: 0.31857  val_loss: 0.38622
# [N-HiTS-F2] [Epoch 044] train_loss: 0.31813  val_loss: 0.38593
# [N-HiTS-F2] [Epoch 045] train_loss: 0.31818  val_loss: 0.38562
# [N-HiTS-F2] [Epoch 046] train_loss: 0.31774  val_loss: 0.38532
# [N-HiTS-F2] [Epoch 047] train_loss: 0.31720  val_loss: 0.38513
# [N-HiTS-F2] [Epoch 048] train_loss: 0.31685  val_loss: 0.38500
# [N-HiTS-F2] [Epoch 049] train_loss: 0.31684  val_loss: 0.38486
# [N-HiTS-F2] [Epoch 050] train_loss: 0.31609  val_loss: 0.38481
# [N-HiTS-F2] [Epoch 051] train_loss: 0.31614  val_loss: 0.38482
# [N-HiTS-F2] [Epoch 052] train_loss: 0.31559  val_loss: 0.38479
# [N-HiTS-F2] [Epoch 053] train_loss: 0.31553  val_loss: 0.38483
# [N-HiTS-F2] [Epoch 054] train_loss: 0.31500  val_loss: 0.38494
# [N-HiTS-F2] [Epoch 055] train_loss: 0.31489  val_loss: 0.38510
# [N-HiTS-F2] [Epoch 056] train_loss: 0.31432  val_loss: 0.38526
# [N-HiTS-F2] [Epoch 057] train_loss: 0.31386  val_loss: 0.38542
# [N-HiTS-F2] [Epoch 058] train_loss: 0.31372  val_loss: 0.38560
# [N-HiTS-F2] [Epoch 059] train_loss: 0.31399  val_loss: 0.38582
# [N-HiTS-F2] [Epoch 060] train_loss: 0.31285  val_loss: 0.38610
# [N-HiTS-F2] [Epoch 061] train_loss: 0.31296  val_loss: 0.38634
# [N-HiTS-F2] [Epoch 062] train_loss: 0.31248  val_loss: 0.38662
# [N-HiTS-F2] [Epoch 063] train_loss: 0.31254  val_loss: 0.38690
# [N-HiTS-F2] [Epoch 064] train_loss: 0.31213  val_loss: 0.38716
# [N-HiTS-F2] Early stopping at epoch 64
# [N-HiTS-F3] [Epoch 001] train_loss: 0.42584  val_loss: 0.88709
# [N-HiTS-F3] [Epoch 002] train_loss: 0.36496  val_loss: 0.83011
# [N-HiTS-F3] [Epoch 003] train_loss: 0.35730  val_loss: 0.77145
# [N-HiTS-F3] [Epoch 004] train_loss: 0.35329  val_loss: 0.70342
# [N-HiTS-F3] [Epoch 005] train_loss: 0.34990  val_loss: 0.63540
# [N-HiTS-F3] [Epoch 006] train_loss: 0.34744  val_loss: 0.57811
# [N-HiTS-F3] [Epoch 007] train_loss: 0.34435  val_loss: 0.53322
# [N-HiTS-F3] [Epoch 008] train_loss: 0.34251  val_loss: 0.50112
# [N-HiTS-F3] [Epoch 009] train_loss: 0.33994  val_loss: 0.47938
# [N-HiTS-F3] [Epoch 010] train_loss: 0.33894  val_loss: 0.46370
# [N-HiTS-F3] [Epoch 011] train_loss: 0.33701  val_loss: 0.45070
# [N-HiTS-F3] [Epoch 012] train_loss: 0.33627  val_loss: 0.44046
# [N-HiTS-F3] [Epoch 013] train_loss: 0.33481  val_loss: 0.43294
# [N-HiTS-F3] [Epoch 014] train_loss: 0.33396  val_loss: 0.42724
# [N-HiTS-F3] [Epoch 015] train_loss: 0.33354  val_loss: 0.42260
# [N-HiTS-F3] [Epoch 016] train_loss: 0.33224  val_loss: 0.41883
# [N-HiTS-F3] [Epoch 017] train_loss: 0.33101  val_loss: 0.41543
# [N-HiTS-F3] [Epoch 018] train_loss: 0.33067  val_loss: 0.41199
# [N-HiTS-F3] [Epoch 019] train_loss: 0.32973  val_loss: 0.40870
# [N-HiTS-F3] [Epoch 020] train_loss: 0.32888  val_loss: 0.40575
# [N-HiTS-F3] [Epoch 021] train_loss: 0.32907  val_loss: 0.40315
# [N-HiTS-F3] [Epoch 022] train_loss: 0.32779  val_loss: 0.40075
# [N-HiTS-F3] [Epoch 023] train_loss: 0.32741  val_loss: 0.39877
# [N-HiTS-F3] [Epoch 024] train_loss: 0.32684  val_loss: 0.39698
# [N-HiTS-F3] [Epoch 025] train_loss: 0.32641  val_loss: 0.39543
# [N-HiTS-F3] [Epoch 026] train_loss: 0.32630  val_loss: 0.39395
# [N-HiTS-F3] [Epoch 027] train_loss: 0.32510  val_loss: 0.39269
# [N-HiTS-F3] [Epoch 028] train_loss: 0.32464  val_loss: 0.39159
# [N-HiTS-F3] [Epoch 029] train_loss: 0.32436  val_loss: 0.39058
# [N-HiTS-F3] [Epoch 030] train_loss: 0.32396  val_loss: 0.38964
# [N-HiTS-F3] [Epoch 031] train_loss: 0.32355  val_loss: 0.38871
# [N-HiTS-F3] [Epoch 032] train_loss: 0.32327  val_loss: 0.38770
# [N-HiTS-F3] [Epoch 033] train_loss: 0.32264  val_loss: 0.38674
# [N-HiTS-F3] [Epoch 034] train_loss: 0.32209  val_loss: 0.38587
# [N-HiTS-F3] [Epoch 035] train_loss: 0.32116  val_loss: 0.38504
# [N-HiTS-F3] [Epoch 036] train_loss: 0.32155  val_loss: 0.38430
# [N-HiTS-F3] [Epoch 037] train_loss: 0.32125  val_loss: 0.38354
# [N-HiTS-F3] [Epoch 038] train_loss: 0.32092  val_loss: 0.38290
# [N-HiTS-F3] [Epoch 039] train_loss: 0.32055  val_loss: 0.38226
# [N-HiTS-F3] [Epoch 040] train_loss: 0.31999  val_loss: 0.38173
# [N-HiTS-F3] [Epoch 041] train_loss: 0.31988  val_loss: 0.38121
# [N-HiTS-F3] [Epoch 042] train_loss: 0.31942  val_loss: 0.38074
# [N-HiTS-F3] [Epoch 043] train_loss: 0.31934  val_loss: 0.38030
# [N-HiTS-F3] [Epoch 044] train_loss: 0.31849  val_loss: 0.37991
# [N-HiTS-F3] [Epoch 045] train_loss: 0.31836  val_loss: 0.37958
# [N-HiTS-F3] [Epoch 046] train_loss: 0.31800  val_loss: 0.37928
# [N-HiTS-F3] [Epoch 047] train_loss: 0.31746  val_loss: 0.37906
# [N-HiTS-F3] [Epoch 048] train_loss: 0.31704  val_loss: 0.37881
# [N-HiTS-F3] [Epoch 049] train_loss: 0.31700  val_loss: 0.37854
# [N-HiTS-F3] [Epoch 050] train_loss: 0.31673  val_loss: 0.37828
# [N-HiTS-F3] [Epoch 051] train_loss: 0.31661  val_loss: 0.37808
# [N-HiTS-F3] [Epoch 052] train_loss: 0.31587  val_loss: 0.37796
# [N-HiTS-F3] [Epoch 053] train_loss: 0.31573  val_loss: 0.37781
# [N-HiTS-F3] [Epoch 054] train_loss: 0.31511  val_loss: 0.37763
# [N-HiTS-F3] [Epoch 055] train_loss: 0.31530  val_loss: 0.37744
# [N-HiTS-F3] [Epoch 056] train_loss: 0.31478  val_loss: 0.37731
# [N-HiTS-F3] [Epoch 057] train_loss: 0.31457  val_loss: 0.37713
# [N-HiTS-F3] [Epoch 058] train_loss: 0.31435  val_loss: 0.37703
# [N-HiTS-F3] [Epoch 059] train_loss: 0.31417  val_loss: 0.37690
# [N-HiTS-F3] [Epoch 060] train_loss: 0.31381  val_loss: 0.37686
# [N-HiTS-F3] [Epoch 061] train_loss: 0.31331  val_loss: 0.37675
# [N-HiTS-F3] [Epoch 062] train_loss: 0.31307  val_loss: 0.37667
# [N-HiTS-F3] [Epoch 063] train_loss: 0.31276  val_loss: 0.37661
# [N-HiTS-F3] [Epoch 064] train_loss: 0.31230  val_loss: 0.37653
# [N-HiTS-F3] [Epoch 065] train_loss: 0.31198  val_loss: 0.37646
# [N-HiTS-F3] [Epoch 066] train_loss: 0.31203  val_loss: 0.37646
# [N-HiTS-F3] [Epoch 067] train_loss: 0.31141  val_loss: 0.37646
# [N-HiTS-F3] [Epoch 068] train_loss: 0.31150  val_loss: 0.37644
# [N-HiTS-F3] [Epoch 069] train_loss: 0.31117  val_loss: 0.37647
# [N-HiTS-F3] [Epoch 070] train_loss: 0.31090  val_loss: 0.37648
# [N-HiTS-F3] [Epoch 071] train_loss: 0.31082  val_loss: 0.37650
# [N-HiTS-F3] [Epoch 072] train_loss: 0.31071  val_loss: 0.37655
# [N-HiTS-F3] [Epoch 073] train_loss: 0.31027  val_loss: 0.37659
# [N-HiTS-F3] [Epoch 074] train_loss: 0.31041  val_loss: 0.37664
# [N-HiTS-F3] [Epoch 075] train_loss: 0.30973  val_loss: 0.37665
# [N-HiTS-F3] [Epoch 076] train_loss: 0.30967  val_loss: 0.37667
# [N-HiTS-F3] [Epoch 077] train_loss: 0.30951  val_loss: 0.37670
# [N-HiTS-F3] [Epoch 078] train_loss: 0.30929  val_loss: 0.37674
# [N-HiTS-F3] [Epoch 079] train_loss: 0.30927  val_loss: 0.37678
# [N-HiTS-F3] [Epoch 080] train_loss: 0.30885  val_loss: 0.37680
# [N-HiTS-F3] Early stopping at epoch 80
# [VAL(avg over folds)] N-HiTS=0.38544
# 📚 PatchTST 학습...
# [PatchTST-F1] [Epoch 001] train_loss: 0.41271  val_loss: 0.97632
# [PatchTST-F1] [Epoch 002] train_loss: 0.36796  val_loss: 0.78309
# [PatchTST-F1] [Epoch 003] train_loss: 0.35701  val_loss: 0.65803
# [PatchTST-F1] [Epoch 004] train_loss: 0.35261  val_loss: 0.59782
# [PatchTST-F1] [Epoch 005] train_loss: 0.34793  val_loss: 0.56606
# [PatchTST-F1] [Epoch 006] train_loss: 0.34391  val_loss: 0.54727
# [PatchTST-F1] [Epoch 007] train_loss: 0.34080  val_loss: 0.52990
# [PatchTST-F1] [Epoch 008] train_loss: 0.33862  val_loss: 0.51429
# [PatchTST-F1] [Epoch 009] train_loss: 0.33676  val_loss: 0.49951
# [PatchTST-F1] [Epoch 010] train_loss: 0.33478  val_loss: 0.48686
# [PatchTST-F1] [Epoch 011] train_loss: 0.33319  val_loss: 0.47545
# [PatchTST-F1] [Epoch 012] train_loss: 0.33276  val_loss: 0.46556
# [PatchTST-F1] [Epoch 013] train_loss: 0.33106  val_loss: 0.45607
# [PatchTST-F1] [Epoch 014] train_loss: 0.33049  val_loss: 0.44840
# [PatchTST-F1] [Epoch 015] train_loss: 0.32978  val_loss: 0.44196
# [PatchTST-F1] [Epoch 016] train_loss: 0.32845  val_loss: 0.43607
# [PatchTST-F1] [Epoch 017] train_loss: 0.32807  val_loss: 0.43087
# [PatchTST-F1] [Epoch 018] train_loss: 0.32693  val_loss: 0.42651
# [PatchTST-F1] [Epoch 019] train_loss: 0.32648  val_loss: 0.42257
# [PatchTST-F1] [Epoch 020] train_loss: 0.32577  val_loss: 0.41913
# [PatchTST-F1] [Epoch 021] train_loss: 0.32489  val_loss: 0.41626
# [PatchTST-F1] [Epoch 022] train_loss: 0.32409  val_loss: 0.41367
# [PatchTST-F1] [Epoch 023] train_loss: 0.32383  val_loss: 0.41121
# [PatchTST-F1] [Epoch 024] train_loss: 0.32340  val_loss: 0.40918
# [PatchTST-F1] [Epoch 025] train_loss: 0.32273  val_loss: 0.40753
# [PatchTST-F1] [Epoch 026] train_loss: 0.32179  val_loss: 0.40614
# [PatchTST-F1] [Epoch 027] train_loss: 0.32179  val_loss: 0.40478
# [PatchTST-F1] [Epoch 028] train_loss: 0.32079  val_loss: 0.40357
# [PatchTST-F1] [Epoch 029] train_loss: 0.32053  val_loss: 0.40281
# [PatchTST-F1] [Epoch 030] train_loss: 0.32055  val_loss: 0.40199
# [PatchTST-F1] [Epoch 031] train_loss: 0.31958  val_loss: 0.40100
# [PatchTST-F1] [Epoch 032] train_loss: 0.31863  val_loss: 0.40005
# [PatchTST-F1] [Epoch 033] train_loss: 0.31828  val_loss: 0.39916
# [PatchTST-F1] [Epoch 034] train_loss: 0.31786  val_loss: 0.39813
# [PatchTST-F1] [Epoch 035] train_loss: 0.31687  val_loss: 0.39707
# [PatchTST-F1] [Epoch 036] train_loss: 0.31657  val_loss: 0.39616
# [PatchTST-F1] [Epoch 037] train_loss: 0.31600  val_loss: 0.39548
# [PatchTST-F1] [Epoch 038] train_loss: 0.31545  val_loss: 0.39482
# [PatchTST-F1] [Epoch 039] train_loss: 0.31539  val_loss: 0.39426
# [PatchTST-F1] [Epoch 040] train_loss: 0.31466  val_loss: 0.39376
# [PatchTST-F1] [Epoch 041] train_loss: 0.31372  val_loss: 0.39333
# [PatchTST-F1] [Epoch 042] train_loss: 0.31389  val_loss: 0.39290
# [PatchTST-F1] [Epoch 043] train_loss: 0.31311  val_loss: 0.39243
# [PatchTST-F1] [Epoch 044] train_loss: 0.31273  val_loss: 0.39211
# [PatchTST-F1] [Epoch 045] train_loss: 0.31217  val_loss: 0.39183
# [PatchTST-F1] [Epoch 046] train_loss: 0.31162  val_loss: 0.39166
# [PatchTST-F1] [Epoch 047] train_loss: 0.31132  val_loss: 0.39136
# [PatchTST-F1] [Epoch 048] train_loss: 0.31010  val_loss: 0.39132
# [PatchTST-F1] [Epoch 049] train_loss: 0.31006  val_loss: 0.39130
# [PatchTST-F1] [Epoch 050] train_loss: 0.30971  val_loss: 0.39105
# [PatchTST-F1] [Epoch 051] train_loss: 0.30883  val_loss: 0.39085
# [PatchTST-F1] [Epoch 052] train_loss: 0.30827  val_loss: 0.39073
# [PatchTST-F1] [Epoch 053] train_loss: 0.30808  val_loss: 0.39078
# [PatchTST-F1] [Epoch 054] train_loss: 0.30773  val_loss: 0.39073
# [PatchTST-F1] [Epoch 055] train_loss: 0.30742  val_loss: 0.39066
# [PatchTST-F1] [Epoch 056] train_loss: 0.30704  val_loss: 0.39056
# [PatchTST-F1] [Epoch 057] train_loss: 0.30622  val_loss: 0.39048
# [PatchTST-F1] [Epoch 058] train_loss: 0.30561  val_loss: 0.39047
# [PatchTST-F1] [Epoch 059] train_loss: 0.30545  val_loss: 0.39047
# [PatchTST-F1] [Epoch 060] train_loss: 0.30520  val_loss: 0.39058
# [PatchTST-F1] [Epoch 061] train_loss: 0.30424  val_loss: 0.39062
# [PatchTST-F1] [Epoch 062] train_loss: 0.30378  val_loss: 0.39072
# [PatchTST-F1] [Epoch 063] train_loss: 0.30336  val_loss: 0.39086
# [PatchTST-F1] [Epoch 064] train_loss: 0.30319  val_loss: 0.39092
# [PatchTST-F1] [Epoch 065] train_loss: 0.30293  val_loss: 0.39103
# [PatchTST-F1] [Epoch 066] train_loss: 0.30262  val_loss: 0.39119
# [PatchTST-F1] [Epoch 067] train_loss: 0.30181  val_loss: 0.39129
# [PatchTST-F1] [Epoch 068] train_loss: 0.30155  val_loss: 0.39141
# [PatchTST-F1] [Epoch 069] train_loss: 0.30114  val_loss: 0.39138
# [PatchTST-F1] [Epoch 070] train_loss: 0.30063  val_loss: 0.39139
# [PatchTST-F1] [Epoch 071] train_loss: 0.30043  val_loss: 0.39139
# [PatchTST-F1] Early stopping at epoch 71
# [PatchTST-F2] [Epoch 001] train_loss: 0.41502  val_loss: 0.96386
# [PatchTST-F2] [Epoch 002] train_loss: 0.36875  val_loss: 0.78405
# [PatchTST-F2] [Epoch 003] train_loss: 0.35859  val_loss: 0.66368
# [PatchTST-F2] [Epoch 004] train_loss: 0.35292  val_loss: 0.59950
# [PatchTST-F2] [Epoch 005] train_loss: 0.34891  val_loss: 0.56137
# [PatchTST-F2] [Epoch 006] train_loss: 0.34519  val_loss: 0.53576
# [PatchTST-F2] [Epoch 007] train_loss: 0.34042  val_loss: 0.51413
# [PatchTST-F2] [Epoch 008] train_loss: 0.33907  val_loss: 0.49506
# [PatchTST-F2] [Epoch 009] train_loss: 0.33643  val_loss: 0.47897
# [PatchTST-F2] [Epoch 010] train_loss: 0.33547  val_loss: 0.46620
# [PatchTST-F2] [Epoch 011] train_loss: 0.33355  val_loss: 0.45576
# [PatchTST-F2] [Epoch 012] train_loss: 0.33283  val_loss: 0.44691
# [PatchTST-F2] [Epoch 013] train_loss: 0.33115  val_loss: 0.43893
# [PatchTST-F2] [Epoch 014] train_loss: 0.32958  val_loss: 0.43194
# [PatchTST-F2] [Epoch 015] train_loss: 0.32927  val_loss: 0.42652
# [PatchTST-F2] [Epoch 016] train_loss: 0.32763  val_loss: 0.42223
# [PatchTST-F2] [Epoch 017] train_loss: 0.32708  val_loss: 0.41840
# [PatchTST-F2] [Epoch 018] train_loss: 0.32719  val_loss: 0.41522
# [PatchTST-F2] [Epoch 019] train_loss: 0.32581  val_loss: 0.41286
# [PatchTST-F2] [Epoch 020] train_loss: 0.32540  val_loss: 0.41085
# [PatchTST-F2] [Epoch 021] train_loss: 0.32476  val_loss: 0.40907
# [PatchTST-F2] [Epoch 022] train_loss: 0.32408  val_loss: 0.40730
# [PatchTST-F2] [Epoch 023] train_loss: 0.32297  val_loss: 0.40588
# [PatchTST-F2] [Epoch 024] train_loss: 0.32264  val_loss: 0.40447
# [PatchTST-F2] [Epoch 025] train_loss: 0.32199  val_loss: 0.40318
# [PatchTST-F2] [Epoch 026] train_loss: 0.32116  val_loss: 0.40208
# [PatchTST-F2] [Epoch 027] train_loss: 0.32125  val_loss: 0.40113
# [PatchTST-F2] [Epoch 028] train_loss: 0.32056  val_loss: 0.40019
# [PatchTST-F2] [Epoch 029] train_loss: 0.31983  val_loss: 0.39935
# [PatchTST-F2] [Epoch 030] train_loss: 0.31922  val_loss: 0.39868
# [PatchTST-F2] [Epoch 031] train_loss: 0.31870  val_loss: 0.39802
# [PatchTST-F2] [Epoch 032] train_loss: 0.31860  val_loss: 0.39770
# [PatchTST-F2] [Epoch 033] train_loss: 0.31763  val_loss: 0.39734
# [PatchTST-F2] [Epoch 034] train_loss: 0.31703  val_loss: 0.39691
# [PatchTST-F2] [Epoch 035] train_loss: 0.31677  val_loss: 0.39658
# [PatchTST-F2] [Epoch 036] train_loss: 0.31614  val_loss: 0.39623
# [PatchTST-F2] [Epoch 037] train_loss: 0.31575  val_loss: 0.39608
# [PatchTST-F2] [Epoch 038] train_loss: 0.31565  val_loss: 0.39596
# [PatchTST-F2] [Epoch 039] train_loss: 0.31500  val_loss: 0.39589
# [PatchTST-F2] [Epoch 040] train_loss: 0.31464  val_loss: 0.39589
# [PatchTST-F2] [Epoch 041] train_loss: 0.31385  val_loss: 0.39599
# [PatchTST-F2] [Epoch 042] train_loss: 0.31339  val_loss: 0.39612
# [PatchTST-F2] [Epoch 043] train_loss: 0.31324  val_loss: 0.39637
# [PatchTST-F2] [Epoch 044] train_loss: 0.31199  val_loss: 0.39648
# [PatchTST-F2] [Epoch 045] train_loss: 0.31225  val_loss: 0.39672
# [PatchTST-F2] [Epoch 046] train_loss: 0.31143  val_loss: 0.39704
# [PatchTST-F2] [Epoch 047] train_loss: 0.31127  val_loss: 0.39729
# [PatchTST-F2] [Epoch 048] train_loss: 0.31085  val_loss: 0.39783
# [PatchTST-F2] [Epoch 049] train_loss: 0.31025  val_loss: 0.39832
# [PatchTST-F2] [Epoch 050] train_loss: 0.30988  val_loss: 0.39874
# [PatchTST-F2] [Epoch 051] train_loss: 0.30928  val_loss: 0.39925
# [PatchTST-F2] Early stopping at epoch 51
# [PatchTST-F3] [Epoch 001] train_loss: 0.41273  val_loss: 0.98206
# [PatchTST-F3] [Epoch 002] train_loss: 0.36741  val_loss: 0.79847
# [PatchTST-F3] [Epoch 003] train_loss: 0.35818  val_loss: 0.67967
# [PatchTST-F3] [Epoch 004] train_loss: 0.35289  val_loss: 0.61786
# [PatchTST-F3] [Epoch 005] train_loss: 0.34852  val_loss: 0.57851
# [PatchTST-F3] [Epoch 006] train_loss: 0.34441  val_loss: 0.54894
# [PatchTST-F3] [Epoch 007] train_loss: 0.34095  val_loss: 0.52563
# [PatchTST-F3] [Epoch 008] train_loss: 0.33740  val_loss: 0.50569
# [PatchTST-F3] [Epoch 009] train_loss: 0.33610  val_loss: 0.48906
# [PatchTST-F3] [Epoch 010] train_loss: 0.33468  val_loss: 0.47516
# [PatchTST-F3] [Epoch 011] train_loss: 0.33270  val_loss: 0.46351
# [PatchTST-F3] [Epoch 012] train_loss: 0.33180  val_loss: 0.45327
# [PatchTST-F3] [Epoch 013] train_loss: 0.33061  val_loss: 0.44505
# [PatchTST-F3] [Epoch 014] train_loss: 0.33035  val_loss: 0.43816
# [PatchTST-F3] [Epoch 015] train_loss: 0.32885  val_loss: 0.43226
# [PatchTST-F3] [Epoch 016] train_loss: 0.32817  val_loss: 0.42725
# [PatchTST-F3] [Epoch 017] train_loss: 0.32698  val_loss: 0.42275
# [PatchTST-F3] [Epoch 018] train_loss: 0.32667  val_loss: 0.41886
# [PatchTST-F3] [Epoch 019] train_loss: 0.32572  val_loss: 0.41548
# [PatchTST-F3] [Epoch 020] train_loss: 0.32516  val_loss: 0.41265
# [PatchTST-F3] [Epoch 021] train_loss: 0.32421  val_loss: 0.41006
# [PatchTST-F3] [Epoch 022] train_loss: 0.32367  val_loss: 0.40761
# [PatchTST-F3] [Epoch 023] train_loss: 0.32314  val_loss: 0.40550
# [PatchTST-F3] [Epoch 024] train_loss: 0.32242  val_loss: 0.40345
# [PatchTST-F3] [Epoch 025] train_loss: 0.32163  val_loss: 0.40205
# [PatchTST-F3] [Epoch 026] train_loss: 0.32089  val_loss: 0.40075
# [PatchTST-F3] [Epoch 027] train_loss: 0.32082  val_loss: 0.39939
# [PatchTST-F3] [Epoch 028] train_loss: 0.31995  val_loss: 0.39779
# [PatchTST-F3] [Epoch 029] train_loss: 0.31962  val_loss: 0.39649
# [PatchTST-F3] [Epoch 030] train_loss: 0.31856  val_loss: 0.39502
# [PatchTST-F3] [Epoch 031] train_loss: 0.31837  val_loss: 0.39369
# [PatchTST-F3] [Epoch 032] train_loss: 0.31761  val_loss: 0.39241
# [PatchTST-F3] [Epoch 033] train_loss: 0.31719  val_loss: 0.39122
# [PatchTST-F3] [Epoch 034] train_loss: 0.31710  val_loss: 0.39011
# [PatchTST-F3] [Epoch 035] train_loss: 0.31593  val_loss: 0.38905
# [PatchTST-F3] [Epoch 036] train_loss: 0.31570  val_loss: 0.38789
# [PatchTST-F3] [Epoch 037] train_loss: 0.31485  val_loss: 0.38671
# [PatchTST-F3] [Epoch 038] train_loss: 0.31483  val_loss: 0.38554
# [PatchTST-F3] [Epoch 039] train_loss: 0.31375  val_loss: 0.38458
# [PatchTST-F3] [Epoch 040] train_loss: 0.31325  val_loss: 0.38375
# [PatchTST-F3] [Epoch 041] train_loss: 0.31287  val_loss: 0.38292
# [PatchTST-F3] [Epoch 042] train_loss: 0.31229  val_loss: 0.38228
# [PatchTST-F3] [Epoch 043] train_loss: 0.31185  val_loss: 0.38170
# [PatchTST-F3] [Epoch 044] train_loss: 0.31138  val_loss: 0.38121
# [PatchTST-F3] [Epoch 045] train_loss: 0.31055  val_loss: 0.38069
# [PatchTST-F3] [Epoch 046] train_loss: 0.31048  val_loss: 0.38026
# [PatchTST-F3] [Epoch 047] train_loss: 0.30955  val_loss: 0.37988
# [PatchTST-F3] [Epoch 048] train_loss: 0.30924  val_loss: 0.37941
# [PatchTST-F3] [Epoch 049] train_loss: 0.30860  val_loss: 0.37908
# [PatchTST-F3] [Epoch 050] train_loss: 0.30787  val_loss: 0.37886
# [PatchTST-F3] [Epoch 051] train_loss: 0.30765  val_loss: 0.37861
# [PatchTST-F3] [Epoch 052] train_loss: 0.30695  val_loss: 0.37844
# [PatchTST-F3] [Epoch 053] train_loss: 0.30677  val_loss: 0.37819
# [PatchTST-F3] [Epoch 054] train_loss: 0.30614  val_loss: 0.37812
# [PatchTST-F3] [Epoch 055] train_loss: 0.30579  val_loss: 0.37811
# [PatchTST-F3] [Epoch 056] train_loss: 0.30514  val_loss: 0.37807
# [PatchTST-F3] [Epoch 057] train_loss: 0.30428  val_loss: 0.37809
# [PatchTST-F3] [Epoch 058] train_loss: 0.30407  val_loss: 0.37813
# [PatchTST-F3] [Epoch 059] train_loss: 0.30345  val_loss: 0.37814
# [PatchTST-F3] [Epoch 060] train_loss: 0.30279  val_loss: 0.37814
# [PatchTST-F3] [Epoch 061] train_loss: 0.30281  val_loss: 0.37814
# [PatchTST-F3] [Epoch 062] train_loss: 0.30247  val_loss: 0.37821
# [PatchTST-F3] [Epoch 063] train_loss: 0.30130  val_loss: 0.37830
# [PatchTST-F3] [Epoch 064] train_loss: 0.30125  val_loss: 0.37842
# [PatchTST-F3] [Epoch 065] train_loss: 0.30070  val_loss: 0.37859
# [PatchTST-F3] [Epoch 066] train_loss: 0.30027  val_loss: 0.37880
# [PatchTST-F3] [Epoch 067] train_loss: 0.30003  val_loss: 0.37901
# [PatchTST-F3] [Epoch 068] train_loss: 0.29937  val_loss: 0.37921
# [PatchTST-F3] Early stopping at epoch 68
# [VAL(avg over folds)] PatchTST=0.38814
# [Ensemble Weights] TimesNet=0.245  GRU=0.274  N-HiTS=0.241  PatchTST=0.240
# 🔮 4-Model 앙상블 예측...
#   📊 /content/drive/MyDrive/data/test/TEST_00.csv 처리 중...
#   📊 /content/drive/MyDrive/data/test/TEST_01.csv 처리 중...
#   📊 /content/drive/MyDrive/data/test/TEST_02.csv 처리 중...
#   📊 /content/drive/MyDrive/data/test/TEST_03.csv 처리 중...
#   📊 /content/drive/MyDrive/data/test/TEST_04.csv 처리 중...
#   📊 /content/drive/MyDrive/data/test/TEST_05.csv 처리 중...
#   📊 /content/drive/MyDrive/data/test/TEST_06.csv 처리 중...
#   📊 /content/drive/MyDrive/data/test/TEST_07.csv 처리 중...
#   📊 /content/drive/MyDrive/data/test/TEST_08.csv 처리 중...
#   📊 /content/drive/MyDrive/data/test/TEST_09.csv 처리 중...
# ✅ 앙상블 완료! → /content/drive/MyDrive/data/delete_dlinear_submission.csv
# 🏆 N-HiTS + PatchTST + TimesNet + GRU 학습/추론 끝
