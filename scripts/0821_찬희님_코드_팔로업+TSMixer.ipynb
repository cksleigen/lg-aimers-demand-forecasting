# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### config
# - 매장 카테고리 변경
# - TSMixer 추가

# %%
# -*- coding: utf-8 -*-
"""
Enhanced N-HiTS + Improved PatchTST + Improved TimesNet + GRU + MLinear (5-Model Ensemble)
+ Optional Optuna Tuning + Multi-fold CV + Safe AMP + Memory-safe EMA

주요 변경:
- DLinear → MLinear로 교체
- 그룹별 선형 변환 + 메타 피처 통합
- Hurdle 모델 지원
"""

import os, gc, glob, json, math, random, warnings
from dataclasses import dataclass
from typing import List, Dict, Tuple, Optional

import numpy as np
import pandas as pd

import torch
from torch import nn
from torch.utils.data import Dataset, DataLoader
import torch.nn.functional as F

# ---- Optuna (옵션) ----
try:
    import optuna
    HAS_OPTUNA = True
except Exception:
    HAS_OPTUNA = False

warnings.filterwarnings('ignore')

# =====================
# Config
# =====================
@dataclass
class EnhancedNHiTSConfig:
    # 경로
    train_csv: str = "/content/drive/MyDrive/data/train/train.csv"
    test_glob: str = "/content/drive/MyDrive/data/test/*.csv"
    submission_template_csv: str = "/content/drive/MyDrive/data/sample_submission.csv"
    out_submission_csv: str = "/content/drive/MyDrive/data/0821_6model_submission.csv"

    # train_csv:str = "train_original.csv"
    # test_glob:str = "test/*.csv"
    # submission_template_csv:str = "sample_submission.csv
    # out_submission_csv: str = "0820_submission.csv"

    # 컬럼명
    date_col: str = "영업일자"
    item_col: str = "영업장명_메뉴명"
    target_col: str = "매출수량"

    # 윈도우
    in_len: int = 28
    out_len: int = 7

    # 학습 설정
    train_end_date: str = "2024-06-15"
    seed: int = 42
    device: str = "cuda" if torch.cuda.is_available() else "cpu"
    log1p: bool = True

    # 공용 학습 하이퍼파라미터(풀 학습)
    EPOCHS_FULL: int = 120
    BATCH_FULL: int = 256
    BASE_LR_FULL: float = 6e-4
    MAX_LR_FULL: float = 1.5e-3
    WD_FULL: float = 6e-4

    # 튜닝 (옵션)
    USE_OPTUNA: bool = False
    N_TRIALS: int = 30
    EPOCHS_TUNE: int = 1
    BATCH_TUNE: int = 256

    # CV folds(끝나는 주의 토요일 등)
    cv_fold_end_dates: Tuple[str, ...] = ("2024-06-14", "2024-06-07", "2024-05-31")

    # DataLoader
    num_workers: int = 4
    pin_memory: bool = True
    persistent_workers: bool = False  # 메모리 안전 우선

    # N-HiTS 구조
    hidden: int = 384
    n_blocks: int = 3
    n_layers: int = 1
    n_pool_kernel_size: Optional[List[int]] = None
    pooling_mode: str = "MaxPool1d"
    interpolation_mode: str = "linear"
    dropout: float = 0.22
    stack_types: Optional[List[str]] = None
    n_freq_downsample: Optional[List[int]] = None

    # Loss
    eps_smape: float = 0.01
    zero_weight: float = 0.01
    hurdle_lambda: float = 0.15

    # AMP/EMA
    use_amp: bool = True
    use_compile: bool = False
    ema_decay: float = 0.9998

    # 가중치/공휴일
    store_weights: Optional[Dict[str, float]] = None
    custom_holidays_list: Optional[List[str]] = None

    # ==== PatchTST ====
    ptst_d_model: int = 192
    ptst_nhead: int = 8
    ptst_num_layers: int = 2
    ptst_patch_len: int = 3
    ptst_stride: int = 2
    ptst_dropout: float = 0.2
    ptst_head_hidden: int = 256
    ptst_ff_mult: float = 1.5  # Config화

    # ==== TimesNet ====
    tnet_channels: int = 128
    tnet_blocks: int = 3
    tnet_kernels: Tuple[int, int, int] = (3, 5, 7)
    tnet_dropout: float = 0.12
    tnet_head_hidden: int = 256

    # ==== GRU ====
    gru_hidden: int = 256
    gru_layers: int = 2
    gru_dropout: float = 0.1
    gru_bidirectional: bool = False
    gru_head_hidden: int = 256

    # ==== MLinear ====
    mlin_hidden_dim: int = 256
    mlin_dropout: float = 0.1
    mlin_use_residual: bool = True
    mlin_use_layer_norm: bool = True

    # TSMixer 하이퍼파라미터
    tsm_d_model: int = 192
    tsm_num_layers: int = 2
    tsm_dropout: float = 0.2
    tsm_patch_len: int = 3
    tsm_head_hidden: int = 256

    # ==== 훈련 보조 ====
    grad_clip: float = 0.5
    earlystop_patience_ratio: float = 0.12
    earlystop_patience_min: int = 8

DEFAULT_STORE_WEIGHTS = {
    "미라시아": 1, "담하": 1, "연회장": 1, "라그로타": 1,
    "느티나무 셀프BBQ": 1, "화담숲주막": 1, "카페테리아": 1,
    "화담숲카페": 1, "포레스트릿": 1,
}

DEFAULT_CUSTOM_HOLIDAYS = [
    '2023-01-01','2023-01-21','2023-01-22','2023-01-23','2023-01-24','2023-03-01','2023-05-01',
    '2023-05-05','2023-05-27','2023-06-06','2023-08-15','2023-09-28','2023-09-29','2023-09-30',
    '2023-10-02','2023-10-03','2023-10-09','2023-12-25',
    '2024-01-01','2024-02-09','2024-02-10','2024-02-11','2024-02-12','2024-03-01','2024-04-10',
    '2024-05-01','2024-05-05','2024-05-06','2024-05-15','2024-06-06','2024-08-15','2024-09-16',
    '2024-09-17','2024-09-18','2024-10-01','2024-10-03','2024-10-09','2024-12-25',
    '2025-01-01','2025-01-28','2025-01-29','2025-01-30','2025-03-01','2025-03-03','2025-05-01',
    '2025-05-05','2025-05-06','2025-06-06','2025-08-15'
]

# %%
# =====================
# Feature Utils
# =====================
def set_seed(seed: int = 42):
    random.seed(seed); np.random.seed(seed)
    torch.manual_seed(seed); torch.cuda.manual_seed_all(seed)

def sine_cosine_encoding(value: float, max_val: float):
    return math.sin(2 * math.pi * value / max_val), math.cos(2 * math.pi * value / max_val)

def get_menu_category(menu_name: str) -> str:
    menu_lower = menu_name.lower()
    if any(word in menu_lower for word in ['막걸리', '소주', '맥주', '와인', '참이슬', '처음처럼', '카스', '하이네켄', '버드와이저', '스텔라']):
        return 'alcohol'
    elif any(word in menu_lower for word in ['찌개', '탕', '국밥', '라면', '해장국', '갈비탕']):
        return 'hot_food'
    elif any(word in menu_lower for word in ['삼겹', '갈비', '목살', 'bbq', '구이', '불고기']):
        return 'bbq'
    elif any(word in menu_lower for word in ['아이스크림', '식혜', '콜라', '스프라이트', '에이드']):
        return 'dessert_drink'
    elif any(word in menu_lower for word in ['아메리카노', '라떼', '커피']):
        return 'coffee'
    elif any(word in menu_lower for word in ['냉면', '파스타', '스파게티', '면', '우동']):
        return 'noodles'
    elif any(word in menu_lower for word in ['비빔밥', '볶음밥', '공깃밥', '정식']):
        return 'rice'
    else:
        return 'others'

# 매장을 경향성별로 페어링
def get_store_type(store_name: str) -> str:
    if store_name in ["느티나무 셀프BBQ", "연회장"]:
        return 'Special_Occasion'
    elif store_name in ["화담숲주막", "화담숲카페"]:
        return 'Forest'
    elif store_name in ["담하", "미라시아"]:
        return 'Fine_Dining'
    elif store_name in ["카페테리아", "포레스트릿"]:
        return 'Casual'
    else:
        return 'Unique_Venue'

def get_menu_group(store_name: str, menu_name: str) -> str:
    """메뉴 그룹 분류 (MLinear용)"""
    category = get_menu_category(menu_name)
    store_type = get_store_type(store_name)

    # 매장 타입과 메뉴 카테고리 조합으로 그룹 생성
    if store_type == 'Fine_Dining' and category in ['alcohol', 'bbq']:
        return 'Fine_Dining_Luxury'
    elif store_type == 'Casual' and category == 'coffee':
        return 'Casual_Coffee'
    elif store_type == 'Special_Occasion' and category == 'bbq':
        return 'Occasion_BBQ'
    elif store_type == 'Forest' and category in ['coffee', 'dessert_drink']:
        return 'Forest_Beverage'
    elif category == 'alcohol':
        return 'Alcohol_All'
    elif category in ['hot_food', 'rice', 'noodles']:
        return 'Main_Dishes'
    else:
        return 'Others_Mixed'

# %%
def build_enhanced_features(dates: List[pd.Timestamp], holidays_set: set) -> pd.DataFrame:
    df = pd.DataFrame({"date": dates})
    df["dow"] = df["date"].dt.weekday
    df["month"] = df["date"].dt.month
    df["day"] = df["date"].dt.day
    df["week"] = df["date"].apply(lambda d: int(d.isocalendar().week))
    df["quarter"] = df["date"].dt.quarter
    df["is_friday"] = (df["dow"] == 4).astype(int)
    df["is_saturday"] = (df["dow"] == 5).astype(int)
    df["is_sunday"] = (df["dow"] == 6).astype(int)
    df["is_weekend"] = df["dow"].isin([5,6]).astype(int)
    df["is_holiday"] = df["date"].isin(holidays_set).astype(int)
    df["is_off"] = ((df["is_weekend"]==1) | (df["is_holiday"]==1)).astype(int)
    df["tomorrow"] = df["date"] + pd.Timedelta(days=1)
    df["yesterday"] = df["date"] - pd.Timedelta(days=1)
    df["is_before_holiday"] = df["tomorrow"].isin(holidays_set).astype(int)
    df["is_after_holiday"] = df["yesterday"].isin(holidays_set).astype(int)
    df["is_month_start"] = (df["day"] <= 3).astype(int)
    df["is_month_end"] = (df["day"] >= 28).astype(int)
    df["is_spring"] = df["month"].isin([4,5,6]).astype(int)
    df["is_summer"] = df["month"].isin([7,8]).astype(int)
    df["is_autumn"] = df["month"].isin([9,10,11]).astype(int)
    df["is_winter"] = df["month"].isin([12,1,2,3]).astype(int)
    df["is_summer_vacation"] = df["month"].isin([7,8]).astype(int)
    df["is_winter_vacation"] = df["month"].isin([12,1,2]).astype(int)
    df[["month_sin", "month_cos"]] = df["month"].apply(lambda m: pd.Series(sine_cosine_encoding(m, 12)))
    df[["dow_sin", "dow_cos"]] = df["dow"].apply(lambda d: pd.Series(sine_cosine_encoding(d, 7)))
    df[["doy_sin", "doy_cos"]] = df["date"].apply(lambda d: pd.Series(sine_cosine_encoding(d.dayofyear, 365)))
    df[["week_sin", "week_cos"]] = df["week"].apply(lambda w: pd.Series(sine_cosine_encoding(w, 52)))
    df[["quarter_sin", "quarter_cos"]] = df["quarter"].apply(lambda q: pd.Series(sine_cosine_encoding(q, 4)))
    return df.drop(columns=["tomorrow", "yesterday"])

def parse_store_name(item_full: str) -> str:
    return item_full.split("_")[0]

def parse_menu_name(item_full: str) -> str:
    return item_full.split("_", 1)[1] if "_" in item_full else item_full

def make_val_mask_by_week(dataset: 'EnhancedNHiTSDataset', end_date_str: str) -> np.ndarray:
    end_date = pd.to_datetime(end_date_str)
    start_date = end_date - pd.Timedelta(days=6)
    ted = dataset.target_end_dates
    return (ted >= start_date) & (ted <= end_date)

# %% [markdown]
# ### ENhancedNHiTSDataset

# %%
# =====================
# Dataset (MLinear용 그룹 정보 추가)
# =====================
class EnhancedNHiTSDataset(Dataset):
    def __init__(self, cfg: EnhancedNHiTSConfig, df: pd.DataFrame):
        self.cfg = cfg
        self.df = df.copy()
        if cfg.date_col not in self.df.columns or cfg.item_col not in self.df.columns or cfg.target_col not in self.df.columns:
            raise ValueError("입력 데이터에 필요한 컬럼이 없습니다.")
        self.df[cfg.date_col] = pd.to_datetime(self.df[cfg.date_col])
        self.df[cfg.target_col] = pd.to_numeric(self.df[cfg.target_col], errors='coerce').fillna(0.0).clip(lower=0)

        pivot = self.df.pivot(index=cfg.date_col, columns=cfg.item_col, values=cfg.target_col).sort_index()
        self.items = list(pivot.columns)
        self.dates = list(pivot.index)
        self.values = pivot.fillna(0.0).values.astype(np.float32)

        holidays_set = set(pd.to_datetime(cfg.custom_holidays_list)) if cfg.custom_holidays_list else set()
        caldf = build_enhanced_features(self.dates, holidays_set)
        self.cal_feats = caldf.drop(columns=["date"]).values.astype(np.float32)
        self.cal_feat_names = [c for c in caldf.columns if c != "date"]

        stores = [parse_store_name(it) for it in self.items]
        menus = [parse_menu_name(it) for it in self.items]

        self.store2idx = {s: i for i, s in enumerate(sorted(set(stores)))}
        self.item_store_idx = np.array([self.store2idx[s] for s in stores], dtype=np.int64)
        self.n_stores = len(self.store2idx)

        menu_categories = [get_menu_category(m) for m in menus]
        self.cat2idx = {c: i for i, c in enumerate(sorted(set(menu_categories)))}
        self.item_cat_idx = np.array([self.cat2idx[c] for c in menu_categories], dtype=np.int64)
        self.n_categories = len(self.cat2idx)

        store_types = [get_store_type(s) for s in stores]
        self.type2idx = {t: i for i, t in enumerate(sorted(set(store_types)))}
        self.item_type_idx = np.array([self.type2idx[t] for t in store_types], dtype=np.int64)
        self.n_types = len(self.type2idx)

        # MLinear용 그룹 정보 추가
        menu_groups = [get_menu_group(s, m) for s, m in zip(stores, menus)]
        self.group2idx = {g: i for i, g in enumerate(sorted(set(menu_groups)))}
        self.item_group_idx = np.array([self.group2idx[g] for g in menu_groups], dtype=np.int64)
        self.n_groups = len(self.group2idx)

        sw = cfg.store_weights or {}
        self.sample_weights = np.array([sw.get(parse_store_name(it), 1.0) for it in self.items], dtype=np.float32)

        self.indices: List[Tuple[int,int]] = []
        self.target_end_dates: List[pd.Timestamp] = []
        T = len(self.dates)
        Lx, Ly = cfg.in_len, cfg.out_len
        cutoff = pd.to_datetime(cfg.train_end_date)
        max_start = max(0, T - (Lx + Ly))

        for j in range(len(self.items)):
            for t0 in range(0, max_start + 1):
                end_date = self.dates[t0 + Lx + Ly - 1]
                if end_date <= cutoff:
                    self.indices.append((t0, j))
                    self.target_end_dates.append(end_date)

        # Type-safe datetime64 ns
        self.target_end_dates = np.asarray(self.target_end_dates, dtype='datetime64[ns]')

    def __len__(self):
        return len(self.indices)

    def __getitem__(self, idx):
        cfg = self.cfg
        t0, j = self.indices[idx]
        Lx, Ly = cfg.in_len, cfg.out_len

        x = self.values[t0:t0 + Lx, j]
        y = self.values[t0 + Lx:t0 + Lx + Ly, j]

        if cfg.log1p:
            x_in = np.log1p(x); y_out = np.log1p(y)
        else:
            x_in, y_out = x.copy(), y.copy()

        past_cal = self.cal_feats[t0:t0 + Lx, :]
        fut_cal = self.cal_feats[t0 + Lx:t0 + Lx + Ly, :]

        store_idx = self.item_store_idx[j]
        cat_idx = self.item_cat_idx[j]
        type_idx = self.item_type_idx[j]
        group_idx = self.item_group_idx[j]  # MLinear용
        sample_w = self.sample_weights[j]

        zero_mask = (y == 0).astype(np.float32)
        pos_mask = (y > 0).astype(np.float32)

        # MLinear용 추가 피처
        zero_ratio = np.mean(x == 0)
        weekend_factor = np.mean(past_cal[:, 12])  # is_weekend 피처 인덱스

        return {
            "x": torch.from_numpy(x_in).float(),
            "y": torch.from_numpy(y_out).float(),
            "past_cal": torch.from_numpy(past_cal).float(),
            "fut_cal": torch.from_numpy(fut_cal).float(),
            "store_idx": torch.tensor(store_idx, dtype=torch.long),
            "cat_idx": torch.tensor(cat_idx, dtype=torch.long),
            "type_idx": torch.tensor(type_idx, dtype=torch.long),
            "group_idx": torch.tensor(group_idx, dtype=torch.long),  # MLinear용
            "sample_w": torch.tensor(sample_w, dtype=torch.float32),
            "zero_mask": torch.from_numpy(zero_mask).float(),
            "pos_mask": torch.from_numpy(pos_mask).float(),
            "zero_ratio": torch.tensor(zero_ratio, dtype=torch.float32),  # MLinear용
            "weekend_factor": torch.tensor(weekend_factor, dtype=torch.float32),  # MLinear용
        }

# %% [markdown]
# ### N-HiTS

# %%
# =====================
# N-HiTS (기존과 동일)
# =====================
class NHiTSBlock(nn.Module):
    def __init__(self, input_size: int, output_size: int, hidden_size: int,
                 n_layers: int, dropout: float, pooling_mode: str = "MaxPool1d",
                 n_pool_kernel_size: int = 2, interpolation_mode: str = "linear"):
        super().__init__()
        if pooling_mode == "MaxPool1d":
            self.pooling_layer = nn.MaxPool1d(kernel_size=n_pool_kernel_size, stride=n_pool_kernel_size, ceil_mode=True)
        else:
            self.pooling_layer = nn.AvgPool1d(kernel_size=n_pool_kernel_size, stride=n_pool_kernel_size, ceil_mode=True)
        pooled_size = math.ceil(input_size / n_pool_kernel_size)
        layers = [nn.Linear(pooled_size, hidden_size), nn.ReLU(), nn.Dropout(dropout)]
        for _ in range(n_layers - 1):
            layers += [nn.Linear(hidden_size, hidden_size), nn.ReLU(), nn.Dropout(dropout)]
        self.mlp = nn.Sequential(*layers)
        self.output_layer = nn.Linear(hidden_size, output_size)

    def forward(self, x):
        x = x.unsqueeze(1)
        x_pooled = self.pooling_layer(x).squeeze(1)
        h = self.mlp(x_pooled)
        output = self.output_layer(h)
        return output

class EnhancedNHiTSModel(nn.Module):
    def __init__(self, in_len: int, out_len: int, cal_dim: int, n_stores: int,
                 n_categories: int, n_types: int, cfg: EnhancedNHiTSConfig):
        super().__init__()
        if cfg.n_pool_kernel_size is None or len(cfg.n_pool_kernel_size) < cfg.n_blocks:
            base_kernels = [2, 2, 1]
            cfg.n_pool_kernel_size = [base_kernels[i % len(base_kernels)] for i in range(cfg.n_blocks)]
        if cfg.stack_types is None or len(cfg.stack_types) < cfg.n_blocks:
            base_types = ["identity", "identity", "trend"]
            cfg.stack_types = [base_types[i % len(base_types)] for i in range(cfg.n_blocks)]
        if cfg.n_freq_downsample is None or len(cfg.n_freq_downsample) < cfg.n_blocks:
            base_downsample = [2, 1, 1]
            cfg.n_freq_downsample = [base_downsample[i % len(base_downsample)] for i in range(cfg.n_blocks)]

        self.out_len = out_len
        self.stack_types = cfg.stack_types

        self.store_emb = nn.Embedding(n_stores, 64)
        self.cat_emb = nn.Embedding(n_categories, 32)
        self.type_emb = nn.Embedding(n_types, 16)
        self.cal_proj = nn.Linear(cal_dim, 128)

        self.blocks = nn.ModuleList([
            NHiTSBlock(in_len, out_len, cfg.hidden, cfg.n_layers, cfg.dropout,
                       pooling_mode=cfg.pooling_mode, n_pool_kernel_size=cfg.n_pool_kernel_size[i],
                       interpolation_mode=cfg.interpolation_mode) for i in range(cfg.n_blocks)
        ])

        self.basis_weights = nn.ParameterList([
            nn.Parameter(torch.randn(out_len, max(1, out_len // cfg.n_freq_downsample[i])))
            for i in range(cfg.n_blocks)
        ])

        meta_dim = 64 + 32 + 16 + 128
        self.meta_integration = nn.Sequential(
            nn.Linear(meta_dim, cfg.hidden),
            nn.ReLU(), nn.Dropout(cfg.dropout),
            nn.Linear(cfg.hidden, out_len)
        )

        self.prob_head = nn.Sequential(
            nn.Linear(meta_dim + 1, cfg.hidden),
            nn.ReLU(), nn.Dropout(cfg.dropout),
            nn.Linear(cfg.hidden, cfg.hidden // 2),
            nn.ReLU(), nn.Dropout(cfg.dropout),
            nn.Linear(cfg.hidden // 2, out_len)
        )

    def forward(self, x, past_cal, fut_cal, store_idx, cat_idx, type_idx, **kwargs):
        store_emb = self.store_emb(store_idx)
        cat_emb = self.cat_emb(cat_idx)
        type_emb = self.type_emb(type_idx)
        cal_all = torch.cat([past_cal, fut_cal], dim=1).mean(dim=1)
        cal_emb = self.cal_proj(cal_all)
        meta_feat = torch.cat([store_emb, cat_emb, type_emb, cal_emb], dim=-1)

        outputs = []
        for i, block in enumerate(self.blocks):
            block_output = block(x)
            if self.stack_types[i] == "trend":
                basis = self.basis_weights[i]  # [out_len, k]
                block_output = block_output @ basis
                block_output = F.interpolate(block_output.unsqueeze(1), size=self.out_len,
                                            mode='linear', align_corners=False).squeeze(1)
            outputs.append(block_output)
        nhits_output = torch.stack(outputs, dim=0).sum(dim=0)

        meta_adjustment = self.meta_integration(meta_feat)
        value_pred = nhits_output + meta_adjustment

        prob_feat = torch.cat([meta_feat, x.mean(dim=1, keepdim=True)], dim=-1)
        prob_logits = self.prob_head(prob_feat)
        return value_pred, prob_logits

# %% [markdown]
# ### PatchTST

# %%
# =====================
# PatchTST (기존과 동일, forward만 수정)
# =====================
def _build_sinusoidal_pos(L: int, d_model: int, device: torch.device, dtype: torch.dtype):
    pos = torch.arange(L, device=device, dtype=dtype).unsqueeze(1)
    i = torch.arange(d_model, device=device, dtype=dtype).unsqueeze(0)
    div = torch.exp(- (i // 2) * math.log(10000.0) / max(1, (d_model // 2)))
    angle = pos * div
    pe = torch.zeros((L, d_model), device=device, dtype=dtype)
    pe[:, 0::2] = torch.sin(angle[:, 0::2])
    pe[:, 1::2] = torch.cos(angle[:, 1::2])
    return pe.unsqueeze(0)

class PatchEmbedding(nn.Module):
    def __init__(self, seq_len: int, patch_len: int, stride: int, d_model: int):
        super().__init__()
        assert patch_len > 0 and stride > 0
        self.patch_len = patch_len
        self.stride = stride
        self.d_model = d_model
        self.proj = nn.Linear(patch_len, d_model)

    def forward(self, x):  # x: [B, L]
        B, L = x.shape
        if L < self.patch_len:
            pad = self.patch_len - L
            last_val = x[:, -1:].repeat(1, pad)
            x = torch.cat([last_val, x], dim=1)

        patches = x.unfold(dimension=1, size=self.patch_len, step=self.stride)  # [B, Np, P]
        Np = patches.size(1)
        x_e = self.proj(patches)
        pe = _build_sinusoidal_pos(Np, self.d_model, x_e.device, x_e.dtype)  # [1,Np,D]
        x_e = x_e + pe
        return x_e

class ImprovedPatchTSTTiny(nn.Module):
    def __init__(self, cfg: EnhancedNHiTSConfig, in_len: int, out_len: int,
                 cal_dim: int, n_stores: int, n_categories: int, n_types: int):
        super().__init__()
        patch_len = max(2, min(cfg.ptst_patch_len, max(2, in_len // 8)))
        stride = max(1, patch_len // 2)
        self.embed = PatchEmbedding(in_len, patch_len, stride, cfg.ptst_d_model)

        enc_layer = nn.TransformerEncoderLayer(
            d_model=cfg.ptst_d_model,
            nhead=cfg.ptst_nhead,
            dim_feedforward=int(cfg.ptst_d_model * cfg.ptst_ff_mult),
            dropout=cfg.ptst_dropout,
            batch_first=True,
            activation='gelu',
            norm_first=True
        )
        self.encoder = nn.TransformerEncoder(enc_layer, num_layers=cfg.ptst_num_layers + 1)

        self.multi_heads = nn.ModuleList([
            nn.Sequential(
                nn.LayerNorm(cfg.ptst_d_model),
                nn.Linear(cfg.ptst_d_model, max(16, cfg.ptst_head_hidden // 4)),
                nn.GELU(),
                nn.Dropout(cfg.ptst_dropout),
                nn.Linear(max(16, cfg.ptst_head_hidden // 4), out_len)
            ) for _ in range(4)
        ])

        self.time_proj = nn.Sequential(
            nn.Linear(cal_dim * 2, max(16, cfg.ptst_d_model // 2)),
            nn.GELU(),
            nn.Dropout(cfg.ptst_dropout)
        )

        self.store_emb = nn.Embedding(n_stores, 64)
        self.cat_emb = nn.Embedding(n_categories, 32)
        self.type_emb = nn.Embedding(n_types, 16)
        self.cal_proj = nn.Linear(cal_dim, 128)

        meta_dim = 64 + 32 + 16 + 128 + max(16, cfg.ptst_d_model // 2)
        self.meta_integration = nn.Sequential(
            nn.Linear(meta_dim, cfg.ptst_head_hidden),
            nn.GELU(), nn.Dropout(cfg.ptst_dropout),
            nn.Linear(cfg.ptst_head_hidden, max(32, cfg.ptst_head_hidden // 2)),
            nn.GELU(), nn.Dropout(cfg.ptst_dropout),
            nn.Linear(max(32, cfg.ptst_head_hidden // 2), out_len)
        )
        self.prob_head = nn.Sequential(
            nn.Linear(meta_dim + 1, cfg.ptst_head_hidden),
            nn.GELU(), nn.Dropout(cfg.ptst_dropout),
            nn.Linear(cfg.ptst_head_hidden, max(32, cfg.ptst_head_hidden // 2)),
            nn.GELU(), nn.Dropout(cfg.ptst_dropout),
            nn.Linear(max(32, cfg.ptst_head_hidden // 2), out_len)
        )
        self.residual_weight = nn.Parameter(torch.tensor(0.1))

    def forward(self, x, past_cal, fut_cal, store_idx, cat_idx, type_idx, **kwargs):
        z = self.embed(x)
        z = self.encoder(z)
        z_global = z.mean(dim=1)
        z_last = z[:, -1, :]
        z_max, _ = z.max(dim=1)
        z_first = z[:, 0, :]

        head_preds = []
        for i, head in enumerate(self.multi_heads):
            vec = [z_global, z_last, z_max, z_first][i]
            head_preds.append(head(vec))
        seq_out = torch.stack(head_preds, dim=0).mean(dim=0)

        time_info = torch.cat([past_cal.mean(dim=1), fut_cal.mean(dim=1)], dim=-1)
        time_emb = self.time_proj(time_info)

        store_emb = self.store_emb(store_idx)
        cat_emb = self.cat_emb(cat_idx)
        type_emb = self.type_emb(type_idx)
        cal_emb = self.cal_proj(torch.cat([past_cal, fut_cal], dim=1).mean(dim=1))
        meta_feat = torch.cat([store_emb, cat_emb, type_emb, cal_emb, time_emb], dim=-1)

        meta_adjustment = self.meta_integration(meta_feat)
        value_pred = seq_out + self.residual_weight * meta_adjustment

        prob_logits = self.prob_head(torch.cat([meta_feat, x.mean(dim=1, keepdim=True)], dim=-1))
        return value_pred, prob_logits

# %% [markdown]
# ### TimesNet

# %%
# =====================
# Improved TimesNet (기존과 동일, forward만 수정)
# =====================
class FrequencyBlock(nn.Module):
    def __init__(self, seq_len: int, top_k: int = 5):
        super().__init__()
        self.seq_len = int(seq_len)
        self.top_k = int(min(max(top_k, 1), max(1, self.seq_len // 2)))

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        B, C, L = x.shape
        in_dtype = x.dtype
        x32 = x.to(torch.float32)
        x_freq = torch.fft.rfft(x32, dim=-1)
        amp = torch.abs(x_freq).mean(dim=1)
        _, top_idx = torch.topk(amp, k=self.top_k, dim=-1)
        x_freq_filt = torch.zeros_like(x_freq)
        for i in range(B):
            x_freq_filt[i, :, top_idx[i]] = x_freq[i, :, top_idx[i]]
        x_filt32 = torch.fft.irfft(x_freq_filt, n=L, dim=-1)
        x_filt = x_filt32.to(in_dtype)
        return x_filt

class ImprovedTimesBlock(nn.Module):
    def __init__(
        self,
        in_ch: int,
        out_ch: int,
        seq_len: int,
        kernels=(3, 5, 7),
        top_k: int = 5,
        dropout: float = 0.1,
    ):
        super().__init__()
        assert in_ch > 0 and out_ch > 0 and seq_len > 0
        self.in_ch = int(in_ch)
        self.out_ch = int(out_ch)
        self.seq_len = int(seq_len)

        self.freq_block = FrequencyBlock(seq_len=self.seq_len, top_k=top_k)
        self.period_base = max(2, self.seq_len // 4)

        self.conv2d = nn.Sequential(
            nn.Conv2d(self.in_ch, self.out_ch, kernel_size=(3, 3), padding=1),
            nn.GELU(),
            nn.Conv2d(self.out_ch, self.out_ch, kernel_size=(3, 3), padding=1),
            nn.GELU(),
        )

        ks = list(kernels)
        n_br = len(ks)
        per = max(1, self.out_ch // n_br)
        branch_chs = [per] * n_br
        for i in range(self.out_ch - sum(branch_chs)):
            branch_chs[i % n_br] += 1

        branches = []
        for i, k in enumerate(ks):
            ch = branch_chs[i]
            branches.append(
                nn.Sequential(
                    nn.Conv1d(self.in_ch, ch, kernel_size=k, padding=k // 2),
                    nn.GELU(),
                    nn.Conv1d(ch, ch, kernel_size=k, padding=k // 2),
                    nn.GELU(),
                )
            )
        self.conv1d_branches = nn.ModuleList(branches)
        self.br_sum_ch = sum(branch_chs)

        self.channel_proj = (
            nn.Conv1d(self.br_sum_ch, self.out_ch, kernel_size=1)
            if self.br_sum_ch != self.out_ch
            else nn.Identity()
        )

        self.norm = nn.LayerNorm([self.out_ch, self.seq_len])
        self.dropout = nn.Dropout(dropout)

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        B, C, L = x.shape
        assert C == self.in_ch, f"in_ch mismatch: got {C}, expected {self.in_ch}"

        xf = self.freq_block(x)

        period = self.period_base
        if L % period != 0:
            pad_len = period - (L % period)
            xf = F.pad(xf, (0, pad_len), mode="replicate")
            L_pad = L + pad_len
        else:
            pad_len = 0
            L_pad = L

        x2d = xf.reshape(B, C, period, L_pad // period).contiguous()
        z2d = self.conv2d(x2d)
        z2d_flat = z2d.reshape(B, self.out_ch, L_pad)
        if pad_len > 0:
            z2d_flat = z2d_flat[:, :, :L]

        z1d_list = [branch(x) for branch in self.conv1d_branches]
        z1d = torch.cat(z1d_list, dim=1)
        z1d = self.channel_proj(z1d)

        out = z2d_flat + z1d
        out = self.norm(out)
        out = self.dropout(out)
        return out

class ImprovedTimesNetTiny(nn.Module):
    def __init__(self, cfg: EnhancedNHiTSConfig, in_len: int, out_len: int,
                 cal_dim: int, n_stores: int, n_categories: int, n_types: int):
        super().__init__()
        C = max(32, min(cfg.tnet_channels, 96))
        C = (C // 8) * 8

        self.stem = nn.Conv1d(1, C, kernel_size=3, padding=1)

        def fast_block(C: int, p: float):
            return nn.Sequential(
                nn.Conv1d(C, C, kernel_size=3, padding=1, groups=C, bias=True),
                nn.Conv1d(C, C, kernel_size=1, bias=False),
                nn.GELU(),
                nn.Conv1d(C, C, kernel_size=3, padding=1, groups=C, bias=True),
                nn.Conv1d(C, C, kernel_size=1, bias=False),
                nn.GELU(),
                nn.Dropout(p)
            )

        self.blocks = nn.ModuleList([
            fast_block(C, p=max(0.0, min(cfg.tnet_dropout, 0.1)))
            for _ in range(max(1, cfg.tnet_blocks))
        ])

        head_hidden = max(128, min(cfg.tnet_head_hidden, 192))
        self.head_fc1 = nn.Linear(C, head_hidden)
        self.head_fc2 = nn.Linear(head_hidden, out_len)
        self.head_drop = nn.Dropout(cfg.tnet_dropout)

        self.store_emb = nn.Embedding(n_stores, 64)
        self.cat_emb   = nn.Embedding(n_categories, 32)
        self.type_emb  = nn.Embedding(n_types, 16)
        self.cal_proj  = nn.Linear(cal_dim, 128)
        meta_dim = 64 + 32 + 16 + 128
        self.meta_integration = nn.Sequential(
            nn.Linear(meta_dim, head_hidden),
            nn.ReLU(),
            nn.Dropout(cfg.tnet_dropout),
            nn.Linear(head_hidden, out_len),
        )
        self.prob_head = nn.Sequential(
            nn.Linear(meta_dim + 1, head_hidden),
            nn.ReLU(),
            nn.Dropout(cfg.tnet_dropout),
            nn.Linear(head_hidden, out_len),
        )
        self.meta_res_weight = nn.Parameter(torch.tensor(0.15))

    def forward(self, x, past_cal, fut_cal, store_idx, cat_idx, type_idx, **kwargs):
        z = self.stem(x.unsqueeze(1))
        for blk in self.blocks:
            z = z + blk(z)

        z_mean = z.mean(dim=-1)
        seq_out = self.head_fc2(self.head_drop(F.gelu(self.head_fc1(z_mean))))

        store_emb = self.store_emb(store_idx)
        cat_emb   = self.cat_emb(cat_idx)
        type_emb  = self.type_emb(type_idx)
        cal_all   = torch.cat([past_cal, fut_cal], dim=1).mean(dim=1)
        cal_emb   = self.cal_proj(cal_all)
        meta_feat = torch.cat([store_emb, cat_emb, type_emb, cal_emb], dim=-1)

        value_pred  = seq_out + self.meta_res_weight * self.meta_integration(meta_feat)
        prob_logits = self.prob_head(torch.cat([meta_feat, x.mean(dim=1, keepdim=True)], dim=-1))
        return value_pred, prob_logits

# %% [markdown]
# ### GRU

# %%
# =====================
# GRU (기존과 동일, forward만 수정)
# =====================
class GRUTiny(nn.Module):
    def __init__(self, cfg: EnhancedNHiTSConfig, in_len: int, out_len: int,
                 cal_dim: int, n_stores: int, n_categories: int, n_types: int):
        super().__init__()
        self.gru = nn.GRU(
            input_size=1,
            hidden_size=cfg.gru_hidden,
            num_layers=cfg.gru_layers,
            batch_first=True,
            dropout=cfg.gru_dropout if cfg.gru_layers > 1 else 0.0,
            bidirectional=cfg.gru_bidirectional
        )
        d_mul = 2 if cfg.gru_bidirectional else 1
        self.head = nn.Sequential(nn.LayerNorm(cfg.gru_hidden * d_mul),
                                  nn.Linear(cfg.gru_hidden * d_mul, out_len))
        self.store_emb = nn.Embedding(n_stores, 64)
        self.cat_emb = nn.Embedding(n_categories, 32)
        self.type_emb = nn.Embedding(n_types, 16)
        self.cal_proj = nn.Linear(cal_dim, 128)
        meta_dim = 64+32+16+128
        self.meta_integration = nn.Sequential(
            nn.Linear(meta_dim, cfg.gru_head_hidden),
            nn.ReLU(), nn.Dropout(0.1),
            nn.Linear(cfg.gru_head_hidden, out_len)
        )
        self.prob_head = nn.Sequential(
            nn.Linear(meta_dim + 1, cfg.gru_head_hidden),
            nn.ReLU(), nn.Dropout(0.1),
            nn.Linear(cfg.gru_head_hidden, cfg.gru_head_hidden // 2),
            nn.ReLU(), nn.Dropout(0.1),
            nn.Linear(cfg.gru_head_hidden // 2, out_len)
        )

    def forward(self, x, past_cal, fut_cal, store_idx, cat_idx, type_idx, **kwargs):
        z_in = x.unsqueeze(-1)
        z_out, _ = self.gru(z_in)
        z_last = z_out[:, -1, :]
        seq_out = self.head(z_last)
        store_emb = self.store_emb(store_idx)
        cat_emb = self.cat_emb(cat_idx)
        type_emb = self.type_emb(type_idx)
        cal_all = torch.cat([past_cal, fut_cal], dim=1).mean(dim=1)
        cal_emb = self.cal_proj(cal_all)
        meta_feat = torch.cat([store_emb, cat_emb, type_emb, cal_emb], dim=-1)
        value_pred = seq_out + self.meta_integration(meta_feat)
        prob_logits = self.prob_head(torch.cat([meta_feat, x.mean(dim=1, keepdim=True)], dim=-1))
        return value_pred, prob_logits

# %% [markdown]
# ### MLinear

# %%
# =====================
# MLinear (새로 추가)
# =====================
class MLinearTiny(nn.Module):
    """MLinear 모델 - 그룹별 선형 변환 + 메타 피처 통합"""

    def __init__(self, cfg: EnhancedNHiTSConfig, in_len: int, out_len: int,
                 cal_dim: int, n_stores: int, n_categories: int, n_types: int, n_groups: int):
        super().__init__()

        self.in_len = in_len
        self.out_len = out_len
        self.cfg = cfg

        # 임베딩
        self.group_emb = nn.Embedding(n_groups, 32)
        self.store_emb = nn.Embedding(n_stores, 32)
        self.cat_emb = nn.Embedding(n_categories, 16)
        self.type_emb = nn.Embedding(n_types, 16)

        # 캘린더 피처 처리
        self.cal_proj = nn.Sequential(
            nn.Linear(cal_dim * 2, 128),
            nn.ReLU(),
            nn.Dropout(cfg.mlin_dropout * 0.5),
            nn.Linear(128, 64)
        )

        # 그룹별 MLinear
        self.group_linears = nn.ModuleDict({
            f'group_{i}': nn.Linear(in_len, out_len) for i in range(n_groups)
        })

        # 공통 MLinear
        self.common_linear = nn.Linear(in_len, out_len)

        # 메타 피처 통합
        meta_dim = 32 + 32 + 16 + 16 + 64  # 160

        self.meta_integration = nn.Sequential(
            nn.Linear(meta_dim, cfg.mlin_hidden_dim),
            nn.ReLU(),
            nn.Dropout(cfg.mlin_dropout),
            nn.Linear(cfg.mlin_hidden_dim, out_len)
        )

        # 가중치 네트워크
        self.weight_net = nn.Sequential(
            nn.Linear(meta_dim + 2, 128),  # +2 for store features
            nn.ReLU(),
            nn.Linear(128, 3),  # [group, common, meta]
            nn.Softmax(dim=-1)
        )

        # Hurdle 모델
        self.prob_head = nn.Sequential(
            nn.Linear(meta_dim + 2, cfg.mlin_hidden_dim),  # +2 for x stats
            nn.ReLU(),
            nn.Dropout(cfg.mlin_dropout),
            nn.Linear(cfg.mlin_hidden_dim, cfg.mlin_hidden_dim // 2),
            nn.ReLU(),
            nn.Linear(cfg.mlin_hidden_dim // 2, out_len)
        )

        # 옵션 기능들
        if cfg.mlin_use_residual:
            self.residual_proj = nn.Linear(in_len, out_len)

        if cfg.mlin_use_layer_norm:
            self.output_norm = nn.LayerNorm(out_len)

    def forward(self, x, past_cal, fut_cal, store_idx, cat_idx, type_idx, group_idx,
                zero_ratio, weekend_factor, **kwargs):
        batch_size = x.size(0)

        # 임베딩
        group_emb = self.group_emb(group_idx)
        store_emb = self.store_emb(store_idx)
        cat_emb = self.cat_emb(cat_idx)
        type_emb = self.type_emb(type_idx)

        # 캘린더 피처
        past_cal_mean = past_cal.mean(dim=1)
        fut_cal_mean = fut_cal.mean(dim=1)
        cal_combined = torch.cat([past_cal_mean, fut_cal_mean], dim=1)
        cal_emb = self.cal_proj(cal_combined)

        # 메타 피처 결합
        meta_feat = torch.cat([group_emb, store_emb, cat_emb, type_emb, cal_emb], dim=-1)

        # 그룹별 MLinear
        group_output = torch.zeros(batch_size, self.out_len, device=x.device)
        for i in range(len(self.group_linears)):
            mask = (group_idx == i).float().unsqueeze(-1)
            group_pred = self.group_linears[f'group_{i}'](x)
            group_output += group_pred * mask

        # 공통 MLinear
        common_output = self.common_linear(x)

        # 메타 조정
        meta_output = self.meta_integration(meta_feat)

        # 가중치 계산
        weight_input = torch.cat([meta_feat, zero_ratio.unsqueeze(-1), weekend_factor.unsqueeze(-1)], dim=-1)
        weights = self.weight_net(weight_input)
        w_group, w_common, w_meta = weights[:, 0:1], weights[:, 1:2], weights[:, 2:3]

        # 최종 예측
        value_pred = w_group * group_output + w_common * common_output + w_meta * meta_output

        # Residual
        if self.cfg.mlin_use_residual:
            value_pred = value_pred + self.residual_proj(x)

        # 정규화
        if self.cfg.mlin_use_layer_norm:
            value_pred = self.output_norm(value_pred)

        # Hurdle 확률
        x_stats = torch.cat([x.mean(dim=1, keepdim=True), x.std(dim=1, keepdim=True)], dim=-1)
        prob_input = torch.cat([meta_feat, x_stats], dim=-1)
        prob_logits = self.prob_head(prob_input)

        return value_pred, prob_logits

# %% [markdown]
# ### TSMixer

# %%
class TSMixerBlock(nn.Module):
    def __init__(self, d_model: int, n_patches: int, dropout: float):
        super().__init__()
        self.norm1 = nn.LayerNorm(d_model)
        self.token_mixing = nn.Sequential(
            nn.Linear(n_patches, n_patches),
            nn.GELU(),
            nn.Dropout(dropout)
        )
        self.norm2 = nn.LayerNorm(d_model)
        self.channel_mixing = nn.Sequential(
            nn.Linear(d_model, d_model),
            nn.GELU(),
            nn.Dropout(dropout)
        )

    def forward(self, x):
        # x: [B, Np, d_model]
        z = self.norm1(x)
        z = self.token_mixing(z.transpose(1, 2)).transpose(1, 2)
        x = x + z

        z = self.norm2(x)
        z = self.channel_mixing(z)
        x = x + z
        return x

class TSMixer(nn.Module):
    """TSMixer 모델 - 패치/채널 MLP 믹싱 + 메타 피처 통합"""

    def __init__(self, cfg: EnhancedNHiTSConfig, in_len: int, out_len: int,
                 cal_dim: int, n_stores: int, n_categories: int, n_types: int,
                 n_groups: int, d_model: int):
        super().__init__()

        self.in_len = in_len
        self.out_len = out_len
        self.cfg = cfg
        self.d_model = d_model

        patch_len = max(2, min(cfg.tsm_patch_len, in_len))
        stride = max(1, patch_len // 2)

        self.patch_len = patch_len
        self.stride = stride

        if in_len < patch_len:
            self.n_patches = 1
        else:
            self.n_patches = math.floor((in_len - patch_len) / stride) + 1

        self.patch_embedding = nn.Linear(self.patch_len, self.d_model)

        self.mixer_blocks = nn.ModuleList([
            TSMixerBlock(self.d_model, self.n_patches, cfg.tsm_dropout)
            for _ in range(cfg.tsm_num_layers)
        ])

        self.store_emb = nn.Embedding(n_stores, 64)
        self.cat_emb = nn.Embedding(n_categories, 32)
        self.type_emb = nn.Embedding(n_types, 16)

        # 🚨 수정된 부분: cal_proj 레이어의 입력 차원을 cal_dim으로 변경
        self.cal_proj = nn.Sequential(
            nn.Linear(cal_dim, 128),
            nn.ReLU(),
            nn.Linear(128, 64)
        )

        self.head = nn.Sequential(
            nn.LayerNorm(self.d_model * self.n_patches),
            nn.Linear(self.d_model * self.n_patches, max(64, cfg.tsm_head_hidden)),
            nn.GELU(),
            nn.Dropout(cfg.tsm_dropout),
            nn.Linear(max(64, cfg.tsm_head_hidden), out_len)
        )

        meta_dim = 64 + 32 + 16 + 64
        self.meta_integration = nn.Sequential(
            nn.Linear(meta_dim, cfg.tsm_head_hidden),
            nn.ReLU(),
            nn.Dropout(cfg.tsm_dropout),
            nn.Linear(cfg.tsm_head_hidden, out_len)
        )

        self.prob_head = nn.Sequential(
            nn.Linear(meta_dim + 1, cfg.tsm_head_hidden),
            nn.ReLU(),
            nn.Dropout(cfg.tsm_dropout),
            nn.Linear(cfg.tsm_head_hidden, out_len)
        )

    def forward(self, x, past_cal, fut_cal, store_idx, cat_idx, type_idx, **kwargs):
        if self.in_len < self.patch_len:
            pad_len = self.patch_len - self.in_len
            x = F.pad(x, (0, pad_len), mode='replicate')

        patches = x.unfold(dimension=1, size=self.patch_len, step=self.stride)
        z = self.patch_embedding(patches)

        for block in self.mixer_blocks:
            z = block(z)

        z_global = z.reshape(z.size(0), -1)
        seq_out = self.head(z_global)

        store_emb = self.store_emb(store_idx)
        cat_emb = self.cat_emb(cat_idx)
        type_emb = self.type_emb(type_idx)

        # 🚨 수정된 부분: cal_all의 차원을 cal_dim으로 변경
        cal_all = torch.cat([past_cal, fut_cal], dim=1) # (B, in_len + out_len, cal_dim)
        cal_all = cal_all.mean(dim=1) # (B, cal_dim)

        cal_emb = self.cal_proj(cal_all)
        meta_feat = torch.cat([store_emb, cat_emb, type_emb, cal_emb], dim=-1)
        meta_adjustment = self.meta_integration(meta_feat)
        value_pred = seq_out + meta_adjustment

        prob_feat = torch.cat([meta_feat, x.mean(dim=1, keepdim=True)], dim=-1)
        prob_logits = self.prob_head(prob_feat)

        return value_pred, prob_logits

# %%
# =====================
# Loss / EMA (기존과 동일)
# =====================
class UltraEnhancedHurdleLoss(nn.Module):
    def __init__(self, eps: float = 0.01, zero_weight: float = 0.01, lambda_bce: float = 0.15):
        super().__init__()
        self.eps = eps; self.zero_weight = zero_weight; self.lambda_bce = lambda_bce
        self.bce = nn.BCEWithLogitsLoss(reduction='none')

    def forward(self, v_pred_log, p_logits, y_true_log, pos_mask, sample_w):
        z = (pos_mask > 0).float()
        bce = self.bce(p_logits, z)
        yp_val = torch.expm1(v_pred_log).clamp_min(0.0)
        yt_val = torch.expm1(y_true_log).clamp_min(0.0)
        ultra_eps = torch.where(yt_val < 0.5, self.eps * 0.2,
                                torch.where(yt_val < 2.0, self.eps * 0.5, self.eps))
        denom = (torch.abs(yp_val) + torch.abs(yt_val)).clamp_min(ultra_eps)
        smape_pos = 2.0 * torch.abs(yp_val - yt_val) / denom
        smape_pos = smape_pos * (yt_val > 0).float()
        p = torch.sigmoid(p_logits)
        y_hat = p * yp_val
        denom2 = (torch.abs(y_hat) + torch.abs(yt_val)).clamp_min(ultra_eps)
        smape_all = 2.0 * torch.abs(y_hat - yt_val) / denom2
        ultra_zero_weight = torch.where(
            yt_val < 0.01, torch.full_like(yt_val, self.zero_weight * 0.1),
            torch.where(yt_val < 0.1, torch.full_like(yt_val, self.zero_weight * 0.3),
                        torch.where(yt_val < 1.0, torch.full_like(yt_val, self.zero_weight * 0.6), torch.ones_like(yt_val)))
        )
        smape_all = smape_all * ultra_zero_weight
        bce_s = bce.mean(dim=1); pos_s = smape_pos.mean(dim=1); all_s = smape_all.mean(dim=1)
        sample_loss = self.lambda_bce * bce_s + 0.4 * pos_s + 0.6 * all_s
        sw = sample_w.view(-1); wsum = sw.sum().clamp_min(1e-8)
        loss = (sample_loss * sw).sum() / wsum
        return loss, sample_loss.detach(), sw.detach()

class EMA:
    def __init__(self, model: nn.Module, decay: float = 0.9998):
        self.decay = decay
        self.shadow = {name: p.detach().clone() for name, p in model.named_parameters() if p.requires_grad}

    def update(self, model: nn.Module):
        with torch.no_grad():
            for name, p in model.named_parameters():
                if p.requires_grad:
                    self.shadow[name].mul_((self.decay)).add_(p.detach(), alpha=1-self.decay)

    def apply_to(self, model: nn.Module):
        with torch.no_grad():
            for name, p in model.named_parameters():
                if p.requires_grad:
                    p.copy_(self.shadow[name])

# %%
# =====================
# Trainer (기존과 동일)
# =====================
class GenericTrainer:
    def __init__(self, cfg: EnhancedNHiTSConfig, dataset: EnhancedNHiTSDataset, model: nn.Module,
                 epochs: int, batch_size: int, base_lr: float, max_lr: float, weight_decay: float):
        self.cfg = cfg; self.dataset = dataset; self.model = model.to(cfg.device)
        self.device = torch.device(cfg.device)
        self.criterion = UltraEnhancedHurdleLoss(cfg.eps_smape, cfg.zero_weight, cfg.hurdle_lambda)
        self.ema = EMA(self.model, decay=cfg.ema_decay)
        self.epochs = epochs; self.batch_size = batch_size
        self.base_lr = base_lr; self.max_lr = max_lr; self.weight_decay = weight_decay

    def make_loaders_from_mask(self, mask_val: np.ndarray):
        idx_all = np.arange(len(self.dataset))
        val_idx = idx_all[mask_val]; train_idx = idx_all[~mask_val]
        train_subset = torch.utils.data.Subset(self.dataset, train_idx)
        val_subset = torch.utils.data.Subset(self.dataset, val_idx)
        train_loader = DataLoader(
            train_subset, batch_size=self.batch_size, shuffle=True,
            num_workers=self.cfg.num_workers, pin_memory=self.cfg.pin_memory,
            persistent_workers=self.cfg.persistent_workers, drop_last=False
        )
        val_loader = DataLoader(
            val_subset, batch_size=self.batch_size, shuffle=False,
            num_workers=self.cfg.num_workers, pin_memory=self.cfg.pin_memory,
            persistent_workers=self.cfg.persistent_workers, drop_last=False
        )
        return train_loader, val_loader

    @torch.no_grad()
    def evaluate(self, loader: DataLoader, use_ema: bool = True) -> float:
        if loader is None:
            return float('inf')
        self.model.eval()

        backup = None
        if use_ema:
            backup = {k: v.detach().clone() for k, v in self.model.state_dict().items()}
            self.ema.apply_to(self.model)

        total_loss = 0.0
        total_weight = 0.0

        amp_ctx = torch.autocast(device_type='cuda', dtype=torch.float16) if (
            self.cfg.use_amp and torch.cuda.is_available() and self.device.type == "cuda"
        ) else torch.cuda.amp.autocast(enabled=False)

        with amp_ctx:
            for batch in loader:
                x = batch["x"].to(self.device)
                y = batch["y"].to(self.device)
                past_cal = batch["past_cal"].to(self.device)
                fut_cal = batch["fut_cal"].to(self.device)
                store_idx = batch["store_idx"].to(self.device)
                cat_idx = batch["cat_idx"].to(self.device)
                type_idx = batch["type_idx"].to(self.device)
                sample_w = batch["sample_w"].to(self.device)
                pos_mask = batch["pos_mask"].to(self.device)

                # MLinear용 추가 입력 (이미 전달한 파라미터 제외)
                excluded_keys = {"x", "y", "past_cal", "fut_cal", "store_idx", "cat_idx", "type_idx", "sample_w", "pos_mask"}
                batch_dict = {k: v.to(self.device) if isinstance(v, torch.Tensor) else v
                            for k, v in batch.items() if k not in excluded_keys}

                v_pred, p_logits = self.model(x, past_cal, fut_cal, store_idx, cat_idx, type_idx, **batch_dict)

                _, sample_loss, sw = self.criterion(v_pred, p_logits, y, pos_mask, sample_w)

                total_loss += (sample_loss * sw).sum().item()
                total_weight += sw.sum().item()

        if use_ema and backup is not None:
            self.model.load_state_dict(backup)
            del backup
            gc.collect(); torch.cuda.empty_cache()

        if total_weight <= 0:
            return float('inf')
        return total_loss / total_weight

    def train_with_loaders(self, train_loader: DataLoader, val_loader: DataLoader, model_name="Model"):
        optim = torch.optim.AdamW(self.model.parameters(), lr=self.base_lr, weight_decay=self.weight_decay, betas=(0.9,0.999))
        steps_per_epoch = max(1, len(train_loader))
        sched = torch.optim.lr_scheduler.OneCycleLR(
            optim, max_lr=self.max_lr, epochs=self.epochs,
            steps_per_epoch=steps_per_epoch, pct_start=0.05,
            div_factor=max(1e-8, self.max_lr / max(1e-8, self.base_lr))
        )
        patience = max(self.cfg.earlystop_patience_min, int(self.epochs * self.cfg.earlystop_patience_ratio))
        best_val = float("inf"); best_state = None; no_improve=0
        for epoch in range(1, self.epochs+1):
            self.model.train()
            amp_ctx = torch.autocast(device_type='cuda', dtype=torch.float16) if (self.cfg.use_amp and torch.cuda.is_available() and self.device.type=="cuda") else torch.cuda.amp.autocast(enabled=False)
            running = []
            for batch in train_loader:
                x = batch["x"].to(self.device); y = batch["y"].to(self.device)
                past_cal = batch["past_cal"].to(self.device); fut_cal = batch["fut_cal"].to(self.device)
                store_idx = batch["store_idx"].to(self.device); cat_idx = batch["cat_idx"].to(self.device)
                type_idx = batch["type_idx"].to(self.device); sample_w = batch["sample_w"].to(self.device)
                pos_mask = batch["pos_mask"].to(self.device)

                # MLinear용 추가 입력 (이미 전달한 파라미터 제외)
                excluded_keys = {"x", "y", "past_cal", "fut_cal", "store_idx", "cat_idx", "type_idx", "sample_w", "pos_mask"}
                batch_dict = {k: v.to(self.device) if isinstance(v, torch.Tensor) else v
                            for k, v in batch.items() if k not in excluded_keys}

                with amp_ctx:
                    v_pred, p_logits = self.model(x, past_cal, fut_cal, store_idx, cat_idx, type_idx, **batch_dict)

                    loss, _, _ = self.criterion(v_pred, p_logits, y, pos_mask, sample_w)
                optim.zero_grad(set_to_none=True); loss.backward()
                torch.nn.utils.clip_grad_norm_(self.model.parameters(), self.cfg.grad_clip)
                optim.step(); sched.step(); self.ema.update(self.model)
                running.append(loss.detach().item())
            val_loss = self.evaluate(val_loader, use_ema=True)
            tr_mean = float(np.mean(running)) if running else float('nan')
            print(f"[{model_name}] [Epoch {epoch:03d}] train_loss: {tr_mean:.5f}  val_loss: {val_loss:.5f}")
            if val_loss < best_val:
                best_val = val_loss
                best_state = {k: v.detach().cpu().clone() for k, v in self.model.state_dict().items()}
                no_improve = 0
            else:
                no_improve += 1
                if no_improve >= patience:
                    print(f"[{model_name}] Early stopping at epoch {epoch}")
                    break
        if best_state is not None:
            self.model.load_state_dict(best_state)
        self.ema.apply_to(self.model)
        return self.model, best_val

# %%
# =====================
# Predict Utils (MLinear용 수정)
# =====================
@torch.no_grad()
def predict_one_file_generic(
    cfg: EnhancedNHiTSConfig,
    model: nn.Module,
    test_df: pd.DataFrame,
    store2idx: Dict,
    cat2idx: Dict,
    type2idx: Dict,
    group2idx: Dict = None
) -> pd.DataFrame:
    device = torch.device(cfg.device)
    if test_df is None or len(test_df) == 0:
        return pd.DataFrame()

    tdf = test_df.copy()
    if cfg.date_col not in tdf.columns or cfg.item_col not in tdf.columns or cfg.target_col not in tdf.columns:
        return pd.DataFrame()

    tdf[cfg.date_col] = pd.to_datetime(tdf[cfg.date_col], errors="coerce")
    tdf = tdf.dropna(subset=[cfg.date_col])
    if len(tdf) == 0:
        return pd.DataFrame()

    tdf[cfg.target_col] = pd.to_numeric(tdf[cfg.target_col], errors="coerce").fillna(0.0).clip(lower=0)

    try:
        pivot = (
            tdf.pivot(index=cfg.date_col, columns=cfg.item_col, values=cfg.target_col)
               .sort_index()
               .fillna(0.0)
        )
    except Exception:
        return pd.DataFrame()
    if pivot.shape[1] == 0:
        return pd.DataFrame()

    items = list(pivot.columns)
    dates = list(pivot.index)
    values = pivot.values.astype(np.float32)

    # replicate padding (훈련과 일관)
    Lx = cfg.in_len
    if len(dates) < Lx:
        pad_rows = Lx - len(dates)
        first_row = values[0:1, :] if len(dates) > 0 else np.zeros((1, values.shape[1]), dtype=np.float32)
        pad = np.repeat(first_row, pad_rows, axis=0)
        values = np.vstack([pad, values])
        start_date = dates[0] if len(dates) > 0 else pd.Timestamp("2000-01-01")
        backfill = [start_date - pd.Timedelta(days=i) for i in range(pad_rows, 0, -1)]
        dates = backfill + dates

    last_date = dates[-1]
    future_dates = [last_date + pd.Timedelta(days=i) for i in range(1, cfg.out_len + 1)]
    holidays_set = set(pd.to_datetime(cfg.custom_holidays_list)) if cfg.custom_holidays_list else set()

    past_cal = build_enhanced_features(dates[-Lx:], holidays_set).drop(columns=["date"]).values.astype(np.float32)
    fut_cal  = build_enhanced_features(future_dates, holidays_set).drop(columns=["date"]).values.astype(np.float32)

    x_np = values[-Lx:, :].T  # [B,L]
    if cfg.log1p:
        x_np = np.log1p(x_np)

    B = len(items)
    x = torch.from_numpy(x_np).to(device=device, dtype=torch.float32)
    past_cal_b = torch.from_numpy(np.repeat(past_cal[None, :, :], B, axis=0)).to(device=device, dtype=torch.float32)
    fut_cal_b  = torch.from_numpy(np.repeat(fut_cal [None, :, :], B, axis=0)).to(device=device, dtype=torch.float32)

    stores = [parse_store_name(it) for it in items]
    menus  = [parse_menu_name(it) for it in items]

    safe_store_default = next(iter(store2idx.values()), 0)
    safe_cat_default   = next(iter(cat2idx.values()), 0)
    safe_type_default  = next(iter(type2idx.values()), 0)

    store_idx = torch.as_tensor([store2idx.get(s, safe_store_default) for s in stores], device=device, dtype=torch.long)
    cat_idx   = torch.as_tensor([cat2idx.get(get_menu_category(m), safe_cat_default) for m in menus], device=device, dtype=torch.long)
    type_idx  = torch.as_tensor([type2idx.get(get_store_type(s), safe_type_default) for s in stores], device=device, dtype=torch.long)

    # MLinear용 그룹 정보
    if group2idx is not None:
        safe_group_default = next(iter(group2idx.values()), 0)
        group_idx = torch.as_tensor([group2idx.get(get_menu_group(s, m), safe_group_default)
                                   for s, m in zip(stores, menus)], device=device, dtype=torch.long)

        # MLinear용 추가 피처
        zero_ratio = torch.tensor([np.mean(x_np[i] == 0) for i in range(B)], device=device, dtype=torch.float32)
        weekend_factor = torch.tensor([np.mean(past_cal[:, 12]) for _ in range(B)], device=device, dtype=torch.float32)
    else:
        group_idx = torch.zeros(B, device=device, dtype=torch.long)
        zero_ratio = torch.zeros(B, device=device, dtype=torch.float32)
        weekend_factor = torch.zeros(B, device=device, dtype=torch.float32)

    use_cuda_amp = bool(cfg.use_amp and torch.cuda.is_available() and device.type == "cuda")
    amp_ctx = torch.autocast(device_type="cuda", dtype=torch.float16) if use_cuda_amp else torch.cuda.amp.autocast(enabled=False)

    model.eval()
    with amp_ctx:
        v_pred_log, p_logits = model(x, past_cal_b, fut_cal_b, store_idx, cat_idx, type_idx,
                                   group_idx=group_idx, zero_ratio=zero_ratio, weekend_factor=weekend_factor)
        y_val  = torch.expm1(v_pred_log).clamp_min(0.0)
        y_prob = torch.sigmoid(p_logits)
        y_hat  = (y_prob * y_val).clamp_min(0.0).detach().cpu().numpy()  # [B, out_len]

    # rows=아웃스텝, cols=아이템 (전치!)
    out = pd.DataFrame(
        y_hat.T,
        index=[f"D+{i}" for i in range(1, cfg.out_len + 1)],
        columns=items
    )
    out = out.replace([np.inf, -np.inf], 0.0).fillna(0.0)
    return out

# %%
# =====================
# Ensemble Helper (기존과 동일)
# =====================
def invloss_weights(vals: List[float], eps: float = 1e-8) -> List[float]:
    arr = np.array(vals, dtype=np.float64)
    arr[~np.isfinite(arr)] = np.nan
    if np.all(np.isnan(arr)):
        return (np.ones_like(arr) / len(arr)).tolist()
    safe = np.nan_to_num(arr, nan=np.nanmax(arr) * 1.5)
    inv = 1.0 / np.clip(safe, eps, None)
    if not np.isfinite(inv).any() or inv.sum() <= 0:
        return (np.ones_like(inv) / len(inv)).tolist()
    w = inv / inv.sum()
    return w.tolist()

# %% [markdown]
# ### 모델 팩토리

# %%
# =====================
# Model factory (MLinear 추가)
# =====================
def build_model_by_name(name: str, cfg: EnhancedNHiTSConfig, ds: EnhancedNHiTSDataset,
                        trial: Optional['optuna.trial.Trial']=None) -> nn.Module:
    if name == "N-HiTS":
        hidden = trial.suggest_categorical("nh_hidden", [256, 384, 512]) if trial else cfg.hidden
        n_layers = trial.suggest_categorical("nh_layers", [1, 2, 3]) if trial else cfg.n_layers
        dropout = trial.suggest_float("nh_dropout", 0.0, 0.3) if trial else cfg.dropout
        nh_cfg = EnhancedNHiTSConfig(**{**cfg.__dict__, "hidden": hidden, "n_layers": n_layers, "dropout": dropout})
        return EnhancedNHiTSModel(cfg.in_len, cfg.out_len, ds.cal_feats.shape[1], ds.n_stores, ds.n_categories, ds.n_types, nh_cfg)

    if name == "PatchTST":
        d_model = trial.suggest_categorical("pt_d_model", [192, 256, 320]) if trial else cfg.ptst_d_model
        nhead   = trial.suggest_categorical("pt_nhead", [8, 12]) if trial else cfg.ptst_nhead
        nlayer  = trial.suggest_categorical("pt_nlayers", [2, 3, 4]) if trial else cfg.ptst_num_layers
        p_len   = trial.suggest_categorical("pt_patch", [2, 3, 4]) if trial else max(2, cfg.ptst_patch_len // 2)
        stride  = trial.suggest_categorical("pt_stride", [1, 2]) if trial else max(1, cfg.ptst_stride // 2)
        drop    = trial.suggest_float("pt_dropout", 0.05, 0.2) if trial else cfg.ptst_dropout
        ff_mult = trial.suggest_float("ptst_ff_mult", 1.5, 3.5) if trial else cfg.ptst_ff_mult
        pt_cfg = EnhancedNHiTSConfig(**{**cfg.__dict__,
            "ptst_d_model": d_model, "ptst_nhead": nhead, "ptst_num_layers": nlayer,
            "ptst_patch_len": p_len, "ptst_stride": stride, "ptst_dropout": drop, "ptst_ff_mult": ff_mult
        })
        return ImprovedPatchTSTTiny(pt_cfg, cfg.in_len, cfg.out_len, ds.cal_feats.shape[1], ds.n_stores, ds.n_categories, ds.n_types)

    if name == "TimesNet":
        channels = trial.suggest_categorical("tn_channels", [96, 128, 160]) if trial else cfg.tnet_channels
        blocks   = trial.suggest_categorical("tn_blocks", [2, 3, 4]) if trial else cfg.tnet_blocks
        drop     = trial.suggest_float("tn_dropout", 0.0, 0.3) if trial else cfg.tnet_dropout
        tn_cfg = EnhancedNHiTSConfig(**{**cfg.__dict__,
            "tnet_channels": channels, "tnet_blocks": blocks, "tnet_dropout": drop
        })
        return ImprovedTimesNetTiny(tn_cfg, cfg.in_len, cfg.out_len, ds.cal_feats.shape[1], ds.n_stores, ds.n_categories, ds.n_types)

    if name == "GRU":
        hidden = trial.suggest_categorical("gru_hidden", [128, 192, 256]) if trial else cfg.gru_hidden
        layers = trial.suggest_categorical("gru_layers", [1, 2, 3]) if trial else cfg.gru_layers
        drop   = trial.suggest_float("gru_dropout", 0.0, 0.3) if trial else cfg.gru_dropout
        bidi   = trial.suggest_categorical("gru_bidi", [False, True]) if trial else cfg.gru_bidirectional
        gr_cfg = EnhancedNHiTSConfig(**{**cfg.__dict__,
            "gru_hidden": hidden, "gru_layers": layers, "gru_dropout": drop, "gru_bidirectional": bidi
        })
        return GRUTiny(gr_cfg, cfg.in_len, cfg.out_len, ds.cal_feats.shape[1], ds.n_stores, ds.n_categories, ds.n_types)

    if name == "MLinear":
        hidden_dim = trial.suggest_categorical("ml_hidden_dim", [256, 384, 512]) if trial else cfg.mlin_hidden_dim
        dropout = trial.suggest_float("ml_dropout", 0.0, 0.3) if trial else cfg.mlin_dropout
        use_residual = trial.suggest_categorical("ml_residual", [True, False]) if trial else cfg.mlin_use_residual
        use_layer_norm = trial.suggest_categorical("ml_layer_norm", [True, False]) if trial else cfg.mlin_use_layer_norm
        ml_cfg = EnhancedNHiTSConfig(**{**cfg.__dict__,
            "mlin_hidden_dim": hidden_dim, "mlin_dropout": dropout,
            "mlin_use_residual": use_residual, "mlin_use_layer_norm": use_layer_norm
        })
        return MLinearTiny(ml_cfg, cfg.in_len, cfg.out_len, ds.cal_feats.shape[1], ds.n_stores, ds.n_categories, ds.n_types, ds.n_groups)

    # build_model_by_name 함수 내의 TSMixer 부분
    if name == "TSMixer":
        d_model = trial.suggest_categorical("tm_d_model", [192, 256, 320]) if trial else cfg.tsm_d_model
        n_layers = trial.suggest_categorical("tm_n_layers", [2, 3, 4]) if trial else cfg.tsm_num_layers
        drop = trial.suggest_float("tm_dropout", 0.0, 0.3) if trial else cfg.tsm_dropout
        p_len = trial.suggest_categorical("tm_patch", [2, 3, 4]) if trial else max(2, cfg.tsm_patch_len)

        tsm_cfg = EnhancedNHiTSConfig(**{**cfg.__dict__,
            "tsm_d_model": d_model, "tsm_num_layers": n_layers, "tsm_dropout": drop,
            "tsm_patch_len": p_len
        })

        # ⭐⭐⭐ d_model 인자를 추가해야 합니다. ⭐⭐⭐
        return TSMixer(tsm_cfg, cfg.in_len, cfg.out_len, ds.cal_feats.shape[1],
                      ds.n_stores, ds.n_categories, ds.n_types, ds.n_groups, d_model)
    raise ValueError(f"Unknown model name: {name}")

def optuna_objective_factory(model_name: str, cfg: EnhancedNHiTSConfig, ds: EnhancedNHiTSDataset, mask_val: np.ndarray):
    def objective(trial: 'optuna.trial.Trial') -> float:
        # 훈련 레벨도 일부 튜닝(옵션)
        base_lr = trial.suggest_float("base_lr", 3e-4, 3e-3, log=True)
        max_lr  = trial.suggest_float("max_lr",  8e-4, 6e-3, log=True)
        wd      = trial.suggest_float("weight_decay", 1e-6, 8e-4, log=True)
        grad_clip = trial.suggest_float("grad_clip", 0.3, 1.0)
        pat_ratio = trial.suggest_float("pat_ratio", 0.15, 0.35)

        tmp_cfg = EnhancedNHiTSConfig(**{**cfg.__dict__,
            "grad_clip": grad_clip, "earlystop_patience_ratio": pat_ratio
        })
        model = build_model_by_name(model_name, tmp_cfg, ds, trial)
        trainer = GenericTrainer(tmp_cfg, ds, model, epochs=tmp_cfg.EPOCHS_TUNE, batch_size=tmp_cfg.BATCH_TUNE,
                                 base_lr=base_lr, max_lr=max_lr, weight_decay=wd)
        train_loader, val_loader = trainer.make_loaders_from_mask(mask_val)
        _, val_loss = trainer.train_with_loaders(train_loader, val_loader, model_name=f"{model_name}-TUNE")
        trial.set_user_attr("val_loss", float(val_loss))
        return float(val_loss)
    return objective

def run_optuna_for_model(model_name: str, cfg: EnhancedNHiTSConfig, ds: EnhancedNHiTSDataset, mask_val: np.ndarray):
    if not HAS_OPTUNA:
        print(f"[Optuna] optuna가 설치되어 있지 않습니다. '{model_name}' 튜닝을 건너뜁니다.")
        return None, None
    print(f"[Optuna] Start tuning for {model_name} (trials={cfg.N_TRIALS})")
    pruner = optuna.pruners.MedianPruner(n_startup_trials=5, n_warmup_steps=10, interval_steps=1)
    sampler = optuna.samplers.TPESampler(multivariate=True, group=True, constant_liar=True, seed=cfg.seed)
    study = optuna.create_study(direction="minimize", sampler=sampler, pruner=pruner, study_name=f"study_{model_name}")
    study.optimize(optuna_objective_factory(model_name, cfg, ds, mask_val), n_trials=cfg.N_TRIALS, show_progress_bar=False)
    print(f"[Optuna] Best {model_name} val_loss: {study.best_value:.6f}")
    best_params = study.best_params
    return study, best_params

def build_final_model_with_best(model_name: str, cfg: EnhancedNHiTSConfig, ds: EnhancedNHiTSDataset, best_params: Optional[dict]) -> nn.Module:
    if best_params is None:
        return build_model_by_name(model_name, cfg, ds, None)

    tmp = dict(cfg.__dict__)
    if model_name == "N-HiTS":
        if "nh_hidden" in best_params: tmp["hidden"] = best_params["nh_hidden"]
        if "nh_layers" in best_params: tmp["n_layers"] = best_params["nh_layers"]
        if "nh_dropout" in best_params: tmp["dropout"] = best_params["nh_dropout"]

    elif model_name == "PatchTST":
        mapping = {"pt_d_model":"ptst_d_model","pt_nhead":"ptst_nhead","pt_nlayers":"ptst_num_layers",
                   "pt_patch":"ptst_patch_len","pt_stride":"ptst_stride","pt_dropout":"ptst_dropout",
                   "ptst_ff_mult":"ptst_ff_mult"}
        for k, v in mapping.items():
            if k in best_params:
                tmp[v] = best_params[k]

    elif model_name == "TimesNet":
        mapping = {"tn_channels":"tnet_channels","tn_blocks":"tnet_blocks","tn_dropout":"tnet_dropout"}
        for k, v in mapping.items():
            if k in best_params:
                tmp[v] = best_params[k]

    elif model_name == "GRU":
        mapping = {"gru_hidden":"gru_hidden","gru_layers":"gru_layers","gru_dropout":"gru_dropout","gru_bidi":"gru_bidirectional"}
        for k, v in mapping.items():
            if k in best_params:
                tmp[v] = best_params[k]

    elif model_name == "MLinear":
        mapping = {"ml_hidden_dim":"mlin_hidden_dim","ml_dropout":"mlin_dropout","ml_residual":"mlin_use_residual","ml_layer_norm":"mlin_use_layer_norm"}
        for k, v in mapping.items():
            if k in best_params:
                tmp[v] = best_params[k]

    elif model_name == "TSMixer":
        # ⭐⭐⭐ 이 부분을 아래와 같이 수정하세요. ⭐⭐⭐
        mapping = {"tm_d_model": "tsm_d_model", "tm_n_layers": "tsm_num_layers", "tm_dropout": "tsm_dropout", "tm_patch": "tsm_patch_len"}
        for k, v in mapping.items():
            if k in best_params:
                tmp[v] = best_params[k]

    new_cfg = EnhancedNHiTSConfig(**tmp)
    return build_model_by_name(model_name, new_cfg, ds, None)

# %% [markdown]
# ### 메인 실행

# %%
# =====================
# Main (MLinear로 변경)
# =====================
if __name__ == "__main__":
    cfg = EnhancedNHiTSConfig()
    if cfg.store_weights is None: cfg.store_weights = DEFAULT_STORE_WEIGHTS
    if cfg.custom_holidays_list is None: cfg.custom_holidays_list = DEFAULT_CUSTOM_HOLIDAYS
    set_seed(cfg.seed)

    print("=== Enhanced 5-Model Ensemble (+ MLinear) 시작 ===")

    if not os.path.exists(cfg.train_csv):
        raise FileNotFoundError(f"학습 파일을 찾을 수 없습니다: {cfg.train_csv}")
    train_df = pd.read_csv(cfg.train_csv)
    ds = EnhancedNHiTSDataset(cfg, train_df)

    # ===== (옵션) Optuna per-model 튜닝 =====
    best_params_all = {}
    if cfg.USE_OPTUNA:
        if not HAS_OPTUNA:
            print("⚠️ cfg.USE_OPTUNA=True지만 optuna가 설치되어 있지 않습니다. 튜닝은 건너뜁니다.")
        else:
            # 단일 fold로 튜닝 효율화(첫 fold)
            tune_mask_val = make_val_mask_by_week(ds, cfg.cv_fold_end_dates[0])
            for name in ["MLinear"]: # "N-HiTS", "PatchTST", "TimesNet", "GRU",
                study, best_params = run_optuna_for_model(name, cfg, ds, tune_mask_val)
                best_params_all[name] = best_params
            os.makedirs("./data", exist_ok=True)
            with open("./data/optuna_best_params.json", "w", encoding="utf-8") as f:
                json.dump(best_params_all, f, ensure_ascii=False, indent=2)

    # ===== 모델 학습 (멀티 폴드 평균 val) =====
    model_names = ["TimesNet", "GRU", "MLinear", "N-HiTS", "PatchTST", "TSMixer"] # "TimesNet", "GRU", "MLinear", "N-HiTS", "PatchTST", "TSMixer"
    trained_models: Dict[str, nn.Module] = {}
    avg_val_losses: Dict[str, float] = {}

    for name in model_names:
        print(f"📚 {name} 학습...")

        # 0) 초기 스냅샷 확보(항상 같은 초기 가중치에서 시작)
        base_model = build_final_model_with_best(
            name, cfg, ds, best_params_all.get(name) if cfg.USE_OPTUNA else None
        )
        init_state = {k: v.detach().cpu().clone() for k, v in base_model.state_dict().items()}
        del base_model
        gc.collect(); torch.cuda.empty_cache()

        fold_vals = []
        best_fold = None
        best_fold_state = None

        # 1) 폴드별로 항상 fresh 모델/트레이너
        for fold_i, end_date in enumerate(cfg.cv_fold_end_dates, start=1):
            mask_val = make_val_mask_by_week(ds, end_date)

            model_f = build_final_model_with_best(
                name, cfg, ds, best_params_all.get(name) if cfg.USE_OPTUNA else None
            )
            model_f.load_state_dict(init_state, strict=True)  # ← 동일 초기값
            trainer = GenericTrainer(
                cfg, ds, model_f,
                epochs=cfg.EPOCHS_FULL, batch_size=cfg.BATCH_FULL,
                base_lr=cfg.BASE_LR_FULL, max_lr=cfg.MAX_LR_FULL, weight_decay=cfg.WD_FULL
            )
            train_loader, val_loader = trainer.make_loaders_from_mask(mask_val)
            model_f, val_loss = trainer.train_with_loaders(
                train_loader, val_loader, model_name=f"{name}-F{fold_i}"
            )
            fold_vals.append(float(val_loss))

            # 베스트 폴드 state 보관
            if (best_fold is None) or (val_loss < fold_vals[best_fold]):
                best_fold = fold_i - 1  # index
                best_fold_state = {k: v.detach().cpu().clone() for k, v in model_f.state_dict().items()}

            # 폴드별 객체 정리
            del trainer, train_loader, val_loader, model_f
            gc.collect(); torch.cuda.empty_cache()

        # 2) 폴드 평균 성능
        avg_val = float(np.mean(fold_vals)) if len(fold_vals) > 0 else float('inf')
        avg_val_losses[name] = avg_val
        print(f"[VAL(avg over folds)] {name}={avg_val:.5f}")

        # 3) 추론용 fresh 모델 생성 후 베스트 폴드 state 로드
        final_model = build_final_model_with_best(
            name, cfg, ds, best_params_all.get(name) if cfg.USE_OPTUNA else None
        )
        if best_fold_state is not None:
            final_model.load_state_dict(best_fold_state, strict=True)
        trained_models[name] = final_model.to(cfg.device)

    # ===== 가중치 산출(역손실, 안전화) =====
    vals_in_order = [avg_val_losses.get(n, np.nan) for n in model_names]
    w = invloss_weights(vals_in_order)
    weights = dict(zip(model_names, w))
    print("[Ensemble Weights] " + "  ".join([f"{k}={weights[k]:.3f}" for k in model_names]))

    # ===== 추론 & 제출 =====
    print("🔮 5-Model 앙상블 예측...")
    test_files = sorted(glob.glob(cfg.test_glob))
    if not os.path.exists(cfg.submission_template_csv):
        raise FileNotFoundError(f"제출 템플릿 파일을 찾을 수 없습니다: {cfg.submission_template_csv}")
    sub_template = pd.read_csv(cfg.submission_template_csv)
    all_preds = []

    if len(test_files) == 0:
        print("⚠️ 테스트 파일이 없습니다. 제출 생성을 건너뜁니다.")
    else:
        for test_idx, test_file in enumerate(test_files):
            print(f"  📊 {test_file} 처리 중...")
            try:
                tdf = pd.read_csv(test_file)
            except Exception as e:
                print(f"  ⚠️ 파일 로드 실패: {e}")
                continue

            df_preds = {}
            for name in model_names:
                # MLinear인 경우 group2idx 전달
                group2idx = ds.group2idx if name == "MLinear" else None
                df = predict_one_file_generic(cfg, trained_models[name], tdf, ds.store2idx, ds.cat2idx, ds.type2idx, group2idx)
                if df.empty:
                    print(f"  ⚠️ {name} 예측이 비어 있습니다. 이 모델은 스킵합니다.")
                df_preds[name] = df

            # 공통 아이템 집합 정렬
            non_empty = [df for df in df_preds.values() if df is not None and not df.empty]
            if len(non_empty) == 0:
                print(f"  ⚠️ {test_file} 유효 예측이 없어 스킵합니다.")
                continue
            items = list(non_empty[0].columns)
            for k in df_preds:
                if df_preds[k] is not None and not df_preds[k].empty:
                    df_preds[k] = df_preds[k].reindex(columns=items).fillna(0.0)

            # 가중 앙상블
            mix = np.zeros_like(non_empty[0].values, dtype=np.float64)
            for name in model_names:
                df = df_preds.get(name, None)
                if df is None or df.empty:
                    continue
                mix += weights[name] * df.values
            mix = np.clip(mix, 0, None)

            submit_block = pd.DataFrame(
                mix,
                index=[f"D+{i}" for i in range(1, cfg.out_len + 1)],
                columns=items
            )
            submit_block.index = [f"TEST_{test_idx:02d}+{k}일" for k in range(1, cfg.out_len + 1)]
            all_preds.append(submit_block)

    if len(all_preds) == 0:
        print("⚠️ 유효한 예측 결과가 없어 제출 파일을 생성하지 않았습니다.")
    else:
        final_submit = pd.concat(all_preds, axis=0)
        final_submit.reset_index(inplace=True)
        final_submit.rename(columns={"index": "영업일자"}, inplace=True)

        final_submit = final_submit.reindex(columns=sub_template.columns, fill_value=0)

        num_cols = [c for c in final_submit.columns if c != "영업일자"]
        for col in num_cols:
            Q95 = final_submit[col].quantile(0.95)
            final_submit[col] = np.where(final_submit[col] > Q95 * 2.0, Q95 * 1.5, final_submit[col])

        final_submit[num_cols] = np.rint(np.clip(final_submit[num_cols].values, a_min=0, a_max=None)).astype(int)
        os.makedirs(os.path.dirname(cfg.out_submission_csv), exist_ok=True)
        final_submit.to_csv(cfg.out_submission_csv, index=False, encoding="utf-8-sig")
        print(f"✅ 앙상블 완료! → {cfg.out_submission_csv}")

    print("🏆 N-HiTS + PatchTST + TimesNet + GRU + MLinear 학습/추론 끝")
# Out:
# === Enhanced 5-Model Ensemble (+ MLinear) 시작 ===
# 📚 TimesNet 학습...
# [TimesNet-F1] [Epoch 001] train_loss: 0.44183  val_loss: 1.05793
# [TimesNet-F1] [Epoch 002] train_loss: 0.38385  val_loss: 0.99805
# [TimesNet-F1] [Epoch 003] train_loss: 0.37181  val_loss: 0.93124
# [TimesNet-F1] [Epoch 004] train_loss: 0.36419  val_loss: 0.87166
# [TimesNet-F1] [Epoch 005] train_loss: 0.35615  val_loss: 0.82373
# [TimesNet-F1] [Epoch 006] train_loss: 0.34944  val_loss: 0.78749
# [TimesNet-F1] [Epoch 007] train_loss: 0.34377  val_loss: 0.75914
# [TimesNet-F1] [Epoch 008] train_loss: 0.34126  val_loss: 0.73445
# [TimesNet-F1] [Epoch 009] train_loss: 0.33823  val_loss: 0.71056
# [TimesNet-F1] [Epoch 010] train_loss: 0.33603  val_loss: 0.68626
# [TimesNet-F1] [Epoch 011] train_loss: 0.33439  val_loss: 0.66389
# [TimesNet-F1] [Epoch 012] train_loss: 0.33222  val_loss: 0.64206
# [TimesNet-F1] [Epoch 013] train_loss: 0.33073  val_loss: 0.62093
# [TimesNet-F1] [Epoch 014] train_loss: 0.32916  val_loss: 0.60253
# [TimesNet-F1] [Epoch 015] train_loss: 0.32786  val_loss: 0.58505
# [TimesNet-F1] [Epoch 016] train_loss: 0.32683  val_loss: 0.56906
# [TimesNet-F1] [Epoch 017] train_loss: 0.32534  val_loss: 0.55496
# [TimesNet-F1] [Epoch 018] train_loss: 0.32440  val_loss: 0.54261
# [TimesNet-F1] [Epoch 019] train_loss: 0.32342  val_loss: 0.53167
# [TimesNet-F1] [Epoch 020] train_loss: 0.32256  val_loss: 0.52145
# [TimesNet-F1] [Epoch 021] train_loss: 0.32167  val_loss: 0.51203
# [TimesNet-F1] [Epoch 022] train_loss: 0.32047  val_loss: 0.50373
# [TimesNet-F1] [Epoch 023] train_loss: 0.31962  val_loss: 0.49533
# [TimesNet-F1] [Epoch 024] train_loss: 0.31854  val_loss: 0.48757
# [TimesNet-F1] [Epoch 025] train_loss: 0.31759  val_loss: 0.47994
# [TimesNet-F1] [Epoch 026] train_loss: 0.31694  val_loss: 0.47300
# [TimesNet-F1] [Epoch 027] train_loss: 0.31572  val_loss: 0.46656
# [TimesNet-F1] [Epoch 028] train_loss: 0.31484  val_loss: 0.46072
# [TimesNet-F1] [Epoch 029] train_loss: 0.31438  val_loss: 0.45483
# [TimesNet-F1] [Epoch 030] train_loss: 0.31367  val_loss: 0.44934
# [TimesNet-F1] [Epoch 031] train_loss: 0.31218  val_loss: 0.44416
# [TimesNet-F1] [Epoch 032] train_loss: 0.31194  val_loss: 0.43904
# [TimesNet-F1] [Epoch 033] train_loss: 0.31141  val_loss: 0.43413
# [TimesNet-F1] [Epoch 034] train_loss: 0.31054  val_loss: 0.42971
# [TimesNet-F1] [Epoch 035] train_loss: 0.30995  val_loss: 0.42574
# [TimesNet-F1] [Epoch 036] train_loss: 0.30913  val_loss: 0.42208
# [TimesNet-F1] [Epoch 037] train_loss: 0.30819  val_loss: 0.41890
# [TimesNet-F1] [Epoch 038] train_loss: 0.30759  val_loss: 0.41555
# [TimesNet-F1] [Epoch 039] train_loss: 0.30669  val_loss: 0.41261
# [TimesNet-F1] [Epoch 040] train_loss: 0.30644  val_loss: 0.40979
# [TimesNet-F1] [Epoch 041] train_loss: 0.30575  val_loss: 0.40736
# [TimesNet-F1] [Epoch 042] train_loss: 0.30521  val_loss: 0.40501
# [TimesNet-F1] [Epoch 043] train_loss: 0.30476  val_loss: 0.40290
# [TimesNet-F1] [Epoch 044] train_loss: 0.30426  val_loss: 0.40082
# [TimesNet-F1] [Epoch 045] train_loss: 0.30344  val_loss: 0.39904
# [TimesNet-F1] [Epoch 046] train_loss: 0.30328  val_loss: 0.39740
# [TimesNet-F1] [Epoch 047] train_loss: 0.30280  val_loss: 0.39588
# [TimesNet-F1] [Epoch 048] train_loss: 0.30211  val_loss: 0.39446
# [TimesNet-F1] [Epoch 049] train_loss: 0.30189  val_loss: 0.39316
# [TimesNet-F1] [Epoch 050] train_loss: 0.30129  val_loss: 0.39191
# [TimesNet-F1] [Epoch 051] train_loss: 0.30080  val_loss: 0.39079
# [TimesNet-F1] [Epoch 052] train_loss: 0.30025  val_loss: 0.38979
# [TimesNet-F1] [Epoch 053] train_loss: 0.29988  val_loss: 0.38882
# [TimesNet-F1] [Epoch 054] train_loss: 0.29924  val_loss: 0.38795
# [TimesNet-F1] [Epoch 055] train_loss: 0.29911  val_loss: 0.38714
# [TimesNet-F1] [Epoch 056] train_loss: 0.29877  val_loss: 0.38640
# [TimesNet-F1] [Epoch 057] train_loss: 0.29778  val_loss: 0.38579
# [TimesNet-F1] [Epoch 058] train_loss: 0.29773  val_loss: 0.38515
# [TimesNet-F1] [Epoch 059] train_loss: 0.29716  val_loss: 0.38457
# [TimesNet-F1] [Epoch 060] train_loss: 0.29715  val_loss: 0.38396
# [TimesNet-F1] [Epoch 061] train_loss: 0.29688  val_loss: 0.38358
# [TimesNet-F1] [Epoch 062] train_loss: 0.29648  val_loss: 0.38320
# [TimesNet-F1] [Epoch 063] train_loss: 0.29579  val_loss: 0.38278
# [TimesNet-F1] [Epoch 064] train_loss: 0.29535  val_loss: 0.38247
# [TimesNet-F1] [Epoch 065] train_loss: 0.29528  val_loss: 0.38224
# [TimesNet-F1] [Epoch 066] train_loss: 0.29484  val_loss: 0.38202
# [TimesNet-F1] [Epoch 067] train_loss: 0.29463  val_loss: 0.38177
# [TimesNet-F1] [Epoch 068] train_loss: 0.29436  val_loss: 0.38156
# [TimesNet-F1] [Epoch 069] train_loss: 0.29391  val_loss: 0.38145
# [TimesNet-F1] [Epoch 070] train_loss: 0.29383  val_loss: 0.38126
# [TimesNet-F1] [Epoch 071] train_loss: 0.29334  val_loss: 0.38119
# [TimesNet-F1] [Epoch 072] train_loss: 0.29320  val_loss: 0.38111
# [TimesNet-F1] [Epoch 073] train_loss: 0.29270  val_loss: 0.38090
# [TimesNet-F1] [Epoch 074] train_loss: 0.29261  val_loss: 0.38079
# [TimesNet-F1] [Epoch 075] train_loss: 0.29247  val_loss: 0.38071
# [TimesNet-F1] [Epoch 076] train_loss: 0.29186  val_loss: 0.38062
# [TimesNet-F1] [Epoch 077] train_loss: 0.29162  val_loss: 0.38058
# [TimesNet-F1] [Epoch 078] train_loss: 0.29142  val_loss: 0.38053
# [TimesNet-F1] [Epoch 079] train_loss: 0.29134  val_loss: 0.38051
# [TimesNet-F1] [Epoch 080] train_loss: 0.29100  val_loss: 0.38048
# [TimesNet-F1] [Epoch 081] train_loss: 0.29051  val_loss: 0.38044
# [TimesNet-F1] [Epoch 082] train_loss: 0.29051  val_loss: 0.38042
# [TimesNet-F1] [Epoch 083] train_loss: 0.29030  val_loss: 0.38039
# [TimesNet-F1] [Epoch 084] train_loss: 0.28993  val_loss: 0.38042
# [TimesNet-F1] [Epoch 085] train_loss: 0.28976  val_loss: 0.38041
# [TimesNet-F1] [Epoch 086] train_loss: 0.28965  val_loss: 0.38047
# [TimesNet-F1] [Epoch 087] train_loss: 0.28957  val_loss: 0.38041
# [TimesNet-F1] [Epoch 088] train_loss: 0.28914  val_loss: 0.38041
# [TimesNet-F1] [Epoch 089] train_loss: 0.28885  val_loss: 0.38045
# [TimesNet-F1] [Epoch 090] train_loss: 0.28868  val_loss: 0.38044
# [TimesNet-F1] [Epoch 091] train_loss: 0.28872  val_loss: 0.38050
# [TimesNet-F1] [Epoch 092] train_loss: 0.28871  val_loss: 0.38055
# [TimesNet-F1] [Epoch 093] train_loss: 0.28821  val_loss: 0.38056
# [TimesNet-F1] [Epoch 094] train_loss: 0.28821  val_loss: 0.38060
# [TimesNet-F1] [Epoch 095] train_loss: 0.28783  val_loss: 0.38062
# [TimesNet-F1] [Epoch 096] train_loss: 0.28806  val_loss: 0.38067
# [TimesNet-F1] [Epoch 097] train_loss: 0.28769  val_loss: 0.38069
# [TimesNet-F1] Early stopping at epoch 97
# [TimesNet-F2] [Epoch 001] train_loss: 0.43988  val_loss: 1.04166
# [TimesNet-F2] [Epoch 002] train_loss: 0.38338  val_loss: 0.98034
# [TimesNet-F2] [Epoch 003] train_loss: 0.37182  val_loss: 0.91284
# [TimesNet-F2] [Epoch 004] train_loss: 0.36457  val_loss: 0.85312
# [TimesNet-F2] [Epoch 005] train_loss: 0.35618  val_loss: 0.80368
# [TimesNet-F2] [Epoch 006] train_loss: 0.34915  val_loss: 0.76287
# [TimesNet-F2] [Epoch 007] train_loss: 0.34432  val_loss: 0.72987
# [TimesNet-F2] [Epoch 008] train_loss: 0.34112  val_loss: 0.70152
# [TimesNet-F2] [Epoch 009] train_loss: 0.33829  val_loss: 0.67814
# [TimesNet-F2] [Epoch 010] train_loss: 0.33628  val_loss: 0.65655
# [TimesNet-F2] [Epoch 011] train_loss: 0.33455  val_loss: 0.63665
# [TimesNet-F2] [Epoch 012] train_loss: 0.33278  val_loss: 0.61786
# [TimesNet-F2] [Epoch 013] train_loss: 0.33136  val_loss: 0.60008
# [TimesNet-F2] [Epoch 014] train_loss: 0.32972  val_loss: 0.58306
# [TimesNet-F2] [Epoch 015] train_loss: 0.32802  val_loss: 0.56720
# [TimesNet-F2] [Epoch 016] train_loss: 0.32724  val_loss: 0.55212
# [TimesNet-F2] [Epoch 017] train_loss: 0.32598  val_loss: 0.53920
# [TimesNet-F2] [Epoch 018] train_loss: 0.32463  val_loss: 0.52757
# [TimesNet-F2] [Epoch 019] train_loss: 0.32359  val_loss: 0.51694
# [TimesNet-F2] [Epoch 020] train_loss: 0.32249  val_loss: 0.50705
# [TimesNet-F2] [Epoch 021] train_loss: 0.32147  val_loss: 0.49732
# [TimesNet-F2] [Epoch 022] train_loss: 0.32039  val_loss: 0.48815
# [TimesNet-F2] [Epoch 023] train_loss: 0.31921  val_loss: 0.47987
# [TimesNet-F2] [Epoch 024] train_loss: 0.31839  val_loss: 0.47193
# [TimesNet-F2] [Epoch 025] train_loss: 0.31762  val_loss: 0.46458
# [TimesNet-F2] [Epoch 026] train_loss: 0.31682  val_loss: 0.45731
# [TimesNet-F2] [Epoch 027] train_loss: 0.31580  val_loss: 0.45032
# [TimesNet-F2] [Epoch 028] train_loss: 0.31519  val_loss: 0.44325
# [TimesNet-F2] [Epoch 029] train_loss: 0.31419  val_loss: 0.43657
# [TimesNet-F2] [Epoch 030] train_loss: 0.31303  val_loss: 0.43018
# [TimesNet-F2] [Epoch 031] train_loss: 0.31236  val_loss: 0.42405
# [TimesNet-F2] [Epoch 032] train_loss: 0.31180  val_loss: 0.41831
# [TimesNet-F2] [Epoch 033] train_loss: 0.31072  val_loss: 0.41303
# [TimesNet-F2] [Epoch 034] train_loss: 0.30963  val_loss: 0.40804
# [TimesNet-F2] [Epoch 035] train_loss: 0.30955  val_loss: 0.40347
# [TimesNet-F2] [Epoch 036] train_loss: 0.30887  val_loss: 0.39920
# [TimesNet-F2] [Epoch 037] train_loss: 0.30830  val_loss: 0.39541
# [TimesNet-F2] [Epoch 038] train_loss: 0.30745  val_loss: 0.39190
# [TimesNet-F2] [Epoch 039] train_loss: 0.30683  val_loss: 0.38885
# [TimesNet-F2] [Epoch 040] train_loss: 0.30623  val_loss: 0.38613
# [TimesNet-F2] [Epoch 041] train_loss: 0.30535  val_loss: 0.38367
# [TimesNet-F2] [Epoch 042] train_loss: 0.30482  val_loss: 0.38145
# [TimesNet-F2] [Epoch 043] train_loss: 0.30437  val_loss: 0.37943
# [TimesNet-F2] [Epoch 044] train_loss: 0.30427  val_loss: 0.37761
# [TimesNet-F2] [Epoch 045] train_loss: 0.30328  val_loss: 0.37603
# [TimesNet-F2] [Epoch 046] train_loss: 0.30283  val_loss: 0.37471
# [TimesNet-F2] [Epoch 047] train_loss: 0.30231  val_loss: 0.37357
# [TimesNet-F2] [Epoch 048] train_loss: 0.30167  val_loss: 0.37244
# [TimesNet-F2] [Epoch 049] train_loss: 0.30139  val_loss: 0.37146
# [TimesNet-F2] [Epoch 050] train_loss: 0.30111  val_loss: 0.37068
# [TimesNet-F2] [Epoch 051] train_loss: 0.30060  val_loss: 0.36994
# [TimesNet-F2] [Epoch 052] train_loss: 0.30025  val_loss: 0.36934
# [TimesNet-F2] [Epoch 053] train_loss: 0.29974  val_loss: 0.36882
# [TimesNet-F2] [Epoch 054] train_loss: 0.29904  val_loss: 0.36839
# [TimesNet-F2] [Epoch 055] train_loss: 0.29892  val_loss: 0.36804
# [TimesNet-F2] [Epoch 056] train_loss: 0.29852  val_loss: 0.36773
# [TimesNet-F2] [Epoch 057] train_loss: 0.29793  val_loss: 0.36756
# [TimesNet-F2] [Epoch 058] train_loss: 0.29755  val_loss: 0.36739
# [TimesNet-F2] [Epoch 059] train_loss: 0.29729  val_loss: 0.36719
# [TimesNet-F2] [Epoch 060] train_loss: 0.29682  val_loss: 0.36704
# [TimesNet-F2] [Epoch 061] train_loss: 0.29651  val_loss: 0.36694
# [TimesNet-F2] [Epoch 062] train_loss: 0.29591  val_loss: 0.36689
# [TimesNet-F2] [Epoch 063] train_loss: 0.29595  val_loss: 0.36686
# [TimesNet-F2] [Epoch 064] train_loss: 0.29514  val_loss: 0.36675
# [TimesNet-F2] [Epoch 065] train_loss: 0.29497  val_loss: 0.36668
# [TimesNet-F2] [Epoch 066] train_loss: 0.29489  val_loss: 0.36664
# [TimesNet-F2] [Epoch 067] train_loss: 0.29451  val_loss: 0.36660
# [TimesNet-F2] [Epoch 068] train_loss: 0.29404  val_loss: 0.36669
# [TimesNet-F2] [Epoch 069] train_loss: 0.29362  val_loss: 0.36671
# [TimesNet-F2] [Epoch 070] train_loss: 0.29328  val_loss: 0.36668
# [TimesNet-F2] [Epoch 071] train_loss: 0.29325  val_loss: 0.36664
# [TimesNet-F2] [Epoch 072] train_loss: 0.29248  val_loss: 0.36664
# [TimesNet-F2] [Epoch 073] train_loss: 0.29253  val_loss: 0.36657
# [TimesNet-F2] [Epoch 074] train_loss: 0.29219  val_loss: 0.36654
# [TimesNet-F2] [Epoch 075] train_loss: 0.29227  val_loss: 0.36649
# [TimesNet-F2] [Epoch 076] train_loss: 0.29166  val_loss: 0.36645
# [TimesNet-F2] [Epoch 077] train_loss: 0.29136  val_loss: 0.36637
# [TimesNet-F2] [Epoch 078] train_loss: 0.29104  val_loss: 0.36630
# [TimesNet-F2] [Epoch 079] train_loss: 0.29076  val_loss: 0.36630
# [TimesNet-F2] [Epoch 080] train_loss: 0.29045  val_loss: 0.36622
# [TimesNet-F2] [Epoch 081] train_loss: 0.29034  val_loss: 0.36625
# [TimesNet-F2] [Epoch 082] train_loss: 0.29009  val_loss: 0.36617
# [TimesNet-F2] [Epoch 083] train_loss: 0.28981  val_loss: 0.36610
# [TimesNet-F2] [Epoch 084] train_loss: 0.28983  val_loss: 0.36601
# [TimesNet-F2] [Epoch 085] train_loss: 0.28963  val_loss: 0.36593
# [TimesNet-F2] [Epoch 086] train_loss: 0.28945  val_loss: 0.36585
# [TimesNet-F2] [Epoch 087] train_loss: 0.28903  val_loss: 0.36580
# [TimesNet-F2] [Epoch 088] train_loss: 0.28893  val_loss: 0.36578
# [TimesNet-F2] [Epoch 089] train_loss: 0.28870  val_loss: 0.36569
# [TimesNet-F2] [Epoch 090] train_loss: 0.28854  val_loss: 0.36561
# [TimesNet-F2] [Epoch 091] train_loss: 0.28843  val_loss: 0.36555
# [TimesNet-F2] [Epoch 092] train_loss: 0.28804  val_loss: 0.36555
# [TimesNet-F2] [Epoch 093] train_loss: 0.28801  val_loss: 0.36555
# [TimesNet-F2] [Epoch 094] train_loss: 0.28770  val_loss: 0.36558
# [TimesNet-F2] [Epoch 095] train_loss: 0.28760  val_loss: 0.36554
# [TimesNet-F2] [Epoch 096] train_loss: 0.28750  val_loss: 0.36550
# [TimesNet-F2] [Epoch 097] train_loss: 0.28742  val_loss: 0.36551
# [TimesNet-F2] [Epoch 098] train_loss: 0.28707  val_loss: 0.36551
# [TimesNet-F2] [Epoch 099] train_loss: 0.28715  val_loss: 0.36555
# [TimesNet-F2] [Epoch 100] train_loss: 0.28693  val_loss: 0.36559
# [TimesNet-F2] [Epoch 101] train_loss: 0.28690  val_loss: 0.36560
# [TimesNet-F2] [Epoch 102] train_loss: 0.28650  val_loss: 0.36559
# [TimesNet-F2] [Epoch 103] train_loss: 0.28666  val_loss: 0.36558
# [TimesNet-F2] [Epoch 104] train_loss: 0.28648  val_loss: 0.36560
# [TimesNet-F2] [Epoch 105] train_loss: 0.28633  val_loss: 0.36556
# [TimesNet-F2] [Epoch 106] train_loss: 0.28634  val_loss: 0.36557
# [TimesNet-F2] [Epoch 107] train_loss: 0.28639  val_loss: 0.36556
# [TimesNet-F2] [Epoch 108] train_loss: 0.28626  val_loss: 0.36550
# [TimesNet-F2] [Epoch 109] train_loss: 0.28623  val_loss: 0.36550
# [TimesNet-F2] [Epoch 110] train_loss: 0.28599  val_loss: 0.36546
# [TimesNet-F2] [Epoch 111] train_loss: 0.28614  val_loss: 0.36544
# [TimesNet-F2] [Epoch 112] train_loss: 0.28614  val_loss: 0.36543
# [TimesNet-F2] [Epoch 113] train_loss: 0.28610  val_loss: 0.36541
# [TimesNet-F2] [Epoch 114] train_loss: 0.28585  val_loss: 0.36539
# [TimesNet-F2] [Epoch 115] train_loss: 0.28586  val_loss: 0.36538
# [TimesNet-F2] [Epoch 116] train_loss: 0.28587  val_loss: 0.36536
# [TimesNet-F2] [Epoch 117] train_loss: 0.28594  val_loss: 0.36537
# [TimesNet-F2] [Epoch 118] train_loss: 0.28570  val_loss: 0.36537
# [TimesNet-F2] [Epoch 119] train_loss: 0.28590  val_loss: 0.36534
# [TimesNet-F2] [Epoch 120] train_loss: 0.28589  val_loss: 0.36534
# [TimesNet-F3] [Epoch 001] train_loss: 0.44073  val_loss: 1.05841
# [TimesNet-F3] [Epoch 002] train_loss: 0.38301  val_loss: 0.99610
# [TimesNet-F3] [Epoch 003] train_loss: 0.37148  val_loss: 0.92780
# [TimesNet-F3] [Epoch 004] train_loss: 0.36441  val_loss: 0.86645
# [TimesNet-F3] [Epoch 005] train_loss: 0.35508  val_loss: 0.81424
# [TimesNet-F3] [Epoch 006] train_loss: 0.34785  val_loss: 0.77170
# [TimesNet-F3] [Epoch 007] train_loss: 0.34363  val_loss: 0.73589
# [TimesNet-F3] [Epoch 008] train_loss: 0.33988  val_loss: 0.70592
# [TimesNet-F3] [Epoch 009] train_loss: 0.33779  val_loss: 0.67899
# [TimesNet-F3] [Epoch 010] train_loss: 0.33523  val_loss: 0.65404
# [TimesNet-F3] [Epoch 011] train_loss: 0.33364  val_loss: 0.63134
# [TimesNet-F3] [Epoch 012] train_loss: 0.33191  val_loss: 0.61089
# [TimesNet-F3] [Epoch 013] train_loss: 0.33047  val_loss: 0.59246
# [TimesNet-F3] [Epoch 014] train_loss: 0.32902  val_loss: 0.57543
# [TimesNet-F3] [Epoch 015] train_loss: 0.32769  val_loss: 0.55912
# [TimesNet-F3] [Epoch 016] train_loss: 0.32656  val_loss: 0.54452
# [TimesNet-F3] [Epoch 017] train_loss: 0.32502  val_loss: 0.53130
# [TimesNet-F3] [Epoch 018] train_loss: 0.32436  val_loss: 0.51968
# [TimesNet-F3] [Epoch 019] train_loss: 0.32340  val_loss: 0.50904
# [TimesNet-F3] [Epoch 020] train_loss: 0.32230  val_loss: 0.49885
# [TimesNet-F3] [Epoch 021] train_loss: 0.32092  val_loss: 0.48876
# [TimesNet-F3] [Epoch 022] train_loss: 0.32020  val_loss: 0.47919
# [TimesNet-F3] [Epoch 023] train_loss: 0.31897  val_loss: 0.47044
# [TimesNet-F3] [Epoch 024] train_loss: 0.31840  val_loss: 0.46250
# [TimesNet-F3] [Epoch 025] train_loss: 0.31771  val_loss: 0.45488
# [TimesNet-F3] [Epoch 026] train_loss: 0.31626  val_loss: 0.44789
# [TimesNet-F3] [Epoch 027] train_loss: 0.31557  val_loss: 0.44062
# [TimesNet-F3] [Epoch 028] train_loss: 0.31498  val_loss: 0.43347
# [TimesNet-F3] [Epoch 029] train_loss: 0.31421  val_loss: 0.42666
# [TimesNet-F3] [Epoch 030] train_loss: 0.31335  val_loss: 0.42005
# [TimesNet-F3] [Epoch 031] train_loss: 0.31260  val_loss: 0.41395
# [TimesNet-F3] [Epoch 032] train_loss: 0.31176  val_loss: 0.40819
# [TimesNet-F3] [Epoch 033] train_loss: 0.31093  val_loss: 0.40289
# [TimesNet-F3] [Epoch 034] train_loss: 0.31017  val_loss: 0.39808
# [TimesNet-F3] [Epoch 035] train_loss: 0.30960  val_loss: 0.39354
# [TimesNet-F3] [Epoch 036] train_loss: 0.30845  val_loss: 0.38936
# [TimesNet-F3] [Epoch 037] train_loss: 0.30823  val_loss: 0.38578
# [TimesNet-F3] [Epoch 038] train_loss: 0.30754  val_loss: 0.38272
# [TimesNet-F3] [Epoch 039] train_loss: 0.30693  val_loss: 0.38007
# [TimesNet-F3] [Epoch 040] train_loss: 0.30627  val_loss: 0.37766
# [TimesNet-F3] [Epoch 041] train_loss: 0.30602  val_loss: 0.37551
# [TimesNet-F3] [Epoch 042] train_loss: 0.30534  val_loss: 0.37363
# [TimesNet-F3] [Epoch 043] train_loss: 0.30464  val_loss: 0.37192
# [TimesNet-F3] [Epoch 044] train_loss: 0.30397  val_loss: 0.37058
# [TimesNet-F3] [Epoch 045] train_loss: 0.30350  val_loss: 0.36937
# [TimesNet-F3] [Epoch 046] train_loss: 0.30294  val_loss: 0.36831
# [TimesNet-F3] [Epoch 047] train_loss: 0.30276  val_loss: 0.36740
# [TimesNet-F3] [Epoch 048] train_loss: 0.30189  val_loss: 0.36659
# [TimesNet-F3] [Epoch 049] train_loss: 0.30178  val_loss: 0.36590
# [TimesNet-F3] [Epoch 050] train_loss: 0.30091  val_loss: 0.36534
# [TimesNet-F3] [Epoch 051] train_loss: 0.30052  val_loss: 0.36482
# [TimesNet-F3] [Epoch 052] train_loss: 0.30021  val_loss: 0.36443
# [TimesNet-F3] [Epoch 053] train_loss: 0.29999  val_loss: 0.36413
# [TimesNet-F3] [Epoch 054] train_loss: 0.29936  val_loss: 0.36394
# [TimesNet-F3] [Epoch 055] train_loss: 0.29902  val_loss: 0.36365
# [TimesNet-F3] [Epoch 056] train_loss: 0.29833  val_loss: 0.36345
# [TimesNet-F3] [Epoch 057] train_loss: 0.29804  val_loss: 0.36328
# [TimesNet-F3] [Epoch 058] train_loss: 0.29770  val_loss: 0.36309
# [TimesNet-F3] [Epoch 059] train_loss: 0.29719  val_loss: 0.36296
# [TimesNet-F3] [Epoch 060] train_loss: 0.29718  val_loss: 0.36288
# [TimesNet-F3] [Epoch 061] train_loss: 0.29650  val_loss: 0.36277
# [TimesNet-F3] [Epoch 062] train_loss: 0.29605  val_loss: 0.36264
# [TimesNet-F3] [Epoch 063] train_loss: 0.29591  val_loss: 0.36256
# [TimesNet-F3] [Epoch 064] train_loss: 0.29524  val_loss: 0.36253
# [TimesNet-F3] [Epoch 065] train_loss: 0.29504  val_loss: 0.36248
# [TimesNet-F3] [Epoch 066] train_loss: 0.29439  val_loss: 0.36247
# [TimesNet-F3] [Epoch 067] train_loss: 0.29434  val_loss: 0.36243
# [TimesNet-F3] [Epoch 068] train_loss: 0.29436  val_loss: 0.36244
# [TimesNet-F3] [Epoch 069] train_loss: 0.29355  val_loss: 0.36242
# [TimesNet-F3] [Epoch 070] train_loss: 0.29311  val_loss: 0.36243
# [TimesNet-F3] [Epoch 071] train_loss: 0.29297  val_loss: 0.36250
# [TimesNet-F3] [Epoch 072] train_loss: 0.29268  val_loss: 0.36247
# [TimesNet-F3] [Epoch 073] train_loss: 0.29237  val_loss: 0.36251
# [TimesNet-F3] [Epoch 074] train_loss: 0.29200  val_loss: 0.36249
# [TimesNet-F3] [Epoch 075] train_loss: 0.29195  val_loss: 0.36252
# [TimesNet-F3] [Epoch 076] train_loss: 0.29147  val_loss: 0.36248
# [TimesNet-F3] [Epoch 077] train_loss: 0.29111  val_loss: 0.36247
# [TimesNet-F3] [Epoch 078] train_loss: 0.29120  val_loss: 0.36243
# [TimesNet-F3] [Epoch 079] train_loss: 0.29079  val_loss: 0.36244
# [TimesNet-F3] [Epoch 080] train_loss: 0.29031  val_loss: 0.36248
# [TimesNet-F3] [Epoch 081] train_loss: 0.29006  val_loss: 0.36246
# [TimesNet-F3] [Epoch 082] train_loss: 0.28990  val_loss: 0.36253
# [TimesNet-F3] [Epoch 083] train_loss: 0.28983  val_loss: 0.36248
# [TimesNet-F3] Early stopping at epoch 83
# [VAL(avg over folds)] TimesNet=0.36938
# 📚 GRU 학습...
# [GRU-F1] [Epoch 001] train_loss: 0.39860  val_loss: 0.78579
# [GRU-F1] [Epoch 002] train_loss: 0.35302  val_loss: 0.71802
# [GRU-F1] [Epoch 003] train_loss: 0.34387  val_loss: 0.65886
# [GRU-F1] [Epoch 004] train_loss: 0.33928  val_loss: 0.62002
# [GRU-F1] [Epoch 005] train_loss: 0.33560  val_loss: 0.60917
# [GRU-F1] [Epoch 006] train_loss: 0.33203  val_loss: 0.61713
# [GRU-F1] [Epoch 007] train_loss: 0.32813  val_loss: 0.62824
# [GRU-F1] [Epoch 008] train_loss: 0.32391  val_loss: 0.63454
# [GRU-F1] [Epoch 009] train_loss: 0.32035  val_loss: 0.63422
# [GRU-F1] [Epoch 010] train_loss: 0.31644  val_loss: 0.62794
# [GRU-F1] [Epoch 011] train_loss: 0.31218  val_loss: 0.61667
# [GRU-F1] [Epoch 012] train_loss: 0.30790  val_loss: 0.60354
# [GRU-F1] [Epoch 013] train_loss: 0.30346  val_loss: 0.59107
# [GRU-F1] [Epoch 014] train_loss: 0.29889  val_loss: 0.57782
# [GRU-F1] [Epoch 015] train_loss: 0.29441  val_loss: 0.56532
# [GRU-F1] [Epoch 016] train_loss: 0.28852  val_loss: 0.55310
# [GRU-F1] [Epoch 017] train_loss: 0.28362  val_loss: 0.54031
# [GRU-F1] [Epoch 018] train_loss: 0.27892  val_loss: 0.52768
# [GRU-F1] [Epoch 019] train_loss: 0.27364  val_loss: 0.51577
# [GRU-F1] [Epoch 020] train_loss: 0.26846  val_loss: 0.50428
# [GRU-F1] [Epoch 021] train_loss: 0.26400  val_loss: 0.49350
# [GRU-F1] [Epoch 022] train_loss: 0.25938  val_loss: 0.48336
# [GRU-F1] [Epoch 023] train_loss: 0.25537  val_loss: 0.47404
# [GRU-F1] [Epoch 024] train_loss: 0.25139  val_loss: 0.46558
# [GRU-F1] [Epoch 025] train_loss: 0.24748  val_loss: 0.45791
# [GRU-F1] [Epoch 026] train_loss: 0.24417  val_loss: 0.45069
# [GRU-F1] [Epoch 027] train_loss: 0.24057  val_loss: 0.44419
# [GRU-F1] [Epoch 028] train_loss: 0.23758  val_loss: 0.43805
# [GRU-F1] [Epoch 029] train_loss: 0.23404  val_loss: 0.43253
# [GRU-F1] [Epoch 030] train_loss: 0.23132  val_loss: 0.42760
# [GRU-F1] [Epoch 031] train_loss: 0.22854  val_loss: 0.42324
# [GRU-F1] [Epoch 032] train_loss: 0.22546  val_loss: 0.41944
# [GRU-F1] [Epoch 033] train_loss: 0.22239  val_loss: 0.41590
# [GRU-F1] [Epoch 034] train_loss: 0.22013  val_loss: 0.41267
# [GRU-F1] [Epoch 035] train_loss: 0.21709  val_loss: 0.40978
# [GRU-F1] [Epoch 036] train_loss: 0.21475  val_loss: 0.40698
# [GRU-F1] [Epoch 037] train_loss: 0.21180  val_loss: 0.40420
# [GRU-F1] [Epoch 038] train_loss: 0.20921  val_loss: 0.40155
# [GRU-F1] [Epoch 039] train_loss: 0.20675  val_loss: 0.39913
# [GRU-F1] [Epoch 040] train_loss: 0.20457  val_loss: 0.39673
# [GRU-F1] [Epoch 041] train_loss: 0.20249  val_loss: 0.39443
# [GRU-F1] [Epoch 042] train_loss: 0.20020  val_loss: 0.39216
# [GRU-F1] [Epoch 043] train_loss: 0.19802  val_loss: 0.38984
# [GRU-F1] [Epoch 044] train_loss: 0.19654  val_loss: 0.38754
# [GRU-F1] [Epoch 045] train_loss: 0.19451  val_loss: 0.38539
# [GRU-F1] [Epoch 046] train_loss: 0.19260  val_loss: 0.38336
# [GRU-F1] [Epoch 047] train_loss: 0.19093  val_loss: 0.38133
# [GRU-F1] [Epoch 048] train_loss: 0.18947  val_loss: 0.37943
# [GRU-F1] [Epoch 049] train_loss: 0.18776  val_loss: 0.37754
# [GRU-F1] [Epoch 050] train_loss: 0.18639  val_loss: 0.37577
# [GRU-F1] [Epoch 051] train_loss: 0.18454  val_loss: 0.37409
# [GRU-F1] [Epoch 052] train_loss: 0.18370  val_loss: 0.37242
# [GRU-F1] [Epoch 053] train_loss: 0.18226  val_loss: 0.37092
# [GRU-F1] [Epoch 054] train_loss: 0.18045  val_loss: 0.36949
# [GRU-F1] [Epoch 055] train_loss: 0.17948  val_loss: 0.36810
# [GRU-F1] [Epoch 056] train_loss: 0.17851  val_loss: 0.36673
# [GRU-F1] [Epoch 057] train_loss: 0.17729  val_loss: 0.36548
# [GRU-F1] [Epoch 058] train_loss: 0.17585  val_loss: 0.36420
# [GRU-F1] [Epoch 059] train_loss: 0.17479  val_loss: 0.36305
# [GRU-F1] [Epoch 060] train_loss: 0.17378  val_loss: 0.36193
# [GRU-F1] [Epoch 061] train_loss: 0.17292  val_loss: 0.36091
# [GRU-F1] [Epoch 062] train_loss: 0.17171  val_loss: 0.36007
# [GRU-F1] [Epoch 063] train_loss: 0.17074  val_loss: 0.35925
# [GRU-F1] [Epoch 064] train_loss: 0.17018  val_loss: 0.35841
# [GRU-F1] [Epoch 065] train_loss: 0.16907  val_loss: 0.35759
# [GRU-F1] [Epoch 066] train_loss: 0.16810  val_loss: 0.35682
# [GRU-F1] [Epoch 067] train_loss: 0.16708  val_loss: 0.35614
# [GRU-F1] [Epoch 068] train_loss: 0.16633  val_loss: 0.35556
# [GRU-F1] [Epoch 069] train_loss: 0.16552  val_loss: 0.35498
# [GRU-F1] [Epoch 070] train_loss: 0.16475  val_loss: 0.35439
# [GRU-F1] [Epoch 071] train_loss: 0.16381  val_loss: 0.35386
# [GRU-F1] [Epoch 072] train_loss: 0.16312  val_loss: 0.35330
# [GRU-F1] [Epoch 073] train_loss: 0.16221  val_loss: 0.35287
# [GRU-F1] [Epoch 074] train_loss: 0.16159  val_loss: 0.35243
# [GRU-F1] [Epoch 075] train_loss: 0.16090  val_loss: 0.35204
# [GRU-F1] [Epoch 076] train_loss: 0.16038  val_loss: 0.35174
# [GRU-F1] [Epoch 077] train_loss: 0.15942  val_loss: 0.35141
# [GRU-F1] [Epoch 078] train_loss: 0.15905  val_loss: 0.35114
# [GRU-F1] [Epoch 079] train_loss: 0.15841  val_loss: 0.35095
# [GRU-F1] [Epoch 080] train_loss: 0.15780  val_loss: 0.35068
# [GRU-F1] [Epoch 081] train_loss: 0.15731  val_loss: 0.35046
# [GRU-F1] [Epoch 082] train_loss: 0.15652  val_loss: 0.35023
# [GRU-F1] [Epoch 083] train_loss: 0.15608  val_loss: 0.34999
# [GRU-F1] [Epoch 084] train_loss: 0.15549  val_loss: 0.34973
# [GRU-F1] [Epoch 085] train_loss: 0.15505  val_loss: 0.34946
# [GRU-F1] [Epoch 086] train_loss: 0.15436  val_loss: 0.34935
# [GRU-F1] [Epoch 087] train_loss: 0.15407  val_loss: 0.34921
# [GRU-F1] [Epoch 088] train_loss: 0.15342  val_loss: 0.34911
# [GRU-F1] [Epoch 089] train_loss: 0.15301  val_loss: 0.34899
# [GRU-F1] [Epoch 090] train_loss: 0.15272  val_loss: 0.34881
# [GRU-F1] [Epoch 091] train_loss: 0.15239  val_loss: 0.34867
# [GRU-F1] [Epoch 092] train_loss: 0.15200  val_loss: 0.34856
# [GRU-F1] [Epoch 093] train_loss: 0.15152  val_loss: 0.34846
# [GRU-F1] [Epoch 094] train_loss: 0.15106  val_loss: 0.34840
# [GRU-F1] [Epoch 095] train_loss: 0.15090  val_loss: 0.34833
# [GRU-F1] [Epoch 096] train_loss: 0.15054  val_loss: 0.34822
# [GRU-F1] [Epoch 097] train_loss: 0.15013  val_loss: 0.34814
# [GRU-F1] [Epoch 098] train_loss: 0.14997  val_loss: 0.34807
# [GRU-F1] [Epoch 099] train_loss: 0.14961  val_loss: 0.34798
# [GRU-F1] [Epoch 100] train_loss: 0.14936  val_loss: 0.34795
# [GRU-F1] [Epoch 101] train_loss: 0.14898  val_loss: 0.34788
# [GRU-F1] [Epoch 102] train_loss: 0.14874  val_loss: 0.34781
# [GRU-F1] [Epoch 103] train_loss: 0.14872  val_loss: 0.34775
# [GRU-F1] [Epoch 104] train_loss: 0.14838  val_loss: 0.34766
# [GRU-F1] [Epoch 105] train_loss: 0.14822  val_loss: 0.34763
# [GRU-F1] [Epoch 106] train_loss: 0.14791  val_loss: 0.34759
# [GRU-F1] [Epoch 107] train_loss: 0.14784  val_loss: 0.34752
# [GRU-F1] [Epoch 108] train_loss: 0.14768  val_loss: 0.34749
# [GRU-F1] [Epoch 109] train_loss: 0.14765  val_loss: 0.34745
# [GRU-F1] [Epoch 110] train_loss: 0.14742  val_loss: 0.34740
# [GRU-F1] [Epoch 111] train_loss: 0.14731  val_loss: 0.34738
# [GRU-F1] [Epoch 112] train_loss: 0.14719  val_loss: 0.34737
# [GRU-F1] [Epoch 113] train_loss: 0.14698  val_loss: 0.34737
# [GRU-F1] [Epoch 114] train_loss: 0.14708  val_loss: 0.34738
# [GRU-F1] [Epoch 115] train_loss: 0.14689  val_loss: 0.34740
# [GRU-F1] [Epoch 116] train_loss: 0.14701  val_loss: 0.34739
# [GRU-F1] [Epoch 117] train_loss: 0.14681  val_loss: 0.34738
# [GRU-F1] [Epoch 118] train_loss: 0.14694  val_loss: 0.34740
# [GRU-F1] [Epoch 119] train_loss: 0.14697  val_loss: 0.34739
# [GRU-F1] [Epoch 120] train_loss: 0.14693  val_loss: 0.34739
# [GRU-F2] [Epoch 001] train_loss: 0.39946  val_loss: 0.77176
# [GRU-F2] [Epoch 002] train_loss: 0.35428  val_loss: 0.70168
# [GRU-F2] [Epoch 003] train_loss: 0.34426  val_loss: 0.64021
# [GRU-F2] [Epoch 004] train_loss: 0.33955  val_loss: 0.60366
# [GRU-F2] [Epoch 005] train_loss: 0.33581  val_loss: 0.59223
# [GRU-F2] [Epoch 006] train_loss: 0.33237  val_loss: 0.59881
# [GRU-F2] [Epoch 007] train_loss: 0.32801  val_loss: 0.61093
# [GRU-F2] [Epoch 008] train_loss: 0.32436  val_loss: 0.61760
# [GRU-F2] [Epoch 009] train_loss: 0.32094  val_loss: 0.61136
# [GRU-F2] [Epoch 010] train_loss: 0.31629  val_loss: 0.59945
# [GRU-F2] [Epoch 011] train_loss: 0.31244  val_loss: 0.58232
# [GRU-F2] [Epoch 012] train_loss: 0.30819  val_loss: 0.56500
# [GRU-F2] [Epoch 013] train_loss: 0.30369  val_loss: 0.55028
# [GRU-F2] [Epoch 014] train_loss: 0.29858  val_loss: 0.53657
# [GRU-F2] [Epoch 015] train_loss: 0.29374  val_loss: 0.52290
# [GRU-F2] [Epoch 016] train_loss: 0.28879  val_loss: 0.50928
# [GRU-F2] [Epoch 017] train_loss: 0.28367  val_loss: 0.49551
# [GRU-F2] [Epoch 018] train_loss: 0.27822  val_loss: 0.48217
# [GRU-F2] [Epoch 019] train_loss: 0.27317  val_loss: 0.46954
# [GRU-F2] [Epoch 020] train_loss: 0.26838  val_loss: 0.45762
# [GRU-F2] [Epoch 021] train_loss: 0.26324  val_loss: 0.44663
# [GRU-F2] [Epoch 022] train_loss: 0.25896  val_loss: 0.43663
# [GRU-F2] [Epoch 023] train_loss: 0.25463  val_loss: 0.42777
# [GRU-F2] [Epoch 024] train_loss: 0.25084  val_loss: 0.41954
# [GRU-F2] [Epoch 025] train_loss: 0.24687  val_loss: 0.41221
# [GRU-F2] [Epoch 026] train_loss: 0.24266  val_loss: 0.40620
# [GRU-F2] [Epoch 027] train_loss: 0.23933  val_loss: 0.40093
# [GRU-F2] [Epoch 028] train_loss: 0.23609  val_loss: 0.39647
# [GRU-F2] [Epoch 029] train_loss: 0.23269  val_loss: 0.39248
# [GRU-F2] [Epoch 030] train_loss: 0.22949  val_loss: 0.38887
# [GRU-F2] [Epoch 031] train_loss: 0.22565  val_loss: 0.38548
# [GRU-F2] [Epoch 032] train_loss: 0.22256  val_loss: 0.38249
# [GRU-F2] [Epoch 033] train_loss: 0.21968  val_loss: 0.37963
# [GRU-F2] [Epoch 034] train_loss: 0.21672  val_loss: 0.37701
# [GRU-F2] [Epoch 035] train_loss: 0.21416  val_loss: 0.37452
# [GRU-F2] [Epoch 036] train_loss: 0.21092  val_loss: 0.37217
# [GRU-F2] [Epoch 037] train_loss: 0.20865  val_loss: 0.36986
# [GRU-F2] [Epoch 038] train_loss: 0.20594  val_loss: 0.36767
# [GRU-F2] [Epoch 039] train_loss: 0.20351  val_loss: 0.36546
# [GRU-F2] [Epoch 040] train_loss: 0.20105  val_loss: 0.36338
# [GRU-F2] [Epoch 041] train_loss: 0.19897  val_loss: 0.36139
# [GRU-F2] [Epoch 042] train_loss: 0.19700  val_loss: 0.35932
# [GRU-F2] [Epoch 043] train_loss: 0.19563  val_loss: 0.35729
# [GRU-F2] [Epoch 044] train_loss: 0.19303  val_loss: 0.35529
# [GRU-F2] [Epoch 045] train_loss: 0.19151  val_loss: 0.35345
# [GRU-F2] [Epoch 046] train_loss: 0.18983  val_loss: 0.35165
# [GRU-F2] [Epoch 047] train_loss: 0.18781  val_loss: 0.34997
# [GRU-F2] [Epoch 048] train_loss: 0.18634  val_loss: 0.34843
# [GRU-F2] [Epoch 049] train_loss: 0.18498  val_loss: 0.34699
# [GRU-F2] [Epoch 050] train_loss: 0.18354  val_loss: 0.34576
# [GRU-F2] [Epoch 051] train_loss: 0.18250  val_loss: 0.34440
# [GRU-F2] [Epoch 052] train_loss: 0.18087  val_loss: 0.34315
# [GRU-F2] [Epoch 053] train_loss: 0.17950  val_loss: 0.34202
# [GRU-F2] [Epoch 054] train_loss: 0.17828  val_loss: 0.34090
# [GRU-F2] [Epoch 055] train_loss: 0.17715  val_loss: 0.33982
# [GRU-F2] [Epoch 056] train_loss: 0.17581  val_loss: 0.33877
# [GRU-F2] [Epoch 057] train_loss: 0.17459  val_loss: 0.33786
# [GRU-F2] [Epoch 058] train_loss: 0.17377  val_loss: 0.33701
# [GRU-F2] [Epoch 059] train_loss: 0.17274  val_loss: 0.33618
# [GRU-F2] [Epoch 060] train_loss: 0.17160  val_loss: 0.33535
# [GRU-F2] [Epoch 061] train_loss: 0.17062  val_loss: 0.33465
# [GRU-F2] [Epoch 062] train_loss: 0.16984  val_loss: 0.33398
# [GRU-F2] [Epoch 063] train_loss: 0.16885  val_loss: 0.33340
# [GRU-F2] [Epoch 064] train_loss: 0.16763  val_loss: 0.33283
# [GRU-F2] [Epoch 065] train_loss: 0.16664  val_loss: 0.33235
# [GRU-F2] [Epoch 066] train_loss: 0.16594  val_loss: 0.33183
# [GRU-F2] [Epoch 067] train_loss: 0.16523  val_loss: 0.33144
# [GRU-F2] [Epoch 068] train_loss: 0.16448  val_loss: 0.33111
# [GRU-F2] [Epoch 069] train_loss: 0.16362  val_loss: 0.33080
# [GRU-F2] [Epoch 070] train_loss: 0.16288  val_loss: 0.33056
# [GRU-F2] [Epoch 071] train_loss: 0.16213  val_loss: 0.33035
# [GRU-F2] [Epoch 072] train_loss: 0.16138  val_loss: 0.33001
# [GRU-F2] [Epoch 073] train_loss: 0.16060  val_loss: 0.32974
# [GRU-F2] [Epoch 074] train_loss: 0.15983  val_loss: 0.32950
# [GRU-F2] [Epoch 075] train_loss: 0.15920  val_loss: 0.32928
# [GRU-F2] [Epoch 076] train_loss: 0.15840  val_loss: 0.32907
# [GRU-F2] [Epoch 077] train_loss: 0.15794  val_loss: 0.32896
# [GRU-F2] [Epoch 078] train_loss: 0.15739  val_loss: 0.32887
# [GRU-F2] [Epoch 079] train_loss: 0.15674  val_loss: 0.32887
# [GRU-F2] [Epoch 080] train_loss: 0.15602  val_loss: 0.32878
# [GRU-F2] [Epoch 081] train_loss: 0.15563  val_loss: 0.32882
# [GRU-F2] [Epoch 082] train_loss: 0.15503  val_loss: 0.32882
# [GRU-F2] [Epoch 083] train_loss: 0.15441  val_loss: 0.32883
# [GRU-F2] [Epoch 084] train_loss: 0.15380  val_loss: 0.32884
# [GRU-F2] [Epoch 085] train_loss: 0.15360  val_loss: 0.32889
# [GRU-F2] [Epoch 086] train_loss: 0.15307  val_loss: 0.32889
# [GRU-F2] [Epoch 087] train_loss: 0.15247  val_loss: 0.32892
# [GRU-F2] [Epoch 088] train_loss: 0.15201  val_loss: 0.32893
# [GRU-F2] [Epoch 089] train_loss: 0.15164  val_loss: 0.32898
# [GRU-F2] [Epoch 090] train_loss: 0.15134  val_loss: 0.32899
# [GRU-F2] [Epoch 091] train_loss: 0.15062  val_loss: 0.32911
# [GRU-F2] [Epoch 092] train_loss: 0.15036  val_loss: 0.32919
# [GRU-F2] [Epoch 093] train_loss: 0.15007  val_loss: 0.32928
# [GRU-F2] [Epoch 094] train_loss: 0.14967  val_loss: 0.32938
# [GRU-F2] Early stopping at epoch 94
# [GRU-F3] [Epoch 001] train_loss: 0.39804  val_loss: 0.78406
# [GRU-F3] [Epoch 002] train_loss: 0.35363  val_loss: 0.71395
# [GRU-F3] [Epoch 003] train_loss: 0.34408  val_loss: 0.64850
# [GRU-F3] [Epoch 004] train_loss: 0.33935  val_loss: 0.60729
# [GRU-F3] [Epoch 005] train_loss: 0.33574  val_loss: 0.59403
# [GRU-F3] [Epoch 006] train_loss: 0.33162  val_loss: 0.60130
# [GRU-F3] [Epoch 007] train_loss: 0.32785  val_loss: 0.61384
# [GRU-F3] [Epoch 008] train_loss: 0.32440  val_loss: 0.62350
# [GRU-F3] [Epoch 009] train_loss: 0.32070  val_loss: 0.62336
# [GRU-F3] [Epoch 010] train_loss: 0.31675  val_loss: 0.61408
# [GRU-F3] [Epoch 011] train_loss: 0.31285  val_loss: 0.60039
# [GRU-F3] [Epoch 012] train_loss: 0.30877  val_loss: 0.58604
# [GRU-F3] [Epoch 013] train_loss: 0.30464  val_loss: 0.57118
# [GRU-F3] [Epoch 014] train_loss: 0.29991  val_loss: 0.55700
# [GRU-F3] [Epoch 015] train_loss: 0.29459  val_loss: 0.54184
# [GRU-F3] [Epoch 016] train_loss: 0.29021  val_loss: 0.52655
# [GRU-F3] [Epoch 017] train_loss: 0.28508  val_loss: 0.51177
# [GRU-F3] [Epoch 018] train_loss: 0.27963  val_loss: 0.49733
# [GRU-F3] [Epoch 019] train_loss: 0.27571  val_loss: 0.48321
# [GRU-F3] [Epoch 020] train_loss: 0.27030  val_loss: 0.46968
# [GRU-F3] [Epoch 021] train_loss: 0.26546  val_loss: 0.45710
# [GRU-F3] [Epoch 022] train_loss: 0.26093  val_loss: 0.44575
# [GRU-F3] [Epoch 023] train_loss: 0.25678  val_loss: 0.43560
# [GRU-F3] [Epoch 024] train_loss: 0.25287  val_loss: 0.42687
# [GRU-F3] [Epoch 025] train_loss: 0.24939  val_loss: 0.41871
# [GRU-F3] [Epoch 026] train_loss: 0.24581  val_loss: 0.41156
# [GRU-F3] [Epoch 027] train_loss: 0.24216  val_loss: 0.40514
# [GRU-F3] [Epoch 028] train_loss: 0.23868  val_loss: 0.39973
# [GRU-F3] [Epoch 029] train_loss: 0.23624  val_loss: 0.39471
# [GRU-F3] [Epoch 030] train_loss: 0.23269  val_loss: 0.39012
# [GRU-F3] [Epoch 031] train_loss: 0.22982  val_loss: 0.38616
# [GRU-F3] [Epoch 032] train_loss: 0.22702  val_loss: 0.38271
# [GRU-F3] [Epoch 033] train_loss: 0.22463  val_loss: 0.37958
# [GRU-F3] [Epoch 034] train_loss: 0.22186  val_loss: 0.37680
# [GRU-F3] [Epoch 035] train_loss: 0.21901  val_loss: 0.37435
# [GRU-F3] [Epoch 036] train_loss: 0.21648  val_loss: 0.37224
# [GRU-F3] [Epoch 037] train_loss: 0.21411  val_loss: 0.37007
# [GRU-F3] [Epoch 038] train_loss: 0.21150  val_loss: 0.36812
# [GRU-F3] [Epoch 039] train_loss: 0.20882  val_loss: 0.36626
# [GRU-F3] [Epoch 040] train_loss: 0.20648  val_loss: 0.36466
# [GRU-F3] [Epoch 041] train_loss: 0.20447  val_loss: 0.36322
# [GRU-F3] [Epoch 042] train_loss: 0.20209  val_loss: 0.36197
# [GRU-F3] [Epoch 043] train_loss: 0.20012  val_loss: 0.36079
# [GRU-F3] [Epoch 044] train_loss: 0.19810  val_loss: 0.35969
# [GRU-F3] [Epoch 045] train_loss: 0.19569  val_loss: 0.35856
# [GRU-F3] [Epoch 046] train_loss: 0.19407  val_loss: 0.35750
# [GRU-F3] [Epoch 047] train_loss: 0.19239  val_loss: 0.35647
# [GRU-F3] [Epoch 048] train_loss: 0.19058  val_loss: 0.35542
# [GRU-F3] [Epoch 049] train_loss: 0.18908  val_loss: 0.35433
# [GRU-F3] [Epoch 050] train_loss: 0.18729  val_loss: 0.35322
# [GRU-F3] [Epoch 051] train_loss: 0.18630  val_loss: 0.35206
# [GRU-F3] [Epoch 052] train_loss: 0.18449  val_loss: 0.35079
# [GRU-F3] [Epoch 053] train_loss: 0.18310  val_loss: 0.34949
# [GRU-F3] [Epoch 054] train_loss: 0.18200  val_loss: 0.34823
# [GRU-F3] [Epoch 055] train_loss: 0.18079  val_loss: 0.34696
# [GRU-F3] [Epoch 056] train_loss: 0.17940  val_loss: 0.34562
# [GRU-F3] [Epoch 057] train_loss: 0.17841  val_loss: 0.34448
# [GRU-F3] [Epoch 058] train_loss: 0.17693  val_loss: 0.34338
# [GRU-F3] [Epoch 059] train_loss: 0.17565  val_loss: 0.34232
# [GRU-F3] [Epoch 060] train_loss: 0.17462  val_loss: 0.34124
# [GRU-F3] [Epoch 061] train_loss: 0.17357  val_loss: 0.34018
# [GRU-F3] [Epoch 062] train_loss: 0.17228  val_loss: 0.33913
# [GRU-F3] [Epoch 063] train_loss: 0.17152  val_loss: 0.33820
# [GRU-F3] [Epoch 064] train_loss: 0.17050  val_loss: 0.33726
# [GRU-F3] [Epoch 065] train_loss: 0.16962  val_loss: 0.33646
# [GRU-F3] [Epoch 066] train_loss: 0.16860  val_loss: 0.33566
# [GRU-F3] [Epoch 067] train_loss: 0.16801  val_loss: 0.33495
# [GRU-F3] [Epoch 068] train_loss: 0.16704  val_loss: 0.33425
# [GRU-F3] [Epoch 069] train_loss: 0.16616  val_loss: 0.33364
# [GRU-F3] [Epoch 070] train_loss: 0.16534  val_loss: 0.33303
# [GRU-F3] [Epoch 071] train_loss: 0.16466  val_loss: 0.33236
# [GRU-F3] [Epoch 072] train_loss: 0.16381  val_loss: 0.33179
# [GRU-F3] [Epoch 073] train_loss: 0.16294  val_loss: 0.33120
# [GRU-F3] [Epoch 074] train_loss: 0.16220  val_loss: 0.33074
# [GRU-F3] [Epoch 075] train_loss: 0.16150  val_loss: 0.33032
# [GRU-F3] [Epoch 076] train_loss: 0.16070  val_loss: 0.32992
# [GRU-F3] [Epoch 077] train_loss: 0.16038  val_loss: 0.32957
# [GRU-F3] [Epoch 078] train_loss: 0.15959  val_loss: 0.32916
# [GRU-F3] [Epoch 079] train_loss: 0.15876  val_loss: 0.32883
# [GRU-F3] [Epoch 080] train_loss: 0.15842  val_loss: 0.32858
# [GRU-F3] [Epoch 081] train_loss: 0.15788  val_loss: 0.32830
# [GRU-F3] [Epoch 082] train_loss: 0.15719  val_loss: 0.32799
# [GRU-F3] [Epoch 083] train_loss: 0.15651  val_loss: 0.32768
# [GRU-F3] [Epoch 084] train_loss: 0.15607  val_loss: 0.32743
# [GRU-F3] [Epoch 085] train_loss: 0.15540  val_loss: 0.32718
# [GRU-F3] [Epoch 086] train_loss: 0.15496  val_loss: 0.32695
# [GRU-F3] [Epoch 087] train_loss: 0.15464  val_loss: 0.32679
# [GRU-F3] [Epoch 088] train_loss: 0.15405  val_loss: 0.32665
# [GRU-F3] [Epoch 089] train_loss: 0.15345  val_loss: 0.32651
# [GRU-F3] [Epoch 090] train_loss: 0.15309  val_loss: 0.32633
# [GRU-F3] [Epoch 091] train_loss: 0.15283  val_loss: 0.32618
# [GRU-F3] [Epoch 092] train_loss: 0.15246  val_loss: 0.32603
# [GRU-F3] [Epoch 093] train_loss: 0.15201  val_loss: 0.32587
# [GRU-F3] [Epoch 094] train_loss: 0.15161  val_loss: 0.32571
# [GRU-F3] [Epoch 095] train_loss: 0.15123  val_loss: 0.32559
# [GRU-F3] [Epoch 096] train_loss: 0.15094  val_loss: 0.32551
# [GRU-F3] [Epoch 097] train_loss: 0.15064  val_loss: 0.32541
# [GRU-F3] [Epoch 098] train_loss: 0.15030  val_loss: 0.32533
# [GRU-F3] [Epoch 099] train_loss: 0.14997  val_loss: 0.32525
# [GRU-F3] [Epoch 100] train_loss: 0.14981  val_loss: 0.32515
# [GRU-F3] [Epoch 101] train_loss: 0.14946  val_loss: 0.32510
# [GRU-F3] [Epoch 102] train_loss: 0.14932  val_loss: 0.32503
# [GRU-F3] [Epoch 103] train_loss: 0.14905  val_loss: 0.32496
# [GRU-F3] [Epoch 104] train_loss: 0.14876  val_loss: 0.32489
# [GRU-F3] [Epoch 105] train_loss: 0.14865  val_loss: 0.32481
# [GRU-F3] [Epoch 106] train_loss: 0.14840  val_loss: 0.32476
# [GRU-F3] [Epoch 107] train_loss: 0.14826  val_loss: 0.32473
# [GRU-F3] [Epoch 108] train_loss: 0.14805  val_loss: 0.32469
# [GRU-F3] [Epoch 109] train_loss: 0.14802  val_loss: 0.32465
# [GRU-F3] [Epoch 110] train_loss: 0.14789  val_loss: 0.32462
# [GRU-F3] [Epoch 111] train_loss: 0.14773  val_loss: 0.32460
# [GRU-F3] [Epoch 112] train_loss: 0.14759  val_loss: 0.32456
# [GRU-F3] [Epoch 113] train_loss: 0.14760  val_loss: 0.32454
# [GRU-F3] [Epoch 114] train_loss: 0.14749  val_loss: 0.32455
# [GRU-F3] [Epoch 115] train_loss: 0.14759  val_loss: 0.32455
# [GRU-F3] [Epoch 116] train_loss: 0.14745  val_loss: 0.32455
# [GRU-F3] [Epoch 117] train_loss: 0.14733  val_loss: 0.32454
# [GRU-F3] [Epoch 118] train_loss: 0.14728  val_loss: 0.32453
# [GRU-F3] [Epoch 119] train_loss: 0.14729  val_loss: 0.32452
# [GRU-F3] [Epoch 120] train_loss: 0.14730  val_loss: 0.32454
# [VAL(avg over folds)] GRU=0.33355
# 📚 MLinear 학습...
# [MLinear-F1] [Epoch 001] train_loss: 0.76183  val_loss: 0.93732
# [MLinear-F1] [Epoch 002] train_loss: 0.68564  val_loss: 0.91453
# [MLinear-F1] [Epoch 003] train_loss: 0.64939  val_loss: 0.88502
# [MLinear-F1] [Epoch 004] train_loss: 0.60622  val_loss: 0.85320
# [MLinear-F1] [Epoch 005] train_loss: 0.54059  val_loss: 0.82122
# [MLinear-F1] [Epoch 006] train_loss: 0.50056  val_loss: 0.79070
# [MLinear-F1] [Epoch 007] train_loss: 0.47347  val_loss: 0.76102
# [MLinear-F1] [Epoch 008] train_loss: 0.45970  val_loss: 0.72318
# [MLinear-F1] [Epoch 009] train_loss: 0.44871  val_loss: 0.68835
# [MLinear-F1] [Epoch 010] train_loss: 0.44038  val_loss: 0.65949
# [MLinear-F1] [Epoch 011] train_loss: 0.43444  val_loss: 0.63314
# [MLinear-F1] [Epoch 012] train_loss: 0.43062  val_loss: 0.61130
# [MLinear-F1] [Epoch 013] train_loss: 0.42785  val_loss: 0.59544
# [MLinear-F1] [Epoch 014] train_loss: 0.42593  val_loss: 0.58352
# [MLinear-F1] [Epoch 015] train_loss: 0.42422  val_loss: 0.57466
# [MLinear-F1] [Epoch 016] train_loss: 0.42323  val_loss: 0.56714
# [MLinear-F1] [Epoch 017] train_loss: 0.42188  val_loss: 0.56042
# [MLinear-F1] [Epoch 018] train_loss: 0.42083  val_loss: 0.55379
# [MLinear-F1] [Epoch 019] train_loss: 0.42030  val_loss: 0.54729
# [MLinear-F1] [Epoch 020] train_loss: 0.41924  val_loss: 0.54115
# [MLinear-F1] [Epoch 021] train_loss: 0.41886  val_loss: 0.53563
# [MLinear-F1] [Epoch 022] train_loss: 0.41799  val_loss: 0.53057
# [MLinear-F1] [Epoch 023] train_loss: 0.41759  val_loss: 0.52611
# [MLinear-F1] [Epoch 024] train_loss: 0.41689  val_loss: 0.52214
# [MLinear-F1] [Epoch 025] train_loss: 0.41615  val_loss: 0.51864
# [MLinear-F1] [Epoch 026] train_loss: 0.41582  val_loss: 0.51550
# [MLinear-F1] [Epoch 027] train_loss: 0.41502  val_loss: 0.51261
# [MLinear-F1] [Epoch 028] train_loss: 0.41437  val_loss: 0.50999
# [MLinear-F1] [Epoch 029] train_loss: 0.41370  val_loss: 0.50767
# [MLinear-F1] [Epoch 030] train_loss: 0.41352  val_loss: 0.50539
# [MLinear-F1] [Epoch 031] train_loss: 0.41286  val_loss: 0.50327
# [MLinear-F1] [Epoch 032] train_loss: 0.41210  val_loss: 0.50132
# [MLinear-F1] [Epoch 033] train_loss: 0.41160  val_loss: 0.49977
# [MLinear-F1] [Epoch 034] train_loss: 0.41124  val_loss: 0.49830
# [MLinear-F1] [Epoch 035] train_loss: 0.41063  val_loss: 0.49716
# [MLinear-F1] [Epoch 036] train_loss: 0.41023  val_loss: 0.49613
# [MLinear-F1] [Epoch 037] train_loss: 0.40971  val_loss: 0.49534
# [MLinear-F1] [Epoch 038] train_loss: 0.40962  val_loss: 0.49469
# [MLinear-F1] [Epoch 039] train_loss: 0.40865  val_loss: 0.49415
# [MLinear-F1] [Epoch 040] train_loss: 0.40870  val_loss: 0.49372
# [MLinear-F1] [Epoch 041] train_loss: 0.40801  val_loss: 0.49345
# [MLinear-F1] [Epoch 042] train_loss: 0.40742  val_loss: 0.49326
# [MLinear-F1] [Epoch 043] train_loss: 0.40722  val_loss: 0.49320
# [MLinear-F1] [Epoch 044] train_loss: 0.40674  val_loss: 0.49314
# [MLinear-F1] [Epoch 045] train_loss: 0.40634  val_loss: 0.49314
# [MLinear-F1] [Epoch 046] train_loss: 0.40601  val_loss: 0.49320
# [MLinear-F1] [Epoch 047] train_loss: 0.40528  val_loss: 0.49327
# [MLinear-F1] [Epoch 048] train_loss: 0.40509  val_loss: 0.49336
# [MLinear-F1] [Epoch 049] train_loss: 0.40491  val_loss: 0.49356
# [MLinear-F1] [Epoch 050] train_loss: 0.40443  val_loss: 0.49380
# [MLinear-F1] [Epoch 051] train_loss: 0.40410  val_loss: 0.49410
# [MLinear-F1] [Epoch 052] train_loss: 0.40379  val_loss: 0.49447
# [MLinear-F1] [Epoch 053] train_loss: 0.40322  val_loss: 0.49481
# [MLinear-F1] [Epoch 054] train_loss: 0.40276  val_loss: 0.49519
# [MLinear-F1] [Epoch 055] train_loss: 0.40267  val_loss: 0.49553
# [MLinear-F1] [Epoch 056] train_loss: 0.40264  val_loss: 0.49608
# [MLinear-F1] [Epoch 057] train_loss: 0.40208  val_loss: 0.49668
# [MLinear-F1] [Epoch 058] train_loss: 0.40197  val_loss: 0.49723
# [MLinear-F1] Early stopping at epoch 58
# [MLinear-F2] [Epoch 001] train_loss: 0.78057  val_loss: 0.92880
# [MLinear-F2] [Epoch 002] train_loss: 0.73154  val_loss: 0.91003
# [MLinear-F2] [Epoch 003] train_loss: 0.66173  val_loss: 0.88727
# [MLinear-F2] [Epoch 004] train_loss: 0.60569  val_loss: 0.86302
# [MLinear-F2] [Epoch 005] train_loss: 0.53530  val_loss: 0.83801
# [MLinear-F2] [Epoch 006] train_loss: 0.49825  val_loss: 0.80951
# [MLinear-F2] [Epoch 007] train_loss: 0.47088  val_loss: 0.76869
# [MLinear-F2] [Epoch 008] train_loss: 0.45419  val_loss: 0.72446
# [MLinear-F2] [Epoch 009] train_loss: 0.44487  val_loss: 0.68646
# [MLinear-F2] [Epoch 010] train_loss: 0.43797  val_loss: 0.65567
# [MLinear-F2] [Epoch 011] train_loss: 0.43201  val_loss: 0.62792
# [MLinear-F2] [Epoch 012] train_loss: 0.42848  val_loss: 0.60566
# [MLinear-F2] [Epoch 013] train_loss: 0.42590  val_loss: 0.58968
# [MLinear-F2] [Epoch 014] train_loss: 0.42436  val_loss: 0.57798
# [MLinear-F2] [Epoch 015] train_loss: 0.42322  val_loss: 0.56919
# [MLinear-F2] [Epoch 016] train_loss: 0.42186  val_loss: 0.56184
# [MLinear-F2] [Epoch 017] train_loss: 0.42096  val_loss: 0.55538
# [MLinear-F2] [Epoch 018] train_loss: 0.41953  val_loss: 0.54932
# [MLinear-F2] [Epoch 019] train_loss: 0.41871  val_loss: 0.54366
# [MLinear-F2] [Epoch 020] train_loss: 0.41759  val_loss: 0.53818
# [MLinear-F2] [Epoch 021] train_loss: 0.41688  val_loss: 0.53317
# [MLinear-F2] [Epoch 022] train_loss: 0.41635  val_loss: 0.52810
# [MLinear-F2] [Epoch 023] train_loss: 0.41527  val_loss: 0.52333
# [MLinear-F2] [Epoch 024] train_loss: 0.41477  val_loss: 0.51896
# [MLinear-F2] [Epoch 025] train_loss: 0.41369  val_loss: 0.51519
# [MLinear-F2] [Epoch 026] train_loss: 0.41318  val_loss: 0.51192
# [MLinear-F2] [Epoch 027] train_loss: 0.41251  val_loss: 0.50902
# [MLinear-F2] [Epoch 028] train_loss: 0.41208  val_loss: 0.50642
# [MLinear-F2] [Epoch 029] train_loss: 0.41140  val_loss: 0.50420
# [MLinear-F2] [Epoch 030] train_loss: 0.41042  val_loss: 0.50235
# [MLinear-F2] [Epoch 031] train_loss: 0.41011  val_loss: 0.50075
# [MLinear-F2] [Epoch 032] train_loss: 0.40986  val_loss: 0.49940
# [MLinear-F2] [Epoch 033] train_loss: 0.40916  val_loss: 0.49835
# [MLinear-F2] [Epoch 034] train_loss: 0.40877  val_loss: 0.49743
# [MLinear-F2] [Epoch 035] train_loss: 0.40800  val_loss: 0.49673
# [MLinear-F2] [Epoch 036] train_loss: 0.40755  val_loss: 0.49624
# [MLinear-F2] [Epoch 037] train_loss: 0.40711  val_loss: 0.49590
# [MLinear-F2] [Epoch 038] train_loss: 0.40693  val_loss: 0.49570
# [MLinear-F2] [Epoch 039] train_loss: 0.40616  val_loss: 0.49560
# [MLinear-F2] [Epoch 040] train_loss: 0.40551  val_loss: 0.49567
# [MLinear-F2] [Epoch 041] train_loss: 0.40524  val_loss: 0.49587
# [MLinear-F2] [Epoch 042] train_loss: 0.40495  val_loss: 0.49602
# [MLinear-F2] [Epoch 043] train_loss: 0.40448  val_loss: 0.49625
# [MLinear-F2] [Epoch 044] train_loss: 0.40415  val_loss: 0.49653
# [MLinear-F2] [Epoch 045] train_loss: 0.40387  val_loss: 0.49694
# [MLinear-F2] [Epoch 046] train_loss: 0.40337  val_loss: 0.49740
# [MLinear-F2] [Epoch 047] train_loss: 0.40359  val_loss: 0.49786
# [MLinear-F2] [Epoch 048] train_loss: 0.40297  val_loss: 0.49834
# [MLinear-F2] [Epoch 049] train_loss: 0.40218  val_loss: 0.49900
# [MLinear-F2] [Epoch 050] train_loss: 0.40233  val_loss: 0.49969
# [MLinear-F2] [Epoch 051] train_loss: 0.40161  val_loss: 0.50046
# [MLinear-F2] [Epoch 052] train_loss: 0.40135  val_loss: 0.50119
# [MLinear-F2] [Epoch 053] train_loss: 0.40103  val_loss: 0.50200
# [MLinear-F2] Early stopping at epoch 53
# [MLinear-F3] [Epoch 001] train_loss: 0.78077  val_loss: 0.94800
# [MLinear-F3] [Epoch 002] train_loss: 0.73178  val_loss: 0.92882
# [MLinear-F3] [Epoch 003] train_loss: 0.63862  val_loss: 0.90390
# [MLinear-F3] [Epoch 004] train_loss: 0.56094  val_loss: 0.87559
# [MLinear-F3] [Epoch 005] train_loss: 0.53830  val_loss: 0.84473
# [MLinear-F3] [Epoch 006] train_loss: 0.51313  val_loss: 0.80750
# [MLinear-F3] [Epoch 007] train_loss: 0.48503  val_loss: 0.76738
# [MLinear-F3] [Epoch 008] train_loss: 0.46437  val_loss: 0.73247
# [MLinear-F3] [Epoch 009] train_loss: 0.45006  val_loss: 0.70194
# [MLinear-F3] [Epoch 010] train_loss: 0.44155  val_loss: 0.67376
# [MLinear-F3] [Epoch 011] train_loss: 0.43577  val_loss: 0.64805
# [MLinear-F3] [Epoch 012] train_loss: 0.43169  val_loss: 0.62473
# [MLinear-F3] [Epoch 013] train_loss: 0.42916  val_loss: 0.60463
# [MLinear-F3] [Epoch 014] train_loss: 0.42704  val_loss: 0.58830
# [MLinear-F3] [Epoch 015] train_loss: 0.42561  val_loss: 0.57491
# ...
# [PatchTST-F3] [Epoch 054] train_loss: 0.29673  val_loss: 0.36074
# [PatchTST-F3] [Epoch 055] train_loss: 0.29624  val_loss: 0.36065
# [PatchTST-F3] [Epoch 056] train_loss: 0.29570  val_loss: 0.36060
# [PatchTST-F3] [Epoch 057] train_loss: 0.29562  val_loss: 0.36064
# [PatchTST-F3] [Epoch 058] train_loss: 0.29538  val_loss: 0.36072
# [PatchTST-F3] [Epoch 059] train_loss: 0.29439  val_loss: 0.36086
# [PatchTST-F3] [Epoch 060] train_loss: 0.29403  val_loss: 0.36096
# [PatchTST-F3] [Epoch 061] train_loss: 0.29334  val_loss: 0.36117
# [PatchTST-F3] [Epoch 062] train_loss: 0.29276  val_loss: 0.36132
# [PatchTST-F3] [Epoch 063] train_loss: 0.29274  val_loss: 0.36152
# [PatchTST-F3] [Epoch 064] train_loss: 0.29207  val_loss: 0.36170
# [PatchTST-F3] [Epoch 065] train_loss: 0.29186  val_loss: 0.36189
# [PatchTST-F3] [Epoch 066] train_loss: 0.29111  val_loss: 0.36217
# [PatchTST-F3] [Epoch 067] train_loss: 0.29077  val_loss: 0.36243
# [PatchTST-F3] [Epoch 068] train_loss: 0.29071  val_loss: 0.36271
# [PatchTST-F3] [Epoch 069] train_loss: 0.29014  val_loss: 0.36288
# [PatchTST-F3] [Epoch 070] train_loss: 0.28974  val_loss: 0.36317
# [PatchTST-F3] Early stopping at epoch 70
# [VAL(avg over folds)] PatchTST=0.37434
# 📚 TSMixer 학습...
# [TSMixer-F1] [Epoch 001] train_loss: 0.40027  val_loss: 0.85254
# [TSMixer-F1] [Epoch 002] train_loss: 0.36298  val_loss: 0.74094
# [TSMixer-F1] [Epoch 003] train_loss: 0.35441  val_loss: 0.65221
# [TSMixer-F1] [Epoch 004] train_loss: 0.35063  val_loss: 0.57848
# [TSMixer-F1] [Epoch 005] train_loss: 0.34884  val_loss: 0.52297
# [TSMixer-F1] [Epoch 006] train_loss: 0.34647  val_loss: 0.48765
# [TSMixer-F1] [Epoch 007] train_loss: 0.34416  val_loss: 0.46480
# [TSMixer-F1] [Epoch 008] train_loss: 0.34162  val_loss: 0.45228
# [TSMixer-F1] [Epoch 009] train_loss: 0.34000  val_loss: 0.44464
# [TSMixer-F1] [Epoch 010] train_loss: 0.33829  val_loss: 0.43974
# [TSMixer-F1] [Epoch 011] train_loss: 0.33617  val_loss: 0.43620
# [TSMixer-F1] [Epoch 012] train_loss: 0.33436  val_loss: 0.43334
# [TSMixer-F1] [Epoch 013] train_loss: 0.33356  val_loss: 0.43051
# [TSMixer-F1] [Epoch 014] train_loss: 0.33218  val_loss: 0.42759
# [TSMixer-F1] [Epoch 015] train_loss: 0.33049  val_loss: 0.42527
# [TSMixer-F1] [Epoch 016] train_loss: 0.32927  val_loss: 0.42300
# [TSMixer-F1] [Epoch 017] train_loss: 0.32862  val_loss: 0.42110
# [TSMixer-F1] [Epoch 018] train_loss: 0.32739  val_loss: 0.41985
# [TSMixer-F1] [Epoch 019] train_loss: 0.32669  val_loss: 0.41925
# [TSMixer-F1] [Epoch 020] train_loss: 0.32598  val_loss: 0.41863
# [TSMixer-F1] [Epoch 021] train_loss: 0.32510  val_loss: 0.41857
# [TSMixer-F1] [Epoch 022] train_loss: 0.32457  val_loss: 0.41838
# [TSMixer-F1] [Epoch 023] train_loss: 0.32345  val_loss: 0.41771
# [TSMixer-F1] [Epoch 024] train_loss: 0.32293  val_loss: 0.41666
# [TSMixer-F1] [Epoch 025] train_loss: 0.32293  val_loss: 0.41507
# [TSMixer-F1] [Epoch 026] train_loss: 0.32207  val_loss: 0.41323
# [TSMixer-F1] [Epoch 027] train_loss: 0.32174  val_loss: 0.41135
# [TSMixer-F1] [Epoch 028] train_loss: 0.32078  val_loss: 0.40967
# [TSMixer-F1] [Epoch 029] train_loss: 0.32038  val_loss: 0.40800
# [TSMixer-F1] [Epoch 030] train_loss: 0.32019  val_loss: 0.40636
# [TSMixer-F1] [Epoch 031] train_loss: 0.31898  val_loss: 0.40481
# [TSMixer-F1] [Epoch 032] train_loss: 0.31840  val_loss: 0.40350
# [TSMixer-F1] [Epoch 033] train_loss: 0.31907  val_loss: 0.40211
# [TSMixer-F1] [Epoch 034] train_loss: 0.31764  val_loss: 0.40077
# [TSMixer-F1] [Epoch 035] train_loss: 0.31779  val_loss: 0.39934
# [TSMixer-F1] [Epoch 036] train_loss: 0.31667  val_loss: 0.39802
# [TSMixer-F1] [Epoch 037] train_loss: 0.31637  val_loss: 0.39673
# [TSMixer-F1] [Epoch 038] train_loss: 0.31523  val_loss: 0.39543
# [TSMixer-F1] [Epoch 039] train_loss: 0.31498  val_loss: 0.39438
# [TSMixer-F1] [Epoch 040] train_loss: 0.31433  val_loss: 0.39356
# [TSMixer-F1] [Epoch 041] train_loss: 0.31351  val_loss: 0.39280
# [TSMixer-F1] [Epoch 042] train_loss: 0.31342  val_loss: 0.39211
# [TSMixer-F1] [Epoch 043] train_loss: 0.31278  val_loss: 0.39141
# [TSMixer-F1] [Epoch 044] train_loss: 0.31243  val_loss: 0.39063
# [TSMixer-F1] [Epoch 045] train_loss: 0.31120  val_loss: 0.39009
# [TSMixer-F1] [Epoch 046] train_loss: 0.31091  val_loss: 0.38958
# [TSMixer-F1] [Epoch 047] train_loss: 0.31058  val_loss: 0.38907
# [TSMixer-F1] [Epoch 048] train_loss: 0.31033  val_loss: 0.38858
# [TSMixer-F1] [Epoch 049] train_loss: 0.30961  val_loss: 0.38806
# [TSMixer-F1] [Epoch 050] train_loss: 0.30881  val_loss: 0.38761
# [TSMixer-F1] [Epoch 051] train_loss: 0.30848  val_loss: 0.38738
# [TSMixer-F1] [Epoch 052] train_loss: 0.30735  val_loss: 0.38719
# [TSMixer-F1] [Epoch 053] train_loss: 0.30684  val_loss: 0.38700
# [TSMixer-F1] [Epoch 054] train_loss: 0.30609  val_loss: 0.38689
# [TSMixer-F1] [Epoch 055] train_loss: 0.30533  val_loss: 0.38679
# [TSMixer-F1] [Epoch 056] train_loss: 0.30477  val_loss: 0.38667
# [TSMixer-F1] [Epoch 057] train_loss: 0.30363  val_loss: 0.38675
# [TSMixer-F1] [Epoch 058] train_loss: 0.30328  val_loss: 0.38683
# [TSMixer-F1] [Epoch 059] train_loss: 0.30295  val_loss: 0.38680
# [TSMixer-F1] [Epoch 060] train_loss: 0.30181  val_loss: 0.38687
# [TSMixer-F1] [Epoch 061] train_loss: 0.30090  val_loss: 0.38699
# [TSMixer-F1] [Epoch 062] train_loss: 0.30044  val_loss: 0.38713
# [TSMixer-F1] [Epoch 063] train_loss: 0.29946  val_loss: 0.38737
# [TSMixer-F1] [Epoch 064] train_loss: 0.29897  val_loss: 0.38762
# [TSMixer-F1] [Epoch 065] train_loss: 0.29820  val_loss: 0.38791
# [TSMixer-F1] [Epoch 066] train_loss: 0.29723  val_loss: 0.38824
# [TSMixer-F1] [Epoch 067] train_loss: 0.29670  val_loss: 0.38850
# [TSMixer-F1] [Epoch 068] train_loss: 0.29602  val_loss: 0.38876
# [TSMixer-F1] [Epoch 069] train_loss: 0.29492  val_loss: 0.38907
# [TSMixer-F1] [Epoch 070] train_loss: 0.29436  val_loss: 0.38934
# [TSMixer-F1] Early stopping at epoch 70
# [TSMixer-F2] [Epoch 001] train_loss: 0.39806  val_loss: 0.84138
# [TSMixer-F2] [Epoch 002] train_loss: 0.36275  val_loss: 0.73972
# [TSMixer-F2] [Epoch 003] train_loss: 0.35488  val_loss: 0.65350
# [TSMixer-F2] [Epoch 004] train_loss: 0.35156  val_loss: 0.57650
# [TSMixer-F2] [Epoch 005] train_loss: 0.34870  val_loss: 0.51843
# [TSMixer-F2] [Epoch 006] train_loss: 0.34700  val_loss: 0.47819
# [TSMixer-F2] [Epoch 007] train_loss: 0.34424  val_loss: 0.45136
# [TSMixer-F2] [Epoch 008] train_loss: 0.34250  val_loss: 0.43305
# [TSMixer-F2] [Epoch 009] train_loss: 0.34010  val_loss: 0.42179
# [TSMixer-F2] [Epoch 010] train_loss: 0.33805  val_loss: 0.41509
# [TSMixer-F2] [Epoch 011] train_loss: 0.33634  val_loss: 0.41060
# [TSMixer-F2] [Epoch 012] train_loss: 0.33517  val_loss: 0.40753
# [TSMixer-F2] [Epoch 013] train_loss: 0.33307  val_loss: 0.40539
# [TSMixer-F2] [Epoch 014] train_loss: 0.33229  val_loss: 0.40348
# [TSMixer-F2] [Epoch 015] train_loss: 0.33041  val_loss: 0.40107
# [TSMixer-F2] [Epoch 016] train_loss: 0.32957  val_loss: 0.39894
# [TSMixer-F2] [Epoch 017] train_loss: 0.32844  val_loss: 0.39722
# [TSMixer-F2] [Epoch 018] train_loss: 0.32748  val_loss: 0.39576
# [TSMixer-F2] [Epoch 019] train_loss: 0.32678  val_loss: 0.39457
# [TSMixer-F2] [Epoch 020] train_loss: 0.32645  val_loss: 0.39342
# [TSMixer-F2] [Epoch 021] train_loss: 0.32514  val_loss: 0.39264
# [TSMixer-F2] [Epoch 022] train_loss: 0.32432  val_loss: 0.39199
# [TSMixer-F2] [Epoch 023] train_loss: 0.32427  val_loss: 0.39123
# [TSMixer-F2] [Epoch 024] train_loss: 0.32361  val_loss: 0.39029
# [TSMixer-F2] [Epoch 025] train_loss: 0.32293  val_loss: 0.38962
# [TSMixer-F2] [Epoch 026] train_loss: 0.32219  val_loss: 0.38924
# [TSMixer-F2] [Epoch 027] train_loss: 0.32160  val_loss: 0.38867
# [TSMixer-F2] [Epoch 028] train_loss: 0.32107  val_loss: 0.38816
# [TSMixer-F2] [Epoch 029] train_loss: 0.32076  val_loss: 0.38766
# [TSMixer-F2] [Epoch 030] train_loss: 0.31975  val_loss: 0.38720
# [TSMixer-F2] [Epoch 031] train_loss: 0.31965  val_loss: 0.38667
# [TSMixer-F2] [Epoch 032] train_loss: 0.31867  val_loss: 0.38613
# [TSMixer-F2] [Epoch 033] train_loss: 0.31859  val_loss: 0.38558
# [TSMixer-F2] [Epoch 034] train_loss: 0.31796  val_loss: 0.38524
# [TSMixer-F2] [Epoch 035] train_loss: 0.31757  val_loss: 0.38485
# [TSMixer-F2] [Epoch 036] train_loss: 0.31696  val_loss: 0.38475
# [TSMixer-F2] [Epoch 037] train_loss: 0.31626  val_loss: 0.38459
# [TSMixer-F2] [Epoch 038] train_loss: 0.31554  val_loss: 0.38458
# [TSMixer-F2] [Epoch 039] train_loss: 0.31502  val_loss: 0.38459
# [TSMixer-F2] [Epoch 040] train_loss: 0.31484  val_loss: 0.38460
# [TSMixer-F2] [Epoch 041] train_loss: 0.31448  val_loss: 0.38446
# [TSMixer-F2] [Epoch 042] train_loss: 0.31380  val_loss: 0.38451
# [TSMixer-F2] [Epoch 043] train_loss: 0.31307  val_loss: 0.38455
# [TSMixer-F2] [Epoch 044] train_loss: 0.31257  val_loss: 0.38460
# [TSMixer-F2] [Epoch 045] train_loss: 0.31182  val_loss: 0.38451
# [TSMixer-F2] [Epoch 046] train_loss: 0.31138  val_loss: 0.38430
# [TSMixer-F2] [Epoch 047] train_loss: 0.31067  val_loss: 0.38414
# [TSMixer-F2] [Epoch 048] train_loss: 0.31010  val_loss: 0.38394
# [TSMixer-F2] [Epoch 049] train_loss: 0.30969  val_loss: 0.38374
# [TSMixer-F2] [Epoch 050] train_loss: 0.30953  val_loss: 0.38329
# [TSMixer-F2] [Epoch 051] train_loss: 0.30944  val_loss: 0.38289
# [TSMixer-F2] [Epoch 052] train_loss: 0.30794  val_loss: 0.38258
# [TSMixer-F2] [Epoch 053] train_loss: 0.30765  val_loss: 0.38246
# [TSMixer-F2] [Epoch 054] train_loss: 0.30680  val_loss: 0.38233
# [TSMixer-F2] [Epoch 055] train_loss: 0.30681  val_loss: 0.38232
# [TSMixer-F2] [Epoch 056] train_loss: 0.30622  val_loss: 0.38217
# [TSMixer-F2] [Epoch 057] train_loss: 0.30577  val_loss: 0.38209
# [TSMixer-F2] [Epoch 058] train_loss: 0.30470  val_loss: 0.38214
# [TSMixer-F2] [Epoch 059] train_loss: 0.30395  val_loss: 0.38228
# [TSMixer-F2] [Epoch 060] train_loss: 0.30369  val_loss: 0.38253
# [TSMixer-F2] [Epoch 061] train_loss: 0.30278  val_loss: 0.38276
# [TSMixer-F2] [Epoch 062] train_loss: 0.30233  val_loss: 0.38317
# [TSMixer-F2] [Epoch 063] train_loss: 0.30170  val_loss: 0.38343
# [TSMixer-F2] [Epoch 064] train_loss: 0.30078  val_loss: 0.38377
# [TSMixer-F2] [Epoch 065] train_loss: 0.30058  val_loss: 0.38419
# [TSMixer-F2] [Epoch 066] train_loss: 0.30006  val_loss: 0.38479
# [TSMixer-F2] [Epoch 067] train_loss: 0.29942  val_loss: 0.38517
# [TSMixer-F2] [Epoch 068] train_loss: 0.29878  val_loss: 0.38547
# [TSMixer-F2] [Epoch 069] train_loss: 0.29770  val_loss: 0.38595
# [TSMixer-F2] [Epoch 070] train_loss: 0.29703  val_loss: 0.38654
# [TSMixer-F2] [Epoch 071] train_loss: 0.29649  val_loss: 0.38695
# [TSMixer-F2] Early stopping at epoch 71
# [TSMixer-F3] [Epoch 001] train_loss: 0.39661  val_loss: 0.86604
# [TSMixer-F3] [Epoch 002] train_loss: 0.36238  val_loss: 0.76195
# [TSMixer-F3] [Epoch 003] train_loss: 0.35366  val_loss: 0.66410
# [TSMixer-F3] [Epoch 004] train_loss: 0.35079  val_loss: 0.57267
# [TSMixer-F3] [Epoch 005] train_loss: 0.34969  val_loss: 0.50586
# [TSMixer-F3] [Epoch 006] train_loss: 0.34653  val_loss: 0.46092
# [TSMixer-F3] [Epoch 007] train_loss: 0.34360  val_loss: 0.43433
# [TSMixer-F3] [Epoch 008] train_loss: 0.34210  val_loss: 0.42148
# [TSMixer-F3] [Epoch 009] train_loss: 0.34011  val_loss: 0.41625
# [TSMixer-F3] [Epoch 010] train_loss: 0.33814  val_loss: 0.41470
# [TSMixer-F3] [Epoch 011] train_loss: 0.33623  val_loss: 0.41463
# [TSMixer-F3] [Epoch 012] train_loss: 0.33463  val_loss: 0.41484
# [TSMixer-F3] [Epoch 013] train_loss: 0.33341  val_loss: 0.41414
# [TSMixer-F3] [Epoch 014] train_loss: 0.33199  val_loss: 0.41235
# [TSMixer-F3] [Epoch 015] train_loss: 0.33117  val_loss: 0.41045
# [TSMixer-F3] [Epoch 016] train_loss: 0.32950  val_loss: 0.40856
# [TSMixer-F3] [Epoch 017] train_loss: 0.32885  val_loss: 0.40656
# [TSMixer-F3] [Epoch 018] train_loss: 0.32747  val_loss: 0.40557
# [TSMixer-F3] [Epoch 019] train_loss: 0.32717  val_loss: 0.40515
# [TSMixer-F3] [Epoch 020] train_loss: 0.32627  val_loss: 0.40479
# [TSMixer-F3] [Epoch 021] train_loss: 0.32568  val_loss: 0.40445
# [TSMixer-F3] [Epoch 022] train_loss: 0.32506  val_loss: 0.40337
# [TSMixer-F3] [Epoch 023] train_loss: 0.32420  val_loss: 0.40228
# [TSMixer-F3] [Epoch 024] train_loss: 0.32307  val_loss: 0.40136
# [TSMixer-F3] [Epoch 025] train_loss: 0.32277  val_loss: 0.40025
# [TSMixer-F3] [Epoch 026] train_loss: 0.32229  val_loss: 0.39940
# [TSMixer-F3] [Epoch 027] train_loss: 0.32121  val_loss: 0.39865
# [TSMixer-F3] [Epoch 028] train_loss: 0.32112  val_loss: 0.39771
# [TSMixer-F3] [Epoch 029] train_loss: 0.32019  val_loss: 0.39623
# [TSMixer-F3] [Epoch 030] train_loss: 0.32041  val_loss: 0.39477
# [TSMixer-F3] [Epoch 031] train_loss: 0.31922  val_loss: 0.39322
# [TSMixer-F3] [Epoch 032] train_loss: 0.31883  val_loss: 0.39203
# [TSMixer-F3] [Epoch 033] train_loss: 0.31799  val_loss: 0.39102
# [TSMixer-F3] [Epoch 034] train_loss: 0.31756  val_loss: 0.38963
# [TSMixer-F3] [Epoch 035] train_loss: 0.31767  val_loss: 0.38836
# [TSMixer-F3] [Epoch 036] train_loss: 0.31626  val_loss: 0.38707
# [TSMixer-F3] [Epoch 037] train_loss: 0.31581  val_loss: 0.38558
# [TSMixer-F3] [Epoch 038] train_loss: 0.31554  val_loss: 0.38406
# [TSMixer-F3] [Epoch 039] train_loss: 0.31462  val_loss: 0.38279
# [TSMixer-F3] [Epoch 040] train_loss: 0.31390  val_loss: 0.38157
# [TSMixer-F3] [Epoch 041] train_loss: 0.31362  val_loss: 0.38014
# [TSMixer-F3] [Epoch 042] train_loss: 0.31318  val_loss: 0.37884
# [TSMixer-F3] [Epoch 043] train_loss: 0.31297  val_loss: 0.37747
# [TSMixer-F3] [Epoch 044] train_loss: 0.31223  val_loss: 0.37602
# [TSMixer-F3] [Epoch 045] train_loss: 0.31168  val_loss: 0.37469
# [TSMixer-F3] [Epoch 046] train_loss: 0.31109  val_loss: 0.37365
# [TSMixer-F3] [Epoch 047] train_loss: 0.31033  val_loss: 0.37258
# [TSMixer-F3] [Epoch 048] train_loss: 0.30974  val_loss: 0.37160
# [TSMixer-F3] [Epoch 049] train_loss: 0.30909  val_loss: 0.37068
# [TSMixer-F3] [Epoch 050] train_loss: 0.30917  val_loss: 0.36993
# [TSMixer-F3] [Epoch 051] train_loss: 0.30821  val_loss: 0.36916
# [TSMixer-F3] [Epoch 052] train_loss: 0.30749  val_loss: 0.36868
# [TSMixer-F3] [Epoch 053] train_loss: 0.30739  val_loss: 0.36833
# [TSMixer-F3] [Epoch 054] train_loss: 0.30648  val_loss: 0.36786
# [TSMixer-F3] [Epoch 055] train_loss: 0.30548  val_loss: 0.36747
# [TSMixer-F3] [Epoch 056] train_loss: 0.30545  val_loss: 0.36716
# [TSMixer-F3] [Epoch 057] train_loss: 0.30501  val_loss: 0.36704
# [TSMixer-F3] [Epoch 058] train_loss: 0.30403  val_loss: 0.36698
# [TSMixer-F3] [Epoch 059] train_loss: 0.30325  val_loss: 0.36693
# [TSMixer-F3] [Epoch 060] train_loss: 0.30284  val_loss: 0.36685
# [TSMixer-F3] [Epoch 061] train_loss: 0.30251  val_loss: 0.36694
# [TSMixer-F3] [Epoch 062] train_loss: 0.30148  val_loss: 0.36710
# [TSMixer-F3] [Epoch 063] train_loss: 0.30106  val_loss: 0.36734
# [TSMixer-F3] [Epoch 064] train_loss: 0.29997  val_loss: 0.36769
# [TSMixer-F3] [Epoch 065] train_loss: 0.29924  val_loss: 0.36806
# [TSMixer-F3] [Epoch 066] train_loss: 0.29895  val_loss: 0.36849
# [TSMixer-F3] [Epoch 067] train_loss: 0.29788  val_loss: 0.36878
# [TSMixer-F3] [Epoch 068] train_loss: 0.29743  val_loss: 0.36930
# [TSMixer-F3] [Epoch 069] train_loss: 0.29681  val_loss: 0.36966
# [TSMixer-F3] [Epoch 070] train_loss: 0.29620  val_loss: 0.37010
# [TSMixer-F3] [Epoch 071] train_loss: 0.29557  val_loss: 0.37063
# [TSMixer-F3] [Epoch 072] train_loss: 0.29491  val_loss: 0.37119
# [TSMixer-F3] [Epoch 073] train_loss: 0.29357  val_loss: 0.37191
# [TSMixer-F3] [Epoch 074] train_loss: 0.29332  val_loss: 0.37259
# [TSMixer-F3] Early stopping at epoch 74
# [VAL(avg over folds)] TSMixer=0.37854
# [Ensemble Weights] TimesNet=0.170  GRU=0.188  MLinear=0.139  N-HiTS=0.168  PatchTST=0.168  TSMixer=0.166
# 🔮 5-Model 앙상블 예측...
#   📊 /content/drive/MyDrive/data/test/TEST_00.csv 처리 중...
#   📊 /content/drive/MyDrive/data/test/TEST_01.csv 처리 중...
#   📊 /content/drive/MyDrive/data/test/TEST_02.csv 처리 중...
#   📊 /content/drive/MyDrive/data/test/TEST_03.csv 처리 중...
#   📊 /content/drive/MyDrive/data/test/TEST_04.csv 처리 중...
#   📊 /content/drive/MyDrive/data/test/TEST_05.csv 처리 중...
#   📊 /content/drive/MyDrive/data/test/TEST_06.csv 처리 중...
#   📊 /content/drive/MyDrive/data/test/TEST_07.csv 처리 중...
#   📊 /content/drive/MyDrive/data/test/TEST_08.csv 처리 중...
#   📊 /content/drive/MyDrive/data/test/TEST_09.csv 처리 중...
# ✅ 앙상블 완료! → /content/drive/MyDrive/data/0821_6model_submission.csv
# 🏆 N-HiTS + PatchTST + TimesNet + GRU + MLinear 학습/추론 끝
