# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### config
# - 매장 카테고리 변경
# - TSMixer 추가

# %%
# -*- coding: utf-8 -*-
"""
Enhanced N-HiTS + Improved PatchTST + Improved TimesNet + GRU + MLinear (5-Model Ensemble)
+ Optional Optuna Tuning + Multi-fold CV + Safe AMP + Memory-safe EMA

주요 변경:
- DLinear → MLinear로 교체
- 그룹별 선형 변환 + 메타 피처 통합
- Hurdle 모델 지원
"""

import os, gc, glob, json, math, random, warnings
from dataclasses import dataclass
from typing import List, Dict, Tuple, Optional

import numpy as np
import pandas as pd

import torch
from torch import nn
from torch.utils.data import Dataset, DataLoader
import torch.nn.functional as F

# ---- Optuna (옵션) ----
try:
    import optuna
    HAS_OPTUNA = True
except Exception:
    HAS_OPTUNA = False

warnings.filterwarnings('ignore')

# =====================
# Config
# =====================
@dataclass
class EnhancedNHiTSConfig:
    # 경로
    train_csv: str = "/content/drive/MyDrive/data/train/train.csv"
    test_glob: str = "/content/drive/MyDrive/data/test/*.csv"
    submission_template_csv: str = "/content/drive/MyDrive/data/sample_submission.csv"
    out_submission_csv: str = "/content/drive/MyDrive/data/0822_6model_clu_ratio_4f_submission.csv"
    checkpoint_dir: str = "/content/drive/MyDrive/tft_models/0822_0.495_clu_ratio_4f_checkpoints"

    # train_csv:str = "train_original.csv"
    # test_glob:str = "test/*.csv"
    # submission_template_csv:str = "sample_submission.csv
    # out_submission_csv: str = "0820_submission.csv"

    # 컬럼명
    date_col: str = "영업일자"
    item_col: str = "영업장명_메뉴명"
    target_col: str = "매출수량"

    # 윈도우
    in_len: int = 28
    out_len: int = 7

    # 학습 설정
    train_end_date: str = "2024-06-15"
    seed: int = 42
    device: str = "cuda" if torch.cuda.is_available() else "cpu"
    log1p: bool = True

    # 공용 학습 하이퍼파라미터(풀 학습)
    EPOCHS_FULL: int = 150
    BATCH_FULL: int = 256
    BASE_LR_FULL: float = 6e-4
    MAX_LR_FULL: float = 1.5e-3
    WD_FULL: float = 6e-4

    # 튜닝 (옵션)
    USE_OPTUNA: bool = False
    N_TRIALS: int = 30
    EPOCHS_TUNE: int = 1
    BATCH_TUNE: int = 256

    # CV folds(끝나는 주의 토요일 등) # 4-fold
    cv_fold_end_dates: Tuple[str, ...] = ("2024-06-14", "2024-06-07", "2024-05-31", "2024-05-24")

    # DataLoader
    num_workers: int = 4
    pin_memory: bool = True
    persistent_workers: bool = False  # 메모리 안전 우선

    # N-HiTS 구조
    hidden: int = 384
    n_blocks: int = 3
    n_layers: int = 1
    n_pool_kernel_size: Optional[List[int]] = None
    pooling_mode: str = "MaxPool1d"
    interpolation_mode: str = "linear"
    dropout: float = 0.22
    stack_types: Optional[List[str]] = None
    n_freq_downsample: Optional[List[int]] = None

    # Loss
    eps_smape: float = 0.01
    zero_weight: float = 0.01
    hurdle_lambda: float = 0.15

    # AMP/EMA
    use_amp: bool = True
    use_compile: bool = False
    ema_decay: float = 0.9998

    # 가중치/공휴일
    store_weights: Optional[Dict[str, float]] = None
    custom_holidays_list: Optional[List[str]] = None

    # ==== PatchTST ====
    ptst_d_model: int = 192
    ptst_nhead: int = 8
    ptst_num_layers: int = 2
    ptst_patch_len: int = 3
    ptst_stride: int = 2
    ptst_dropout: float = 0.2
    ptst_head_hidden: int = 256
    ptst_ff_mult: float = 1.5  # Config화

    # ==== TimesNet ====
    tnet_channels: int = 128
    tnet_blocks: int = 3
    tnet_kernels: Tuple[int, int, int] = (3, 5, 7)
    tnet_dropout: float = 0.12
    tnet_head_hidden: int = 256

    # ==== GRU ====
    gru_hidden: int = 256
    gru_layers: int = 2
    gru_dropout: float = 0.1
    gru_bidirectional: bool = False
    gru_head_hidden: int = 256

    # ==== MLinear ====
    mlin_hidden_dim: int = 256
    mlin_dropout: float = 0.1
    mlin_use_residual: bool = True
    mlin_use_layer_norm: bool = True

    # TSMixer 하이퍼파라미터
    tsm_d_model: int = 192
    tsm_num_layers: int = 2
    tsm_dropout: float = 0.2
    tsm_patch_len: int = 3
    tsm_head_hidden: int = 256

    # ==== 훈련 보조 ====
    grad_clip: float = 0.5
    earlystop_patience_ratio: float = 0.12
    earlystop_patience_min: int = 8

DEFAULT_STORE_WEIGHTS = {
    "미라시아": 1, "담하": 1, "연회장": 1, "라그로타": 1,
    "느티나무 셀프BBQ": 1, "화담숲주막": 1, "카페테리아": 1,
    "화담숲카페": 1, "포레스트릿": 1,
}

DEFAULT_CUSTOM_HOLIDAYS = [
    '2023-01-01','2023-01-21','2023-01-22','2023-01-23','2023-01-24','2023-03-01','2023-05-01',
    '2023-05-05','2023-05-27','2023-06-06','2023-08-15','2023-09-28','2023-09-29','2023-09-30',
    '2023-10-02','2023-10-03','2023-10-09','2023-12-25',
    '2024-01-01','2024-02-09','2024-02-10','2024-02-11','2024-02-12','2024-03-01','2024-04-10',
    '2024-05-01','2024-05-05','2024-05-06','2024-05-15','2024-06-06','2024-08-15','2024-09-16',
    '2024-09-17','2024-09-18','2024-10-01','2024-10-03','2024-10-09','2024-12-25',
    '2025-01-01','2025-01-28','2025-01-29','2025-01-30','2025-03-01','2025-03-03','2025-05-01',
    '2025-05-05','2025-05-06','2025-06-06','2025-08-15'
]

# %%
# =====================
# Feature Utils
# =====================
def set_seed(seed: int = 42):
    random.seed(seed); np.random.seed(seed)
    torch.manual_seed(seed); torch.cuda.manual_seed_all(seed)

def sine_cosine_encoding(value: float, max_val: float):
    return math.sin(2 * math.pi * value / max_val), math.cos(2 * math.pi * value / max_val)

def get_menu_category(menu_name: str) -> str:
    menu_lower = menu_name.lower()
    if any(word in menu_lower for word in ['막걸리', '소주', '맥주', '와인', '참이슬', '처음처럼', '카스', '하이네켄', '버드와이저', '스텔라']):
        return 'alcohol'
    elif any(word in menu_lower for word in ['찌개', '탕', '국밥', '라면', '해장국', '갈비탕']):
        return 'hot_food'
    elif any(word in menu_lower for word in ['삼겹', '갈비', '목살', 'bbq', '구이', '불고기']):
        return 'bbq'
    elif any(word in menu_lower for word in ['아이스크림', '식혜', '콜라', '스프라이트', '에이드']):
        return 'dessert_drink'
    elif any(word in menu_lower for word in ['아메리카노', '라떼', '커피']):
        return 'coffee'
    elif any(word in menu_lower for word in ['냉면', '파스타', '스파게티', '면', '우동']):
        return 'noodles'
    elif any(word in menu_lower for word in ['비빔밥', '볶음밥', '공깃밥', '정식']):
        return 'rice'
    else:
        return 'others'

# 매장을 경향성별로 페어링
def get_store_type(store_name: str) -> str:
    if store_name in ["느티나무 셀프BBQ", "연회장"]:
        return 'Special_Occasion'
    elif store_name in ["화담숲주막", "화담숲카페"]:
        return 'Forest'
    elif store_name in ["담하", "미라시아"]:
        return 'Fine_Dining'
    elif store_name in ["카페테리아", "포레스트릿"]:
        return 'Casual'
    else:
        return 'Unique_Venue'

# 주말 상대적 판매량 피처를 계산하는 함수.
def get_weekend_sales_ratio(df: pd.DataFrame) -> pd.DataFrame:

    df_copy = df.copy()
    df_copy['영업일자'] = pd.to_datetime(df_copy['영업일자'])
    df_copy['요일'] = df_copy['영업일자'].dt.weekday  # 월요일=0, 일요일=6

    # 주말(토, 일)과 주중(월~금)으로 데이터 분리
    weekend_df = df_copy[df_copy['요일'].isin([5, 6])]
    weekday_df = df_copy[~df_copy['요일'].isin([5, 6])]

    # 영업장_메뉴명별 주말/주중 평균 매출 계산
    weekend_sales = weekend_df.groupby('영업장명_메뉴명')['매출수량'].mean()
    weekday_sales = weekday_df.groupby('영업장명_메뉴명')['매출수량'].mean()

    # 주말 상대적 판매량 비율 계산
    sales_ratio = (weekend_sales / weekday_sales).fillna(1.0).reset_index()
    sales_ratio.rename(columns={'매출수량': 'weekend_sales_ratio'}, inplace=True)

    # 분모(평일 매출)가 0인 경우, 비율이 무한대가 되는 것을 방지
    sales_ratio['weekend_sales_ratio'] = sales_ratio['weekend_sales_ratio'].replace([float('inf'), -float('inf')], 1.0)

    return sales_ratio

# =============================================================
# cluster dict (사용자 정의 직접 입력)
# =============================================================
cluster_mapping = {
    # Cluster 1
    "카페테리아_수제 등심 돈까스": 1,
    "포레스트릿_생수": 1,
    "포레스트릿_치즈 핫도그": 1,
    "포레스트릿_코카콜라": 1,

    # Cluster 2
    "담하_공깃밥": 2,
    "담하_담하 한우 불고기": 2,
    "미라시아_미라시아 브런치 (패키지)": 2,
    "미라시아_브런치(대인) 주말": 2,
    "미라시아_브런치(대인) 주중": 2,
    "화담숲주막_느린마을 막걸리": 2,
    "화담숲주막_병천순대": 2,
    "화담숲주막_참살이 막걸리": 2,
    "화담숲주막_찹쌀식혜": 2,
    "화담숲카페_메밀미숫가루": 2,
    "화담숲카페_아메리카노 ICE": 2,

    # Cluster 3
    "화담숲주막_해물파전": 3,

    # Cluster 4 (36개)
    "느티나무 셀프BBQ_스프라이트 (단체)": 4,
    "느티나무 셀프BBQ_잔디그늘집 대여료 (6인석)": 4,
    "느티나무 셀프BBQ_콜라 (단체)": 4,
    "담하_담하 한우 불고기 정식": 4,
    "담하_생목살 김치찌개": 4,
    "담하_한우 떡갈비 정식": 4,
    "담하_한우 우거지 국밥": 4,
    "담하_한우 차돌박이 된장찌개": 4,
    "미라시아_브런치(어린이)": 4,
    "연회장_Cass Beer": 4,
    "카페테리아_공깃밥(추가)": 4,
    "카페테리아_구슬아이스크림": 4,
    "카페테리아_돼지고기 김치찌개": 4,
    "카페테리아_새우 볶음밥": 4,
    "카페테리아_새우튀김 우동": 4,
    "카페테리아_아메리카노(HOT)": 4,
    "카페테리아_아메리카노(ICE)": 4,
    "카페테리아_약 고추장 돌솥비빔밥": 4,
    "카페테리아_어린이 돈까스": 4,
    "카페테리아_오픈푸드": 4,
    "카페테리아_짜장면": 4,
    "카페테리아_짬뽕": 4,
    "카페테리아_치즈돈까스": 4,
    "카페테리아_카페라떼(HOT)": 4,
    "포레스트릿_복숭아 아이스티": 4,
    "포레스트릿_스프라이트": 4,
    "포레스트릿_아메리카노(HOT)": 4,
    "포레스트릿_아메리카노(ICE)": 4,
    "포레스트릿_카페라떼(HOT)": 4,
    "포레스트릿_페스츄리 소시지": 4,
    "화담숲주막_단호박 식혜": 4,
    "화담숲주막_스프라이트": 4,
    "화담숲주막_콜라": 4,
    "화담숲카페_아메리카노 HOT": 4,
    "화담숲카페_카페라떼 ICE": 4,
    "화담숲카페_현미뻥스크림": 4,

    # Cluster 5
    "포레스트릿_꼬치어묵": 5,
    "포레스트릿_떡볶이": 5,

    # Cluster 6
    "카페테리아_단체식 13000(신)": 6,
    "카페테리아_단체식 18000(신)": 6,

    # Cluster 7
    "느티나무 셀프BBQ_BBQ55(단체)": 7,
    "느티나무 셀프BBQ_참이슬 (단체)": 7,
    "느티나무 셀프BBQ_카스 병(단체)": 7,
    "담하_(단체) 황태해장국 3/27까지": 7,
    "미라시아_(단체)브런치주중 36,000": 7,
    "연회장_Regular Coffee": 7,
}

def get_menu_group(store_name: str, menu_name: str) -> str:
    """하드코딩된 딕셔너리를 사용하여 클러스터 그룹 반환 (MLinear용)"""
    item_full_name = f"{store_name}_{menu_name}"
    cluster_id = cluster_mapping.get(item_full_name, '8')
    return f"cluster_{cluster_id}"

# %%
def get_longest_off_season_feature(df: pd.DataFrame) -> pd.DataFrame:
    """비판매 기간 피처 생성"""
    df_copy = df.copy()
    df_copy['영업일자'] = pd.to_datetime(df_copy['영업일자'])

    sales_matrix = df_copy.pivot_table(
        index='영업일자', columns='영업장명_메뉴명',
        values='매출수량', fill_value=0
    )

    longest_zero_streak = {}
    for menu in sales_matrix.columns:
        is_zero_sales = (sales_matrix[menu] == 0)
        zero_streaks = is_zero_sales.cumsum() - is_zero_sales.cumsum().where(~is_zero_sales).ffill().fillna(0)
        longest_streak = zero_streaks.max()
        longest_zero_streak[menu] = int(longest_streak)

    off_season_df = pd.DataFrame(longest_zero_streak.items(),
                                columns=['영업장명_메뉴명', 'longest_off_season_days'])
    off_season_df['is_long_off_season'] = (off_season_df['longest_off_season_days'] >= 90).astype(int)

    return off_season_df

def create_regular_holiday_features(df: pd.DataFrame) -> pd.DataFrame:
    """정기 휴무일 피처 생성"""
    df_copy = df.copy()
    df_copy['영업일자'] = pd.to_datetime(df_copy['영업일자'])
    df_copy['영업장명'] = df_copy['영업장명_메뉴명'].apply(lambda x: x.split('_', 1)[0])
    df_copy['연도'] = df_copy['영업일자'].dt.year
    df_copy['월'] = df_copy['영업일자'].dt.month
    df_copy['요일'] = df_copy['영업일자'].dt.day_name()
    df_copy['is_regular_holiday'] = 0

    # 라그로타 정기휴무 (월요일)
    cond_lagrotta = (
        (df_copy['영업장명'] == '라그로타') &
        (df_copy['요일'] == 'Monday') &
        (
            ((df_copy['연도'] == 2023) & (df_copy['월'].isin(range(2, 12)))) |
            ((df_copy['연도'] == 2024) & (df_copy['월'].isin(range(3, 7))))
        )
    )

    # 포레스트릿 정기휴무
    cond_forest = (
        (df_copy['영업장명'] == '포레스트릿') &
        (
            ((df_copy['연도'] == 2023) & (df_copy['월'] == 3)) |
            ((df_copy['연도'] == 2023) & (df_copy['월'] == 9) &
             (df_copy['요일'].isin(['Monday', 'Tuesday', 'Wednesday']))) |
            ((df_copy['연도'] == 2024) & (df_copy['월'] == 3)) |
            ((df_copy['영업일자'] >= '2023-05-01') &
             (df_copy['요일'].isin(['Monday', 'Tuesday', 'Wednesday', 'Thursday'])))
        )
    )

    # 화담숲 계열 휴무 (겨울철 + 평상시 월요일)
    stores_hwadam = ['화담숲주막', '화담숲카페']
    cond_hwadam = (
        (df_copy['영업장명'].isin(stores_hwadam)) &
        (
            (df_copy['월'].isin([12, 1, 2, 3])) |  # 겨울철
            ((~df_copy['월'].isin([12, 1, 2, 3])) & (df_copy['요일'] == 'Monday'))  # 평상시 월요일
        )
    )

    df_copy.loc[cond_lagrotta | cond_forest | cond_hwadam, 'is_regular_holiday'] = 1
    df_copy.drop(columns=['연도', '월', '요일', '영업장명'], inplace=True)

    return df_copy

# %%
# =====================
# Feature Utils
# =====================
# build_enhanced_features 함수 수정
def build_enhanced_features(dates: List[pd.Timestamp], holidays_set: set, store_names: Optional[List[str]] = None) -> pd.DataFrame:
    df = pd.DataFrame({"date": dates})
    df["dow"] = df["date"].dt.weekday
    df["month"] = df["date"].dt.month
    df["day"] = df["date"].dt.day
    df["week"] = df["date"].apply(lambda d: int(d.isocalendar().week))
    df["quarter"] = df["date"].dt.quarter
    df["is_friday"] = (df["dow"] == 4).astype(int)
    df["is_saturday"] = (df["dow"] == 5).astype(int)
    df["is_sunday"] = (df["dow"] == 6).astype(int)
    df["is_weekend"] = df["dow"].isin([5, 6]).astype(int)
    df["is_holiday"] = df["date"].isin(holidays_set).astype(int)
    df["is_off"] = ((df["is_weekend"] == 1) | (df["is_holiday"] == 1)).astype(int)
    df["tomorrow"] = df["date"] + pd.Timedelta(days=1)
    df["yesterday"] = df["date"] - pd.Timedelta(days=1)
    df["is_before_holiday"] = df["tomorrow"].isin(holidays_set).astype(int)
    df["is_after_holiday"] = df["yesterday"].isin(holidays_set).astype(int)
    df["is_month_start"] = (df["day"] <= 3).astype(int)
    df["is_month_end"] = (df["day"] >= 28).astype(int)
    df["is_spring"] = df["month"].isin([4, 5, 6]).astype(int)
    df["is_summer"] = df["month"].isin([7, 8]).astype(int)
    df["is_autumn"] = df["month"].isin([9, 10, 11]).astype(int)
    df["is_winter"] = df["month"].isin([12, 1, 2, 3]).astype(int)
    df["is_summer_vacation"] = df["month"].isin([7, 8]).astype(int)
    df["is_winter_vacation"] = df["month"].isin([12, 1, 2]).astype(int)

    # 🚨 정기 휴무일 피처를 날짜 기반으로 직접 생성
    df['is_regular_holiday'] = 0
    df.loc[((df['date'].dt.month.isin(range(2, 12))) & (df['date'].dt.year == 2023) & (df['dow'] == 0)) |
           ((df['date'].dt.month.isin(range(3, 7))) & (df['date'].dt.year == 2024) & (df['dow'] == 0)) |
           (df['date'].isin(['2023-03-01'])) |
           (df['date'].isin(['2023-09-01', '2023-09-02', '2023-09-03']) & (df['dow'].isin([0, 1, 2]))) |
           (df['date'].isin(['2024-03-01'])) |
           ((df['date'] >= '2023-05-01') & (df['dow'].isin([0, 1, 2, 3]))) |
           (df['date'].dt.month.isin([12, 1, 2, 3]) & df['date'].dt.year.isin([2023, 2024, 2025])) |
           ((~df['date'].dt.month.isin([12, 1, 2, 3])) & (df['dow'] == 0)), 'is_regular_holiday'] = 1

    df[["month_sin", "month_cos"]] = df["month"].apply(lambda m: pd.Series(sine_cosine_encoding(m, 12)))
    df[["dow_sin", "dow_cos"]] = df["dow"].apply(lambda d: pd.Series(sine_cosine_encoding(d, 7)))
    df[["doy_sin", "doy_cos"]] = df["date"].apply(lambda d: pd.Series(sine_cosine_encoding(d.dayofyear, 365)))
    df[["week_sin", "week_cos"]] = df["week"].apply(lambda w: pd.Series(sine_cosine_encoding(w, 52)))
    df[["quarter_sin", "quarter_cos"]] = df["quarter"].apply(lambda q: pd.Series(sine_cosine_encoding(q, 4)))

    return df.drop(columns=["tomorrow", "yesterday"])

def parse_store_name(item_full: str) -> str:
    return item_full.split("_")[0]

def parse_menu_name(item_full: str) -> str:
    return item_full.split("_", 1)[1] if "_" in item_full else item_full

def make_val_mask_by_week(dataset: 'EnhancedNHiTSDataset', end_date_str: str) -> np.ndarray:
    end_date = pd.to_datetime(end_date_str)
    start_date = end_date - pd.Timedelta(days=6)
    ted = dataset.target_end_dates
    return (ted >= start_date) & (ted <= end_date)

# %% [markdown]
# ### ENhancedNHiTSDataset

# %%
# =====================
# Dataset (MLinear용 그룹 정보 추가)
# =====================
class EnhancedNHiTSDataset(Dataset):
    def __init__(self, cfg: EnhancedNHiTSConfig, df: pd.DataFrame):
        self.cfg = cfg
        self.df = df.copy()
        if cfg.date_col not in self.df.columns or cfg.item_col not in self.df.columns or cfg.target_col not in self.df.columns:
            raise ValueError("입력 데이터에 필요한 컬럼이 없습니다.")
        self.df[cfg.date_col] = pd.to_datetime(self.df[cfg.date_col])
        self.df[cfg.target_col] = pd.to_numeric(self.df[cfg.target_col], errors='coerce').fillna(0.0).clip(lower=0)

        # 🚨 Dense Dataset 전처리
        all_dates = pd.date_range(start=self.df[cfg.date_col].min(), end=self.df[cfg.date_col].max())
        all_items = self.df[cfg.item_col].unique()
        full_df = pd.MultiIndex.from_product([all_dates, all_items], names=[cfg.date_col, cfg.item_col]).to_frame(index=False)
        self.df = pd.merge(full_df, self.df, on=[cfg.date_col, cfg.item_col], how='left')
        self.df[cfg.target_col] = self.df[cfg.target_col].fillna(0)

        # 🚨 (추가) 주말 상대적 판매량 피처를 계산하여 병합
        weekend_ratio_df = get_weekend_sales_ratio(self.df)
        self.df = pd.merge(self.df, weekend_ratio_df, on=cfg.item_col, how='left')
        self.df['weekend_sales_ratio'].fillna(1.0, inplace=True) # 없는 경우 1.0으로 채움 (패턴 없음)

        pivot = self.df.pivot(index=cfg.date_col, columns=cfg.item_col, values=cfg.target_col).sort_index()
        self.items = list(pivot.columns)
        self.dates = list(pivot.index)
        self.values = pivot.fillna(0.0).values.astype(np.float32)

        holidays_set = set(pd.to_datetime(cfg.custom_holidays_list)) if cfg.custom_holidays_list else set()

        # 🚨 build_enhanced_features 함수 호출
        caldf = build_enhanced_features(self.dates, holidays_set)

        self.cal_feats = caldf.drop(columns=["date"]).values.astype(np.float32)
        self.cal_feat_names = [c for c in caldf.columns if c != "date"]

        stores = [parse_store_name(it) for it in self.items]
        menus = [parse_menu_name(it) for it in self.items]

        self.store2idx = {s: i for i, s in enumerate(sorted(set(stores)))}
        self.item_store_idx = np.array([self.store2idx[s] for s in stores], dtype=np.int64)
        self.n_stores = len(self.store2idx)

        menu_categories = [get_menu_category(m) for m in menus]
        self.cat2idx = {c: i for i, c in enumerate(sorted(set(menu_categories)))}
        self.item_cat_idx = np.array([self.cat2idx[c] for c in menu_categories], dtype=np.int64)
        self.n_categories = len(self.cat2idx)

        store_types = [get_store_type(s) for s in stores]
        self.type2idx = {t: i for i, t in enumerate(sorted(set(store_types)))}
        self.item_type_idx = np.array([self.type2idx[t] for t in store_types], dtype=np.int64)
        self.n_types = len(self.type2idx)

        menu_groups = [get_menu_group(s, m) for s, m in zip(stores, menus)]
        self.group2idx = {g: i for i, g in enumerate(sorted(set(menu_groups)))}
        self.item_group_idx = np.array([self.group2idx[g] for g in menu_groups], dtype=np.int64)
        self.n_groups = len(self.group2idx)

        # 🚨 (추가) 주말 상대적 판매량 피처를 배열로 저장
        self.item_weekend_ratio = self.df.drop_duplicates(subset=[cfg.item_col])\
                                      .set_index(cfg.item_col)\
                                      .loc[self.items, 'weekend_sales_ratio'].values.astype(np.float32)

        sw = cfg.store_weights or {}
        self.sample_weights = np.array([sw.get(parse_store_name(it), 1.0) for it in self.items], dtype=np.float32)

        self.indices: List[Tuple[int,int]] = []
        self.target_end_dates: List[pd.Timestamp] = []
        T = len(self.dates)
        Lx, Ly = cfg.in_len, cfg.out_len
        cutoff = pd.to_datetime(cfg.train_end_date)
        max_start = max(0, T - (Lx + Ly))

        for j in range(len(self.items)):
            for t0 in range(0, max_start + 1):
                end_date = self.dates[t0 + Lx + Ly - 1]
                if end_date <= cutoff:
                    self.indices.append((t0, j))
                    self.target_end_dates.append(end_date)

        self.target_end_dates = np.asarray(self.target_end_dates, dtype='datetime64[ns]')

    def __len__(self):
        return len(self.indices)

    def __getitem__(self, idx):
        cfg = self.cfg
        t0, j = self.indices[idx]
        Lx, Ly = cfg.in_len, cfg.out_len

        x = self.values[t0:t0 + Lx, j]
        y = self.values[t0 + Lx:t0 + Lx + Ly, j]

        if cfg.log1p:
            x_in = np.log1p(x); y_out = np.log1p(y)
        else:
            x_in, y_out = x.copy(), y.copy()

        past_cal = self.cal_feats[t0:t0 + Lx, :]
        fut_cal = self.cal_feats[t0 + Lx:t0 + Lx + Ly, :]

        store_idx = self.item_store_idx[j]
        cat_idx = self.item_cat_idx[j]
        type_idx = self.item_type_idx[j]
        group_idx = self.item_group_idx[j]
        sample_w = self.sample_weights[j]

        # 🚨 (추가) 주말 상대적 판매량 피처 가져오기
        weekend_ratio = self.item_weekend_ratio[j]

        zero_mask = (y == 0).astype(np.float32)
        pos_mask = (y > 0).astype(np.float32)

        zero_ratio = np.mean(x == 0)
        weekend_factor = np.mean(past_cal[:, 12])

        return {
            "x": torch.from_numpy(x_in).float(),
            "y": torch.from_numpy(y_out).float(),
            "past_cal": torch.from_numpy(past_cal).float(),
            "fut_cal": torch.from_numpy(fut_cal).float(),
            "store_idx": torch.tensor(store_idx, dtype=torch.long),
            "cat_idx": torch.tensor(cat_idx, dtype=torch.long),
            "type_idx": torch.tensor(type_idx, dtype=torch.long),
            "group_idx": torch.tensor(group_idx, dtype=torch.long),
            "sample_w": torch.tensor(sample_w, dtype=torch.float32),
            "zero_mask": torch.from_numpy(zero_mask).float(),
            "pos_mask": torch.from_numpy(pos_mask).float(),
            "zero_ratio": torch.tensor(zero_ratio, dtype=torch.float32),
            "weekend_factor": torch.tensor(weekend_factor, dtype=torch.float32),
            "weekend_ratio": torch.tensor(weekend_ratio, dtype=torch.float32), # 🚨 새로운 피처 추가
        }

# %% [markdown]
# ### N-HiTS

# %%
# =====================
# N-HiTS (수정된 코드)
# =====================
class NHiTSBlock(nn.Module):
    def __init__(self, input_size: int, output_size: int, hidden_size: int,
                 n_layers: int, dropout: float, pooling_mode: str = "MaxPool1d",
                 n_pool_kernel_size: int = 2, interpolation_mode: str = "linear"):
        super().__init__()
        if pooling_mode == "MaxPool1d":
            self.pooling_layer = nn.MaxPool1d(kernel_size=n_pool_kernel_size, stride=n_pool_kernel_size, ceil_mode=True)
        else:
            self.pooling_layer = nn.AvgPool1d(kernel_size=n_pool_kernel_size, stride=n_pool_kernel_size, ceil_mode=True)
        pooled_size = math.ceil(input_size / n_pool_kernel_size)
        layers = [nn.Linear(pooled_size, hidden_size), nn.ReLU(), nn.Dropout(dropout)]
        for _ in range(n_layers - 1):
            layers += [nn.Linear(hidden_size, hidden_size), nn.ReLU(), nn.Dropout(dropout)]
        self.mlp = nn.Sequential(*layers)
        self.output_layer = nn.Linear(hidden_size, output_size)

    def forward(self, x):
        x = x.unsqueeze(1)
        x_pooled = self.pooling_layer(x).squeeze(1)
        h = self.mlp(x_pooled)
        output = self.output_layer(h)
        return output

class EnhancedNHiTSModel(nn.Module):
    def __init__(self, in_len: int, out_len: int, cal_dim: int, n_stores: int,
                 n_categories: int, n_types: int, cfg: EnhancedNHiTSConfig, has_weekend_ratio: bool = False): # 🚨 (수정) has_weekend_ratio 인자 추가
        super().__init__()
        if cfg.n_pool_kernel_size is None or len(cfg.n_pool_kernel_size) < cfg.n_blocks:
            base_kernels = [2, 2, 1]
            cfg.n_pool_kernel_size = [base_kernels[i % len(base_kernels)] for i in range(cfg.n_blocks)]
        if cfg.stack_types is None or len(cfg.stack_types) < cfg.n_blocks:
            base_types = ["identity", "identity", "trend"]
            cfg.stack_types = [base_types[i % len(base_types)] for i in range(cfg.n_blocks)]
        if cfg.n_freq_downsample is None or len(cfg.n_freq_downsample) < cfg.n_blocks:
            base_downsample = [2, 1, 1]
            cfg.n_freq_downsample = [base_downsample[i % len(base_downsample)] for i in range(cfg.n_blocks)]

        self.out_len = out_len
        self.stack_types = cfg.stack_types

        self.store_emb = nn.Embedding(n_stores, 64)
        self.cat_emb = nn.Embedding(n_categories, 32)
        self.type_emb = nn.Embedding(n_types, 16)
        self.cal_proj = nn.Linear(cal_dim, 128)

        # 🚨 (추가) weekend_ratio를 위한 MLP를 조건부로 생성
        self.has_weekend_ratio = has_weekend_ratio
        meta_dim = 64 + 32 + 16 + 128
        if self.has_weekend_ratio:
            self.weekend_ratio_mlp = nn.Sequential(
                nn.Linear(1, 32), # 입력 차원 1, 출력 차원 32
                nn.ReLU(),
                nn.Dropout(cfg.dropout)
            )
            meta_dim += 32

        self.blocks = nn.ModuleList([
            NHiTSBlock(in_len, out_len, cfg.hidden, cfg.n_layers, cfg.dropout,
                       pooling_mode=cfg.pooling_mode, n_pool_kernel_size=cfg.n_pool_kernel_size[i],
                       interpolation_mode=cfg.interpolation_mode) for i in range(cfg.n_blocks)
        ])

        self.basis_weights = nn.ParameterList([
            nn.Parameter(torch.randn(out_len, max(1, out_len // cfg.n_freq_downsample[i])))
            for i in range(cfg.n_blocks)
        ])

        # 🚨 (수정) meta_dim에 weekend_ratio_mlp의 출력 차원(32) 추가
        self.meta_integration = nn.Sequential(
            nn.Linear(meta_dim, cfg.hidden),
            nn.ReLU(), nn.Dropout(cfg.dropout),
            nn.Linear(cfg.hidden, out_len)
        )

        self.prob_head = nn.Sequential(
            # 🚨 (수정) prob_head 입력 차원에 weekend_ratio_mlp의 출력 차원(32) 추가
            nn.Linear(meta_dim + 1, cfg.hidden),
            nn.ReLU(), nn.Dropout(cfg.dropout),
            nn.Linear(cfg.hidden, cfg.hidden // 2),
            nn.ReLU(), nn.Dropout(cfg.dropout),
            nn.Linear(cfg.hidden // 2, out_len)
        )

    def forward(self, x, past_cal, fut_cal, store_idx, cat_idx, type_idx, weekend_ratio=None, **kwargs): # 🚨 (수정) weekend_ratio 인자 추가 및 기본값 설정
        store_emb = self.store_emb(store_idx)
        cat_emb = self.cat_emb(cat_idx)
        type_emb = self.type_emb(type_idx)
        cal_all = torch.cat([past_cal, fut_cal], dim=1).mean(dim=1)
        cal_emb = self.cal_proj(cal_all)

        # 🚨 (수정) weekend_ratio 처리 로직을 조건부로 실행
        if self.has_weekend_ratio and weekend_ratio is not None:
            weekend_ratio_emb = self.weekend_ratio_mlp(weekend_ratio.unsqueeze(1))
            meta_feat = torch.cat([store_emb, cat_emb, type_emb, cal_emb, weekend_ratio_emb], dim=-1)
        else:
            meta_feat = torch.cat([store_emb, cat_emb, type_emb, cal_emb], dim=-1)

        outputs = []
        for i, block in enumerate(self.blocks):
            block_output = block(x)
            if self.stack_types[i] == "trend":
                basis = self.basis_weights[i]
                block_output = block_output @ basis
                block_output = F.interpolate(block_output.unsqueeze(1), size=self.out_len,
                                             mode='linear', align_corners=False).squeeze(1)
            outputs.append(block_output)
        nhits_output = torch.stack(outputs, dim=0).sum(dim=0)

        meta_adjustment = self.meta_integration(meta_feat)
        value_pred = nhits_output + meta_adjustment

        prob_feat = torch.cat([meta_feat, x.mean(dim=1, keepdim=True)], dim=-1)
        prob_logits = self.prob_head(prob_feat)
        return value_pred, prob_logits

# %% [markdown]
# ### PatchTST

# %%
# =====================
# PatchTST (수정된 코드)
# =====================
def _build_sinusoidal_pos(L: int, d_model: int, device: torch.device, dtype: torch.dtype):
    pos = torch.arange(L, device=device, dtype=dtype).unsqueeze(1)
    i = torch.arange(d_model, device=device, dtype=dtype).unsqueeze(0)
    div = torch.exp(- (i // 2) * math.log(10000.0) / max(1, (d_model // 2)))
    angle = pos * div
    pe = torch.zeros((L, d_model), device=device, dtype=dtype)
    pe[:, 0::2] = torch.sin(angle[:, 0::2])
    pe[:, 1::2] = torch.cos(angle[:, 1::2])
    return pe.unsqueeze(0)

class PatchEmbedding(nn.Module):
    def __init__(self, seq_len: int, patch_len: int, stride: int, d_model: int):
        super().__init__()
        assert patch_len > 0 and stride > 0
        self.patch_len = patch_len
        self.stride = stride
        self.d_model = d_model
        self.proj = nn.Linear(patch_len, d_model)

    def forward(self, x):  # x: [B, L]
        B, L = x.shape
        if L < self.patch_len:
            pad = self.patch_len - L
            last_val = x[:, -1:].repeat(1, pad)
            x = torch.cat([last_val, x], dim=1)

        patches = x.unfold(dimension=1, size=self.patch_len, step=self.stride)  # [B, Np, P]
        Np = patches.size(1)
        x_e = self.proj(patches)
        pe = _build_sinusoidal_pos(Np, self.d_model, x_e.device, x_e.dtype)  # [1,Np,D]
        x_e = x_e + pe
        return x_e

class ImprovedPatchTSTTiny(nn.Module):
    def __init__(self, cfg: EnhancedNHiTSConfig, in_len: int, out_len: int,
                 cal_dim: int, n_stores: int, n_categories: int, n_types: int, has_weekend_ratio: bool = False): # 🚨 (수정) has_weekend_ratio 인자 추가
        super().__init__()
        patch_len = max(2, min(cfg.ptst_patch_len, max(2, in_len // 8)))
        stride = max(1, patch_len // 2)
        self.embed = PatchEmbedding(in_len, patch_len, stride, cfg.ptst_d_model)

        enc_layer = nn.TransformerEncoderLayer(
            d_model=cfg.ptst_d_model,
            nhead=cfg.ptst_nhead,
            dim_feedforward=int(cfg.ptst_d_model * cfg.ptst_ff_mult),
            dropout=cfg.ptst_dropout,
            batch_first=True,
            activation='gelu',
            norm_first=True
        )
        self.encoder = nn.TransformerEncoder(enc_layer, num_layers=cfg.ptst_num_layers + 1)

        self.multi_heads = nn.ModuleList([
            nn.Sequential(
                nn.LayerNorm(cfg.ptst_d_model),
                nn.Linear(cfg.ptst_d_model, max(16, cfg.ptst_head_hidden // 4)),
                nn.GELU(),
                nn.Dropout(cfg.ptst_dropout),
                nn.Linear(max(16, cfg.ptst_head_hidden // 4), out_len)
            ) for _ in range(4)
        ])

        self.time_proj = nn.Sequential(
            nn.Linear(cal_dim * 2, max(16, cfg.ptst_d_model // 2)),
            nn.GELU(),
            nn.Dropout(cfg.ptst_dropout)
        )

        self.store_emb = nn.Embedding(n_stores, 64)
        self.cat_emb = nn.Embedding(n_categories, 32)
        self.type_emb = nn.Embedding(n_types, 16)
        self.cal_proj = nn.Linear(cal_dim, 128)

        # 🚨 (추가) weekend_ratio를 위한 MLP를 조건부로 생성
        self.has_weekend_ratio = has_weekend_ratio
        meta_dim = 64 + 32 + 16 + 128 + max(16, cfg.ptst_d_model // 2)
        if self.has_weekend_ratio:
            self.weekend_ratio_mlp = nn.Sequential(
                nn.Linear(1, 32),
                nn.GELU(),
                nn.Dropout(cfg.ptst_dropout)
            )
            meta_dim += 32

        # 🚨 (수정) meta_dim에 weekend_ratio_mlp의 출력 차원(32) 추가
        self.meta_integration = nn.Sequential(
            nn.Linear(meta_dim, cfg.ptst_head_hidden),
            nn.GELU(), nn.Dropout(cfg.ptst_dropout),
            nn.Linear(cfg.ptst_head_hidden, max(32, cfg.ptst_head_hidden // 2)),
            nn.GELU(), nn.Dropout(cfg.ptst_dropout),
            nn.Linear(max(32, cfg.ptst_head_hidden // 2), out_len)
        )
        self.prob_head = nn.Sequential(
            # 🚨 (수정) prob_head 입력 차원에 weekend_ratio_mlp의 출력 차원(32) 추가
            nn.Linear(meta_dim + 1, cfg.ptst_head_hidden),
            nn.GELU(), nn.Dropout(cfg.ptst_dropout),
            nn.Linear(cfg.ptst_head_hidden, max(32, cfg.ptst_head_hidden // 2)),
            nn.GELU(), nn.Dropout(cfg.ptst_dropout),
            nn.Linear(max(32, cfg.ptst_head_hidden // 2), out_len)
        )
        self.residual_weight = nn.Parameter(torch.tensor(0.1))

    def forward(self, x, past_cal, fut_cal, store_idx, cat_idx, type_idx, weekend_ratio=None, **kwargs): # 🚨 (수정) weekend_ratio 인자 추가 및 기본값 설정
        z = self.embed(x)
        z = self.encoder(z)
        z_global = z.mean(dim=1)
        z_last = z[:, -1, :]
        z_max, _ = z.max(dim=1)
        z_first = z[:, 0, :]

        head_preds = []
        for i, head in enumerate(self.multi_heads):
            vec = [z_global, z_last, z_max, z_first][i]
            head_preds.append(head(vec))
        seq_out = torch.stack(head_preds, dim=0).mean(dim=0)

        time_info = torch.cat([past_cal.mean(dim=1), fut_cal.mean(dim=1)], dim=-1)
        time_emb = self.time_proj(time_info)

        store_emb = self.store_emb(store_idx)
        cat_emb = self.cat_emb(cat_idx)
        type_emb = self.type_emb(type_idx)
        cal_emb = self.cal_proj(torch.cat([past_cal, fut_cal], dim=1).mean(dim=1))

        # 🚨 (수정) weekend_ratio 처리 로직을 조건부로 실행
        if self.has_weekend_ratio and weekend_ratio is not None:
            weekend_ratio_emb = self.weekend_ratio_mlp(weekend_ratio.unsqueeze(1))
            meta_feat = torch.cat([store_emb, cat_emb, type_emb, cal_emb, time_emb, weekend_ratio_emb], dim=-1)
        else:
            meta_feat = torch.cat([store_emb, cat_emb, type_emb, cal_emb, time_emb], dim=-1)

        meta_adjustment = self.meta_integration(meta_feat)
        value_pred = seq_out + self.residual_weight * meta_adjustment

        prob_logits = self.prob_head(torch.cat([meta_feat, x.mean(dim=1, keepdim=True)], dim=-1))
        return value_pred, prob_logits

# %% [markdown]
# ### TimesNet

# %%
# =====================
# Improved TimesNet (수정된 코드)
# =====================
class FrequencyBlock(nn.Module):
    def __init__(self, seq_len: int, top_k: int = 5):
        super().__init__()
        self.seq_len = int(seq_len)
        self.top_k = int(min(max(top_k, 1), max(1, self.seq_len // 2)))

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        B, C, L = x.shape
        in_dtype = x.dtype
        x32 = x.to(torch.float32)
        x_freq = torch.fft.rfft(x32, dim=-1)
        amp = torch.abs(x_freq).mean(dim=1)
        _, top_idx = torch.topk(amp, k=self.top_k, dim=-1)
        x_freq_filt = torch.zeros_like(x_freq)
        for i in range(B):
            x_freq_filt[i, :, top_idx[i]] = x_freq[i, :, top_idx[i]]
        x_filt32 = torch.fft.irfft(x_freq_filt, n=L, dim=-1)
        x_filt = x_filt32.to(in_dtype)
        return x_filt

class ImprovedTimesBlock(nn.Module):
    def __init__(
        self,
        in_ch: int,
        out_ch: int,
        seq_len: int,
        kernels=(3, 5, 7),
        top_k: int = 5,
        dropout: float = 0.1,
    ):
        super().__init__()
        assert in_ch > 0 and out_ch > 0 and seq_len > 0
        self.in_ch = int(in_ch)
        self.out_ch = int(out_ch)
        self.seq_len = int(seq_len)

        self.freq_block = FrequencyBlock(seq_len=self.seq_len, top_k=top_k)
        self.period_base = max(2, self.seq_len // 4)

        self.conv2d = nn.Sequential(
            nn.Conv2d(self.in_ch, self.out_ch, kernel_size=(3, 3), padding=1),
            nn.GELU(),
            nn.Conv2d(self.out_ch, self.out_ch, kernel_size=(3, 3), padding=1),
            nn.GELU(),
        )

        ks = list(kernels)
        n_br = len(ks)
        per = max(1, self.out_ch // n_br)
        branch_chs = [per] * n_br
        for i in range(self.out_ch - sum(branch_chs)):
            branch_chs[i % n_br] += 1

        branches = []
        for i, k in enumerate(ks):
            ch = branch_chs[i]
            branches.append(
                nn.Sequential(
                    nn.Conv1d(self.in_ch, ch, kernel_size=k, padding=k // 2),
                    nn.GELU(),
                    nn.Conv1d(ch, ch, kernel_size=k, padding=k // 2),
                    nn.GELU(),
                )
            )
        self.conv1d_branches = nn.ModuleList(branches)
        self.br_sum_ch = sum(branch_chs)

        self.channel_proj = (
            nn.Conv1d(self.br_sum_ch, self.out_ch, kernel_size=1)
            if self.br_sum_ch != self.out_ch
            else nn.Identity()
        )

        self.norm = nn.LayerNorm([self.out_ch, self.seq_len])
        self.dropout = nn.Dropout(dropout)

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        B, C, L = x.shape
        assert C == self.in_ch, f"in_ch mismatch: got {C}, expected {self.in_ch}"

        xf = self.freq_block(x)

        period = self.period_base
        if L % period != 0:
            pad_len = period - (L % period)
            xf = F.pad(xf, (0, pad_len), mode="replicate")
            L_pad = L + pad_len
        else:
            pad_len = 0
            L_pad = L

        x2d = xf.reshape(B, C, period, L_pad // period).contiguous()
        z2d = self.conv2d(x2d)
        z2d_flat = z2d.reshape(B, self.out_ch, L_pad)
        if pad_len > 0:
            z2d_flat = z2d_flat[:, :, :L]

        z1d_list = [branch(x) for branch in self.conv1d_branches]
        z1d = torch.cat(z1d_list, dim=1)
        z1d = self.channel_proj(z1d)

        out = z2d_flat + z1d
        out = self.norm(out)
        out = self.dropout(out)
        return out

class ImprovedTimesNetTiny(nn.Module):
    def __init__(self, cfg: EnhancedNHiTSConfig, in_len: int, out_len: int,
                 cal_dim: int, n_stores: int, n_categories: int, n_types: int, has_weekend_ratio: bool = False): # 🚨 (수정) has_weekend_ratio 인자 추가
        super().__init__()
        C = max(32, min(cfg.tnet_channels, 96))
        C = (C // 8) * 8

        self.stem = nn.Conv1d(1, C, kernel_size=3, padding=1)

        def fast_block(C: int, p: float):
            return nn.Sequential(
                nn.Conv1d(C, C, kernel_size=3, padding=1, groups=C, bias=True),
                nn.Conv1d(C, C, kernel_size=1, bias=False),
                nn.GELU(),
                nn.Conv1d(C, C, kernel_size=3, padding=1, groups=C, bias=True),
                nn.Conv1d(C, C, kernel_size=1, bias=False),
                nn.GELU(),
                nn.Dropout(p)
            )

        self.blocks = nn.ModuleList([
            fast_block(C, p=max(0.0, min(cfg.tnet_dropout, 0.1)))
            for _ in range(max(1, cfg.tnet_blocks))
        ])

        head_hidden = max(128, min(cfg.tnet_head_hidden, 192))
        self.head_fc1 = nn.Linear(C, head_hidden)
        self.head_fc2 = nn.Linear(head_hidden, out_len)
        self.head_drop = nn.Dropout(cfg.tnet_dropout)

        self.store_emb = nn.Embedding(n_stores, 64)
        self.cat_emb = nn.Embedding(n_categories, 32)
        self.type_emb = nn.Embedding(n_types, 16)
        self.cal_proj = nn.Linear(cal_dim, 128)

        # 🚨 (추가) weekend_ratio를 위한 MLP를 조건부로 생성
        self.has_weekend_ratio = has_weekend_ratio
        meta_dim = 64 + 32 + 16 + 128
        if self.has_weekend_ratio:
            self.weekend_ratio_mlp = nn.Sequential(
                nn.Linear(1, 32),
                nn.ReLU(),
                nn.Dropout(cfg.tnet_dropout)
            )
            meta_dim += 32

        self.meta_integration = nn.Sequential(
            nn.Linear(meta_dim, head_hidden),
            nn.ReLU(),
            nn.Dropout(cfg.tnet_dropout),
            nn.Linear(head_hidden, out_len),
        )
        self.prob_head = nn.Sequential(
            nn.Linear(meta_dim + 1, head_hidden),
            nn.ReLU(),
            nn.Dropout(cfg.tnet_dropout),
            nn.Linear(head_hidden, out_len),
        )
        self.meta_res_weight = nn.Parameter(torch.tensor(0.15))

    def forward(self, x, past_cal, fut_cal, store_idx, cat_idx, type_idx, weekend_ratio=None, **kwargs): # 🚨 (수정) weekend_ratio 인자 추가 및 기본값 설정
        z = self.stem(x.unsqueeze(1))
        for blk in self.blocks:
            z = z + blk(z)

        z_mean = z.mean(dim=-1)
        seq_out = self.head_fc2(self.head_drop(F.gelu(self.head_fc1(z_mean))))

        store_emb = self.store_emb(store_idx)
        cat_emb = self.cat_emb(cat_idx)
        type_emb = self.type_emb(type_idx)
        cal_all = torch.cat([past_cal, fut_cal], dim=1).mean(dim=1)
        cal_emb = self.cal_proj(cal_all)

        # 🚨 (수정) weekend_ratio 처리 로직을 조건부로 실행
        if self.has_weekend_ratio and weekend_ratio is not None:
            weekend_ratio_emb = self.weekend_ratio_mlp(weekend_ratio.unsqueeze(1))
            meta_feat = torch.cat([store_emb, cat_emb, type_emb, cal_emb, weekend_ratio_emb], dim=-1)
        else:
            meta_feat = torch.cat([store_emb, cat_emb, type_emb, cal_emb], dim=-1)

        value_pred = seq_out + self.meta_res_weight * self.meta_integration(meta_feat)
        prob_logits = self.prob_head(torch.cat([meta_feat, x.mean(dim=1, keepdim=True)], dim=-1))
        return value_pred, prob_logits

# %% [markdown]
# ### GRU

# %%
# =====================
# GRU (수정된 코드)
# =====================
class GRUTiny(nn.Module):
    def __init__(self, cfg: EnhancedNHiTSConfig, in_len: int, out_len: int,
                 cal_dim: int, n_stores: int, n_categories: int, n_types: int, has_weekend_ratio: bool = False): # 🚨 (수정) has_weekend_ratio 인자 추가
        super().__init__()
        self.gru = nn.GRU(
            input_size=1,
            hidden_size=cfg.gru_hidden,
            num_layers=cfg.gru_layers,
            batch_first=True,
            dropout=cfg.gru_dropout if cfg.gru_layers > 1 else 0.0,
            bidirectional=cfg.gru_bidirectional
        )
        d_mul = 2 if cfg.gru_bidirectional else 1
        self.head = nn.Sequential(nn.LayerNorm(cfg.gru_hidden * d_mul),
                                  nn.Linear(cfg.gru_hidden * d_mul, out_len))
        self.store_emb = nn.Embedding(n_stores, 64)
        self.cat_emb = nn.Embedding(n_categories, 32)
        self.type_emb = nn.Embedding(n_types, 16)
        self.cal_proj = nn.Linear(cal_dim, 128)

        # 🚨 (추가) weekend_ratio를 위한 MLP를 조건부로 생성
        self.has_weekend_ratio = has_weekend_ratio
        meta_dim = 64 + 32 + 16 + 128
        if self.has_weekend_ratio:
            self.weekend_ratio_mlp = nn.Sequential(
                nn.Linear(1, 32),
                nn.ReLU(),
                nn.Dropout(0.1)
            )
            meta_dim += 32

        self.meta_integration = nn.Sequential(
            nn.Linear(meta_dim, cfg.gru_head_hidden),
            nn.ReLU(), nn.Dropout(0.1),
            nn.Linear(cfg.gru_head_hidden, out_len)
        )
        self.prob_head = nn.Sequential(
            nn.Linear(meta_dim + 1, cfg.gru_head_hidden),
            nn.ReLU(), nn.Dropout(0.1),
            nn.Linear(cfg.gru_head_hidden, cfg.gru_head_hidden // 2),
            nn.ReLU(), nn.Dropout(0.1),
            nn.Linear(cfg.gru_head_hidden // 2, out_len)
        )

    def forward(self, x, past_cal, fut_cal, store_idx, cat_idx, type_idx, weekend_ratio=None, **kwargs): # 🚨 (수정) weekend_ratio 인자 추가 및 기본값 설정
        z_in = x.unsqueeze(-1)
        z_out, _ = self.gru(z_in)
        z_last = z_out[:, -1, :]
        seq_out = self.head(z_last)
        store_emb = self.store_emb(store_idx)
        cat_emb = self.cat_emb(cat_idx)
        type_emb = self.type_emb(type_idx)
        cal_all = torch.cat([past_cal, fut_cal], dim=1).mean(dim=1)
        cal_emb = self.cal_proj(cal_all)

        # 🚨 (수정) weekend_ratio 처리 로직을 조건부로 실행
        if self.has_weekend_ratio and weekend_ratio is not None:
            weekend_ratio_emb = self.weekend_ratio_mlp(weekend_ratio.unsqueeze(1))
            meta_feat = torch.cat([store_emb, cat_emb, type_emb, cal_emb, weekend_ratio_emb], dim=-1)
        else:
            meta_feat = torch.cat([store_emb, cat_emb, type_emb, cal_emb], dim=-1)

        value_pred = seq_out + self.meta_integration(meta_feat)
        prob_logits = self.prob_head(torch.cat([meta_feat, x.mean(dim=1, keepdim=True)], dim=-1))
        return value_pred, prob_logits

# %% [markdown]
# ### MLinear

# %%
# =====================
# MLinear (수정된 코드)
# =====================
class MLinearTiny(nn.Module):
    """MLinear 모델 - 그룹별 선형 변환 + 메타 피처 통합"""

    def __init__(self, cfg: EnhancedNHiTSConfig, in_len: int, out_len: int,
                 cal_dim: int, n_stores: int, n_categories: int, n_types: int, n_groups: int, has_weekend_ratio: bool = False): # 🚨 (수정) has_weekend_ratio 인자 추가
        super().__init__()

        self.in_len = in_len
        self.out_len = out_len
        self.cfg = cfg

        # 임베딩
        self.group_emb = nn.Embedding(n_groups, 32)
        self.store_emb = nn.Embedding(n_stores, 32)
        self.cat_emb = nn.Embedding(n_categories, 16)
        self.type_emb = nn.Embedding(n_types, 16)

        # 캘린더 피처 처리
        self.cal_proj = nn.Sequential(
            nn.Linear(cal_dim * 2, 128),
            nn.ReLU(),
            nn.Dropout(cfg.mlin_dropout * 0.5),
            nn.Linear(128, 64)
        )

        # 🚨 (추가) weekend_ratio를 위한 MLP를 조건부로 생성
        self.has_weekend_ratio = has_weekend_ratio
        meta_dim = 32 + 32 + 16 + 16 + 64
        if self.has_weekend_ratio:
            self.weekend_ratio_mlp = nn.Sequential(
                nn.Linear(1, 32),
                nn.ReLU(),
                nn.Dropout(cfg.mlin_dropout)
            )
            meta_dim += 32

        # 그룹별 MLinear
        self.group_linears = nn.ModuleDict({
            f'group_{i}': nn.Linear(in_len, out_len) for i in range(n_groups)
        })

        # 공통 MLinear
        self.common_linear = nn.Linear(in_len, out_len)

        # 메타 피처 통합
        self.meta_integration = nn.Sequential(
            nn.Linear(meta_dim, cfg.mlin_hidden_dim),
            nn.ReLU(),
            nn.Dropout(cfg.mlin_dropout),
            nn.Linear(cfg.mlin_hidden_dim, out_len)
        )

        # 가중치 네트워크
        self.weight_net = nn.Sequential(
            nn.Linear(meta_dim + 2, 128),
            nn.ReLU(),
            nn.Linear(128, 3),
            nn.Softmax(dim=-1)
        )

        # Hurdle 모델
        self.prob_head = nn.Sequential(
            nn.Linear(meta_dim + 2, cfg.mlin_hidden_dim),
            nn.ReLU(),
            nn.Dropout(cfg.mlin_dropout),
            nn.Linear(cfg.mlin_hidden_dim, cfg.mlin_hidden_dim // 2),
            nn.ReLU(),
            nn.Linear(cfg.mlin_hidden_dim // 2, out_len)
        )

        # 옵션 기능들
        if cfg.mlin_use_residual:
            self.residual_proj = nn.Linear(in_len, out_len)

        if cfg.mlin_use_layer_norm:
            self.output_norm = nn.LayerNorm(out_len)

    def forward(self, x, past_cal, fut_cal, store_idx, cat_idx, type_idx, group_idx,
                zero_ratio, weekend_factor, weekend_ratio=None, **kwargs): # 🚨 (수정) weekend_ratio 인자 추가 및 기본값 설정
        batch_size = x.size(0)

        # 임베딩
        group_emb = self.group_emb(group_idx)
        store_emb = self.store_emb(store_idx)
        cat_emb = self.cat_emb(cat_idx)
        type_emb = self.type_emb(type_idx)

        # 캘린더 피처
        past_cal_mean = past_cal.mean(dim=1)
        fut_cal_mean = fut_cal.mean(dim=1)
        cal_combined = torch.cat([past_cal_mean, fut_cal_mean], dim=1)
        cal_emb = self.cal_proj(cal_combined)

        # 🚨 (수정) weekend_ratio 처리 로직을 조건부로 실행
        if self.has_weekend_ratio and weekend_ratio is not None:
            weekend_ratio_emb = self.weekend_ratio_mlp(weekend_ratio.unsqueeze(1))
            meta_feat = torch.cat([group_emb, store_emb, cat_emb, type_emb, cal_emb, weekend_ratio_emb], dim=-1)
        else:
            meta_feat = torch.cat([group_emb, store_emb, cat_emb, type_emb, cal_emb], dim=-1)

        # 그룹별 MLinear
        group_output = torch.zeros(batch_size, self.out_len, device=x.device)
        for i in range(len(self.group_linears)):
            mask = (group_idx == i).float().unsqueeze(-1)
            group_pred = self.group_linears[f'group_{i}'](x)
            group_output += group_pred * mask

        # 공통 MLinear
        common_output = self.common_linear(x)

        # 메타 조정
        meta_output = self.meta_integration(meta_feat)

        # 가중치 계산
        weight_input = torch.cat([meta_feat, zero_ratio.unsqueeze(-1), weekend_factor.unsqueeze(-1)], dim=-1)
        weights = self.weight_net(weight_input)
        w_group, w_common, w_meta = weights[:, 0:1], weights[:, 1:2], weights[:, 2:3]

        # 최종 예측
        value_pred = w_group * group_output + w_common * common_output + w_meta * meta_output

        # Residual
        if self.cfg.mlin_use_residual:
            value_pred = value_pred + self.residual_proj(x)

        # 정규화
        if self.cfg.mlin_use_layer_norm:
            value_pred = self.output_norm(value_pred)

        # Hurdle 확률
        x_stats = torch.cat([x.mean(dim=1, keepdim=True), x.std(dim=1, keepdim=True)], dim=-1)
        prob_input = torch.cat([meta_feat, x_stats], dim=-1)
        prob_logits = self.prob_head(prob_input)

        return value_pred, prob_logits

# %% [markdown]
# ### TSMixer

# %%
# =====================
# TSMixer (수정된 코드)
# =====================
class TSMixerBlock(nn.Module):
    def __init__(self, d_model: int, n_patches: int, dropout: float):
        super().__init__()
        self.norm1 = nn.LayerNorm(d_model)
        self.token_mixing = nn.Sequential(
            nn.Linear(n_patches, n_patches),
            nn.GELU(),
            nn.Dropout(dropout)
        )
        self.norm2 = nn.LayerNorm(d_model)
        self.channel_mixing = nn.Sequential(
            nn.Linear(d_model, d_model),
            nn.GELU(),
            nn.Dropout(dropout)
        )

    def forward(self, x):
        z = self.norm1(x)
        z = self.token_mixing(z.transpose(1, 2)).transpose(1, 2)
        x = x + z
        z = self.norm2(x)
        z = self.channel_mixing(z)
        x = x + z
        return x

class TSMixer(nn.Module):
    """TSMixer 모델 - 패치/채널 MLP 믹싱 + 메타 피처 통합"""

    def __init__(self, cfg: EnhancedNHiTSConfig, in_len: int, out_len: int,
                 cal_dim: int, n_stores: int, n_categories: int, n_types: int,
                 n_groups: int, d_model: int, has_weekend_ratio: bool = False): # 🚨 (수정) has_weekend_ratio 인자 추가
        super().__init__()

        self.in_len = in_len
        self.out_len = out_len
        self.cfg = cfg
        self.d_model = d_model

        patch_len = max(2, min(cfg.tsm_patch_len, in_len))
        stride = max(1, patch_len // 2)
        self.patch_len = patch_len
        self.stride = stride

        if in_len < patch_len:
            self.n_patches = 1
        else:
            self.n_patches = math.floor((in_len - patch_len) / stride) + 1

        self.patch_embedding = nn.Linear(self.patch_len, self.d_model)
        self.mixer_blocks = nn.ModuleList([
            TSMixerBlock(self.d_model, self.n_patches, cfg.tsm_dropout)
            for _ in range(cfg.tsm_num_layers)
        ])

        self.store_emb = nn.Embedding(n_stores, 64)
        self.cat_emb = nn.Embedding(n_categories, 32)
        self.type_emb = nn.Embedding(n_types, 16)

        self.cal_proj = nn.Sequential(
            nn.Linear(cal_dim, 128),
            nn.ReLU(),
            nn.Linear(128, 64)
        )

        # 🚨 (추가) weekend_ratio를 위한 MLP를 조건부로 생성
        self.has_weekend_ratio = has_weekend_ratio
        meta_dim = 64 + 32 + 16 + 64
        if self.has_weekend_ratio:
            self.weekend_ratio_mlp = nn.Sequential(
                nn.Linear(1, 32),
                nn.ReLU(),
                nn.Dropout(cfg.tsm_dropout)
            )
            meta_dim += 32

        self.meta_integration = nn.Sequential(
            nn.Linear(meta_dim, cfg.tsm_head_hidden),
            nn.ReLU(),
            nn.Dropout(cfg.tsm_dropout),
            nn.Linear(cfg.tsm_head_hidden, out_len)
        )

        self.prob_head = nn.Sequential(
            nn.Linear(meta_dim + 1, cfg.tsm_head_hidden),
            nn.ReLU(),
            nn.Dropout(cfg.tsm_dropout),
            nn.Linear(cfg.tsm_head_hidden, out_len)
        )

        self.head = nn.Sequential(
            nn.LayerNorm(self.d_model * self.n_patches),
            nn.Linear(self.d_model * self.n_patches, max(64, cfg.tsm_head_hidden)),
            nn.GELU(),
            nn.Dropout(cfg.tsm_dropout),
            nn.Linear(max(64, cfg.tsm_head_hidden), out_len)
        )

    def forward(self, x, past_cal, fut_cal, store_idx, cat_idx, type_idx, weekend_ratio=None, **kwargs): # 🚨 (수정) weekend_ratio 인자 추가 및 기본값 설정
        if self.in_len < self.patch_len:
            pad_len = self.patch_len - self.in_len
            x = F.pad(x, (0, pad_len), mode='replicate')

        patches = x.unfold(dimension=1, size=self.patch_len, step=self.stride)
        z = self.patch_embedding(patches)

        for block in self.mixer_blocks:
            z = block(z)

        z_global = z.reshape(z.size(0), -1)
        seq_out = self.head(z_global)

        store_emb = self.store_emb(store_idx)
        cat_emb = self.cat_emb(cat_idx)
        type_emb = self.type_emb(type_idx)

        cal_all = torch.cat([past_cal, fut_cal], dim=1)
        cal_all = cal_all.mean(dim=1)

        cal_emb = self.cal_proj(cal_all)

        # 🚨 (수정) weekend_ratio 처리 로직을 조건부로 실행
        if self.has_weekend_ratio and weekend_ratio is not None:
            weekend_ratio_emb = self.weekend_ratio_mlp(weekend_ratio.unsqueeze(1))
            meta_feat = torch.cat([store_emb, cat_emb, type_emb, cal_emb, weekend_ratio_emb], dim=-1)
        else:
            meta_feat = torch.cat([store_emb, cat_emb, type_emb, cal_emb], dim=-1)

        meta_adjustment = self.meta_integration(meta_feat)
        value_pred = seq_out + meta_adjustment

        prob_feat = torch.cat([meta_feat, x.mean(dim=1, keepdim=True)], dim=-1)
        prob_logits = self.prob_head(prob_feat)

        return value_pred, prob_logits

# %%
# =====================
# Loss / EMA (기존과 동일)
# =====================
class UltraEnhancedHurdleLoss(nn.Module):
    def __init__(self, eps: float = 0.01, zero_weight: float = 0.01, lambda_bce: float = 0.15):
        super().__init__()
        self.eps = eps; self.zero_weight = zero_weight; self.lambda_bce = lambda_bce
        self.bce = nn.BCEWithLogitsLoss(reduction='none')

    def forward(self, v_pred_log, p_logits, y_true_log, pos_mask, sample_w):
        z = (pos_mask > 0).float()
        bce = self.bce(p_logits, z)
        yp_val = torch.expm1(v_pred_log).clamp_min(0.0)
        yt_val = torch.expm1(y_true_log).clamp_min(0.0)
        ultra_eps = torch.where(yt_val < 0.5, self.eps * 0.2,
                                torch.where(yt_val < 2.0, self.eps * 0.5, self.eps))
        denom = (torch.abs(yp_val) + torch.abs(yt_val)).clamp_min(ultra_eps)
        smape_pos = 2.0 * torch.abs(yp_val - yt_val) / denom
        smape_pos = smape_pos * (yt_val > 0).float()
        p = torch.sigmoid(p_logits)
        y_hat = p * yp_val
        denom2 = (torch.abs(y_hat) + torch.abs(yt_val)).clamp_min(ultra_eps)
        smape_all = 2.0 * torch.abs(y_hat - yt_val) / denom2
        ultra_zero_weight = torch.where(
            yt_val < 0.01, torch.full_like(yt_val, self.zero_weight * 0.1),
            torch.where(yt_val < 0.1, torch.full_like(yt_val, self.zero_weight * 0.3),
                        torch.where(yt_val < 1.0, torch.full_like(yt_val, self.zero_weight * 0.6), torch.ones_like(yt_val)))
        )
        smape_all = smape_all * ultra_zero_weight
        bce_s = bce.mean(dim=1); pos_s = smape_pos.mean(dim=1); all_s = smape_all.mean(dim=1)
        sample_loss = self.lambda_bce * bce_s + 0.4 * pos_s + 0.6 * all_s
        sw = sample_w.view(-1); wsum = sw.sum().clamp_min(1e-8)
        loss = (sample_loss * sw).sum() / wsum
        return loss, sample_loss.detach(), sw.detach()

class EMA:
    def __init__(self, model: nn.Module, decay: float = 0.9998):
        self.decay = decay
        self.shadow = {name: p.detach().clone() for name, p in model.named_parameters() if p.requires_grad}

    def update(self, model: nn.Module):
        with torch.no_grad():
            for name, p in model.named_parameters():
                if p.requires_grad:
                    self.shadow[name].mul_((self.decay)).add_(p.detach(), alpha=1-self.decay)

    def apply_to(self, model: nn.Module):
        with torch.no_grad():
            for name, p in model.named_parameters():
                if p.requires_grad:
                    p.copy_(self.shadow[name])

# %%
# =====================
# Trainer (수정된 코드)
# =====================
class GenericTrainer:
    def __init__(self, cfg: EnhancedNHiTSConfig, dataset: EnhancedNHiTSDataset, model: nn.Module,
                 epochs: int, batch_size: int, base_lr: float, max_lr: float, weight_decay: float):
        self.cfg = cfg; self.dataset = dataset; self.model = model.to(cfg.device)
        self.device = torch.device(cfg.device)
        self.criterion = UltraEnhancedHurdleLoss(cfg.eps_smape, cfg.zero_weight, cfg.hurdle_lambda)
        self.ema = EMA(self.model, decay=cfg.ema_decay)
        self.epochs = epochs; self.batch_size = batch_size
        self.base_lr = base_lr; self.max_lr = max_lr; self.weight_decay = weight_decay

    def make_loaders_from_mask(self, mask_val: np.ndarray):
        idx_all = np.arange(len(self.dataset))
        val_idx = idx_all[mask_val]; train_idx = idx_all[~mask_val]
        train_subset = torch.utils.data.Subset(self.dataset, train_idx)
        val_subset = torch.utils.data.Subset(self.dataset, val_idx)
        train_loader = DataLoader(
            train_subset, batch_size=self.batch_size, shuffle=True,
            num_workers=self.cfg.num_workers, pin_memory=self.cfg.pin_memory,
            persistent_workers=self.cfg.persistent_workers, drop_last=False
        )
        val_loader = DataLoader(
            val_subset, batch_size=self.batch_size, shuffle=False,
            num_workers=self.cfg.num_workers, pin_memory=self.cfg.pin_memory,
            persistent_workers=self.cfg.persistent_workers, drop_last=False
        )
        return train_loader, val_loader

    @torch.no_grad()
    def evaluate(self, loader: DataLoader, use_ema: bool = True) -> float:
        if loader is None:
            return float('inf')
        self.model.eval()

        backup = None
        if use_ema:
            backup = {k: v.detach().clone() for k, v in self.model.state_dict().items()}
            self.ema.apply_to(self.model)

        total_loss = 0.0
        total_weight = 0.0

        amp_ctx = torch.autocast(device_type='cuda', dtype=torch.float16) if (
            self.cfg.use_amp and torch.cuda.is_available() and self.device.type == "cuda"
        ) else torch.cuda.amp.autocast(enabled=False)

        with amp_ctx:
            for batch in loader:
                x = batch["x"].to(self.device)
                y = batch["y"].to(self.device)
                past_cal = batch["past_cal"].to(self.device)
                fut_cal = batch["fut_cal"].to(self.device)
                store_idx = batch["store_idx"].to(self.device)
                cat_idx = batch["cat_idx"].to(self.device)
                type_idx = batch["type_idx"].to(self.device)
                sample_w = batch["sample_w"].to(self.device)
                pos_mask = batch["pos_mask"].to(self.device)

                # 🚨 (추가) weekend_ratio 가져오기
                weekend_ratio = batch["weekend_ratio"].to(self.device)

                # MLinear용 추가 입력 (이미 전달한 파라미터 제외)
                excluded_keys = {"x", "y", "past_cal", "fut_cal", "store_idx", "cat_idx", "type_idx", "sample_w", "pos_mask", "weekend_ratio"}
                batch_dict = {k: v.to(self.device) if isinstance(v, torch.Tensor) else v
                              for k, v in batch.items() if k not in excluded_keys}

                # 🚨 (수정) 모델에 weekend_ratio 전달
                v_pred, p_logits = self.model(x, past_cal, fut_cal, store_idx, cat_idx, type_idx, weekend_ratio=weekend_ratio, **batch_dict)

                _, sample_loss, sw = self.criterion(v_pred, p_logits, y, pos_mask, sample_w)

                total_loss += (sample_loss * sw).sum().item()
                total_weight += sw.sum().item()

        if use_ema and backup is not None:
            self.model.load_state_dict(backup)
            del backup
            gc.collect(); torch.cuda.empty_cache()

        if total_weight <= 0:
            return float('inf')
        return total_loss / total_weight

    def train_with_loaders(self, train_loader: DataLoader, val_loader: DataLoader, model_name="Model"):
        optim = torch.optim.AdamW(self.model.parameters(), lr=self.base_lr, weight_decay=self.weight_decay, betas=(0.9,0.999))
        steps_per_epoch = max(1, len(train_loader))
        sched = torch.optim.lr_scheduler.OneCycleLR(
            optim, max_lr=self.max_lr, epochs=self.epochs,
            steps_per_epoch=steps_per_epoch, pct_start=0.05,
            div_factor=max(1e-8, self.max_lr / max(1e-8, self.base_lr))
        )
        patience = max(self.cfg.earlystop_patience_min, int(self.epochs * self.cfg.earlystop_patience_ratio))
        best_val = float("inf"); best_state = None; no_improve=0
        for epoch in range(1, self.epochs+1):
            self.model.train()
            amp_ctx = torch.autocast(device_type='cuda', dtype=torch.float16) if (self.cfg.use_amp and torch.cuda.is_available() and self.device.type=="cuda") else torch.cuda.amp.autocast(enabled=False)
            running = []
            for batch in train_loader:
                x = batch["x"].to(self.device); y = batch["y"].to(self.device)
                past_cal = batch["past_cal"].to(self.device); fut_cal = batch["fut_cal"].to(self.device)
                store_idx = batch["store_idx"].to(self.device); cat_idx = batch["cat_idx"].to(self.device)
                type_idx = batch["type_idx"].to(self.device); sample_w = batch["sample_w"].to(self.device)
                pos_mask = batch["pos_mask"].to(self.device)

                # 🚨 (추가) weekend_ratio 가져오기
                weekend_ratio = batch["weekend_ratio"].to(self.device)

                # MLinear용 추가 입력 (이미 전달한 파라미터 제외)
                excluded_keys = {"x", "y", "past_cal", "fut_cal", "store_idx", "cat_idx", "type_idx", "sample_w", "pos_mask", "weekend_ratio"}
                batch_dict = {k: v.to(self.device) if isinstance(v, torch.Tensor) else v
                              for k, v in batch.items() if k not in excluded_keys}

                with amp_ctx:
                    # 🚨 (수정) 모델에 weekend_ratio 전달
                    v_pred, p_logits = self.model(x, past_cal, fut_cal, store_idx, cat_idx, type_idx, weekend_ratio=weekend_ratio, **batch_dict)

                    loss, _, _ = self.criterion(v_pred, p_logits, y, pos_mask, sample_w)
                optim.zero_grad(set_to_none=True); loss.backward()
                torch.nn.utils.clip_grad_norm_(self.model.parameters(), self.cfg.grad_clip)
                optim.step(); sched.step(); self.ema.update(self.model)
                running.append(loss.detach().item())
            val_loss = self.evaluate(val_loader, use_ema=True)
            tr_mean = float(np.mean(running)) if running else float('nan')
            print(f"[{model_name}] [Epoch {epoch:03d}] train_loss: {tr_mean:.5f}  val_loss: {val_loss:.5f}")
            if val_loss < best_val:
                best_val = val_loss
                best_state = {k: v.detach().cpu().clone() for k, v in self.model.state_dict().items()}
                no_improve = 0
            else:
                no_improve += 1
                if no_improve >= patience:
                    print(f"[{model_name}] Early stopping at epoch {epoch}")
                    break
        if best_state is not None:
            self.model.load_state_dict(best_state)
        self.ema.apply_to(self.model)
        return self.model, best_val

# %%
# =====================
# Predict Utils (수정된 코드)
# =====================
@torch.no_grad()
def predict_one_file_generic(
    cfg: EnhancedNHiTSConfig,
    model: nn.Module,
    test_df: pd.DataFrame,
    train_df: pd.DataFrame, # 🚨 (추가) train_df 인자 추가
    store2idx: Dict,
    cat2idx: Dict,
    type2idx: Dict,
    group2idx: Dict = None
) -> pd.DataFrame:
    device = torch.device(cfg.device)
    if test_df is None or len(test_df) == 0:
        return pd.DataFrame()

    tdf = test_df.copy()
    if cfg.date_col not in tdf.columns or cfg.item_col not in tdf.columns or cfg.target_col not in tdf.columns:
        return pd.DataFrame()

    tdf[cfg.date_col] = pd.to_datetime(tdf[cfg.date_col], errors="coerce")
    tdf = tdf.dropna(subset=[cfg.date_col])
    if len(tdf) == 0:
        return pd.DataFrame()

    tdf[cfg.target_col] = pd.to_numeric(tdf[cfg.target_col], errors="coerce").fillna(0.0).clip(lower=0)

    try:
        pivot = (
            tdf.pivot(index=cfg.date_col, columns=cfg.item_col, values=cfg.target_col)
                .sort_index()
                .fillna(0.0)
        )
    except Exception:
        return pd.DataFrame()
    if pivot.shape[1] == 0:
        return pd.DataFrame()

    items = list(pivot.columns)
    dates = list(pivot.index)
    values = pivot.values.astype(np.float32)

    # replicate padding (훈련과 일관)
    Lx = cfg.in_len
    if len(dates) < Lx:
        pad_rows = Lx - len(dates)
        first_row = values[0:1, :] if len(dates) > 0 else np.zeros((1, values.shape[1]), dtype=np.float32)
        pad = np.repeat(first_row, pad_rows, axis=0)
        values = np.vstack([pad, values])
        start_date = dates[0] if len(dates) > 0 else pd.Timestamp("2000-01-01")
        backfill = [start_date - pd.Timedelta(days=i) for i in range(pad_rows, 0, -1)]
        dates = backfill + dates

    last_date = dates[-1]
    future_dates = [last_date + pd.Timedelta(days=i) for i in range(1, cfg.out_len + 1)]
    holidays_set = set(pd.to_datetime(cfg.custom_holidays_list)) if cfg.custom_holidays_list else set()

    store_names = [parse_store_name(it) for it in items]

    past_cal = build_enhanced_features(dates[-Lx:], holidays_set, store_names).drop(columns=["date"]).values.astype(np.float32)
    fut_cal = build_enhanced_features(future_dates, holidays_set, store_names).drop(columns=["date"]).values.astype(np.float32)

    x_np = values[-Lx:, :].T  # [B,L]
    if cfg.log1p:
        x_np = np.log1p(x_np)

    B = len(items)
    x = torch.from_numpy(x_np).to(device=device, dtype=torch.float32)
    past_cal_b = torch.from_numpy(np.repeat(past_cal[None, :, :], B, axis=0)).to(device=device, dtype=torch.float32)
    fut_cal_b = torch.from_numpy(np.repeat(fut_cal[None, :, :], B, axis=0)).to(device=device, dtype=torch.float32)

    stores = [parse_store_name(it) for it in items]
    menus = [parse_menu_name(it) for it in items]

    # 🚨 (추가) 주말 상대적 판매량 피처 계산 및 모델 입력으로 준비
    all_df = pd.concat([train_df, tdf], axis=0)
    weekend_ratio_df = get_weekend_sales_ratio(all_df)
    weekend_ratio_map = weekend_ratio_df.set_index(cfg.item_col)['weekend_sales_ratio'].to_dict()
    weekend_ratio_np = np.array([weekend_ratio_map.get(it, 1.0) for it in items], dtype=np.float32)
    weekend_ratio_tensor = torch.from_numpy(weekend_ratio_np).to(device=device, dtype=torch.float32)

    safe_store_default = next(iter(store2idx.values()), 0)
    safe_cat_default = next(iter(cat2idx.values()), 0)
    safe_type_default = next(iter(type2idx.values()), 0)

    store_idx = torch.as_tensor([store2idx.get(s, safe_store_default) for s in stores], device=device, dtype=torch.long)
    cat_idx = torch.as_tensor([cat2idx.get(get_menu_category(m), safe_cat_default) for m in menus], device=device, dtype=torch.long)
    type_idx = torch.as_tensor([type2idx.get(get_store_type(s), safe_type_default) for s in stores], device=device, dtype=torch.long)

    # MLinear용 그룹 정보
    if group2idx is not None:
        safe_group_default = next(iter(group2idx.values()), 0)
        group_idx = torch.as_tensor([group2idx.get(get_menu_group(s, m), safe_group_default)
                                     for s, m in zip(stores, menus)], device=device, dtype=torch.long)

        # MLinear용 추가 피처
        zero_ratio = torch.tensor([np.mean(x_np[i] == 0) for i in range(B)], device=device, dtype=torch.float32)
        weekend_factor = torch.tensor([np.mean(past_cal[:, 12]) for _ in range(B)], device=device, dtype=torch.float32)
    else:
        group_idx = torch.zeros(B, device=device, dtype=torch.long)
        zero_ratio = torch.zeros(B, device=device, dtype=torch.float32)
        weekend_factor = torch.zeros(B, device=device, dtype=torch.float32)

    use_cuda_amp = bool(cfg.use_amp and torch.cuda.is_available() and device.type == "cuda")
    amp_ctx = torch.autocast(device_type="cuda", dtype=torch.float16) if use_cuda_amp else torch.cuda.amp.autocast(enabled=False)

    model.eval()
    with amp_ctx:
        # 🚨 (수정) 모델에 weekend_ratio 전달
        v_pred_log, p_logits = model(x, past_cal_b, fut_cal_b, store_idx, cat_idx, type_idx,
                                     weekend_ratio=weekend_ratio_tensor,
                                     group_idx=group_idx, zero_ratio=zero_ratio, weekend_factor=weekend_factor)
        y_val = torch.expm1(v_pred_log).clamp_min(0.0)
        y_prob = torch.sigmoid(p_logits)
        y_hat = (y_prob * y_val).clamp_min(0.0).detach().cpu().numpy()  # [B, out_len]

    out = pd.DataFrame(
        y_hat.T,
        index=[f"D+{i}" for i in range(1, cfg.out_len + 1)],
        columns=items
    )
    out = out.replace([np.inf, -np.inf], 0.0).fillna(0.0)
    return out

# %%
# =====================
# Ensemble Helper (기존과 동일)
# =====================
def invloss_weights(vals: List[float], eps: float = 1e-8) -> List[float]:
    arr = np.array(vals, dtype=np.float64)
    arr[~np.isfinite(arr)] = np.nan
    if np.all(np.isnan(arr)):
        return (np.ones_like(arr) / len(arr)).tolist()
    safe = np.nan_to_num(arr, nan=np.nanmax(arr) * 1.5)
    inv = 1.0 / np.clip(safe, eps, None)
    if not np.isfinite(inv).any() or inv.sum() <= 0:
        return (np.ones_like(inv) / len(inv)).tolist()
    w = inv / inv.sum()
    return w.tolist()

# %% [markdown]
# ### 모델 팩토리

# %%
# =====================
# Model factory (수정된 코드)
# =====================
def build_model_by_name(name: str, cfg: EnhancedNHiTSConfig, ds: EnhancedNHiTSDataset,
                        trial: Optional['optuna.trial.Trial']=None) -> nn.Module:
    # 🚨 (추가) weekend_ratio 피처의 존재 여부 확인
    has_weekend_ratio = hasattr(ds, 'item_weekend_ratio')

    if name == "N-HiTS":
        hidden = trial.suggest_categorical("nh_hidden", [256, 384, 512]) if trial else cfg.hidden
        n_layers = trial.suggest_categorical("nh_layers", [1, 2, 3]) if trial else cfg.n_layers
        dropout = trial.suggest_float("nh_dropout", 0.0, 0.3) if trial else cfg.dropout
        nh_cfg = EnhancedNHiTSConfig(**{**cfg.__dict__, "hidden": hidden, "n_layers": n_layers, "dropout": dropout})
        # 🚨 (수정) weekend_ratio 존재 여부를 전달
        return EnhancedNHiTSModel(cfg.in_len, cfg.out_len, ds.cal_feats.shape[1], ds.n_stores, ds.n_categories, ds.n_types, nh_cfg, has_weekend_ratio=has_weekend_ratio)

    if name == "PatchTST":
        d_model = trial.suggest_categorical("pt_d_model", [192, 256, 320]) if trial else cfg.ptst_d_model
        nhead = trial.suggest_categorical("pt_nhead", [8, 12]) if trial else cfg.ptst_nhead
        nlayer = trial.suggest_categorical("pt_nlayers", [2, 3, 4]) if trial else cfg.ptst_num_layers
        p_len = trial.suggest_categorical("pt_patch", [2, 3, 4]) if trial else max(2, cfg.ptst_patch_len // 2)
        stride = trial.suggest_categorical("pt_stride", [1, 2]) if trial else max(1, cfg.ptst_stride // 2)
        drop = trial.suggest_float("pt_dropout", 0.05, 0.2) if trial else cfg.ptst_dropout
        ff_mult = trial.suggest_float("ptst_ff_mult", 1.5, 3.5) if trial else cfg.ptst_ff_mult
        pt_cfg = EnhancedNHiTSConfig(**{**cfg.__dict__,
                                        "ptst_d_model": d_model, "ptst_nhead": nhead, "ptst_num_layers": nlayer,
                                        "ptst_patch_len": p_len, "ptst_stride": stride, "ptst_dropout": drop, "ptst_ff_mult": ff_mult
                                        })
        # 🚨 (수정) weekend_ratio 존재 여부를 전달
        return ImprovedPatchTSTTiny(pt_cfg, cfg.in_len, cfg.out_len, ds.cal_feats.shape[1], ds.n_stores, ds.n_categories, ds.n_types, has_weekend_ratio=has_weekend_ratio)

    if name == "TimesNet":
        channels = trial.suggest_categorical("tn_channels", [96, 128, 160]) if trial else cfg.tnet_channels
        blocks = trial.suggest_categorical("tn_blocks", [2, 3, 4]) if trial else cfg.tnet_blocks
        drop = trial.suggest_float("tn_dropout", 0.0, 0.3) if trial else cfg.tnet_dropout
        tn_cfg = EnhancedNHiTSConfig(**{**cfg.__dict__,
                                        "tnet_channels": channels, "tnet_blocks": blocks, "tnet_dropout": drop
                                        })
        # 🚨 (수정) weekend_ratio 존재 여부를 전달
        return ImprovedTimesNetTiny(tn_cfg, cfg.in_len, cfg.out_len, ds.cal_feats.shape[1], ds.n_stores, ds.n_categories, ds.n_types, has_weekend_ratio=has_weekend_ratio)

    if name == "GRU":
        hidden = trial.suggest_categorical("gru_hidden", [128, 192, 256]) if trial else cfg.gru_hidden
        layers = trial.suggest_categorical("gru_layers", [1, 2, 3]) if trial else cfg.gru_layers
        drop = trial.suggest_float("gru_dropout", 0.0, 0.3) if trial else cfg.gru_dropout
        bidi = trial.suggest_categorical("gru_bidi", [False, True]) if trial else cfg.gru_bidirectional
        gr_cfg = EnhancedNHiTSConfig(**{**cfg.__dict__,
                                        "gru_hidden": hidden, "gru_layers": layers, "gru_dropout": drop, "gru_bidirectional": bidi
                                        })
        # 🚨 (수정) weekend_ratio 존재 여부를 전달
        return GRUTiny(gr_cfg, cfg.in_len, cfg.out_len, ds.cal_feats.shape[1], ds.n_stores, ds.n_categories, ds.n_types, has_weekend_ratio=has_weekend_ratio)

    if name == "MLinear":
        hidden_dim = trial.suggest_categorical("ml_hidden_dim", [256, 384, 512]) if trial else cfg.mlin_hidden_dim
        dropout = trial.suggest_float("ml_dropout", 0.0, 0.3) if trial else cfg.mlin_dropout
        use_residual = trial.suggest_categorical("ml_residual", [True, False]) if trial else cfg.mlin_use_residual
        use_layer_norm = trial.suggest_categorical("ml_layer_norm", [True, False]) if trial else cfg.mlin_use_layer_norm
        ml_cfg = EnhancedNHiTSConfig(**{**cfg.__dict__,
                                        "mlin_hidden_dim": hidden_dim, "mlin_dropout": dropout,
                                        "mlin_use_residual": use_residual, "mlin_use_layer_norm": use_layer_norm
                                        })
        # 🚨 (수정) weekend_ratio 존재 여부를 전달
        return MLinearTiny(ml_cfg, cfg.in_len, cfg.out_len, ds.cal_feats.shape[1], ds.n_stores, ds.n_categories, ds.n_types, ds.n_groups, has_weekend_ratio=has_weekend_ratio)

    if name == "TSMixer":
        d_model = trial.suggest_categorical("tm_d_model", [192, 256, 320]) if trial else cfg.tsm_d_model
        n_layers = trial.suggest_categorical("tm_n_layers", [2, 3, 4]) if trial else cfg.tsm_num_layers
        drop = trial.suggest_float("tm_dropout", 0.0, 0.3) if trial else cfg.tsm_dropout
        p_len = trial.suggest_categorical("tm_patch", [2, 3, 4]) if trial else max(2, cfg.tsm_patch_len)
        tsm_cfg = EnhancedNHiTSConfig(**{**cfg.__dict__,
                                        "tsm_d_model": d_model, "tsm_num_layers": n_layers, "tsm_dropout": drop,
                                        "tsm_patch_len": p_len
                                        })
        # 🚨 (수정) weekend_ratio 존재 여부를 전달
        return TSMixer(tsm_cfg, cfg.in_len, cfg.out_len, ds.cal_feats.shape[1],
                       ds.n_stores, ds.n_categories, ds.n_types, ds.n_groups, d_model, has_weekend_ratio=has_weekend_ratio)
    raise ValueError(f"Unknown model name: {name}")

def optuna_objective_factory(model_name: str, cfg: EnhancedNHiTSConfig, ds: EnhancedNHiTSDataset, mask_val: np.ndarray):
    def objective(trial: 'optuna.trial.Trial') -> float:
        # 훈련 레벨도 일부 튜닝(옵션)
        base_lr = trial.suggest_float("base_lr", 3e-4, 3e-3, log=True)
        max_lr  = trial.suggest_float("max_lr",  8e-4, 6e-3, log=True)
        wd      = trial.suggest_float("weight_decay", 1e-6, 8e-4, log=True)
        grad_clip = trial.suggest_float("grad_clip", 0.3, 1.0)
        pat_ratio = trial.suggest_float("pat_ratio", 0.15, 0.35)

        tmp_cfg = EnhancedNHiTSConfig(**{**cfg.__dict__,
            "grad_clip": grad_clip, "earlystop_patience_ratio": pat_ratio
        })
        model = build_model_by_name(model_name, tmp_cfg, ds, trial)
        trainer = GenericTrainer(tmp_cfg, ds, model, epochs=tmp_cfg.EPOCHS_TUNE, batch_size=tmp_cfg.BATCH_TUNE,
                                 base_lr=base_lr, max_lr=max_lr, weight_decay=wd)
        train_loader, val_loader = trainer.make_loaders_from_mask(mask_val)
        _, val_loss = trainer.train_with_loaders(train_loader, val_loader, model_name=f"{model_name}-TUNE")
        trial.set_user_attr("val_loss", float(val_loss))
        return float(val_loss)
    return objective

def run_optuna_for_model(model_name: str, cfg: EnhancedNHiTSConfig, ds: EnhancedNHiTSDataset, mask_val: np.ndarray):
    if not HAS_OPTUNA:
        print(f"[Optuna] optuna가 설치되어 있지 않습니다. '{model_name}' 튜닝을 건너뜁니다.")
        return None, None
    print(f"[Optuna] Start tuning for {model_name} (trials={cfg.N_TRIALS})")
    pruner = optuna.pruners.MedianPruner(n_startup_trials=5, n_warmup_steps=10, interval_steps=1)
    sampler = optuna.samplers.TPESampler(multivariate=True, group=True, constant_liar=True, seed=cfg.seed)
    study = optuna.create_study(direction="minimize", sampler=sampler, pruner=pruner, study_name=f"study_{model_name}")
    study.optimize(optuna_objective_factory(model_name, cfg, ds, mask_val), n_trials=cfg.N_TRIALS, show_progress_bar=False)
    print(f"[Optuna] Best {model_name} val_loss: {study.best_value:.6f}")
    best_params = study.best_params
    return study, best_params

def build_final_model_with_best(model_name: str, cfg: EnhancedNHiTSConfig, ds: EnhancedNHiTSDataset, best_params: Optional[dict]) -> nn.Module:
    if best_params is None:
        return build_model_by_name(model_name, cfg, ds, None)

    tmp = dict(cfg.__dict__)
    if model_name == "N-HiTS":
        if "nh_hidden" in best_params: tmp["hidden"] = best_params["nh_hidden"]
        if "nh_layers" in best_params: tmp["n_layers"] = best_params["nh_layers"]
        if "nh_dropout" in best_params: tmp["dropout"] = best_params["nh_dropout"]

    elif model_name == "PatchTST":
        mapping = {"pt_d_model":"ptst_d_model","pt_nhead":"ptst_nhead","pt_nlayers":"ptst_num_layers",
                   "pt_patch":"ptst_patch_len","pt_stride":"ptst_stride","pt_dropout":"ptst_dropout",
                   "ptst_ff_mult":"ptst_ff_mult"}
        for k, v in mapping.items():
            if k in best_params:
                tmp[v] = best_params[k]

    elif model_name == "TimesNet":
        mapping = {"tn_channels":"tnet_channels","tn_blocks":"tnet_blocks","tn_dropout":"tnet_dropout"}
        for k, v in mapping.items():
            if k in best_params:
                tmp[v] = best_params[k]

    elif model_name == "GRU":
        mapping = {"gru_hidden":"gru_hidden","gru_layers":"gru_layers","gru_dropout":"gru_dropout","gru_bidi":"gru_bidirectional"}
        for k, v in mapping.items():
            if k in best_params:
                tmp[v] = best_params[k]

    elif model_name == "MLinear":
        mapping = {"ml_hidden_dim":"mlin_hidden_dim","ml_dropout":"mlin_dropout","ml_residual":"mlin_use_residual","ml_layer_norm":"mlin_use_layer_norm"}
        for k, v in mapping.items():
            if k in best_params:
                tmp[v] = best_params[k]

    elif model_name == "TSMixer":
        # ⭐⭐⭐ 이 부분을 아래와 같이 수정하세요. ⭐⭐⭐
        mapping = {"tm_d_model": "tsm_d_model", "tm_n_layers": "tsm_num_layers", "tm_dropout": "tsm_dropout", "tm_patch": "tsm_patch_len"}
        for k, v in mapping.items():
            if k in best_params:
                tmp[v] = best_params[k]

    new_cfg = EnhancedNHiTSConfig(**tmp)
    return build_model_by_name(model_name, new_cfg, ds, None)

# %% [markdown]
# ### 메인 실행

# %%
if __name__ == "__main__":
    cfg = EnhancedNHiTSConfig()
    if cfg.store_weights is None: cfg.store_weights = DEFAULT_STORE_WEIGHTS
    if cfg.custom_holidays_list is None: cfg.custom_holidays_list = DEFAULT_CUSTOM_HOLIDAYS
    set_seed(cfg.seed)

    print("=== Enhanced 6-Model Ensemble (+ MLinear) 시작 ===")

    if not os.path.exists(cfg.train_csv):
        raise FileNotFoundError(f"학습 파일을 찾을 수 없습니다: {cfg.train_csv}")

    # 🚨 (수정) train_df를 ds 객체 생성 전에 로드하여 추후 predict 함수에 전달
    train_df = pd.read_csv(cfg.train_csv)
    ds = EnhancedNHiTSDataset(cfg, train_df)

    # 🚨 체크포인트 저장 디렉터리 생성
    os.makedirs(cfg.checkpoint_dir, exist_ok=True)

    # ===== (옵션) Optuna per-model 튜닝 =====
    best_params_all = {}
    if cfg.USE_OPTUNA:
        if not HAS_OPTUNA:
            print("⚠️ cfg.USE_OPTUNA=True지만 optuna가 설치되어 있지 않습니다. 튜닝은 건너뜁니다.")
        else:
            tune_mask_val = make_val_mask_by_week(ds, cfg.cv_fold_end_dates[0])
            for name in ["MLinear"]:
                study, best_params = run_optuna_for_model(name, cfg, ds, tune_mask_val)
                best_params_all[name] = best_params
            os.makedirs("./data", exist_ok=True)
            with open("./data/optuna_best_params.json", "w", encoding="utf-8") as f:
                json.dump(best_params_all, f, ensure_ascii=False, indent=2)

    # ===== 모델 학습 (멀티 폴드 평균 val) =====
    # "TimesNet", "GRU", "MLinear", "N-HiTS", "PatchTST", "TSMixer"
    model_names = ["TimesNet", "GRU", "MLinear", "N-HiTS", "PatchTST", "TSMixer"]
    trained_models: Dict[str, nn.Module] = {}
    avg_val_losses: Dict[str, float] = {}

    for name in model_names:
        checkpoint_path = os.path.join(cfg.checkpoint_dir, f"{name}_best_fold.pth")

        # 🚨 체크포인트 파일이 존재하면 불러오기
        #if os.path.exists(checkpoint_path):
        #    print(f"✅ {name} 체크포인트 불러오기...")
        #    model_f = build_final_model_with_best(name, cfg, ds, best_params_all.get(name) if cfg.USE_OPTUNA else None)
        #    model_f.load_state_dict(torch.load(checkpoint_path, map_location=cfg.device))
        #    trained_models[name] = model_f.to(cfg.device)

        #    trainer = GenericTrainer(cfg, ds, trained_models[name], epochs=1, batch_size=cfg.BATCH_FULL, base_lr=0, max_lr=0, weight_decay=0)
        #    avg_val_losses[name] = trainer.evaluate(trainer.make_loaders_from_mask(make_val_mask_by_week(ds, cfg.cv_fold_end_dates[0]))[1], use_ema=True)
        #    print(f"[VAL(re-evaluated)] {name}={avg_val_losses[name]:.5f}")
        #    continue

        print(f"📚 {name} 학습...")

        base_model = build_final_model_with_best(
            name, cfg, ds, best_params_all.get(name) if cfg.USE_OPTUNA else None
        )
        init_state = {k: v.detach().cpu().clone() for k, v in base_model.state_dict().items()}
        del base_model
        gc.collect(); torch.cuda.empty_cache()

        fold_vals = []
        best_fold = None
        best_fold_state = None

        for fold_i, end_date in enumerate(cfg.cv_fold_end_dates, start=1):
            mask_val = make_val_mask_by_week(ds, end_date)

            model_f = build_final_model_with_best(
                name, cfg, ds, best_params_all.get(name) if cfg.USE_OPTUNA else None
            )
            model_f.load_state_dict(init_state, strict=True)
            trainer = GenericTrainer(
                cfg, ds, model_f,
                epochs=cfg.EPOCHS_FULL, batch_size=cfg.BATCH_FULL,
                base_lr=cfg.BASE_LR_FULL, max_lr=cfg.MAX_LR_FULL, weight_decay=cfg.WD_FULL
            )
            train_loader, val_loader = trainer.make_loaders_from_mask(mask_val)
            model_f, val_loss = trainer.train_with_loaders(
                train_loader, val_loader, model_name=f"{name}-F{fold_i}"
            )
            fold_vals.append(float(val_loss))

            if (best_fold is None) or (val_loss < fold_vals[best_fold]):
                best_fold = fold_i - 1
                best_fold_state = {k: v.detach().cpu().clone() for k, v in model_f.state_dict().items()}

            del trainer, train_loader, val_loader, model_f
            gc.collect(); torch.cuda.empty_cache()

        avg_val = float(np.mean(fold_vals)) if len(fold_vals) > 0 else float('inf')
        avg_val_losses[name] = avg_val
        print(f"[VAL(avg over folds)] {name}={avg_val:.5f}")

        final_model = build_final_model_with_best(
            name, cfg, ds, best_params_all.get(name) if cfg.USE_OPTUNA else None
        )
        if best_fold_state is not None:
            final_model.load_state_dict(best_fold_state, strict=True)
        trained_models[name] = final_model.to(cfg.device)

        if best_fold_state is not None:
            torch.save(best_fold_state, checkpoint_path)
            print(f"💾 {name} 베스트 폴드 체크포인트 저장: {checkpoint_path}")

    # ===== 가중치 산출(역손실, 안전화) =====
    vals_in_order = [avg_val_losses.get(n, np.nan) for n in model_names]
    w = invloss_weights(vals_in_order)
    weights = dict(zip(model_names, w))
    print("[Ensemble Weights] " + "  ".join([f"{k}={weights[k]:.3f}" for k in model_names]))

    # ===== 추론 & 제출 =====
    print("🔮 5-Model 앙상블 예측...")
    test_files = sorted(glob.glob(cfg.test_glob))
    if not os.path.exists(cfg.submission_template_csv):
        raise FileNotFoundError(f"제출 템플릿 파일을 찾을 수 없습니다: {cfg.submission_template_csv}")
    sub_template = pd.read_csv(cfg.submission_template_csv)
    all_preds = []

    if len(test_files) == 0:
        print("⚠️ 테스트 파일이 없습니다. 제출 생성을 건너뜁니다.")
    else:
        for test_idx, test_file in enumerate(test_files):
            print(f"  📊 {test_file} 처리 중...")
            try:
                tdf = pd.read_csv(test_file)
            except Exception as e:
                print(f"  ⚠️ 파일 로드 실패: {e}")
                continue

            df_preds = {}
            for name in model_names:
                group2idx = ds.group2idx if name == "MLinear" else None
                # 🚨 (수정) predict_one_file_generic 함수에 train_df 인자 추가
                df = predict_one_file_generic(cfg, trained_models[name], tdf, train_df, ds.store2idx, ds.cat2idx, ds.type2idx, group2idx)
                if df.empty:
                    print(f"  ⚠️ {name} 예측이 비어 있습니다. 이 모델은 스킵합니다.")
                df_preds[name] = df

            non_empty = [df for df in df_preds.values() if df is not None and not df.empty]
            if len(non_empty) == 0:
                print(f"  ⚠️ {test_file} 유효 예측이 없어 스킵합니다.")
                continue
            items = list(non_empty[0].columns)
            for k in df_preds:
                if df_preds[k] is not None and not df_preds[k].empty:
                    df_preds[k] = df_preds[k].reindex(columns=items).fillna(0.0)

            mix = np.zeros_like(non_empty[0].values, dtype=np.float64)
            for name in model_names:
                df = df_preds.get(name, None)
                if df is None or df.empty:
                    continue
                mix += weights[name] * df.values
            mix = np.clip(mix, 0, None)

            submit_block = pd.DataFrame(
                mix,
                index=[f"D+{i}" for i in range(1, cfg.out_len + 1)],
                columns=items
            )
            submit_block.index = [f"TEST_{test_idx:02d}+{k}일" for k in range(1, cfg.out_len + 1)]
            all_preds.append(submit_block)

    if len(all_preds) == 0:
        print("⚠️ 유효한 예측 결과가 없어 제출 파일을 생성하지 않았습니다.")
    else:
        final_submit = pd.concat(all_preds, axis=0)
        final_submit.reset_index(inplace=True)
        final_submit.rename(columns={"index": "영업일자"}, inplace=True)

        final_submit = final_submit.reindex(columns=sub_template.columns, fill_value=0)

        num_cols = [c for c in final_submit.columns if c != "영업일자"]
        for col in num_cols:
            Q95 = final_submit[col].quantile(0.95)
            final_submit[col] = np.where(final_submit[col] > Q95 * 2.0, Q95 * 1.5, final_submit[col])

        final_submit[num_cols] = np.rint(np.clip(final_submit[num_cols].values, a_min=0, a_max=None)).astype(int)
        os.makedirs(os.path.dirname(cfg.out_submission_csv), exist_ok=True)
        final_submit.to_csv(cfg.out_submission_csv, index=False, encoding="utf-8-sig")
        print(f"✅ 앙상블 완료! → {cfg.out_submission_csv}")

    print("🏆 TimesNet + GRU + MLinear + N-HiTS + PatchTST + TSMixer 학습/추론 끝")
# Out:
# === Enhanced 6-Model Ensemble (+ MLinear) 시작 ===
# 📚 TimesNet 학습...
# [TimesNet-F1] [Epoch 001] train_loss: 0.44246  val_loss: 1.07110
# [TimesNet-F1] [Epoch 002] train_loss: 0.38329  val_loss: 1.00925
# [TimesNet-F1] [Epoch 003] train_loss: 0.37185  val_loss: 0.94141
# [TimesNet-F1] [Epoch 004] train_loss: 0.36382  val_loss: 0.88293
# [TimesNet-F1] [Epoch 005] train_loss: 0.35452  val_loss: 0.83458
# [TimesNet-F1] [Epoch 006] train_loss: 0.34680  val_loss: 0.79506
# [TimesNet-F1] [Epoch 007] train_loss: 0.34212  val_loss: 0.76244
# [TimesNet-F1] [Epoch 008] train_loss: 0.33878  val_loss: 0.73428
# [TimesNet-F1] [Epoch 009] train_loss: 0.33563  val_loss: 0.70840
# [TimesNet-F1] [Epoch 010] train_loss: 0.33362  val_loss: 0.68501
# [TimesNet-F1] [Epoch 011] train_loss: 0.33154  val_loss: 0.66294
# [TimesNet-F1] [Epoch 012] train_loss: 0.33008  val_loss: 0.64254
# [TimesNet-F1] [Epoch 013] train_loss: 0.32823  val_loss: 0.62410
# [TimesNet-F1] [Epoch 014] train_loss: 0.32644  val_loss: 0.60675
# [TimesNet-F1] [Epoch 015] train_loss: 0.32550  val_loss: 0.59056
# [TimesNet-F1] [Epoch 016] train_loss: 0.32409  val_loss: 0.57548
# [TimesNet-F1] [Epoch 017] train_loss: 0.32296  val_loss: 0.56319
# [TimesNet-F1] [Epoch 018] train_loss: 0.32147  val_loss: 0.55211
# [TimesNet-F1] [Epoch 019] train_loss: 0.32052  val_loss: 0.54071
# [TimesNet-F1] [Epoch 020] train_loss: 0.31976  val_loss: 0.53025
# [TimesNet-F1] [Epoch 021] train_loss: 0.31888  val_loss: 0.52097
# [TimesNet-F1] [Epoch 022] train_loss: 0.31775  val_loss: 0.51169
# [TimesNet-F1] [Epoch 023] train_loss: 0.31670  val_loss: 0.50277
# [TimesNet-F1] [Epoch 024] train_loss: 0.31575  val_loss: 0.49430
# [TimesNet-F1] [Epoch 025] train_loss: 0.31474  val_loss: 0.48635
# [TimesNet-F1] [Epoch 026] train_loss: 0.31381  val_loss: 0.47903
# [TimesNet-F1] [Epoch 027] train_loss: 0.31276  val_loss: 0.47223
# [TimesNet-F1] [Epoch 028] train_loss: 0.31259  val_loss: 0.46598
# [TimesNet-F1] [Epoch 029] train_loss: 0.31115  val_loss: 0.45963
# [TimesNet-F1] [Epoch 030] train_loss: 0.31062  val_loss: 0.45351
# [TimesNet-F1] [Epoch 031] train_loss: 0.30941  val_loss: 0.44758
# [TimesNet-F1] [Epoch 032] train_loss: 0.30893  val_loss: 0.44219
# [TimesNet-F1] [Epoch 033] train_loss: 0.30824  val_loss: 0.43726
# [TimesNet-F1] [Epoch 034] train_loss: 0.30740  val_loss: 0.43254
# [TimesNet-F1] [Epoch 035] train_loss: 0.30739  val_loss: 0.42840
# [TimesNet-F1] [Epoch 036] train_loss: 0.30616  val_loss: 0.42417
# [TimesNet-F1] [Epoch 037] train_loss: 0.30526  val_loss: 0.42024
# [TimesNet-F1] [Epoch 038] train_loss: 0.30470  val_loss: 0.41668
# [TimesNet-F1] [Epoch 039] train_loss: 0.30398  val_loss: 0.41340
# [TimesNet-F1] [Epoch 040] train_loss: 0.30349  val_loss: 0.41020
# [TimesNet-F1] [Epoch 041] train_loss: 0.30293  val_loss: 0.40754
# [TimesNet-F1] [Epoch 042] train_loss: 0.30254  val_loss: 0.40510
# [TimesNet-F1] [Epoch 043] train_loss: 0.30152  val_loss: 0.40271
# [TimesNet-F1] [Epoch 044] train_loss: 0.30124  val_loss: 0.40054
# [TimesNet-F1] [Epoch 045] train_loss: 0.30065  val_loss: 0.39856
# [TimesNet-F1] [Epoch 046] train_loss: 0.30027  val_loss: 0.39672
# [TimesNet-F1] [Epoch 047] train_loss: 0.29982  val_loss: 0.39505
# [TimesNet-F1] [Epoch 048] train_loss: 0.29914  val_loss: 0.39353
# [TimesNet-F1] [Epoch 049] train_loss: 0.29892  val_loss: 0.39196
# [TimesNet-F1] [Epoch 050] train_loss: 0.29831  val_loss: 0.39061
# [TimesNet-F1] [Epoch 051] train_loss: 0.29791  val_loss: 0.38943
# [TimesNet-F1] [Epoch 052] train_loss: 0.29728  val_loss: 0.38832
# [TimesNet-F1] [Epoch 053] train_loss: 0.29665  val_loss: 0.38733
# [TimesNet-F1] [Epoch 054] train_loss: 0.29665  val_loss: 0.38638
# [TimesNet-F1] [Epoch 055] train_loss: 0.29629  val_loss: 0.38552
# [TimesNet-F1] [Epoch 056] train_loss: 0.29586  val_loss: 0.38472
# [TimesNet-F1] [Epoch 057] train_loss: 0.29577  val_loss: 0.38405
# [TimesNet-F1] [Epoch 058] train_loss: 0.29487  val_loss: 0.38354
# [TimesNet-F1] [Epoch 059] train_loss: 0.29446  val_loss: 0.38307
# [TimesNet-F1] [Epoch 060] train_loss: 0.29410  val_loss: 0.38262
# [TimesNet-F1] [Epoch 061] train_loss: 0.29406  val_loss: 0.38217
# [TimesNet-F1] [Epoch 062] train_loss: 0.29321  val_loss: 0.38179
# [TimesNet-F1] [Epoch 063] train_loss: 0.29307  val_loss: 0.38149
# [TimesNet-F1] [Epoch 064] train_loss: 0.29259  val_loss: 0.38123
# [TimesNet-F1] [Epoch 065] train_loss: 0.29229  val_loss: 0.38090
# [TimesNet-F1] [Epoch 066] train_loss: 0.29172  val_loss: 0.38066
# [TimesNet-F1] [Epoch 067] train_loss: 0.29162  val_loss: 0.38044
# [TimesNet-F1] [Epoch 068] train_loss: 0.29137  val_loss: 0.38019
# [TimesNet-F1] [Epoch 069] train_loss: 0.29110  val_loss: 0.38004
# [TimesNet-F1] [Epoch 070] train_loss: 0.29059  val_loss: 0.37986
# [TimesNet-F1] [Epoch 071] train_loss: 0.29056  val_loss: 0.37966
# [TimesNet-F1] [Epoch 072] train_loss: 0.29004  val_loss: 0.37951
# [TimesNet-F1] [Epoch 073] train_loss: 0.28967  val_loss: 0.37928
# [TimesNet-F1] [Epoch 074] train_loss: 0.28953  val_loss: 0.37912
# [TimesNet-F1] [Epoch 075] train_loss: 0.28921  val_loss: 0.37899
# [TimesNet-F1] [Epoch 076] train_loss: 0.28871  val_loss: 0.37887
# [TimesNet-F1] [Epoch 077] train_loss: 0.28854  val_loss: 0.37868
# [TimesNet-F1] [Epoch 078] train_loss: 0.28808  val_loss: 0.37857
# [TimesNet-F1] [Epoch 079] train_loss: 0.28809  val_loss: 0.37838
# [TimesNet-F1] [Epoch 080] train_loss: 0.28788  val_loss: 0.37821
# [TimesNet-F1] [Epoch 081] train_loss: 0.28748  val_loss: 0.37813
# [TimesNet-F1] [Epoch 082] train_loss: 0.28734  val_loss: 0.37806
# [TimesNet-F1] [Epoch 083] train_loss: 0.28702  val_loss: 0.37790
# [TimesNet-F1] [Epoch 084] train_loss: 0.28659  val_loss: 0.37780
# [TimesNet-F1] [Epoch 085] train_loss: 0.28638  val_loss: 0.37768
# [TimesNet-F1] [Epoch 086] train_loss: 0.28654  val_loss: 0.37752
# [TimesNet-F1] [Epoch 087] train_loss: 0.28603  val_loss: 0.37741
# [TimesNet-F1] [Epoch 088] train_loss: 0.28573  val_loss: 0.37736
# [TimesNet-F1] [Epoch 089] train_loss: 0.28537  val_loss: 0.37720
# [TimesNet-F1] [Epoch 090] train_loss: 0.28534  val_loss: 0.37708
# [TimesNet-F1] [Epoch 091] train_loss: 0.28519  val_loss: 0.37695
# [TimesNet-F1] [Epoch 092] train_loss: 0.28473  val_loss: 0.37689
# [TimesNet-F1] [Epoch 093] train_loss: 0.28460  val_loss: 0.37679
# [TimesNet-F1] [Epoch 094] train_loss: 0.28441  val_loss: 0.37665
# [TimesNet-F1] [Epoch 095] train_loss: 0.28437  val_loss: 0.37655
# [TimesNet-F1] [Epoch 096] train_loss: 0.28389  val_loss: 0.37640
# [TimesNet-F1] [Epoch 097] train_loss: 0.28376  val_loss: 0.37633
# [TimesNet-F1] [Epoch 098] train_loss: 0.28315  val_loss: 0.37616
# [TimesNet-F1] [Epoch 099] train_loss: 0.28323  val_loss: 0.37611
# [TimesNet-F1] [Epoch 100] train_loss: 0.28303  val_loss: 0.37596
# [TimesNet-F1] [Epoch 101] train_loss: 0.28287  val_loss: 0.37583
# [TimesNet-F1] [Epoch 102] train_loss: 0.28270  val_loss: 0.37574
# [TimesNet-F1] [Epoch 103] train_loss: 0.28257  val_loss: 0.37567
# [TimesNet-F1] [Epoch 104] train_loss: 0.28240  val_loss: 0.37558
# [TimesNet-F1] [Epoch 105] train_loss: 0.28219  val_loss: 0.37543
# [TimesNet-F1] [Epoch 106] train_loss: 0.28205  val_loss: 0.37531
# [TimesNet-F1] [Epoch 107] train_loss: 0.28173  val_loss: 0.37523
# [TimesNet-F1] [Epoch 108] train_loss: 0.28157  val_loss: 0.37511
# [TimesNet-F1] [Epoch 109] train_loss: 0.28149  val_loss: 0.37503
# [TimesNet-F1] [Epoch 110] train_loss: 0.28164  val_loss: 0.37491
# [TimesNet-F1] [Epoch 111] train_loss: 0.28083  val_loss: 0.37481
# [TimesNet-F1] [Epoch 112] train_loss: 0.28091  val_loss: 0.37472
# [TimesNet-F1] [Epoch 113] train_loss: 0.28100  val_loss: 0.37459
# [TimesNet-F1] [Epoch 114] train_loss: 0.28070  val_loss: 0.37451
# [TimesNet-F1] [Epoch 115] train_loss: 0.28072  val_loss: 0.37438
# [TimesNet-F1] [Epoch 116] train_loss: 0.28020  val_loss: 0.37428
# [TimesNet-F1] [Epoch 117] train_loss: 0.28052  val_loss: 0.37418
# [TimesNet-F1] [Epoch 118] train_loss: 0.28020  val_loss: 0.37412
# [TimesNet-F1] [Epoch 119] train_loss: 0.28030  val_loss: 0.37404
# [TimesNet-F1] [Epoch 120] train_loss: 0.27976  val_loss: 0.37400
# [TimesNet-F1] [Epoch 121] train_loss: 0.27983  val_loss: 0.37395
# [TimesNet-F1] [Epoch 122] train_loss: 0.27964  val_loss: 0.37390
# [TimesNet-F1] [Epoch 123] train_loss: 0.27974  val_loss: 0.37386
# [TimesNet-F1] [Epoch 124] train_loss: 0.27933  val_loss: 0.37389
# [TimesNet-F1] [Epoch 125] train_loss: 0.27942  val_loss: 0.37383
# [TimesNet-F1] [Epoch 126] train_loss: 0.27958  val_loss: 0.37380
# [TimesNet-F1] [Epoch 127] train_loss: 0.27954  val_loss: 0.37373
# [TimesNet-F1] [Epoch 128] train_loss: 0.27919  val_loss: 0.37370
# [TimesNet-F1] [Epoch 129] train_loss: 0.27905  val_loss: 0.37369
# [TimesNet-F1] [Epoch 130] train_loss: 0.27914  val_loss: 0.37366
# [TimesNet-F1] [Epoch 131] train_loss: 0.27906  val_loss: 0.37364
# [TimesNet-F1] [Epoch 132] train_loss: 0.27907  val_loss: 0.37363
# [TimesNet-F1] [Epoch 133] train_loss: 0.27900  val_loss: 0.37357
# [TimesNet-F1] [Epoch 134] train_loss: 0.27887  val_loss: 0.37353
# [TimesNet-F1] [Epoch 135] train_loss: 0.27873  val_loss: 0.37345
# [TimesNet-F1] [Epoch 136] train_loss: 0.27876  val_loss: 0.37339
# [TimesNet-F1] [Epoch 137] train_loss: 0.27849  val_loss: 0.37335
# [TimesNet-F1] [Epoch 138] train_loss: 0.27850  val_loss: 0.37334
# [TimesNet-F1] [Epoch 139] train_loss: 0.27828  val_loss: 0.37330
# [TimesNet-F1] [Epoch 140] train_loss: 0.27851  val_loss: 0.37322
# [TimesNet-F1] [Epoch 141] train_loss: 0.27842  val_loss: 0.37321
# [TimesNet-F1] [Epoch 142] train_loss: 0.27856  val_loss: 0.37321
# [TimesNet-F1] [Epoch 143] train_loss: 0.27843  val_loss: 0.37316
# [TimesNet-F1] [Epoch 144] train_loss: 0.27852  val_loss: 0.37312
# [TimesNet-F1] [Epoch 145] train_loss: 0.27828  val_loss: 0.37310
# [TimesNet-F1] [Epoch 146] train_loss: 0.27825  val_loss: 0.37306
# [TimesNet-F1] [Epoch 147] train_loss: 0.27823  val_loss: 0.37302
# [TimesNet-F1] [Epoch 148] train_loss: 0.27845  val_loss: 0.37300
# [TimesNet-F1] [Epoch 149] train_loss: 0.27837  val_loss: 0.37300
# [TimesNet-F1] [Epoch 150] train_loss: 0.27850  val_loss: 0.37295
# [TimesNet-F2] [Epoch 001] train_loss: 0.44092  val_loss: 1.05346
# [TimesNet-F2] [Epoch 002] train_loss: 0.38234  val_loss: 0.99124
# [TimesNet-F2] [Epoch 003] train_loss: 0.37022  val_loss: 0.92166
# [TimesNet-F2] [Epoch 004] train_loss: 0.36388  val_loss: 0.86111
# [TimesNet-F2] [Epoch 005] train_loss: 0.35555  val_loss: 0.80985
# [TimesNet-F2] [Epoch 006] train_loss: 0.34733  val_loss: 0.76808
# [TimesNet-F2] [Epoch 007] train_loss: 0.34254  val_loss: 0.73427
# [TimesNet-F2] [Epoch 008] train_loss: 0.33831  val_loss: 0.70528
# [TimesNet-F2] [Epoch 009] train_loss: 0.33562  val_loss: 0.67868
# [TimesNet-F2] [Epoch 010] train_loss: 0.33345  val_loss: 0.65510
# [TimesNet-F2] [Epoch 011] train_loss: 0.33151  val_loss: 0.63403
# [TimesNet-F2] [Epoch 012] train_loss: 0.33001  val_loss: 0.61485
# [TimesNet-F2] [Epoch 013] train_loss: 0.32849  val_loss: 0.59764
# [TimesNet-F2] [Epoch 014] train_loss: 0.32747  val_loss: 0.58129
# [TimesNet-F2] [Epoch 015] train_loss: 0.32599  val_loss: 0.56739
# [TimesNet-F2] [Epoch 016] train_loss: 0.32397  val_loss: 0.55406
# [TimesNet-F2] [Epoch 017] train_loss: 0.32324  val_loss: 0.54219
# [TimesNet-F2] [Epoch 018] train_loss: 0.32163  val_loss: 0.53129
# [TimesNet-F2] [Epoch 019] train_loss: 0.32065  val_loss: 0.52035
# [TimesNet-F2] [Epoch 020] train_loss: 0.31969  val_loss: 0.50977
# [TimesNet-F2] [Epoch 021] train_loss: 0.31872  val_loss: 0.50023
# [TimesNet-F2] [Epoch 022] train_loss: 0.31763  val_loss: 0.49057
# [TimesNet-F2] [Epoch 023] train_loss: 0.31688  val_loss: 0.48121
# [TimesNet-F2] [Epoch 024] train_loss: 0.31571  val_loss: 0.47210
# [TimesNet-F2] [Epoch 025] train_loss: 0.31468  val_loss: 0.46405
# [TimesNet-F2] [Epoch 026] train_loss: 0.31388  val_loss: 0.45615
# [TimesNet-F2] [Epoch 027] train_loss: 0.31303  val_loss: 0.44828
# [TimesNet-F2] [Epoch 028] train_loss: 0.31224  val_loss: 0.44061
# [TimesNet-F2] [Epoch 029] train_loss: 0.31138  val_loss: 0.43352
# [TimesNet-F2] [Epoch 030] train_loss: 0.31086  val_loss: 0.42658
# [TimesNet-F2] [Epoch 031] train_loss: 0.31022  val_loss: 0.42011
# [TimesNet-F2] [Epoch 032] train_loss: 0.30906  val_loss: 0.41392
# [TimesNet-F2] [Epoch 033] train_loss: 0.30848  val_loss: 0.40823
# [TimesNet-F2] [Epoch 034] train_loss: 0.30774  val_loss: 0.40319
# [TimesNet-F2] [Epoch 035] train_loss: 0.30660  val_loss: 0.39861
# [TimesNet-F2] [Epoch 036] train_loss: 0.30621  val_loss: 0.39434
# [TimesNet-F2] [Epoch 037] train_loss: 0.30557  val_loss: 0.39042
# [TimesNet-F2] [Epoch 038] train_loss: 0.30486  val_loss: 0.38700
# [TimesNet-F2] [Epoch 039] train_loss: 0.30409  val_loss: 0.38378
# [TimesNet-F2] [Epoch 040] train_loss: 0.30350  val_loss: 0.38093
# [TimesNet-F2] [Epoch 041] train_loss: 0.30290  val_loss: 0.37841
# [TimesNet-F2] [Epoch 042] train_loss: 0.30199  val_loss: 0.37621
# [TimesNet-F2] [Epoch 043] train_loss: 0.30201  val_loss: 0.37411
# [TimesNet-F2] [Epoch 044] train_loss: 0.30131  val_loss: 0.37235
# [TimesNet-F2] [Epoch 045] train_loss: 0.30090  val_loss: 0.37077
# [TimesNet-F2] [Epoch 046] train_loss: 0.30044  val_loss: 0.36935
# [TimesNet-F2] [Epoch 047] train_loss: 0.29963  val_loss: 0.36811
# [TimesNet-F2] [Epoch 048] train_loss: 0.29924  val_loss: 0.36703
# [TimesNet-F2] [Epoch 049] train_loss: 0.29870  val_loss: 0.36599
# [TimesNet-F2] [Epoch 050] train_loss: 0.29868  val_loss: 0.36520
# [TimesNet-F2] [Epoch 051] train_loss: 0.29793  val_loss: 0.36450
# [TimesNet-F2] [Epoch 052] train_loss: 0.29726  val_loss: 0.36392
# [TimesNet-F2] [Epoch 053] train_loss: 0.29699  val_loss: 0.36347
# [TimesNet-F2] [Epoch 054] train_loss: 0.29661  val_loss: 0.36304
# [TimesNet-F2] [Epoch 055] train_loss: 0.29619  val_loss: 0.36272
# [TimesNet-F2] [Epoch 056] train_loss: 0.29536  val_loss: 0.36242
# [TimesNet-F2] [Epoch 057] train_loss: 0.29546  val_loss: 0.36218
# [TimesNet-F2] [Epoch 058] train_loss: 0.29490  val_loss: 0.36200
# [TimesNet-F2] [Epoch 059] train_loss: 0.29449  val_loss: 0.36184
# [TimesNet-F2] [Epoch 060] train_loss: 0.29401  val_loss: 0.36167
# [TimesNet-F2] [Epoch 061] train_loss: 0.29370  val_loss: 0.36149
# [TimesNet-F2] [Epoch 062] train_loss: 0.29307  val_loss: 0.36142
# [TimesNet-F2] [Epoch 063] train_loss: 0.29283  val_loss: 0.36137
# [TimesNet-F2] [Epoch 064] train_loss: 0.29253  val_loss: 0.36133
# [TimesNet-F2] [Epoch 065] train_loss: 0.29209  val_loss: 0.36133
# [TimesNet-F2] [Epoch 066] train_loss: 0.29216  val_loss: 0.36142
# [TimesNet-F2] [Epoch 067] train_loss: 0.29168  val_loss: 0.36134
# [TimesNet-F2] [Epoch 068] train_loss: 0.29109  val_loss: 0.36139
# [TimesNet-F2] [Epoch 069] train_loss: 0.29106  val_loss: 0.36142
# [TimesNet-F2] [Epoch 070] train_loss: 0.29041  val_loss: 0.36141
# [TimesNet-F2] [Epoch 071] train_loss: 0.29029  val_loss: 0.36137
# [TimesNet-F2] [Epoch 072] train_loss: 0.28995  val_loss: 0.36131
# [TimesNet-F2] [Epoch 073] train_loss: 0.28991  val_loss: 0.36132
# [TimesNet-F2] [Epoch 074] train_loss: 0.28963  val_loss: 0.36132
# [TimesNet-F2] [Epoch 075] train_loss: 0.28904  val_loss: 0.36127
# [TimesNet-F2] [Epoch 076] train_loss: 0.28887  val_loss: 0.36127
# [TimesNet-F2] [Epoch 077] train_loss: 0.28877  val_loss: 0.36130
# [TimesNet-F2] [Epoch 078] train_loss: 0.28823  val_loss: 0.36128
# [TimesNet-F2] [Epoch 079] train_loss: 0.28803  val_loss: 0.36125
# [TimesNet-F2] [Epoch 080] train_loss: 0.28776  val_loss: 0.36125
# [TimesNet-F2] [Epoch 081] train_loss: 0.28740  val_loss: 0.36117
# [TimesNet-F2] [Epoch 082] train_loss: 0.28694  val_loss: 0.36114
# [TimesNet-F2] [Epoch 083] train_loss: 0.28672  val_loss: 0.36114
# [TimesNet-F2] [Epoch 084] train_loss: 0.28637  val_loss: 0.36118
# [TimesNet-F2] [Epoch 085] train_loss: 0.28645  val_loss: 0.36112
# [TimesNet-F2] [Epoch 086] train_loss: 0.28629  val_loss: 0.36107
# [TimesNet-F2] [Epoch 087] train_loss: 0.28600  val_loss: 0.36102
# [TimesNet-F2] [Epoch 088] train_loss: 0.28569  val_loss: 0.36095
# [TimesNet-F2] [Epoch 089] train_loss: 0.28530  val_loss: 0.36098
# [TimesNet-F2] [Epoch 090] train_loss: 0.28494  val_loss: 0.36097
# [TimesNet-F2] [Epoch 091] train_loss: 0.28497  val_loss: 0.36096
# [TimesNet-F2] [Epoch 092] train_loss: 0.28465  val_loss: 0.36094
# [TimesNet-F2] [Epoch 093] train_loss: 0.28442  val_loss: 0.36096
# [TimesNet-F2] [Epoch 094] train_loss: 0.28443  val_loss: 0.36091
# [TimesNet-F2] [Epoch 095] train_loss: 0.28404  val_loss: 0.36094
# [TimesNet-F2] [Epoch 096] train_loss: 0.28366  val_loss: 0.36088
# [TimesNet-F2] [Epoch 097] train_loss: 0.28377  val_loss: 0.36078
# [TimesNet-F2] [Epoch 098] train_loss: 0.28344  val_loss: 0.36073
# [TimesNet-F2] [Epoch 099] train_loss: 0.28315  val_loss: 0.36063
# [TimesNet-F2] [Epoch 100] train_loss: 0.28299  val_loss: 0.36059
# [TimesNet-F2] [Epoch 101] train_loss: 0.28286  val_loss: 0.36053
# [TimesNet-F2] [Epoch 102] train_loss: 0.28261  val_loss: 0.36042
# [TimesNet-F2] [Epoch 103] train_loss: 0.28240  val_loss: 0.36040
# [TimesNet-F2] [Epoch 104] train_loss: 0.28214  val_loss: 0.36031
# [TimesNet-F2] [Epoch 105] train_loss: 0.28213  val_loss: 0.36023
# [TimesNet-F2] [Epoch 106] train_loss: 0.28181  val_loss: 0.36017
# [TimesNet-F2] [Epoch 107] train_loss: 0.28187  val_loss: 0.36008
# [TimesNet-F2] [Epoch 108] train_loss: 0.28173  val_loss: 0.36000
# [TimesNet-F2] [Epoch 109] train_loss: 0.28160  val_loss: 0.35995
# [TimesNet-F2] [Epoch 110] train_loss: 0.28109  val_loss: 0.35990
# [TimesNet-F2] [Epoch 111] train_loss: 0.28096  val_loss: 0.35975
# [TimesNet-F2] [Epoch 112] train_loss: 0.28095  val_loss: 0.35965
# [TimesNet-F2] [Epoch 113] train_loss: 0.28079  val_loss: 0.35953
# [TimesNet-F2] [Epoch 114] train_loss: 0.28064  val_loss: 0.35951
# [TimesNet-F2] [Epoch 115] train_loss: 0.28044  val_loss: 0.35943
# [TimesNet-F2] [Epoch 116] train_loss: 0.28046  val_loss: 0.35934
# [TimesNet-F2] [Epoch 117] train_loss: 0.28000  val_loss: 0.35929
# [TimesNet-F2] [Epoch 118] train_loss: 0.27997  val_loss: 0.35923
# [TimesNet-F2] [Epoch 119] train_loss: 0.27997  val_loss: 0.35918
# [TimesNet-F2] [Epoch 120] train_loss: 0.27962  val_loss: 0.35914
# [TimesNet-F2] [Epoch 121] train_loss: 0.27976  val_loss: 0.35904
# [TimesNet-F2] [Epoch 122] train_loss: 0.27932  val_loss: 0.35897
# [TimesNet-F2] [Epoch 123] train_loss: 0.27926  val_loss: 0.35886
# [TimesNet-F2] [Epoch 124] train_loss: 0.27930  val_loss: 0.35879
# [TimesNet-F2] [Epoch 125] train_loss: 0.27919  val_loss: 0.35873
# [TimesNet-F2] [Epoch 126] train_loss: 0.27920  val_loss: 0.35862
# [TimesNet-F2] [Epoch 127] train_loss: 0.27912  val_loss: 0.35857
# [TimesNet-F2] [Epoch 128] train_loss: 0.27901  val_loss: 0.35852
# [TimesNet-F2] [Epoch 129] train_loss: 0.27891  val_loss: 0.35844
# [TimesNet-F2] [Epoch 130] train_loss: 0.27893  val_loss: 0.35837
# [TimesNet-F2] [Epoch 131] train_loss: 0.27866  val_loss: 0.35834
# [TimesNet-F2] [Epoch 132] train_loss: 0.27864  val_loss: 0.35828
# [TimesNet-F2] [Epoch 133] train_loss: 0.27869  val_loss: 0.35826
# [TimesNet-F2] [Epoch 134] train_loss: 0.27863  val_loss: 0.35823
# [TimesNet-F2] [Epoch 135] train_loss: 0.27854  val_loss: 0.35816
# [TimesNet-F2] [Epoch 136] train_loss: 0.27848  val_loss: 0.35811
# [TimesNet-F2] [Epoch 137] train_loss: 0.27839  val_loss: 0.35809
# [TimesNet-F2] [Epoch 138] train_loss: 0.27829  val_loss: 0.35805
# [TimesNet-F2] [Epoch 139] train_loss: 0.27819  val_loss: 0.35805
# [TimesNet-F2] [Epoch 140] train_loss: 0.27833  val_loss: 0.35804
# [TimesNet-F2] [Epoch 141] train_loss: 0.27845  val_loss: 0.35802
# [TimesNet-F2] [Epoch 142] train_loss: 0.27833  val_loss: 0.35800
# [TimesNet-F2] [Epoch 143] train_loss: 0.27831  val_loss: 0.35799
# [TimesNet-F2] [Epoch 144] train_loss: 0.27818  val_loss: 0.35794
# [TimesNet-F2] [Epoch 145] train_loss: 0.27815  val_loss: 0.35792
# [TimesNet-F2] [Epoch 146] train_loss: 0.27808  val_loss: 0.35791
# [TimesNet-F2] [Epoch 147] train_loss: 0.27817  val_loss: 0.35791
# [TimesNet-F2] [Epoch 148] train_loss: 0.27823  val_loss: 0.35791
# [TimesNet-F2] [Epoch 149] train_loss: 0.27815  val_loss: 0.35788
# [TimesNet-F2] [Epoch 150] train_loss: 0.27824  val_loss: 0.35786
# [TimesNet-F3] [Epoch 001] train_loss: 0.44137  val_loss: 1.07115
# [TimesNet-F3] [Epoch 002] train_loss: 0.38280  val_loss: 1.00554
# [TimesNet-F3] [Epoch 003] train_loss: 0.37172  val_loss: 0.93389
# [TimesNet-F3] [Epoch 004] train_loss: 0.36517  val_loss: 0.87216
# [TimesNet-F3] [Epoch 005] train_loss: 0.35661  val_loss: 0.82146
# [TimesNet-F3] [Epoch 006] train_loss: 0.34802  val_loss: 0.78043
# [TimesNet-F3] [Epoch 007] train_loss: 0.34317  val_loss: 0.74634
# [TimesNet-F3] [Epoch 008] train_loss: 0.33927  val_loss: 0.71634
# [TimesNet-F3] [Epoch 009] train_loss: 0.33650  val_loss: 0.68824
# [TimesNet-F3] [Epoch 010] train_loss: 0.33410  val_loss: 0.66182
# [TimesNet-F3] [Epoch 011] train_loss: 0.33198  val_loss: 0.63644
# [TimesNet-F3] [Epoch 012] train_loss: 0.33004  val_loss: 0.61286
# [TimesNet-F3] [Epoch 013] train_loss: 0.32891  val_loss: 0.59237
# [TimesNet-F3] [Epoch 014] train_loss: 0.32705  val_loss: 0.57387
# [TimesNet-F3] [Epoch 015] train_loss: 0.32584  val_loss: 0.55728
# [TimesNet-F3] [Epoch 016] train_loss: 0.32459  val_loss: 0.54244
# [TimesNet-F3] [Epoch 017] train_loss: 0.32379  val_loss: 0.52895
# [TimesNet-F3] [Epoch 018] train_loss: 0.32197  val_loss: 0.51670
# [TimesNet-F3] [Epoch 019] train_loss: 0.32131  val_loss: 0.50593
# [TimesNet-F3] [Epoch 020] train_loss: 0.32064  val_loss: 0.49599
# [TimesNet-F3] [Epoch 021] train_loss: 0.31926  val_loss: 0.48696
# [TimesNet-F3] [Epoch 022] train_loss: 0.31825  val_loss: 0.47901
# [TimesNet-F3] [Epoch 023] train_loss: 0.31773  val_loss: 0.47154
# [TimesNet-F3] [Epoch 024] train_loss: 0.31648  val_loss: 0.46433
# [TimesNet-F3] [Epoch 025] train_loss: 0.31593  val_loss: 0.45744
# [TimesNet-F3] [Epoch 026] train_loss: 0.31507  val_loss: 0.45045
# [TimesNet-F3] [Epoch 027] train_loss: 0.31424  val_loss: 0.44366
# [TimesNet-F3] [Epoch 028] train_loss: 0.31318  val_loss: 0.43696
# [TimesNet-F3] [Epoch 029] train_loss: 0.31223  val_loss: 0.43056
# [TimesNet-F3] [Epoch 030] train_loss: 0.31165  val_loss: 0.42433
# [TimesNet-F3] [Epoch 031] train_loss: 0.31077  val_loss: 0.41834
# [TimesNet-F3] [Epoch 032] train_loss: 0.31023  val_loss: 0.41277
# [TimesNet-F3] [Epoch 033] train_loss: 0.30933  val_loss: 0.40734
# [TimesNet-F3] [Epoch 034] train_loss: 0.30886  val_loss: 0.40238
# [TimesNet-F3] [Epoch 035] train_loss: 0.30801  val_loss: 0.39781
# [TimesNet-F3] [Epoch 036] train_loss: 0.30727  val_loss: 0.39352
# [TimesNet-F3] [Epoch 037] train_loss: 0.30680  val_loss: 0.38961
# [TimesNet-F3] [Epoch 038] train_loss: 0.30617  val_loss: 0.38595
# [TimesNet-F3] [Epoch 039] train_loss: 0.30560  val_loss: 0.38272
# [TimesNet-F3] [Epoch 040] train_loss: 0.30513  val_loss: 0.37974
# [TimesNet-F3] [Epoch 041] train_loss: 0.30425  val_loss: 0.37725
# [TimesNet-F3] [Epoch 042] train_loss: 0.30332  val_loss: 0.37494
# [TimesNet-F3] [Epoch 043] train_loss: 0.30288  val_loss: 0.37288
# [TimesNet-F3] [Epoch 044] train_loss: 0.30251  val_loss: 0.37097
# [TimesNet-F3] [Epoch 045] train_loss: 0.30180  val_loss: 0.36931
# [TimesNet-F3] [Epoch 046] train_loss: 0.30124  val_loss: 0.36796
# [TimesNet-F3] [Epoch 047] train_loss: 0.30059  val_loss: 0.36672
# [TimesNet-F3] [Epoch 048] train_loss: 0.30034  val_loss: 0.36551
# [TimesNet-F3] [Epoch 049] train_loss: 0.29997  val_loss: 0.36448
# [TimesNet-F3] [Epoch 050] train_loss: 0.29894  val_loss: 0.36364
# [TimesNet-F3] [Epoch 051] train_loss: 0.29886  val_loss: 0.36287
# [TimesNet-F3] [Epoch 052] train_loss: 0.29841  val_loss: 0.36217
# [TimesNet-F3] [Epoch 053] train_loss: 0.29825  val_loss: 0.36159
# [TimesNet-F3] [Epoch 054] train_loss: 0.29741  val_loss: 0.36108
# [TimesNet-F3] [Epoch 055] train_loss: 0.29740  val_loss: 0.36065
# [TimesNet-F3] [Epoch 056] train_loss: 0.29676  val_loss: 0.36026
# [TimesNet-F3] [Epoch 057] train_loss: 0.29658  val_loss: 0.35990
# [TimesNet-F3] [Epoch 058] train_loss: 0.29563  val_loss: 0.35958
# [TimesNet-F3] [Epoch 059] train_loss: 0.29555  val_loss: 0.35929
# [TimesNet-F3] [Epoch 060] train_loss: 0.29502  val_loss: 0.35913
# [TimesNet-F3] [Epoch 061] train_loss: 0.29494  val_loss: 0.35897
# [TimesNet-F3] [Epoch 062] train_loss: 0.29432  val_loss: 0.35882
# [TimesNet-F3] [Epoch 063] train_loss: 0.29403  val_loss: 0.35871
# [TimesNet-F3] [Epoch 064] train_loss: 0.29371  val_loss: 0.35861
# [TimesNet-F3] [Epoch 065] train_loss: 0.29326  val_loss: 0.35844
# [TimesNet-F3] [Epoch 066] train_loss: 0.29317  val_loss: 0.35836
# [TimesNet-F3] [Epoch 067] train_loss: 0.29271  val_loss: 0.35832
# [TimesNet-F3] [Epoch 068] train_loss: 0.29205  val_loss: 0.35829
# [TimesNet-F3] [Epoch 069] train_loss: 0.29186  val_loss: 0.35827
# [TimesNet-F3] [Epoch 070] train_loss: 0.29172  val_loss: 0.35826
# [TimesNet-F3] [Epoch 071] train_loss: 0.29122  val_loss: 0.35827
# [TimesNet-F3] [Epoch 072] train_loss: 0.29086  val_loss: 0.35831
# [TimesNet-F3] [Epoch 073] train_loss: 0.29043  val_loss: 0.35843
# [TimesNet-F3] [Epoch 074] train_loss: 0.29033  val_loss: 0.35853
# [TimesNet-F3] [Epoch 075] train_loss: 0.29010  val_loss: 0.35864
# [TimesNet-F3] [Epoch 076] train_loss: 0.28956  val_loss: 0.35867
# [TimesNet-F3] [Epoch 077] train_loss: 0.28952  val_loss: 0.35872
# [TimesNet-F3] [Epoch 078] train_loss: 0.28921  val_loss: 0.35875
# [TimesNet-F3] [Epoch 079] train_loss: 0.28883  val_loss: 0.35878
# [TimesNet-F3] [Epoch 080] train_loss: 0.28871  val_loss: 0.35887
# [TimesNet-F3] [Epoch 081] train_loss: 0.28821  val_loss: 0.35888
# [TimesNet-F3] [Epoch 082] train_loss: 0.28794  val_loss: 0.35888
# [TimesNet-F3] [Epoch 083] train_loss: 0.28784  val_loss: 0.35889
# [TimesNet-F3] [Epoch 084] train_loss: 0.28750  val_loss: 0.35890
# [TimesNet-F3] [Epoch 085] train_loss: 0.28743  val_loss: 0.35894
# [TimesNet-F3] [Epoch 086] train_loss: 0.28679  val_loss: 0.35901
# [TimesNet-F3] [Epoch 087] train_loss: 0.28684  val_loss: 0.35904
# [TimesNet-F3] [Epoch 088] train_loss: 0.28642  val_loss: 0.35915
# [TimesNet-F3] Early stopping at epoch 88
# [TimesNet-F4] [Epoch 001] train_loss: 0.44215  val_loss: 1.08270
# [TimesNet-F4] [Epoch 002] train_loss: 0.38183  val_loss: 1.01917
# [TimesNet-F4] [Epoch 003] train_loss: 0.37086  val_loss: 0.94868
# [TimesNet-F4] [Epoch 004] train_loss: 0.36327  val_loss: 0.88753
# [TimesNet-F4] [Epoch 005] train_loss: 0.35498  val_loss: 0.83580
# [TimesNet-F4] [Epoch 006] train_loss: 0.34745  val_loss: 0.79354
# [TimesNet-F4] [Epoch 007] train_loss: 0.34294  val_loss: 0.75633
# [TimesNet-F4] [Epoch 008] train_loss: 0.33818  val_loss: 0.72221
# [TimesNet-F4] [Epoch 009] train_loss: 0.33536  val_loss: 0.69167
# [TimesNet-F4] [Epoch 010] train_loss: 0.33302  val_loss: 0.66294
# [TimesNet-F4] [Epoch 011] train_loss: 0.33124  val_loss: 0.63689
# [TimesNet-F4] [Epoch 012] train_loss: 0.32963  val_loss: 0.61267
# [TimesNet-F4] [Epoch 013] train_loss: 0.32811  val_loss: 0.59094
# [TimesNet-F4] [Epoch 014] train_loss: 0.32692  val_loss: 0.57114
# [TimesNet-F4] [Epoch 015] train_loss: 0.32507  val_loss: 0.55346
# [TimesNet-F4] [Epoch 016] train_loss: 0.32380  val_loss: 0.53795
# [TimesNet-F4] [Epoch 017] train_loss: 0.32319  val_loss: 0.52340
# [TimesNet-F4] [Epoch 018] train_loss: 0.32141  val_loss: 0.51061
# [TimesNet-F4] [Epoch 019] train_loss: 0.32056  val_loss: 0.49907
# [TimesNet-F4] [Epoch 020] train_loss: 0.31936  val_loss: 0.48822
# [TimesNet-F4] [Epoch 021] train_loss: 0.31827  val_loss: 0.47813
# [TimesNet-F4] [Epoch 022] train_loss: 0.31783  val_loss: 0.46863
# [TimesNet-F4] [Epoch 023] train_loss: 0.31649  val_loss: 0.45977
# [TimesNet-F4] [Epoch 024] train_loss: 0.31574  val_loss: 0.45198
# [TimesNet-F4] [Epoch 025] train_loss: 0.31456  val_loss: 0.44466
# [TimesNet-F4] [Epoch 026] train_loss: 0.31381  val_loss: 0.43735
# [TimesNet-F4] [Epoch 027] train_loss: 0.31311  val_loss: 0.43082
# [TimesNet-F4] [Epoch 028] train_loss: 0.31203  val_loss: 0.42444
# [TimesNet-F4] [Epoch 029] train_loss: 0.31088  val_loss: 0.41838
# [TimesNet-F4] [Epoch 030] train_loss: 0.31018  val_loss: 0.41248
# [TimesNet-F4] [Epoch 031] train_loss: 0.30965  val_loss: 0.40694
# [TimesNet-F4] [Epoch 032] train_loss: 0.30873  val_loss: 0.40192
# [TimesNet-F4] [Epoch 033] train_loss: 0.30842  val_loss: 0.39706
# [TimesNet-F4] [Epoch 034] train_loss: 0.30748  val_loss: 0.39293
# [TimesNet-F4] [Epoch 035] train_loss: 0.30680  val_loss: 0.38898
# [TimesNet-F4] [Epoch 036] train_loss: 0.30575  val_loss: 0.38529
# [TimesNet-F4] [Epoch 037] train_loss: 0.30516  val_loss: 0.38174
# [TimesNet-F4] [Epoch 038] train_loss: 0.30498  val_loss: 0.37866
# [TimesNet-F4] [Epoch 039] train_loss: 0.30440  val_loss: 0.37595
# [TimesNet-F4] [Epoch 040] train_loss: 0.30330  val_loss: 0.37338
# [TimesNet-F4] [Epoch 041] train_loss: 0.30291  val_loss: 0.37102
# [TimesNet-F4] [Epoch 042] train_loss: 0.30237  val_loss: 0.36901
# [TimesNet-F4] [Epoch 043] train_loss: 0.30185  val_loss: 0.36707
# [TimesNet-F4] [Epoch 044] train_loss: 0.30126  val_loss: 0.36537
# [TimesNet-F4] [Epoch 045] train_loss: 0.30084  val_loss: 0.36389
# [TimesNet-F4] [Epoch 046] train_loss: 0.30004  val_loss: 0.36250
# [TimesNet-F4] [Epoch 047] train_loss: 0.29986  val_loss: 0.36130
# [TimesNet-F4] [Epoch 048] train_loss: 0.29938  val_loss: 0.36011
# [TimesNet-F4] [Epoch 049] train_loss: 0.29849  val_loss: 0.35908
# [TimesNet-F4] [Epoch 050] train_loss: 0.29801  val_loss: 0.35825
# [TimesNet-F4] [Epoch 051] train_loss: 0.29768  val_loss: 0.35746
# [TimesNet-F4] [Epoch 052] train_loss: 0.29721  val_loss: 0.35680
# [TimesNet-F4] [Epoch 053] train_loss: 0.29688  val_loss: 0.35615
# [TimesNet-F4] [Epoch 054] train_loss: 0.29633  val_loss: 0.35557
# [TimesNet-F4] [Epoch 055] train_loss: 0.29614  val_loss: 0.35497
# [TimesNet-F4] [Epoch 056] train_loss: 0.29528  val_loss: 0.35451
# [TimesNet-F4] [Epoch 057] train_loss: 0.29494  val_loss: 0.35410
# [TimesNet-F4] [Epoch 058] train_loss: 0.29490  val_loss: 0.35353
# [TimesNet-F4] [Epoch 059] train_loss: 0.29446  val_loss: 0.35311
# [TimesNet-F4] [Epoch 060] train_loss: 0.29426  val_loss: 0.35270
# [TimesNet-F4] [Epoch 061] train_loss: 0.29365  val_loss: 0.35229
# [TimesNet-F4] [Epoch 062] train_loss: 0.29313  val_loss: 0.35190
# [TimesNet-F4] [Epoch 063] train_loss: 0.29305  val_loss: 0.35149
# [TimesNet-F4] [Epoch 064] train_loss: 0.29276  val_loss: 0.35125
# [TimesNet-F4] [Epoch 065] train_loss: 0.29240  val_loss: 0.35096
# [TimesNet-F4] [Epoch 066] train_loss: 0.29205  val_loss: 0.35078
# [TimesNet-F4] [Epoch 067] train_loss: 0.29146  val_loss: 0.35055
# [TimesNet-F4] [Epoch 068] train_loss: 0.29124  val_loss: 0.35038
# [TimesNet-F4] [Epoch 069] train_loss: 0.29101  val_loss: 0.35033
# [TimesNet-F4] [Epoch 070] train_loss: 0.29072  val_loss: 0.35021
# [TimesNet-F4] [Epoch 071] train_loss: 0.29030  val_loss: 0.35016
# [TimesNet-F4] [Epoch 072] train_loss: 0.29000  val_loss: 0.35013
# [TimesNet-F4] [Epoch 073] train_loss: 0.28979  val_loss: 0.34996
# [TimesNet-F4] [Epoch 074] train_loss: 0.28957  val_loss: 0.35002
# [TimesNet-F4] [Epoch 075] train_loss: 0.28923  val_loss: 0.34996
# [TimesNet-F4] [Epoch 076] train_loss: 0.28876  val_loss: 0.34998
# [TimesNet-F4] [Epoch 077] train_loss: 0.28877  val_loss: 0.35003
# [TimesNet-F4] [Epoch 078] train_loss: 0.28827  val_loss: 0.35004
# [TimesNet-F4] [Epoch 079] train_loss: 0.28834  val_loss: 0.35007
# [TimesNet-F4] [Epoch 080] train_loss: 0.28782  val_loss: 0.35011
# [TimesNet-F4] [Epoch 081] train_loss: 0.28747  val_loss: 0.35014
# [TimesNet-F4] [Epoch 082] train_loss: 0.28749  val_loss: 0.35026
# [TimesNet-F4] [Epoch 083] train_loss: 0.28694  val_loss: 0.35034
# [TimesNet-F4] [Epoch 084] train_loss: 0.28668  val_loss: 0.35046
# [TimesNet-F4] [Epoch 085] train_loss: 0.28636  val_loss: 0.35050
# [TimesNet-F4] [Epoch 086] train_loss: 0.28648  val_loss: 0.35054
# [TimesNet-F4] [Epoch 087] train_loss: 0.28576  val_loss: 0.35055
# [TimesNet-F4] [Epoch 088] train_loss: 0.28547  val_loss: 0.35070
# [TimesNet-F4] [Epoch 089] train_loss: 0.28541  val_loss: 0.35068
# [TimesNet-F4] [Epoch 090] train_loss: 0.28535  val_loss: 0.35078
# [TimesNet-F4] [Epoch 091] train_loss: 0.28517  val_loss: 0.35083
# [TimesNet-F4] [Epoch 092] train_loss: 0.28458  val_loss: 0.35089
# [TimesNet-F4] [Epoch 093] train_loss: 0.28478  val_loss: 0.35089
# [TimesNet-F4] Early stopping at epoch 93
# [VAL(avg over folds)] TimesNet=0.35976
# 💾 TimesNet 베스트 폴드 체크포인트 저장: /content/drive/MyDrive/tft_models/0822_0.495_clu_ratio_4f_checkpoints/TimesNet_best_fold.pth
# 📚 GRU 학습...
# [GRU-F1] [Epoch 001] train_loss: 0.39530  val_loss: 0.78119
# [GRU-F1] [Epoch 002] train_loss: 0.35225  val_loss: 0.70339
# [GRU-F1] [Epoch 003] train_loss: 0.34168  val_loss: 0.63510
# [GRU-F1] [Epoch 004] train_loss: 0.33652  val_loss: 0.59185
# [GRU-F1] [Epoch 005] train_loss: 0.33198  val_loss: 0.56798
# [GRU-F1] [Epoch 006] train_loss: 0.32936  val_loss: 0.55757
# [GRU-F1] [Epoch 007] train_loss: 0.32557  val_loss: 0.55623
# [GRU-F1] [Epoch 008] train_loss: 0.32210  val_loss: 0.55629
# [GRU-F1] [Epoch 009] train_loss: 0.31886  val_loss: 0.55673
# [GRU-F1] [Epoch 010] train_loss: 0.31572  val_loss: 0.55431
# [GRU-F1] [Epoch 011] train_loss: 0.31163  val_loss: 0.55022
# [GRU-F1] [Epoch 012] train_loss: 0.30738  val_loss: 0.54580
# [GRU-F1] [Epoch 013] train_loss: 0.30334  val_loss: 0.54084
# [GRU-F1] [Epoch 014] train_loss: 0.29862  val_loss: 0.53551
# [GRU-F1] [Epoch 015] train_loss: 0.29406  val_loss: 0.52907
# [GRU-F1] [Epoch 016] train_loss: 0.28953  val_loss: 0.52145
# [GRU-F1] [Epoch 017] train_loss: 0.28412  val_loss: 0.51261
# [GRU-F1] [Epoch 018] train_loss: 0.27907  val_loss: 0.50273
# [GRU-F1] [Epoch 019] train_loss: 0.27372  val_loss: 0.49268
# [GRU-F1] [Epoch 020] train_loss: 0.26829  val_loss: 0.48293
# [GRU-F1] [Epoch 021] train_loss: 0.26342  val_loss: 0.47355
# [GRU-F1] [Epoch 022] train_loss: 0.25926  val_loss: 0.46412
# [GRU-F1] [Epoch 023] train_loss: 0.25448  val_loss: 0.45570
# [GRU-F1] [Epoch 024] train_loss: 0.25034  val_loss: 0.44846
# [GRU-F1] [Epoch 025] train_loss: 0.24633  val_loss: 0.44209
# [GRU-F1] [Epoch 026] train_loss: 0.24274  val_loss: 0.43668
# [GRU-F1] [Epoch 027] train_loss: 0.23913  val_loss: 0.43194
# [GRU-F1] [Epoch 028] train_loss: 0.23518  val_loss: 0.42799
# [GRU-F1] [Epoch 029] train_loss: 0.23216  val_loss: 0.42445
# [GRU-F1] [Epoch 030] train_loss: 0.22884  val_loss: 0.42125
# [GRU-F1] [Epoch 031] train_loss: 0.22602  val_loss: 0.41817
# [GRU-F1] [Epoch 032] train_loss: 0.22244  val_loss: 0.41521
# [GRU-F1] [Epoch 033] train_loss: 0.21960  val_loss: 0.41270
# [GRU-F1] [Epoch 034] train_loss: 0.21679  val_loss: 0.41039
# [GRU-F1] [Epoch 035] train_loss: 0.21390  val_loss: 0.40816
# [GRU-F1] [Epoch 036] train_loss: 0.21109  val_loss: 0.40608
# [GRU-F1] [Epoch 037] train_loss: 0.20859  val_loss: 0.40400
# [GRU-F1] [Epoch 038] train_loss: 0.20608  val_loss: 0.40181
# [GRU-F1] [Epoch 039] train_loss: 0.20359  val_loss: 0.39959
# [GRU-F1] [Epoch 040] train_loss: 0.20082  val_loss: 0.39755
# [GRU-F1] [Epoch 041] train_loss: 0.19914  val_loss: 0.39546
# [GRU-F1] [Epoch 042] train_loss: 0.19653  val_loss: 0.39340
# [GRU-F1] [Epoch 043] train_loss: 0.19466  val_loss: 0.39122
# [GRU-F1] [Epoch 044] train_loss: 0.19309  val_loss: 0.38905
# [GRU-F1] [Epoch 045] train_loss: 0.19068  val_loss: 0.38684
# [GRU-F1] [Epoch 046] train_loss: 0.18907  val_loss: 0.38463
# [GRU-F1] [Epoch 047] train_loss: 0.18749  val_loss: 0.38252
# [GRU-F1] [Epoch 048] train_loss: 0.18595  val_loss: 0.38051
# [GRU-F1] [Epoch 049] train_loss: 0.18453  val_loss: 0.37860
# [GRU-F1] [Epoch 050] train_loss: 0.18299  val_loss: 0.37672
# [GRU-F1] [Epoch 051] train_loss: 0.18126  val_loss: 0.37502
# [GRU-F1] [Epoch 052] train_loss: 0.17985  val_loss: 0.37339
# [GRU-F1] [Epoch 053] train_loss: 0.17878  val_loss: 0.37193
# [GRU-F1] [Epoch 054] train_loss: 0.17771  val_loss: 0.37050
# [GRU-F1] [Epoch 055] train_loss: 0.17632  val_loss: 0.36906
# [GRU-F1] [Epoch 056] train_loss: 0.17511  val_loss: 0.36779
# [GRU-F1] [Epoch 057] train_loss: 0.17399  val_loss: 0.36656
# [GRU-F1] [Epoch 058] train_loss: 0.17284  val_loss: 0.36543
# [GRU-F1] [Epoch 059] train_loss: 0.17198  val_loss: 0.36434
# [GRU-F1] [Epoch 060] train_loss: 0.17086  val_loss: 0.36338
# [GRU-F1] [Epoch 061] train_loss: 0.16969  val_loss: 0.36250
# [GRU-F1] [Epoch 062] train_loss: 0.16895  val_loss: 0.36174
# [GRU-F1] [Epoch 063] train_loss: 0.16810  val_loss: 0.36091
# [GRU-F1] [Epoch 064] train_loss: 0.16686  val_loss: 0.36021
# [GRU-F1] [Epoch 065] train_loss: 0.16627  val_loss: 0.35950
# [GRU-F1] [Epoch 066] train_loss: 0.16499  val_loss: 0.35879
# [GRU-F1] [Epoch 067] train_loss: 0.16449  val_loss: 0.35815
# [GRU-F1] [Epoch 068] train_loss: 0.16380  val_loss: 0.35738
# [GRU-F1] [Epoch 069] train_loss: 0.16282  val_loss: 0.35677
# [GRU-F1] [Epoch 070] train_loss: 0.16215  val_loss: 0.35618
# [GRU-F1] [Epoch 071] train_loss: 0.16120  val_loss: 0.35552
# [GRU-F1] [Epoch 072] train_loss: 0.16055  val_loss: 0.35483
# [GRU-F1] [Epoch 073] train_loss: 0.15956  val_loss: 0.35418
# [GRU-F1] [Epoch 074] train_loss: 0.15918  val_loss: 0.35364
# [GRU-F1] [Epoch 075] train_loss: 0.15831  val_loss: 0.35306
# [GRU-F1] [Epoch 076] train_loss: 0.15757  val_loss: 0.35247
# [GRU-F1] [Epoch 077] train_loss: 0.15699  val_loss: 0.35191
# [GRU-F1] [Epoch 078] train_loss: 0.15622  val_loss: 0.35134
# [GRU-F1] [Epoch 079] train_loss: 0.15572  val_loss: 0.35076
# [GRU-F1] [Epoch 080] train_loss: 0.15485  val_loss: 0.35026
# [GRU-F1] [Epoch 081] train_loss: 0.15475  val_loss: 0.34972
# [GRU-F1] [Epoch 082] train_loss: 0.15405  val_loss: 0.34915
# [GRU-F1] [Epoch 083] train_loss: 0.15318  val_loss: 0.34866
# [GRU-F1] [Epoch 084] train_loss: 0.15282  val_loss: 0.34819
# [GRU-F1] [Epoch 085] train_loss: 0.15190  val_loss: 0.34780
# [GRU-F1] [Epoch 086] train_loss: 0.15146  val_loss: 0.34743
# [GRU-F1] [Epoch 087] train_loss: 0.15106  val_loss: 0.34700
# [GRU-F1] [Epoch 088] train_loss: 0.15046  val_loss: 0.34655
# [GRU-F1] [Epoch 089] train_loss: 0.14989  val_loss: 0.34616
# [GRU-F1] [Epoch 090] train_loss: 0.14952  val_loss: 0.34582
# [GRU-F1] [Epoch 091] train_loss: 0.14873  val_loss: 0.34555
# [GRU-F1] [Epoch 092] train_loss: 0.14827  val_loss: 0.34520
# [GRU-F1] [Epoch 093] train_loss: 0.14791  val_loss: 0.34485
# [GRU-F1] [Epoch 094] train_loss: 0.14748  val_loss: 0.34447
# [GRU-F1] [Epoch 095] train_loss: 0.14704  val_loss: 0.34414
# [GRU-F1] [Epoch 096] train_loss: 0.14666  val_loss: 0.34384
# [GRU-F1] [Epoch 097] train_loss: 0.14614  val_loss: 0.34349
# [GRU-F1] [Epoch 098] train_loss: 0.14580  val_loss: 0.34319
# [GRU-F1] [Epoch 099] train_loss: 0.14531  val_loss: 0.34289
# [GRU-F1] [Epoch 100] train_loss: 0.14486  val_loss: 0.34261
# [GRU-F1] [Epoch 101] train_loss: 0.14449  val_loss: 0.34231
# [GRU-F1] [Epoch 102] train_loss: 0.14405  val_loss: 0.34206
# [GRU-F1] [Epoch 103] train_loss: 0.14352  val_loss: 0.34182
# [GRU-F1] [Epoch 104] train_loss: 0.14331  val_loss: 0.34162
# [GRU-F1] [Epoch 105] train_loss: 0.14265  val_loss: 0.34142
# [GRU-F1] [Epoch 106] train_loss: 0.14248  val_loss: 0.34125
# [GRU-F1] [Epoch 107] train_loss: 0.14226  val_loss: 0.34111
# [GRU-F1] [Epoch 108] train_loss: 0.14156  val_loss: 0.34101
# [GRU-F1] [Epoch 109] train_loss: 0.14145  val_loss: 0.34091
# [GRU-F1] [Epoch 110] train_loss: 0.14111  val_loss: 0.34084
# [GRU-F1] [Epoch 111] train_loss: 0.14087  val_loss: 0.34081
# [GRU-F1] [Epoch 112] train_loss: 0.14055  val_loss: 0.34067
# [GRU-F1] [Epoch 113] train_loss: 0.14020  val_loss: 0.34064
# [GRU-F1] [Epoch 114] train_loss: 0.13997  val_loss: 0.34057
# [GRU-F1] [Epoch 115] train_loss: 0.13970  val_loss: 0.34048
# [GRU-F1] [Epoch 116] train_loss: 0.13935  val_loss: 0.34032
# [GRU-F1] [Epoch 117] train_loss: 0.13918  val_loss: 0.34023
# [GRU-F1] [Epoch 118] train_loss: 0.13879  val_loss: 0.34007
# [GRU-F1] [Epoch 119] train_loss: 0.13857  val_loss: 0.33996
# [GRU-F1] [Epoch 120] train_loss: 0.13855  val_loss: 0.33991
# [GRU-F1] [Epoch 121] train_loss: 0.13829  val_loss: 0.33985
# [GRU-F1] [Epoch 122] train_loss: 0.13798  val_loss: 0.33980
# [GRU-F1] [Epoch 123] train_loss: 0.13790  val_loss: 0.33978
# [GRU-F1] [Epoch 124] train_loss: 0.13757  val_loss: 0.33980
# [GRU-F1] [Epoch 125] train_loss: 0.13742  val_loss: 0.33977
# [GRU-F1] [Epoch 126] train_loss: 0.13706  val_loss: 0.33971
# [GRU-F1] [Epoch 127] train_loss: 0.13711  val_loss: 0.33968
# [GRU-F1] [Epoch 128] train_loss: 0.13687  val_loss: 0.33965
# [GRU-F1] [Epoch 129] train_loss: 0.13672  val_loss: 0.33966
# [GRU-F1] [Epoch 130] train_loss: 0.13653  val_loss: 0.33966
# [GRU-F1] [Epoch 131] train_loss: 0.13636  val_loss: 0.33964
# [GRU-F1] [Epoch 132] train_loss: 0.13627  val_loss: 0.33963
# [GRU-F1] [Epoch 133] train_loss: 0.13611  val_loss: 0.33965
# [GRU-F1] [Epoch 134] train_loss: 0.13611  val_loss: 0.33963
# [GRU-F1] [Epoch 135] train_loss: 0.13591  val_loss: 0.33964
# [GRU-F1] [Epoch 136] train_loss: 0.13579  val_loss: 0.33967
# [GRU-F1] [Epoch 137] train_loss: 0.13584  val_loss: 0.33967
# [GRU-F1] [Epoch 138] train_loss: 0.13573  val_loss: 0.33969
# [GRU-F1] [Epoch 139] train_loss: 0.13555  val_loss: 0.33969
# [GRU-F1] [Epoch 140] train_loss: 0.13540  val_loss: 0.33970
# [GRU-F1] [Epoch 141] train_loss: 0.13543  val_loss: 0.33973
# [GRU-F1] [Epoch 142] train_loss: 0.13537  val_loss: 0.33975
# [GRU-F1] [Epoch 143] train_loss: 0.13533  val_loss: 0.33972
# [GRU-F1] [Epoch 144] train_loss: 0.13534  val_loss: 0.33973
# [GRU-F1] [Epoch 145] train_loss: 0.13532  val_loss: 0.33974
# [GRU-F1] [Epoch 146] train_loss: 0.13531  val_loss: 0.33974
# [GRU-F1] [Epoch 147] train_loss: 0.13524  val_loss: 0.33975
# [GRU-F1] [Epoch 148] train_loss: 0.13521  val_loss: 0.33976
# [GRU-F1] [Epoch 149] train_loss: 0.13530  val_loss: 0.33978
# [GRU-F1] [Epoch 150] train_loss: 0.13518  val_loss: 0.33978
# [GRU-F1] Early stopping at epoch 150
# [GRU-F2] [Epoch 001] train_loss: 0.39714  val_loss: 0.75580
# [GRU-F2] [Epoch 002] train_loss: 0.35184  val_loss: 0.67429
# [GRU-F2] [Epoch 003] train_loss: 0.34159  val_loss: 0.60444
# [GRU-F2] [Epoch 004] train_loss: 0.33595  val_loss: 0.56262
# [GRU-F2] [Epoch 005] train_loss: 0.33313  val_loss: 0.54346
# [GRU-F2] [Epoch 006] train_loss: 0.32836  val_loss: 0.53884
# [GRU-F2] [Epoch 007] train_loss: 0.32544  val_loss: 0.53930
# [GRU-F2] [Epoch 008] train_loss: 0.32196  val_loss: 0.54158
# [GRU-F2] [Epoch 009] train_loss: 0.31835  val_loss: 0.54191
# [GRU-F2] [Epoch 010] train_loss: 0.31474  val_loss: 0.53903
# [GRU-F2] [Epoch 011] train_loss: 0.31098  val_loss: 0.53567
# [GRU-F2] [Epoch 012] train_loss: 0.30678  val_loss: 0.53062
# [GRU-F2] [Epoch 013] train_loss: 0.30269  val_loss: 0.52287
# [GRU-F2] [Epoch 014] train_loss: 0.29778  val_loss: 0.51520
# [GRU-F2] [Epoch 015] train_loss: 0.29286  val_loss: 0.50733
# [GRU-F2] [Epoch 016] train_loss: 0.28811  val_loss: 0.49876
# [GRU-F2] [Epoch 017] train_loss: 0.28255  val_loss: 0.48995
# [GRU-F2] [Epoch 018] train_loss: 0.27740  val_loss: 0.48032
# [GRU-F2] [Epoch 019] train_loss: 0.27253  val_loss: 0.47063
# [GRU-F2] [Epoch 020] train_loss: 0.26789  val_loss: 0.46128
# [GRU-F2] [Epoch 021] train_loss: 0.26283  val_loss: 0.45193
# [GRU-F2] [Epoch 022] train_loss: 0.25887  val_loss: 0.44333
# [GRU-F2] [Epoch 023] train_loss: 0.25396  val_loss: 0.43532
# [GRU-F2] [Epoch 024] train_loss: 0.24962  val_loss: 0.42788
# [GRU-F2] [Epoch 025] train_loss: 0.24556  val_loss: 0.42121
# [GRU-F2] [Epoch 026] train_loss: 0.24161  val_loss: 0.41487
# [GRU-F2] [Epoch 027] train_loss: 0.23738  val_loss: 0.40908
# [GRU-F2] [Epoch 028] train_loss: 0.23399  val_loss: 0.40335
# [GRU-F2] [Epoch 029] train_loss: 0.22970  val_loss: 0.39818
# [GRU-F2] [Epoch 030] train_loss: 0.22616  val_loss: 0.39376
# [GRU-F2] [Epoch 031] train_loss: 0.22274  val_loss: 0.38995
# [GRU-F2] [Epoch 032] train_loss: 0.21931  val_loss: 0.38642
# [GRU-F2] [Epoch 033] train_loss: 0.21594  val_loss: 0.38316
# [GRU-F2] [Epoch 034] train_loss: 0.21295  val_loss: 0.38001
# [GRU-F2] [Epoch 035] train_loss: 0.21042  val_loss: 0.37707
# [GRU-F2] [Epoch 036] train_loss: 0.20744  val_loss: 0.37438
# [GRU-F2] [Epoch 037] train_loss: 0.20497  val_loss: 0.37170
# [GRU-F2] [Epoch 038] train_loss: 0.20239  val_loss: 0.36915
# [GRU-F2] [Epoch 039] train_loss: 0.20026  val_loss: 0.36669
# [GRU-F2] [Epoch 040] train_loss: 0.19822  val_loss: 0.36438
# [GRU-F2] [Epoch 041] train_loss: 0.19581  val_loss: 0.36204
# [GRU-F2] [Epoch 042] train_loss: 0.19424  val_loss: 0.35999
# [GRU-F2] [Epoch 043] train_loss: 0.19206  val_loss: 0.35810
# [GRU-F2] [Epoch 044] train_loss: 0.19052  val_loss: 0.35622
# [GRU-F2] [Epoch 045] train_loss: 0.18895  val_loss: 0.35417
# [GRU-F2] [Epoch 046] train_loss: 0.18718  val_loss: 0.35224
# [GRU-F2] [Epoch 047] train_loss: 0.18547  val_loss: 0.35043
# [GRU-F2] [Epoch 048] train_loss: 0.18413  val_loss: 0.34872
# [GRU-F2] [Epoch 049] train_loss: 0.18249  val_loss: 0.34717
# [GRU-F2] [Epoch 050] train_loss: 0.18139  val_loss: 0.34566
# [GRU-F2] [Epoch 051] train_loss: 0.17993  val_loss: 0.34429
# [GRU-F2] [Epoch 052] train_loss: 0.17858  val_loss: 0.34303
# [GRU-F2] [Epoch 053] train_loss: 0.17771  val_loss: 0.34188
# [GRU-F2] [Epoch 054] train_loss: 0.17640  val_loss: 0.34077
# [GRU-F2] [Epoch 055] train_loss: 0.17529  val_loss: 0.33973
# [GRU-F2] [Epoch 056] train_loss: 0.17419  val_loss: 0.33866
# [GRU-F2] [Epoch 057] train_loss: 0.17310  val_loss: 0.33772
# [GRU-F2] [Epoch 058] train_loss: 0.17200  val_loss: 0.33664
# [GRU-F2] [Epoch 059] train_loss: 0.17130  val_loss: 0.33553
# [GRU-F2] [Epoch 060] train_loss: 0.17002  val_loss: 0.33443
# [GRU-F2] [Epoch 061] train_loss: 0.16921  val_loss: 0.33336
# [GRU-F2] [Epoch 062] train_loss: 0.16827  val_loss: 0.33241
# [GRU-F2] [Epoch 063] train_loss: 0.16744  val_loss: 0.33151
# [GRU-F2] [Epoch 064] train_loss: 0.16643  val_loss: 0.33061
# [GRU-F2] [Epoch 065] train_loss: 0.16570  val_loss: 0.32978
# [GRU-F2] [Epoch 066] train_loss: 0.16473  val_loss: 0.32915
# [GRU-F2] [Epoch 067] train_loss: 0.16414  val_loss: 0.32852
# [GRU-F2] [Epoch 068] train_loss: 0.16319  val_loss: 0.32788
# [GRU-F2] [Epoch 069] train_loss: 0.16248  val_loss: 0.32736
# [GRU-F2] [Epoch 070] train_loss: 0.16172  val_loss: 0.32680
# [GRU-F2] [Epoch 071] train_loss: 0.16083  val_loss: 0.32619
# [GRU-F2] [Epoch 072] train_loss: 0.15994  val_loss: 0.32566
# [GRU-F2] [Epoch 073] train_loss: 0.15945  val_loss: 0.32526
# [GRU-F2] [Epoch 074] train_loss: 0.15854  val_loss: 0.32491
# [GRU-F2] [Epoch 075] train_loss: 0.15801  val_loss: 0.32458
# [GRU-F2] [Epoch 076] train_loss: 0.15739  val_loss: 0.32421
# [GRU-F2] [Epoch 077] train_loss: 0.15662  val_loss: 0.32392
# [GRU-F2] [Epoch 078] train_loss: 0.15612  val_loss: 0.32362
# [GRU-F2] [Epoch 079] train_loss: 0.15530  val_loss: 0.32338
# [GRU-F2] [Epoch 080] train_loss: 0.15452  val_loss: 0.32309
# [GRU-F2] [Epoch 081] train_loss: 0.15392  val_loss: 0.32285
# [GRU-F2] [Epoch 082] train_loss: 0.15346  val_loss: 0.32273
# [GRU-F2] [Epoch 083] train_loss: 0.15292  val_loss: 0.32255
# [GRU-F2] [Epoch 084] train_loss: 0.15225  val_loss: 0.32237
# [GRU-F2] [Epoch 085] train_loss: 0.15194  val_loss: 0.32213
# [GRU-F2] [Epoch 086] train_loss: 0.15141  val_loss: 0.32195
# [GRU-F2] [Epoch 087] train_loss: 0.15083  val_loss: 0.32178
# [GRU-F2] [Epoch 088] train_loss: 0.15012  val_loss: 0.32153
# [GRU-F2] [Epoch 089] train_loss: 0.14973  val_loss: 0.32146
# [GRU-F2] [Epoch 090] train_loss: 0.14920  val_loss: 0.32135
# [GRU-F2] [Epoch 091] train_loss: 0.14867  val_loss: 0.32134
# [GRU-F2] [Epoch 092] train_loss: 0.14813  val_loss: 0.32135
# [GRU-F2] [Epoch 093] train_loss: 0.14790  val_loss: 0.32141
# [GRU-F2] [Epoch 094] train_loss: 0.14728  val_loss: 0.32140
# [GRU-F2] [Epoch 095] train_loss: 0.14662  val_loss: 0.32139
# [GRU-F2] [Epoch 096] train_loss: 0.14640  val_loss: 0.32143
# [GRU-F2] [Epoch 097] train_loss: 0.14582  val_loss: 0.32145
# [GRU-F2] [Epoch 098] train_loss: 0.14549  val_loss: 0.32142
# [GRU-F2] [Epoch 099] train_loss: 0.14489  val_loss: 0.32136
# [GRU-F2] [Epoch 100] train_loss: 0.14451  val_loss: 0.32138
# [GRU-F2] [Epoch 101] train_loss: 0.14428  val_loss: 0.32145
# [GRU-F2] [Epoch 102] train_loss: 0.14385  val_loss: 0.32147
# [GRU-F2] [Epoch 103] train_loss: 0.14338  val_loss: 0.32152
# [GRU-F2] [Epoch 104] train_loss: 0.14312  val_loss: 0.32150
# [GRU-F2] [Epoch 105] train_loss: 0.14264  val_loss: 0.32153
# [GRU-F2] [Epoch 106] train_loss: 0.14224  val_loss: 0.32151
# [GRU-F2] [Epoch 107] train_loss: 0.14186  val_loss: 0.32151
# [GRU-F2] [Epoch 108] train_loss: 0.14161  val_loss: 0.32154
# [GRU-F2] [Epoch 109] train_loss: 0.14128  val_loss: 0.32164
# [GRU-F2] Early stopping at epoch 109
# [GRU-F3] [Epoch 001] train_loss: 0.39881  val_loss: 0.78199
# [GRU-F3] [Epoch 002] train_loss: 0.35277  val_loss: 0.70192
# [GRU-F3] [Epoch 003] train_loss: 0.34258  val_loss: 0.62919
# [GRU-F3] [Epoch 004] train_loss: 0.33695  val_loss: 0.58181
# [GRU-F3] [Epoch 005] train_loss: 0.33183  val_loss: 0.55506
# [GRU-F3] [Epoch 006] train_loss: 0.32922  val_loss: 0.54129
# [GRU-F3] [Epoch 007] train_loss: 0.32518  val_loss: 0.53714
# [GRU-F3] [Epoch 008] train_loss: 0.32182  val_loss: 0.53719
# [GRU-F3] [Epoch 009] train_loss: 0.31828  val_loss: 0.53585
# [GRU-F3] [Epoch 010] train_loss: 0.31419  val_loss: 0.53409
# [GRU-F3] [Epoch 011] train_loss: 0.31008  val_loss: 0.53086
# [GRU-F3] [Epoch 012] train_loss: 0.30628  val_loss: 0.52574
# [GRU-F3] [Epoch 013] train_loss: 0.30228  val_loss: 0.51805
# ...
# [TSMixer-F1] [Epoch 046] train_loss: 0.30556  val_loss: 0.39455
# [TSMixer-F1] [Epoch 047] train_loss: 0.30433  val_loss: 0.39436
# [TSMixer-F1] [Epoch 048] train_loss: 0.30402  val_loss: 0.39441
# [TSMixer-F1] [Epoch 049] train_loss: 0.30299  val_loss: 0.39442
# [TSMixer-F1] [Epoch 050] train_loss: 0.30225  val_loss: 0.39463
# [TSMixer-F1] [Epoch 051] train_loss: 0.30156  val_loss: 0.39476
# [TSMixer-F1] [Epoch 052] train_loss: 0.30072  val_loss: 0.39496
# [TSMixer-F1] [Epoch 053] train_loss: 0.30016  val_loss: 0.39518
# [TSMixer-F1] [Epoch 054] train_loss: 0.29958  val_loss: 0.39542
# [TSMixer-F1] [Epoch 055] train_loss: 0.29841  val_loss: 0.39545
# [TSMixer-F1] [Epoch 056] train_loss: 0.29754  val_loss: 0.39580
# [TSMixer-F1] [Epoch 057] train_loss: 0.29745  val_loss: 0.39599
# [TSMixer-F1] [Epoch 058] train_loss: 0.29603  val_loss: 0.39615
# [TSMixer-F1] [Epoch 059] train_loss: 0.29529  val_loss: 0.39627
# [TSMixer-F1] [Epoch 060] train_loss: 0.29463  val_loss: 0.39641
# [TSMixer-F1] [Epoch 061] train_loss: 0.29340  val_loss: 0.39663
# [TSMixer-F1] [Epoch 062] train_loss: 0.29273  val_loss: 0.39656
# [TSMixer-F1] [Epoch 063] train_loss: 0.29181  val_loss: 0.39642
# [TSMixer-F1] [Epoch 064] train_loss: 0.29121  val_loss: 0.39647
# [TSMixer-F1] [Epoch 065] train_loss: 0.29007  val_loss: 0.39643
# [TSMixer-F1] Early stopping at epoch 65
# [TSMixer-F2] [Epoch 001] train_loss: 0.39578  val_loss: 0.76373
# [TSMixer-F2] [Epoch 002] train_loss: 0.36066  val_loss: 0.71472
# [TSMixer-F2] [Epoch 003] train_loss: 0.35138  val_loss: 0.63860
# [TSMixer-F2] [Epoch 004] train_loss: 0.34684  val_loss: 0.56526
# [TSMixer-F2] [Epoch 005] train_loss: 0.34539  val_loss: 0.51070
# [TSMixer-F2] [Epoch 006] train_loss: 0.34282  val_loss: 0.47187
# [TSMixer-F2] [Epoch 007] train_loss: 0.34151  val_loss: 0.44597
# [TSMixer-F2] [Epoch 008] train_loss: 0.33931  val_loss: 0.42975
# [TSMixer-F2] [Epoch 009] train_loss: 0.33656  val_loss: 0.41925
# [TSMixer-F2] [Epoch 010] train_loss: 0.33358  val_loss: 0.41309
# [TSMixer-F2] [Epoch 011] train_loss: 0.33169  val_loss: 0.40894
# [TSMixer-F2] [Epoch 012] train_loss: 0.33070  val_loss: 0.40582
# [TSMixer-F2] [Epoch 013] train_loss: 0.32894  val_loss: 0.40360
# [TSMixer-F2] [Epoch 014] train_loss: 0.32755  val_loss: 0.40200
# [TSMixer-F2] [Epoch 015] train_loss: 0.32681  val_loss: 0.40102
# [TSMixer-F2] [Epoch 016] train_loss: 0.32560  val_loss: 0.40032
# [TSMixer-F2] [Epoch 017] train_loss: 0.32411  val_loss: 0.39968
# [TSMixer-F2] [Epoch 018] train_loss: 0.32347  val_loss: 0.39911
# [TSMixer-F2] [Epoch 019] train_loss: 0.32282  val_loss: 0.39864
# [TSMixer-F2] [Epoch 020] train_loss: 0.32207  val_loss: 0.39825
# [TSMixer-F2] [Epoch 021] train_loss: 0.32097  val_loss: 0.39793
# [TSMixer-F2] [Epoch 022] train_loss: 0.32052  val_loss: 0.39778
# [TSMixer-F2] [Epoch 023] train_loss: 0.32000  val_loss: 0.39756
# [TSMixer-F2] [Epoch 024] train_loss: 0.31897  val_loss: 0.39673
# [TSMixer-F2] [Epoch 025] train_loss: 0.31850  val_loss: 0.39574
# [TSMixer-F2] [Epoch 026] train_loss: 0.31785  val_loss: 0.39534
# [TSMixer-F2] [Epoch 027] train_loss: 0.31720  val_loss: 0.39494
# [TSMixer-F2] [Epoch 028] train_loss: 0.31687  val_loss: 0.39499
# [TSMixer-F2] [Epoch 029] train_loss: 0.31628  val_loss: 0.39452
# [TSMixer-F2] [Epoch 030] train_loss: 0.31542  val_loss: 0.39389
# [TSMixer-F2] [Epoch 031] train_loss: 0.31469  val_loss: 0.39372
# [TSMixer-F2] [Epoch 032] train_loss: 0.31480  val_loss: 0.39356
# [TSMixer-F2] [Epoch 033] train_loss: 0.31382  val_loss: 0.39317
# [TSMixer-F2] [Epoch 034] train_loss: 0.31292  val_loss: 0.39279
# [TSMixer-F2] [Epoch 035] train_loss: 0.31229  val_loss: 0.39241
# [TSMixer-F2] [Epoch 036] train_loss: 0.31239  val_loss: 0.39192
# [TSMixer-F2] [Epoch 037] train_loss: 0.31162  val_loss: 0.39125
# [TSMixer-F2] [Epoch 038] train_loss: 0.31107  val_loss: 0.39097
# [TSMixer-F2] [Epoch 039] train_loss: 0.31022  val_loss: 0.39031
# [TSMixer-F2] [Epoch 040] train_loss: 0.30991  val_loss: 0.38956
# [TSMixer-F2] [Epoch 041] train_loss: 0.30923  val_loss: 0.38935
# [TSMixer-F2] [Epoch 042] train_loss: 0.30887  val_loss: 0.38891
# [TSMixer-F2] [Epoch 043] train_loss: 0.30789  val_loss: 0.38837
# [TSMixer-F2] [Epoch 044] train_loss: 0.30772  val_loss: 0.38821
# [TSMixer-F2] [Epoch 045] train_loss: 0.30712  val_loss: 0.38807
# [TSMixer-F2] [Epoch 046] train_loss: 0.30692  val_loss: 0.38799
# [TSMixer-F2] [Epoch 047] train_loss: 0.30542  val_loss: 0.38787
# [TSMixer-F2] [Epoch 048] train_loss: 0.30489  val_loss: 0.38783
# [TSMixer-F2] [Epoch 049] train_loss: 0.30459  val_loss: 0.38783
# [TSMixer-F2] [Epoch 050] train_loss: 0.30383  val_loss: 0.38799
# [TSMixer-F2] [Epoch 051] train_loss: 0.30325  val_loss: 0.38838
# [TSMixer-F2] [Epoch 052] train_loss: 0.30223  val_loss: 0.38878
# [TSMixer-F2] [Epoch 053] train_loss: 0.30172  val_loss: 0.38933
# [TSMixer-F2] [Epoch 054] train_loss: 0.30069  val_loss: 0.38983
# [TSMixer-F2] [Epoch 055] train_loss: 0.30032  val_loss: 0.39031
# [TSMixer-F2] [Epoch 056] train_loss: 0.29949  val_loss: 0.39088
# [TSMixer-F2] [Epoch 057] train_loss: 0.29842  val_loss: 0.39135
# [TSMixer-F2] [Epoch 058] train_loss: 0.29751  val_loss: 0.39181
# [TSMixer-F2] [Epoch 059] train_loss: 0.29682  val_loss: 0.39224
# [TSMixer-F2] [Epoch 060] train_loss: 0.29589  val_loss: 0.39256
# [TSMixer-F2] [Epoch 061] train_loss: 0.29545  val_loss: 0.39271
# [TSMixer-F2] [Epoch 062] train_loss: 0.29391  val_loss: 0.39277
# [TSMixer-F2] [Epoch 063] train_loss: 0.29322  val_loss: 0.39314
# [TSMixer-F2] [Epoch 064] train_loss: 0.29244  val_loss: 0.39350
# [TSMixer-F2] [Epoch 065] train_loss: 0.29167  val_loss: 0.39347
# [TSMixer-F2] [Epoch 066] train_loss: 0.29128  val_loss: 0.39378
# [TSMixer-F2] [Epoch 067] train_loss: 0.29004  val_loss: 0.39415
# [TSMixer-F2] Early stopping at epoch 67
# [TSMixer-F3] [Epoch 001] train_loss: 0.39728  val_loss: 0.79518
# [TSMixer-F3] [Epoch 002] train_loss: 0.36138  val_loss: 0.74664
# [TSMixer-F3] [Epoch 003] train_loss: 0.35028  val_loss: 0.66217
# [TSMixer-F3] [Epoch 004] train_loss: 0.34657  val_loss: 0.58023
# [TSMixer-F3] [Epoch 005] train_loss: 0.34477  val_loss: 0.51813
# [TSMixer-F3] [Epoch 006] train_loss: 0.34278  val_loss: 0.47403
# [TSMixer-F3] [Epoch 007] train_loss: 0.34147  val_loss: 0.44517
# [TSMixer-F3] [Epoch 008] train_loss: 0.33859  val_loss: 0.42621
# [TSMixer-F3] [Epoch 009] train_loss: 0.33617  val_loss: 0.41572
# [TSMixer-F3] [Epoch 010] train_loss: 0.33367  val_loss: 0.41005
# [TSMixer-F3] [Epoch 011] train_loss: 0.33227  val_loss: 0.40733
# [TSMixer-F3] [Epoch 012] train_loss: 0.33035  val_loss: 0.40589
# [TSMixer-F3] [Epoch 013] train_loss: 0.32894  val_loss: 0.40433
# [TSMixer-F3] [Epoch 014] train_loss: 0.32807  val_loss: 0.40286
# [TSMixer-F3] [Epoch 015] train_loss: 0.32646  val_loss: 0.40194
# [TSMixer-F3] [Epoch 016] train_loss: 0.32539  val_loss: 0.40073
# [TSMixer-F3] [Epoch 017] train_loss: 0.32426  val_loss: 0.39919
# [TSMixer-F3] [Epoch 018] train_loss: 0.32327  val_loss: 0.39784
# [TSMixer-F3] [Epoch 019] train_loss: 0.32222  val_loss: 0.39661
# [TSMixer-F3] [Epoch 020] train_loss: 0.32208  val_loss: 0.39569
# [TSMixer-F3] [Epoch 021] train_loss: 0.32096  val_loss: 0.39458
# [TSMixer-F3] [Epoch 022] train_loss: 0.32063  val_loss: 0.39359
# [TSMixer-F3] [Epoch 023] train_loss: 0.31930  val_loss: 0.39263
# [TSMixer-F3] [Epoch 024] train_loss: 0.31937  val_loss: 0.39183
# [TSMixer-F3] [Epoch 025] train_loss: 0.31822  val_loss: 0.39067
# [TSMixer-F3] [Epoch 026] train_loss: 0.31799  val_loss: 0.39005
# [TSMixer-F3] [Epoch 027] train_loss: 0.31709  val_loss: 0.38917
# [TSMixer-F3] [Epoch 028] train_loss: 0.31662  val_loss: 0.38842
# [TSMixer-F3] [Epoch 029] train_loss: 0.31580  val_loss: 0.38790
# [TSMixer-F3] [Epoch 030] train_loss: 0.31531  val_loss: 0.38709
# [TSMixer-F3] [Epoch 031] train_loss: 0.31527  val_loss: 0.38635
# [TSMixer-F3] [Epoch 032] train_loss: 0.31434  val_loss: 0.38574
# [TSMixer-F3] [Epoch 033] train_loss: 0.31391  val_loss: 0.38525
# [TSMixer-F3] [Epoch 034] train_loss: 0.31390  val_loss: 0.38476
# [TSMixer-F3] [Epoch 035] train_loss: 0.31305  val_loss: 0.38437
# [TSMixer-F3] [Epoch 036] train_loss: 0.31213  val_loss: 0.38384
# [TSMixer-F3] [Epoch 037] train_loss: 0.31199  val_loss: 0.38299
# [TSMixer-F3] [Epoch 038] train_loss: 0.31069  val_loss: 0.38228
# [TSMixer-F3] [Epoch 039] train_loss: 0.31072  val_loss: 0.38163
# [TSMixer-F3] [Epoch 040] train_loss: 0.31001  val_loss: 0.38119
# [TSMixer-F3] [Epoch 041] train_loss: 0.30968  val_loss: 0.38059
# [TSMixer-F3] [Epoch 042] train_loss: 0.30914  val_loss: 0.37986
# [TSMixer-F3] [Epoch 043] train_loss: 0.30822  val_loss: 0.37916
# [TSMixer-F3] [Epoch 044] train_loss: 0.30799  val_loss: 0.37850
# [TSMixer-F3] [Epoch 045] train_loss: 0.30731  val_loss: 0.37807
# [TSMixer-F3] [Epoch 046] train_loss: 0.30730  val_loss: 0.37768
# [TSMixer-F3] [Epoch 047] train_loss: 0.30639  val_loss: 0.37716
# [TSMixer-F3] [Epoch 048] train_loss: 0.30594  val_loss: 0.37642
# [TSMixer-F3] [Epoch 049] train_loss: 0.30493  val_loss: 0.37595
# [TSMixer-F3] [Epoch 050] train_loss: 0.30464  val_loss: 0.37549
# [TSMixer-F3] [Epoch 051] train_loss: 0.30373  val_loss: 0.37515
# [TSMixer-F3] [Epoch 052] train_loss: 0.30290  val_loss: 0.37484
# [TSMixer-F3] [Epoch 053] train_loss: 0.30241  val_loss: 0.37461
# [TSMixer-F3] [Epoch 054] train_loss: 0.30216  val_loss: 0.37447
# [TSMixer-F3] [Epoch 055] train_loss: 0.30111  val_loss: 0.37425
# [TSMixer-F3] [Epoch 056] train_loss: 0.30028  val_loss: 0.37429
# [TSMixer-F3] [Epoch 057] train_loss: 0.29999  val_loss: 0.37447
# [TSMixer-F3] [Epoch 058] train_loss: 0.29898  val_loss: 0.37473
# [TSMixer-F3] [Epoch 059] train_loss: 0.29857  val_loss: 0.37492
# [TSMixer-F3] [Epoch 060] train_loss: 0.29754  val_loss: 0.37513
# [TSMixer-F3] [Epoch 061] train_loss: 0.29698  val_loss: 0.37512
# [TSMixer-F3] [Epoch 062] train_loss: 0.29626  val_loss: 0.37559
# [TSMixer-F3] [Epoch 063] train_loss: 0.29535  val_loss: 0.37601
# [TSMixer-F3] [Epoch 064] train_loss: 0.29421  val_loss: 0.37679
# [TSMixer-F3] [Epoch 065] train_loss: 0.29373  val_loss: 0.37736
# [TSMixer-F3] [Epoch 066] train_loss: 0.29312  val_loss: 0.37772
# [TSMixer-F3] [Epoch 067] train_loss: 0.29227  val_loss: 0.37815
# [TSMixer-F3] [Epoch 068] train_loss: 0.29169  val_loss: 0.37836
# [TSMixer-F3] [Epoch 069] train_loss: 0.29108  val_loss: 0.37872
# [TSMixer-F3] [Epoch 070] train_loss: 0.28971  val_loss: 0.37911
# [TSMixer-F3] [Epoch 071] train_loss: 0.28907  val_loss: 0.37954
# [TSMixer-F3] [Epoch 072] train_loss: 0.28829  val_loss: 0.37988
# [TSMixer-F3] [Epoch 073] train_loss: 0.28761  val_loss: 0.38044
# [TSMixer-F3] Early stopping at epoch 73
# [TSMixer-F4] [Epoch 001] train_loss: 0.39614  val_loss: 0.78522
# [TSMixer-F4] [Epoch 002] train_loss: 0.36001  val_loss: 0.72482
# [TSMixer-F4] [Epoch 003] train_loss: 0.35100  val_loss: 0.63816
# [TSMixer-F4] [Epoch 004] train_loss: 0.34656  val_loss: 0.55604
# [TSMixer-F4] [Epoch 005] train_loss: 0.34441  val_loss: 0.49211
# [TSMixer-F4] [Epoch 006] train_loss: 0.34272  val_loss: 0.44637
# [TSMixer-F4] [Epoch 007] train_loss: 0.34100  val_loss: 0.41597
# [TSMixer-F4] [Epoch 008] train_loss: 0.33861  val_loss: 0.39662
# [TSMixer-F4] [Epoch 009] train_loss: 0.33608  val_loss: 0.38428
# [TSMixer-F4] [Epoch 010] train_loss: 0.33403  val_loss: 0.37760
# [TSMixer-F4] [Epoch 011] train_loss: 0.33177  val_loss: 0.37439
# [TSMixer-F4] [Epoch 012] train_loss: 0.33037  val_loss: 0.37358
# [TSMixer-F4] [Epoch 013] train_loss: 0.32853  val_loss: 0.37288
# [TSMixer-F4] [Epoch 014] train_loss: 0.32746  val_loss: 0.37192
# [TSMixer-F4] [Epoch 015] train_loss: 0.32569  val_loss: 0.37119
# [TSMixer-F4] [Epoch 016] train_loss: 0.32445  val_loss: 0.37041
# [TSMixer-F4] [Epoch 017] train_loss: 0.32390  val_loss: 0.36946
# [TSMixer-F4] [Epoch 018] train_loss: 0.32259  val_loss: 0.36850
# [TSMixer-F4] [Epoch 019] train_loss: 0.32172  val_loss: 0.36782
# [TSMixer-F4] [Epoch 020] train_loss: 0.32104  val_loss: 0.36765
# [TSMixer-F4] [Epoch 021] train_loss: 0.32010  val_loss: 0.36728
# [TSMixer-F4] [Epoch 022] train_loss: 0.31954  val_loss: 0.36708
# [TSMixer-F4] [Epoch 023] train_loss: 0.31862  val_loss: 0.36662
# [TSMixer-F4] [Epoch 024] train_loss: 0.31828  val_loss: 0.36606
# [TSMixer-F4] [Epoch 025] train_loss: 0.31743  val_loss: 0.36546
# [TSMixer-F4] [Epoch 026] train_loss: 0.31667  val_loss: 0.36463
# [TSMixer-F4] [Epoch 027] train_loss: 0.31619  val_loss: 0.36432
# [TSMixer-F4] [Epoch 028] train_loss: 0.31616  val_loss: 0.36388
# [TSMixer-F4] [Epoch 029] train_loss: 0.31500  val_loss: 0.36344
# [TSMixer-F4] [Epoch 030] train_loss: 0.31434  val_loss: 0.36299
# [TSMixer-F4] [Epoch 031] train_loss: 0.31414  val_loss: 0.36253
# [TSMixer-F4] [Epoch 032] train_loss: 0.31327  val_loss: 0.36190
# [TSMixer-F4] [Epoch 033] train_loss: 0.31278  val_loss: 0.36159
# [TSMixer-F4] [Epoch 034] train_loss: 0.31274  val_loss: 0.36120
# [TSMixer-F4] [Epoch 035] train_loss: 0.31114  val_loss: 0.36085
# [TSMixer-F4] [Epoch 036] train_loss: 0.31086  val_loss: 0.36040
# [TSMixer-F4] [Epoch 037] train_loss: 0.31050  val_loss: 0.35985
# [TSMixer-F4] [Epoch 038] train_loss: 0.30993  val_loss: 0.35937
# [TSMixer-F4] [Epoch 039] train_loss: 0.30943  val_loss: 0.35879
# [TSMixer-F4] [Epoch 040] train_loss: 0.30907  val_loss: 0.35824
# [TSMixer-F4] [Epoch 041] train_loss: 0.30807  val_loss: 0.35758
# [TSMixer-F4] [Epoch 042] train_loss: 0.30771  val_loss: 0.35693
# [TSMixer-F4] [Epoch 043] train_loss: 0.30724  val_loss: 0.35638
# [TSMixer-F4] [Epoch 044] train_loss: 0.30691  val_loss: 0.35576
# [TSMixer-F4] [Epoch 045] train_loss: 0.30585  val_loss: 0.35530
# [TSMixer-F4] [Epoch 046] train_loss: 0.30539  val_loss: 0.35481
# [TSMixer-F4] [Epoch 047] train_loss: 0.30491  val_loss: 0.35441
# [TSMixer-F4] [Epoch 048] train_loss: 0.30461  val_loss: 0.35414
# [TSMixer-F4] [Epoch 049] train_loss: 0.30403  val_loss: 0.35393
# [TSMixer-F4] [Epoch 050] train_loss: 0.30321  val_loss: 0.35384
# [TSMixer-F4] [Epoch 051] train_loss: 0.30282  val_loss: 0.35367
# [TSMixer-F4] [Epoch 052] train_loss: 0.30210  val_loss: 0.35357
# [TSMixer-F4] [Epoch 053] train_loss: 0.30156  val_loss: 0.35357
# [TSMixer-F4] [Epoch 054] train_loss: 0.30107  val_loss: 0.35363
# [TSMixer-F4] [Epoch 055] train_loss: 0.30052  val_loss: 0.35373
# [TSMixer-F4] [Epoch 056] train_loss: 0.30023  val_loss: 0.35396
# [TSMixer-F4] [Epoch 057] train_loss: 0.29934  val_loss: 0.35419
# [TSMixer-F4] [Epoch 058] train_loss: 0.29847  val_loss: 0.35434
# [TSMixer-F4] [Epoch 059] train_loss: 0.29810  val_loss: 0.35467
# [TSMixer-F4] [Epoch 060] train_loss: 0.29705  val_loss: 0.35488
# [TSMixer-F4] [Epoch 061] train_loss: 0.29689  val_loss: 0.35520
# [TSMixer-F4] [Epoch 062] train_loss: 0.29555  val_loss: 0.35559
# [TSMixer-F4] [Epoch 063] train_loss: 0.29555  val_loss: 0.35587
# [TSMixer-F4] [Epoch 064] train_loss: 0.29425  val_loss: 0.35621
# [TSMixer-F4] [Epoch 065] train_loss: 0.29379  val_loss: 0.35657
# [TSMixer-F4] [Epoch 066] train_loss: 0.29308  val_loss: 0.35693
# [TSMixer-F4] [Epoch 067] train_loss: 0.29247  val_loss: 0.35725
# [TSMixer-F4] [Epoch 068] train_loss: 0.29176  val_loss: 0.35763
# [TSMixer-F4] [Epoch 069] train_loss: 0.29088  val_loss: 0.35811
# [TSMixer-F4] [Epoch 070] train_loss: 0.29028  val_loss: 0.35847
# [TSMixer-F4] [Epoch 071] train_loss: 0.28923  val_loss: 0.35873
# [TSMixer-F4] Early stopping at epoch 71
# [VAL(avg over folds)] TSMixer=0.37750
# 💾 TSMixer 베스트 폴드 체크포인트 저장: /content/drive/MyDrive/tft_models/0822_0.495_clu_ratio_4f_checkpoints/TSMixer_best_fold.pth
# [Ensemble Weights] TimesNet=0.173  GRU=0.195  MLinear=0.129  N-HiTS=0.170  PatchTST=0.169  TSMixer=0.165
# 🔮 5-Model 앙상블 예측...
#   📊 /content/drive/MyDrive/data/test/TEST_00.csv 처리 중...
#   📊 /content/drive/MyDrive/data/test/TEST_01.csv 처리 중...
#   📊 /content/drive/MyDrive/data/test/TEST_02.csv 처리 중...
#   📊 /content/drive/MyDrive/data/test/TEST_03.csv 처리 중...
#   📊 /content/drive/MyDrive/data/test/TEST_04.csv 처리 중...
#   📊 /content/drive/MyDrive/data/test/TEST_05.csv 처리 중...
#   📊 /content/drive/MyDrive/data/test/TEST_06.csv 처리 중...
#   📊 /content/drive/MyDrive/data/test/TEST_07.csv 처리 중...
#   📊 /content/drive/MyDrive/data/test/TEST_08.csv 처리 중...
#   📊 /content/drive/MyDrive/data/test/TEST_09.csv 처리 중...
# ✅ 앙상블 완료! → /content/drive/MyDrive/data/0822_6model_clu_ratio_4f_submission.csv
# 🏆 TimesNet + GRU + MLinear + N-HiTS + PatchTST + TSMixer 학습/추론 끝
